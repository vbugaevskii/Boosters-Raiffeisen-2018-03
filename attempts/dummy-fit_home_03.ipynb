# %%
import codecs

from operator import itemgetter

import numpy as np
import pandas as pd

import xgboost as xgb
import sklearn

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib

# %%
def is_inside_area(lat_pred, lon_pred, lat_true, lon_true, radius=0.02):
    return np.power(lat_pred - lat_true, 2) + np.power(lon_pred - lon_true, 2) <= radius ** 2

# %%
time_features = {u'day', u'day_of_week', u'days_after_holiday',
       u'days_before_holiday', u'is_dayoff', u'is_holiday', u'is_short',
       u'is_weekend', u'month', u'timestamp', u'week_of_year'}

# %% [markdown]
# ### Подготавливаем данные

# %%
df = pd.read_csv("data/sets/train_set_final.csv", sep=',', encoding='utf-8')
df.drop(labels=time_features, axis=1, inplace=True)
df.drop_duplicates(inplace=True)
print df.shape
df.head()
# Out:
# (1131820, 36)
#      amount  city  country  currency                       customer_id  \
# 0  2.884034     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 1  2.775633     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 2  3.708368     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 4  2.787498     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 6  2.892510     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
#
#    home_add_lat  home_add_lon   mcc                       terminal_id  \
# 0     59.851002        30.232  5261  11606fde0c814ce78e0d726e39a0a5ee
# 1     59.851002        30.232  5261  e9647a5e1eacfb06713b6af755ccc595
# 2     59.851002        30.232  5992  df06c1fcd3718a514535ae822785f716
# 4     59.851002        30.232  5261  6c5e5793ebc984fb72875feffff62854
# 6     59.851002        30.232  5261  0576445d74e374c92c0902e612fca356
#
#    work_add_lat    ...      has_children  has_pet  amount_mean  amount_sub  \
# 0        59.847    ...                 0        0     3.552742   -0.668708
# 1        59.847    ...                 0        0     3.552742   -0.777109
# 2        59.847    ...                 0        0     3.552742    0.155626
# 4        59.847    ...                 0        0     3.552742   -0.765244
# 6        59.847    ...                 0        0     3.552742   -0.660232
#
#    amount_div  pct_term_counts  pct_mcc_g_counts  is_abroad   amount_true  \
# 0    0.811777         0.013889          0.138889          0   1914.141006
# 1    0.781265         0.013889          0.138889          0   1491.327772
# 2    1.043805         0.013889          0.013889          0  12773.452874
# 4    0.784605         0.013889          0.138889          0   1532.631571
# 6    0.814163         0.041667          0.138889          0   1951.865761
#
#    is_native
# 0          1
# 1          1
# 2          1
# 4          1
# 6          1
#
# [5 rows x 36 columns]

# %%
df.to_csv("data/sets/tmp/train_set_final.csv", sep=',', encoding='utf-8', index=False)

# %%
np.random.seed(8888)

# %%
df = pd.read_csv("data/sets/tmp/train_set_final.csv", sep=',', encoding='utf-8', usecols=['customer_id'])
df.head()
# Out:
#                         customer_id
# 0  0dc0137d280a2a82d2dc89282450ff1b
# 1  0dc0137d280a2a82d2dc89282450ff1b
# 2  0dc0137d280a2a82d2dc89282450ff1b
# 3  0dc0137d280a2a82d2dc89282450ff1b
# 4  0dc0137d280a2a82d2dc89282450ff1b

# %%
customers = df['customer_id'].unique()
np.random.shuffle(customers)
    
border = int(len(customers) * 0.9)
cust_train, cust_valid = set(customers[:border]), set(customers[border:])

# %%
variants_mods = [(i,j) for i in range(-2, 3) for j in range(-2, 3)]
variants_mods.remove((0,0))

with codecs.open('data/sets/tmp/train_set_final.csv', mode='r', encoding='utf-8') as f_input,\
        codecs.open('data/sets/tmp/valid_home.libsvm', mode='w', encoding='utf-8') as f_valid,\
        codecs.open('data/sets/tmp/train_home.libsvm', mode='w', encoding='utf-8') as f_train,\
        codecs.open('data/sets/tmp/valid_home.labels', mode='w', encoding='utf-8') as f_valid_,\
        codecs.open('data/sets/tmp/train_home.labels', mode='w', encoding='utf-8') as f_train_:
    f_train_.write('customer_id,home_add_lat,home_add_lon,lat,lon\n')
    f_valid_.write('customer_id,home_add_lat,home_add_lon,lat,lon\n')
    
    # получаем индексы для каждой из колонок
    header = next(f_input).strip().split(',')
    header_cols = { col: col_i for col_i, col in enumerate(header) }
    
    # настраиваем список фичей
    features = [f for f in header
        if f not in {'home_add_lon', 'home_add_lat',
              'work_add_lon', 'work_add_lat',
              'is_work', 'is_home',
              'customer_id', 'terminal_id'} and f not in time_features]
    n_features = len(features)
    
    def format_line():
        is_coord = int(is_inside_area(lat, lon, lat_coord, lon_coord))
        output_line = [
            str(is_coord),
            features_line,
            '{}:{}'.format(n_features, lat),
            '{}:{}'.format(n_features + 1, lon)
        ]
        output_line = ' '.join(output_line) + '\n'
        return output_line
    
    for line in f_input:        
        line = line.strip()
        line_cols = line.split(',')
        
        lat_coord, lon_coord = \
            line_cols[header_cols['home_add_lat']], line_cols[header_cols['home_add_lon']]
            
        if lat_coord == '' or lon_coord == '':
            continue
            
        lat_coord, lon_coord = map(float, [lat_coord, lon_coord])
        
        cust_id = line_cols[header_cols['customer_id']]
        
        f_output_ = f_train_ if cust_id in cust_train else f_valid_
        
        f_output = f_train if cust_id in cust_train else f_valid
        
        features_line = [str(f_i)+':'+line_cols[header_cols[f]] for f_i, f in enumerate(features)]
        features_line = ' '.join(features_line)
        
        labels_line = ','.join([cust_id, str(lat_coord), str(lon_coord)])
        
        lat, lon = line_cols[header_cols['lat']], line_cols[header_cols['lon']]
        if lat != '' and lon != '':
            lat, lon = map(float, [lat, lon])
            f_output.write(format_line())
            f_output_.write(labels_line+','+str(lat)+','+str(lon)+'\n')
        
            np.random.shuffle(variants_mods)
            for mul_lat, mul_lon in variants_mods[:4]:
                lat_ = lat + mul_lat * 0.02
                lon_ = lon + mul_lon * 0.02
                f_output.write(format_line())
                f_output_.write(labels_line+','+str(lat_)+','+str(lon_)+'\n')
        
        lat, lon = lat_coord, lon_coord
        lat, lon = map(float, [lat, lon])
        f_output.write(format_line())
        f_output_.write(labels_line+','+str(lat)+','+str(lon)+'\n')
        
        np.random.shuffle(variants_mods)
        for mul_lat, mul_lon in variants_mods[:4]:
            lat_ = lat + mul_lat * 0.02
            lon_ = lon + mul_lon * 0.02
            f_output.write(format_line())
            f_output_.write(labels_line+','+str(lat_)+','+str(lon_)+'\n')

# %%
def choose_random_lines(libsvm, labels, frac=0.8):
    with codecs.open(libsvm, mode='r') as f_libsvm,\
            codecs.open(labels, mode='r') as f_labels,\
            codecs.open(libsvm+'_random', mode='w') as f_libsvm_r,\
            codecs.open(labels+'_random', mode='w') as f_labels_r:
        try:
            while True:
                line_1, line_2 = next(f_libsvm), next(f_labels)
                if np.random.random() < frac:
                    f_libsvm_r.write(line_1)
                    f_labels_r.write(line_2)
        except StopIteration:
            pass

# %%
choose_random_lines('data/sets/tmp/train_home.libsvm', 'data/sets/tmp/train_home.labels', frac=0.5)

# %%
choose_random_lines('data/sets/tmp/valid_home.libsvm', 'data/sets/tmp/valid_home.labels', frac=0.5)

# %%
with codecs.open('data/sets/train_set_final.csv', mode='r', encoding='utf-8') as f_input:
    header = next(f_input).strip().split(',')
    header_cols = { col: col_i for col_i, col in enumerate(header) }
    
    # настраиваем список фичей
    features = [f for f in header
        if f not in {'home_add_lon', 'home_add_lat',
              'work_add_lon', 'work_add_lat',
              'is_work', 'is_home',
              'customer_id', 'terminal_id'}]
    n_features = len(features)

# %% [markdown]
# ### Обучаем модель

# %%
train_set = xgb.DMatrix('data/sets/tmp/train_home.libsvm')

# %%
valid_set = xgb.DMatrix('data/sets/tmp/valid_home.libsvm')

# %%
clf = xgb.XGBClassifier(n_estimators=10, n_jobs=3, max_depth=7, objective='binary:logistic')

model = xgb.train(
    params=clf.get_xgb_params(),
    dtrain=train_set,
    evals=[(train_set, 'train'), (valid_set, 'valid')],
    verbose_eval=1,
    num_boost_round=300,
    early_stopping_rounds=10
)
# Out:
# [0]	train-error:0.320939	valid-error:0.318144
# Multiple eval metrics have been passed: 'valid-error' will be used for early stopping.
#
# Will train until valid-error hasn't improved in 10 rounds.
# [1]	train-error:0.31907	valid-error:0.317881
# [2]	train-error:0.319388	valid-error:0.31827
# [3]	train-error:0.314986	valid-error:0.313211
# [4]	train-error:0.300575	valid-error:0.298489
# [5]	train-error:0.301127	valid-error:0.299757
# [6]	train-error:0.289752	valid-error:0.289991
# [7]	train-error:0.290403	valid-error:0.289701
# [8]	train-error:0.288218	valid-error:0.287432
# [9]	train-error:0.282867	valid-error:0.283215
# [10]	train-error:0.279541	valid-error:0.280492
# [11]	train-error:0.275312	valid-error:0.276302
# [12]	train-error:0.274046	valid-error:0.274979
# [13]	train-error:0.270216	valid-error:0.271292
# [14]	train-error:0.26605	valid-error:0.267274
# [15]	train-error:0.264224	valid-error:0.265535
# [16]	train-error:0.263018	valid-error:0.264334
# [17]	train-error:0.261005	valid-error:0.261775
# [18]	train-error:0.258756	valid-error:0.260389
# [19]	train-error:0.255342	valid-error:0.255905
# [20]	train-error:0.254966	valid-error:0.255094
# [21]	train-error:0.253697	valid-error:0.254364
# [22]	train-error:0.252144	valid-error:0.252879
# [23]	train-error:0.250945	valid-error:0.252172
# [24]	train-error:0.250598	valid-error:0.251955
# [25]	train-error:0.249746	valid-error:0.251814
# [26]	train-error:0.248732	valid-error:0.251067
# [27]	train-error:0.247468	valid-error:0.250528
# [28]	train-error:0.246324	valid-error:0.249712
# [29]	train-error:0.245054	valid-error:0.249608
# [30]	train-error:0.244181	valid-error:0.249989
# [31]	train-error:0.243313	valid-error:0.249685
# [32]	train-error:0.241915	valid-error:0.249504
# [33]	train-error:0.241601	valid-error:0.24896
# [34]	train-error:0.240762	valid-error:0.248322
# [35]	train-error:0.240523	valid-error:0.247307
# [36]	train-error:0.239425	valid-error:0.246193
# [37]	train-error:0.237833	valid-error:0.244553
# [38]	train-error:0.236786	valid-error:0.243629
# [39]	train-error:0.2355	valid-error:0.24275
# [40]	train-error:0.233839	valid-error:0.241332
# [41]	train-error:0.233209	valid-error:0.240635
# [42]	train-error:0.231142	valid-error:0.239883
# [43]	train-error:0.230693	valid-error:0.239321
# [44]	train-error:0.229871	valid-error:0.239058
# [45]	train-error:0.228833	valid-error:0.238365
# [46]	train-error:0.228578	valid-error:0.238528
# [47]	train-error:0.22856	valid-error:0.238334
# [48]	train-error:0.227869	valid-error:0.237541
# [49]	train-error:0.226964	valid-error:0.23697
# [50]	train-error:0.226125	valid-error:0.236164
# [51]	train-error:0.225436	valid-error:0.235933
# [52]	train-error:0.223991	valid-error:0.234542
# [53]	train-error:0.22308	valid-error:0.233269
# [54]	train-error:0.222593	valid-error:0.232377
# [55]	train-error:0.221432	valid-error:0.231562
# [56]	train-error:0.220314	valid-error:0.230973
# [57]	train-error:0.219946	valid-error:0.231118
# [58]	train-error:0.219816	valid-error:0.231027
# [59]	train-error:0.218659	valid-error:0.230678
# [60]	train-error:0.218318	valid-error:0.230366
# [61]	train-error:0.217847	valid-error:0.230171
# [62]	train-error:0.21694	valid-error:0.229564
# [63]	train-error:0.215753	valid-error:0.228767
# [64]	train-error:0.214902	valid-error:0.228604
# [65]	train-error:0.214888	valid-error:0.228364
# [66]	train-error:0.214333	valid-error:0.228278
# [67]	train-error:0.213494	valid-error:0.227471
# [68]	train-error:0.213009	valid-error:0.227104
# [69]	train-error:0.212702	valid-error:0.226515
# [70]	train-error:0.211951	valid-error:0.226112
# [71]	train-error:0.211502	valid-error:0.225736
# [72]	train-error:0.211157	valid-error:0.226515
# [73]	train-error:0.210262	valid-error:0.225587
# [74]	train-error:0.209532	valid-error:0.22536
# [75]	train-error:0.209116	valid-error:0.225283
# [76]	train-error:0.208442	valid-error:0.224568
# [77]	train-error:0.207925	valid-error:0.224993
# [78]	train-error:0.207672	valid-error:0.225406
# [79]	train-error:0.207394	valid-error:0.225052
# [80]	train-error:0.206825	valid-error:0.224608
# [81]	train-error:0.206479	valid-error:0.22397
# [82]	train-error:0.205825	valid-error:0.223843
# [83]	train-error:0.205441	valid-error:0.223136
# [84]	train-error:0.205196	valid-error:0.223544
# [85]	train-error:0.204653	valid-error:0.223888
# [86]	train-error:0.20421	valid-error:0.223992
# [87]	train-error:0.203686	valid-error:0.224169
# [88]	train-error:0.203333	valid-error:0.223286
# [89]	train-error:0.202867	valid-error:0.223209
# [90]	train-error:0.202461	valid-error:0.223245
# [91]	train-error:0.201642	valid-error:0.222778
# [92]	train-error:0.201018	valid-error:0.222534
# [93]	train-error:0.200708	valid-error:0.222624
# [94]	train-error:0.200322	valid-error:0.222276
# [95]	train-error:0.200233	valid-error:0.222144
# [96]	train-error:0.199187	valid-error:0.222298
# [97]	train-error:0.198785	valid-error:0.221066
# [98]	train-error:0.198495	valid-error:0.22112
# [99]	train-error:0.198183	valid-error:0.221025
# [100]	train-error:0.19781	valid-error:0.220414
# [101]	train-error:0.196814	valid-error:0.219204
# [102]	train-error:0.196386	valid-error:0.219118
# [103]	train-error:0.196026	valid-error:0.219426
# [104]	train-error:0.195524	valid-error:0.219232
# [105]	train-error:0.195007	valid-error:0.219417
# [106]	train-error:0.194457	valid-error:0.219829
# [107]	train-error:0.1941	valid-error:0.219263
# [108]	train-error:0.193799	valid-error:0.219531
# [109]	train-error:0.19351	valid-error:0.219245
# [110]	train-error:0.193199	valid-error:0.218851
# [111]	train-error:0.192977	valid-error:0.218765
# [112]	train-error:0.191954	valid-error:0.218937
# [113]	train-error:0.191643	valid-error:0.219032
# [114]	train-error:0.190982	valid-error:0.218883
# [115]	train-error:0.190343	valid-error:0.21857
# [116]	train-error:0.190055	valid-error:0.21876
# [117]	train-error:0.189745	valid-error:0.218226
# [118]	train-error:0.188813	valid-error:0.217682
# [119]	train-error:0.188417	valid-error:0.217778
# [120]	train-error:0.188311	valid-error:0.217651
# [121]	train-error:0.187784	valid-error:0.217442
# [122]	train-error:0.18694	valid-error:0.217252
# [123]	train-error:0.186702	valid-error:0.217003
# [124]	train-error:0.186365	valid-error:0.216912
# [125]	train-error:0.185818	valid-error:0.2166
# [126]	train-error:0.185534	valid-error:0.216314
# [127]	train-error:0.185187	valid-error:0.216396
# [128]	train-error:0.184934	valid-error:0.216627
# [129]	train-error:0.184597	valid-error:0.216641
# [130]	train-error:0.184241	valid-error:0.216505
# [131]	train-error:0.184046	valid-error:0.21655
# [132]	train-error:0.183766	valid-error:0.216378
# [133]	train-error:0.183352	valid-error:0.21641
# [134]	train-error:0.183118	valid-error:0.216568
# [135]	train-error:0.182606	valid-error:0.216559
# [136]	train-error:0.182328	valid-error:0.216477
# Stopping. Best iteration:
# [126]	train-error:0.185534	valid-error:0.216314

# %%
joblib.dump(model, 'data/models/clf_home_04.model')
# Out:
# ['data/models/clf_home_04.model']

# %% [markdown]
# ### Оценка модели

# %%
model = joblib.load('data/models/clf_home_04.model')

# %% [markdown]
# ### Train

# %%
train_set = xgb.DMatrix('data/sets/tmp/train_home.libsvm')

# %%
y_pred = model.predict(train_set)
y_pred.shape
# Out:
# (10214230,)

# %%
df = pd.read_csv('data/sets/tmp/train_home.labels', sep=',', encoding='utf-8')
df.columns = ['customer_id', 'home_lat', 'home_lon', 'lat', 'lon']
print df.shape
df.head()
# Out:
# (10214230, 5)
#                         customer_id   home_lat  home_lon        lat        lon
# 0  0dc0137d280a2a82d2dc89282450ff1b  59.851002    30.232  59.844074  30.179153
# 1  0dc0137d280a2a82d2dc89282450ff1b  59.851002    30.232  59.844074  30.199153
# 2  0dc0137d280a2a82d2dc89282450ff1b  59.851002    30.232  59.824074  30.179153
# 3  0dc0137d280a2a82d2dc89282450ff1b  59.851002    30.232  59.824074  30.199153
# 4  0dc0137d280a2a82d2dc89282450ff1b  59.851002    30.232  59.864074  30.159153

# %%
df['is_home'] = y_pred

# %%
df_preds = []

for cust_i, group in df.groupby('customer_id'):
    pred_i = group['is_home'].idxmax()
    home_lat, home_lon, lat, lon = group.loc[pred_i, ['home_lat', 'home_lon', 'lat', 'lon']]
    df_preds.append((cust_i, home_lat, home_lon, lat, lon))
    
df_preds = pd.DataFrame(df_preds, columns=['customer_id', 'home_lat', 'home_lon', 'lat', 'lon'])
df_preds.head()
# Out:
#                         customer_id   home_lat   home_lon        lat  \
# 0  0001f322716470bf9bfc1708f06f00fc  44.708000  37.775002  44.708000
# 1  0007297d86e14bd68bd87b1dbdefe302  55.799000  37.388000  55.799000
# 2  000b709c6c6fb1e8efcfd95e57c2a9de  54.993999  82.863998  54.993999
# 3  0027a7618d97cc9fbda55fac457eaeb7  55.742001  37.575001  55.742001
# 4  002b9f6e118c54f1292e03d1a04d516e  55.693001  37.594002  55.693001
#
#          lon
# 0  37.775002
# 1  37.388000
# 2  82.863998
# 3  37.575001
# 4  37.594002

# %%
score = is_inside_area(df_preds['home_lat'], df_preds['home_lon'], df_preds['lat'], df_preds['lon'])
print "Train score: {}".format(score.sum() / float(score.shape[0]))
# Out:
# Train score: 0.971

# %% [markdown]
# ### Valid

# %%
valid_set = xgb.DMatrix('data/sets/tmp/valid_home.libsvm')

# %%
y_pred = model.predict(valid_set)
y_pred.shape
# Out:
# (1103810,)

# %%
df = pd.read_csv('data/sets/tmp/valid_home.labels', sep=',', encoding='utf-8')
df.columns = ['customer_id', 'home_lat', 'home_lon', 'lat', 'lon']
print df.shape
df.head()
# Out:
# (1103810, 5)
#                         customer_id   home_lat  home_lon        lat        lon
# 0  13d194bdf7adf721eeec5c438879da08  56.734001    37.166  55.668335  37.518272
# 1  13d194bdf7adf721eeec5c438879da08  56.734001    37.166  55.708335  37.518272
# 2  13d194bdf7adf721eeec5c438879da08  56.734001    37.166  55.708335  37.478272
# 3  13d194bdf7adf721eeec5c438879da08  56.734001    37.166  55.648335  37.558272
# 4  13d194bdf7adf721eeec5c438879da08  56.734001    37.166  55.688335  37.478272

# %%
df['is_home'] = y_pred

# %%
df_preds = []

for cust_i, group in df.groupby('customer_id'):
    pred_i = group['is_home'].idxmax()
    home_lat, home_lon, lat, lon = group.loc[pred_i, ['home_lat', 'home_lon', 'lat', 'lon']]
    df_preds.append((cust_i, home_lat, home_lon, lat, lon))
    
df_preds = pd.DataFrame(df_preds, columns=['customer_id', 'home_lat', 'home_lon', 'lat', 'lon'])
df_preds.head()
# Out:
#                         customer_id   home_lat   home_lon        lat  \
# 0  0037f3de3d890df1022cc760a1dfd9d6  55.622002  37.841999  55.622002
# 1  007525af0bc3ce72137b586a298f7b98  55.821999  37.370998  55.821999
# 2  00a840ccc4f35f8ead26610f788a6a61  59.945000  30.495001  59.945000
# 3  00cefcb1c777d2bf7a32f082c040088f  55.679001  37.543999  55.679001
# 4  00dc51ccd3993f55974bd7afc1ceecea  55.844002  37.580002  55.844002
#
#          lon
# 0  37.841999
# 1  37.370998
# 2  30.495001
# 3  37.543999
# 4  37.580002

# %%
score = is_inside_area(df_preds['home_lat'], df_preds['home_lon'], df_preds['lat'], df_preds['lon'])
print "Valid score: {}".format(score.sum() / float(score.shape[0]))
# Out:
# Valid score: 0.962

# %% [markdown]
# ### FAIR SCORE

# %%
model = joblib.load('data/models/clf_home_04.model')

# %%
df_valid = pd.read_csv('data/sets/tmp/valid_home.labels', sep=',', encoding='utf-8',
                       usecols=['customer_id', 'home_add_lat', 'home_add_lon'])
df_valid.drop_duplicates(inplace=True)
df_valid.head()
# Out:
#                            customer_id  home_add_lat  home_add_lon
# 0     13d194bdf7adf721eeec5c438879da08     56.734001     37.166000
# 110   3209e87b652f46439784c4d254dd5d12     55.629002     37.863998
# 750   331e65f3b6beb0991d91468d2e0f50d2     55.612000     37.596001
# 1230  455564b15a4fea65f12caf304b1b2571     55.806000     37.540001
# 2350  9c8cf84c4bae8d5341f4fd06c964e8ed     59.827000     30.214001

# %%
df = pd.read_csv("data/sets/tmp/train_set_final.csv", sep=',', encoding='utf-8')
df.head()
# Out:
#      amount  city  country  currency                       customer_id  \
# 0  2.884034     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 1  2.775633     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 2  3.708368     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 3  2.787498     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 4  2.892510     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
#
#    home_add_lat  home_add_lon   mcc                       terminal_id  \
# 0     59.851002        30.232  5261  11606fde0c814ce78e0d726e39a0a5ee
# 1     59.851002        30.232  5261  e9647a5e1eacfb06713b6af755ccc595
# 2     59.851002        30.232  5992  df06c1fcd3718a514535ae822785f716
# 3     59.851002        30.232  5261  6c5e5793ebc984fb72875feffff62854
# 4     59.851002        30.232  5261  0576445d74e374c92c0902e612fca356
#
#    work_add_lat    ...      has_children  has_pet  amount_mean  amount_sub  \
# 0        59.847    ...                 0        0     3.552742   -0.668708
# 1        59.847    ...                 0        0     3.552742   -0.777109
# 2        59.847    ...                 0        0     3.552742    0.155626
# 3        59.847    ...                 0        0     3.552742   -0.765244
# 4        59.847    ...                 0        0     3.552742   -0.660232
#
#    amount_div  pct_term_counts  pct_mcc_g_counts  is_abroad   amount_true  \
# 0    0.811777         0.013889          0.138889          0   1914.141006
# 1    0.781265         0.013889          0.138889          0   1491.327772
# 2    1.043805         0.013889          0.013889          0  12773.452874
# 3    0.784605         0.013889          0.138889          0   1532.631571
# 4    0.814163         0.041667          0.138889          0   1951.865761
#
#    is_native
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 36 columns]

# %%
df = pd.merge(df_valid.loc[:, ["customer_id"]], df, how='left', on='customer_id', suffixes=('', ''))
df['lat_pred'] = df['lon_pred'] = np.nan
df.head()
# Out:
#                         customer_id    amount  city  country  currency  \
# 0  13d194bdf7adf721eeec5c438879da08  2.702240     0        0       643
# 1  13d194bdf7adf721eeec5c438879da08  2.195717     9        0       643
# 2  13d194bdf7adf721eeec5c438879da08  2.648815     0        0       643
# 3  13d194bdf7adf721eeec5c438879da08  2.243423     0        0       643
# 4  13d194bdf7adf721eeec5c438879da08  2.336553     0        0       643
#
#    home_add_lat  home_add_lon   mcc                       terminal_id  \
# 0     56.734001        37.166  5641  1ba8bbab7a1e35baa53bb0d2a3119fe1
# 1     56.734001        37.166  5814  cab40f7bb974797ecbdeae0507288099
# 2     56.734001        37.166  5912  f301fe6b6925d989b4bae659461188c7
# 3     56.734001        37.166  5814  6f76119f98fa96f2e2e659e87e14fb5d
# 4     56.734001        37.166  5814  6f76119f98fa96f2e2e659e87e14fb5d
#
#    work_add_lat    ...     amount_mean  amount_sub  amount_div  \
# 0           NaN    ...        2.995777   -0.293538    0.902016
# 1           NaN    ...        2.995777   -0.800060    0.732937
# 2           NaN    ...        2.995777   -0.346962    0.884183
# 3           NaN    ...        2.995777   -0.752355    0.748862
# 4           NaN    ...        2.995777   -0.659225    0.779949
#
#    pct_term_counts  pct_mcc_g_counts  is_abroad  amount_true  is_native  \
# 0           0.0625            0.0625          0  1259.446606          1
# 1           0.0625            0.3125          0   392.335047          0
# 2           0.0625            0.3125          0  1113.666520          1
# 3           0.1250            0.3125          0   437.887709          1
# 4           0.1250            0.3125          0   542.616041          1
#
#    lat_pred  lon_pred
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#
# [5 rows x 38 columns]

# %%
def choose_best(group):
    y_pred = group.loc[:, pred_columns].values
    index = np.unravel_index(np.argmax(y_pred, axis=None), y_pred.shape)
    lat, lon = group.iloc[index[0]].loc[["lat", "lon"]]
    lat_mul, lon_mul = multip[index[1]]
    lat += lat_mul * 0.02
    lon += lon_mul * 0.02
    return pd.Series([lat, lon], index=['lat', 'lon'])

# %%
features = [f for f in df.columns
    if f not in {'home_add_lon', 'home_add_lat',
                 'work_add_lon', 'work_add_lat',
                 'is_work', 'is_home',
                 'customer_id', 'terminal_id'} and f not in time_features]
features
# Out:
# [u'amount',
#  u'city',
#  u'country',
#  u'currency',
#  u'mcc',
#  u'access24h',
#  u'is_office',
#  u'lat',
#  u'lon',
#  u'n_points',
#  u'is_atm',
#  u'is_raiff',
#  u'is_partner',
#  u'pct_same',
#  u'neg_home',
#  u'neg_work',
#  u'pos_home',
#  u'pos_work',
#  u'mcc_group',
#  u'has_car',
#  u'has_children',
#  u'has_pet',
#  u'amount_mean',
#  u'amount_sub',
#  u'amount_div',
#  u'pct_term_counts',
#  u'pct_mcc_g_counts',
#  u'is_abroad',
#  u'amount_true',
#  u'is_native',
#  'lat_pred',
#  'lon_pred']

# %%
multip = [(lat_mul, lon_mul) for lat_mul in range(-2, 3) for lon_mul in range(-2, 3)]

# multip = [(0, 0)]

for i, (lat_mul, lon_mul) in enumerate(multip):
    df.loc[:, "lat_pred"] = df.loc[:, "lat"] * lat_mul
    df.loc[:, "lon_pred"] = df.loc[:, "lon"] * lon_mul
        
    y_pred = model.predict(xgb.DMatrix(df.loc[:, features].values))
    df["pred@{}".format(i)] = y_pred
        
    print i, "predicted..."
        
pred_columns = filter(lambda c: '@' in c, df.columns)
df_pred = df[['customer_id', 'lat', 'lon'] + pred_columns].groupby('customer_id').apply(choose_best)
df_pred.reset_index(drop=False, inplace=True)
df_pred.head()
# Out:
# 0 predicted...
# 1 predicted...
# 2 predicted...
# 3 predicted...
# 4 predicted...
# 5 predicted...
# 6 predicted...
# 7 predicted...
# 8 predicted...
# 9 predicted...
# 10 predicted...
# 11 predicted...
# 12 predicted...
# 13 predicted...
# 14 predicted...
# 15 predicted...
# 16 predicted...
# 17 predicted...
# 18 predicted...
# 19 predicted...
# 20 predicted...
# 21 predicted...
# 22 predicted...
# 23 predicted...
# 24 predicted...
#                         customer_id        lat        lon
# 0  0037f3de3d890df1022cc760a1dfd9d6  55.760490  37.782098
# 1  007525af0bc3ce72137b586a298f7b98  55.769626  37.597295
# 2  00a840ccc4f35f8ead26610f788a6a61  59.917203  30.337762
# 3  00cefcb1c777d2bf7a32f082c040088f  59.899520  30.360276
# 4  00dc51ccd3993f55974bd7afc1ceecea  55.950183  37.502191

# %%
df = df.loc[:, filter(lambda c: '@' not in c, df.columns)]

# %%
df_pred = pd.merge(df_valid, df_pred, how='left', on='customer_id')

# %%
score = is_inside_area(df_pred['home_add_lat'], df_pred['home_add_lon'], df_pred['lat'], df_pred['lon'])
print "Valid score: {}".format(score.sum() / float(score.shape[0]))
# Out:
# Valid score: 0.0107212475634
