# %%
import codecs

from operator import itemgetter

import numpy as np
import pandas as pd

import xgboost as xgb
import sklearn

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib

# %%
def is_inside_area(lat_pred, lon_pred, lat_true, lon_true, radius=0.02):
    return np.power(lat_pred - lat_true, 2) + np.power(lon_pred - lon_true, 2) <= radius ** 2

# %%
time_features = {u'day', u'day_of_week', u'days_after_holiday',
       u'days_before_holiday', u'is_dayoff', u'is_holiday', u'is_short',
       u'is_weekend', u'month', u'timestamp', u'week_of_year'}

# %% [markdown]
# ### Подготавливаем данные

# %%
df = pd.read_csv("data/sets/train_set_final.csv", sep=',', encoding='utf-8')
df.drop(labels=time_features, axis=1, inplace=True)
df.drop_duplicates(inplace=True)
print df.shape
df.head()
# Out:
# (1131820, 36)
#      amount  city  country  currency                       customer_id  \
# 0  2.884034     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 1  2.775633     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 2  3.708368     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 4  2.787498     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 6  2.892510     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
#
#    home_add_lat  home_add_lon   mcc                       terminal_id  \
# 0     59.851002        30.232  5261  11606fde0c814ce78e0d726e39a0a5ee
# 1     59.851002        30.232  5261  e9647a5e1eacfb06713b6af755ccc595
# 2     59.851002        30.232  5992  df06c1fcd3718a514535ae822785f716
# 4     59.851002        30.232  5261  6c5e5793ebc984fb72875feffff62854
# 6     59.851002        30.232  5261  0576445d74e374c92c0902e612fca356
#
#    work_add_lat    ...      has_children  has_pet  amount_mean  amount_sub  \
# 0        59.847    ...                 0        0     3.552742   -0.668708
# 1        59.847    ...                 0        0     3.552742   -0.777109
# 2        59.847    ...                 0        0     3.552742    0.155626
# 4        59.847    ...                 0        0     3.552742   -0.765244
# 6        59.847    ...                 0        0     3.552742   -0.660232
#
#    amount_div  pct_term_counts  pct_mcc_g_counts  is_abroad   amount_true  \
# 0    0.811777         0.013889          0.138889          0   1914.141006
# 1    0.781265         0.013889          0.138889          0   1491.327772
# 2    1.043805         0.013889          0.013889          0  12773.452874
# 4    0.784605         0.013889          0.138889          0   1532.631571
# 6    0.814163         0.041667          0.138889          0   1951.865761
#
#    is_native
# 0          1
# 1          1
# 2          1
# 4          1
# 6          1
#
# [5 rows x 36 columns]

# %%
df.to_csv("data/sets/tmp/train_set_final.csv", sep=',', encoding='utf-8', index=False)

# %%
np.random.seed(8888)

# %%
df = pd.read_csv("data/sets/tmp/train_set_final.csv", sep=',', encoding='utf-8', usecols=['customer_id'])
df.head()
# Out:
#                         customer_id
# 0  0dc0137d280a2a82d2dc89282450ff1b
# 1  0dc0137d280a2a82d2dc89282450ff1b
# 2  0dc0137d280a2a82d2dc89282450ff1b
# 3  0dc0137d280a2a82d2dc89282450ff1b
# 4  0dc0137d280a2a82d2dc89282450ff1b

# %%
customers = df['customer_id'].unique()
np.random.shuffle(customers)
    
border = int(len(customers) * 0.9)
cust_train, cust_valid = set(customers[:border]), set(customers[border:])

# %%
variants_mods = [(i,j) for i in range(-2, 3) for j in range(-2, 3)]
variants_mods.remove((0,0))

with codecs.open('data/sets/tmp/train_set_final.csv', mode='r', encoding='utf-8') as f_input,\
        codecs.open('data/sets/tmp/valid_work.libsvm', mode='w', encoding='utf-8') as f_valid,\
        codecs.open('data/sets/tmp/train_work.libsvm', mode='w', encoding='utf-8') as f_train,\
        codecs.open('data/sets/tmp/valid_work.labels', mode='w', encoding='utf-8') as f_valid_,\
        codecs.open('data/sets/tmp/train_work.labels', mode='w', encoding='utf-8') as f_train_:
    f_train_.write('customer_id,work_add_lat,work_add_lon,lat,lon\n')
    f_valid_.write('customer_id,work_add_lat,work_add_lon,lat,lon\n')
    
    # получаем индексы для каждой из колонок
    header = next(f_input).strip().split(',')
    header_cols = { col: col_i for col_i, col in enumerate(header) }
    
    # настраиваем список фичей
    features = [f for f in header
        if f not in {'home_add_lon', 'home_add_lat',
              'work_add_lon', 'work_add_lat',
              'is_work', 'is_home',
              'customer_id', 'terminal_id'} and f not in time_features]
    n_features = len(features)
    
    def format_line():
        is_coord = int(is_inside_area(lat, lon, lat_coord, lon_coord))
        output_line = [
            str(is_coord),
            features_line,
            '{}:{}'.format(n_features, lat),
            '{}:{}'.format(n_features + 1, lon)
        ]
        output_line = ' '.join(output_line) + '\n'
        return output_line
    
    for line in f_input:        
        line = line.strip()
        line_cols = line.split(',')
        
        lat_coord, lon_coord = \
            line_cols[header_cols['work_add_lat']], line_cols[header_cols['work_add_lon']]
            
        if lat_coord == '' or lon_coord == '':
            continue
            
        lat_coord, lon_coord = map(float, [lat_coord, lon_coord])
        
        cust_id = line_cols[header_cols['customer_id']]
        
        f_output_ = f_train_ if cust_id in cust_train else f_valid_
        
        f_output = f_train if cust_id in cust_train else f_valid
        
        features_line = [str(f_i)+':'+line_cols[header_cols[f]] for f_i, f in enumerate(features)]
        features_line = ' '.join(features_line)
        
        labels_line = ','.join([cust_id, str(lat_coord), str(lon_coord)])
        
        lat, lon = line_cols[header_cols['lat']], line_cols[header_cols['lon']]
        if lat != '' and lon != '':
            lat, lon = map(float, [lat, lon])
            f_output.write(format_line())
            f_output_.write(labels_line+','+str(lat)+','+str(lon)+'\n')
        
            np.random.shuffle(variants_mods)
            for mul_lat, mul_lon in variants_mods[:4]:
                lat_ = lat + mul_lat * 0.02
                lon_ = lon + mul_lon * 0.02
                f_output.write(format_line())
                f_output_.write(labels_line+','+str(lat_)+','+str(lon_)+'\n')
        
        lat, lon = lat_coord, lon_coord
        lat, lon = map(float, [lat, lon])
        f_output.write(format_line())
        f_output_.write(labels_line+','+str(lat)+','+str(lon)+'\n')
        
        np.random.shuffle(variants_mods)
        for mul_lat, mul_lon in variants_mods[:4]:
            lat_ = lat + mul_lat * 0.02
            lon_ = lon + mul_lon * 0.02
            f_output.write(format_line())
            f_output_.write(labels_line+','+str(lat_)+','+str(lon_)+'\n')

# %%
def choose_random_lines(libsvm, labels, frac=0.8):
    with codecs.open(libsvm, mode='r') as f_libsvm,\
            codecs.open(labels, mode='r') as f_labels,\
            codecs.open(libsvm+'_random', mode='w') as f_libsvm_r,\
            codecs.open(labels+'_random', mode='w') as f_labels_r:
        try:
            while True:
                line_1, line_2 = next(f_libsvm), next(f_labels)
                if np.random.random() < frac:
                    f_libsvm_r.write(line_1)
                    f_labels_r.write(line_2)
        except StopIteration:
            pass

# %%
choose_random_lines('data/sets/tmp/train_work.libsvm', 'data/sets/tmp/train_work.labels', frac=0.5)

# %%
choose_random_lines('data/sets/tmp/valid_work.libsvm', 'data/sets/tmp/valid_work.labels', frac=0.5)

# %%
with codecs.open('data/sets/train_set_final.csv', mode='r', encoding='utf-8') as f_input:
    header = next(f_input).strip().split(',')
    header_cols = { col: col_i for col_i, col in enumerate(header) }
    
    # настраиваем список фичей
    features = [f for f in header
        if f not in {'home_add_lon', 'home_add_lat',
              'work_add_lon', 'work_add_lat',
              'is_work', 'is_home',
              'customer_id', 'terminal_id'}]
    n_features = len(features)

# %% [markdown]
# ### Обучаем модель

# %%
train_set = xgb.DMatrix('data/sets/tmp/train_work.libsvm')

# %%
valid_set = xgb.DMatrix('data/sets/tmp/valid_work.libsvm')

# %%
clf = xgb.XGBClassifier(n_estimators=10, n_jobs=3, max_depth=7, objective='binary:logistic')

model = xgb.train(
    params=clf.get_xgb_params(),
    dtrain=train_set,
    evals=[(train_set, 'train'), (valid_set, 'valid')],
    verbose_eval=1,
    num_boost_round=300,
    early_stopping_rounds=10
)
# Out:
# [0]	train-error:0.321076	valid-error:0.322691
# Multiple eval metrics have been passed: 'valid-error' will be used for early stopping.
#
# Will train until valid-error hasn't improved in 10 rounds.
# [1]	train-error:0.31477	valid-error:0.318102
# [2]	train-error:0.303517	valid-error:0.306104
# [3]	train-error:0.271275	valid-error:0.273878
# [4]	train-error:0.277378	valid-error:0.284753
# [5]	train-error:0.278018	valid-error:0.286441
# [6]	train-error:0.251849	valid-error:0.263419
# [7]	train-error:0.248241	valid-error:0.261706
# [8]	train-error:0.247378	valid-error:0.258838
# [9]	train-error:0.244337	valid-error:0.259154
# [10]	train-error:0.242197	valid-error:0.25848
# [11]	train-error:0.240294	valid-error:0.253467
# [12]	train-error:0.238791	valid-error:0.252885
# [13]	train-error:0.237559	valid-error:0.249701
# [14]	train-error:0.237109	valid-error:0.249534
# [15]	train-error:0.233821	valid-error:0.246084
# [16]	train-error:0.230929	valid-error:0.244072
# [17]	train-error:0.229681	valid-error:0.241794
# [18]	train-error:0.22827	valid-error:0.240056
# [19]	train-error:0.226158	valid-error:0.238917
# [20]	train-error:0.224307	valid-error:0.237354
# [21]	train-error:0.219773	valid-error:0.237055
# [22]	train-error:0.217998	valid-error:0.235242
# [23]	train-error:0.2171	valid-error:0.234195
# [24]	train-error:0.215027	valid-error:0.234053
# [25]	train-error:0.213779	valid-error:0.231592
# [26]	train-error:0.212828	valid-error:0.230204
# [27]	train-error:0.211578	valid-error:0.231384
# [28]	train-error:0.210466	valid-error:0.230087
# [29]	train-error:0.20874	valid-error:0.228524
# [30]	train-error:0.207291	valid-error:0.227311
# [31]	train-error:0.205334	valid-error:0.225764
# [32]	train-error:0.203875	valid-error:0.225473
# [33]	train-error:0.202539	valid-error:0.224018
# [34]	train-error:0.201928	valid-error:0.222305
# [35]	train-error:0.200692	valid-error:0.22233
# [36]	train-error:0.199378	valid-error:0.221108
# [37]	train-error:0.198125	valid-error:0.220584
# [38]	train-error:0.196491	valid-error:0.217965
# [39]	train-error:0.195482	valid-error:0.217999
# [40]	train-error:0.194966	valid-error:0.217442
# [41]	train-error:0.193067	valid-error:0.216219
# [42]	train-error:0.192363	valid-error:0.215139
# [43]	train-error:0.191114	valid-error:0.214698
# [44]	train-error:0.19041	valid-error:0.214033
# [45]	train-error:0.189201	valid-error:0.212353
# [46]	train-error:0.188216	valid-error:0.211522
# [47]	train-error:0.18691	valid-error:0.211588
# [48]	train-error:0.186035	valid-error:0.21084
# [49]	train-error:0.185891	valid-error:0.211314
# [50]	train-error:0.183967	valid-error:0.210965
# [51]	train-error:0.183425	valid-error:0.210591
# [52]	train-error:0.182361	valid-error:0.209285
# [53]	train-error:0.182093	valid-error:0.208562
# [54]	train-error:0.181004	valid-error:0.208637
# [55]	train-error:0.180388	valid-error:0.209701
# [56]	train-error:0.180073	valid-error:0.209668
# [57]	train-error:0.179531	valid-error:0.209485
# [58]	train-error:0.178784	valid-error:0.210017
# [59]	train-error:0.177861	valid-error:0.209734
# [60]	train-error:0.17738	valid-error:0.209576
# [61]	train-error:0.177041	valid-error:0.209585
# [62]	train-error:0.176626	valid-error:0.208836
# [63]	train-error:0.176266	valid-error:0.208487
# [64]	train-error:0.175349	valid-error:0.207714
# [65]	train-error:0.174878	valid-error:0.207257
# [66]	train-error:0.174179	valid-error:0.208071
# [67]	train-error:0.173894	valid-error:0.207614
# [68]	train-error:0.17336	valid-error:0.206683
# [69]	train-error:0.173176	valid-error:0.206226
# [70]	train-error:0.173069	valid-error:0.206791
# [71]	train-error:0.172161	valid-error:0.205694
# [72]	train-error:0.171492	valid-error:0.20566
# [73]	train-error:0.170152	valid-error:0.205311
# [74]	train-error:0.169069	valid-error:0.204846
# [75]	train-error:0.168984	valid-error:0.204945
# [76]	train-error:0.167123	valid-error:0.204114
# [77]	train-error:0.166515	valid-error:0.204413
# [78]	train-error:0.166252	valid-error:0.204471
# [79]	train-error:0.16553	valid-error:0.204613
# [80]	train-error:0.164343	valid-error:0.204081
# [81]	train-error:0.163791	valid-error:0.203848
# [82]	train-error:0.163193	valid-error:0.203997
# [83]	train-error:0.162851	valid-error:0.204313
# [84]	train-error:0.162564	valid-error:0.20369
# [85]	train-error:0.161835	valid-error:0.203815
# [86]	train-error:0.16112	valid-error:0.202967
# [87]	train-error:0.160396	valid-error:0.203141
# [88]	train-error:0.159525	valid-error:0.202709
# [89]	train-error:0.158843	valid-error:0.204821
# [90]	train-error:0.15828	valid-error:0.203989
# [91]	train-error:0.157851	valid-error:0.204197
# [92]	train-error:0.157344	valid-error:0.204762
# [93]	train-error:0.155913	valid-error:0.204629
# [94]	train-error:0.155214	valid-error:0.203191
# [95]	train-error:0.154407	valid-error:0.202651
# [96]	train-error:0.153778	valid-error:0.201063
# [97]	train-error:0.153022	valid-error:0.201354
# [98]	train-error:0.152704	valid-error:0.201171
# [99]	train-error:0.151872	valid-error:0.200331
# [100]	train-error:0.151343	valid-error:0.199932
# [101]	train-error:0.150962	valid-error:0.199433
# [102]	train-error:0.150779	valid-error:0.199317
# [103]	train-error:0.150285	valid-error:0.200838
# [104]	train-error:0.149807	valid-error:0.200589
# [105]	train-error:0.149214	valid-error:0.200896
# [106]	train-error:0.148819	valid-error:0.201586
# [107]	train-error:0.148105	valid-error:0.199982
# [108]	train-error:0.147189	valid-error:0.197587
# [109]	train-error:0.146527	valid-error:0.197097
# [110]	train-error:0.146302	valid-error:0.197163
# [111]	train-error:0.145892	valid-error:0.197321
# [112]	train-error:0.145802	valid-error:0.196964
# [113]	train-error:0.144838	valid-error:0.196573
# [114]	train-error:0.144576	valid-error:0.196972
# [115]	train-error:0.143896	valid-error:0.194686
# [116]	train-error:0.143393	valid-error:0.194361
# [117]	train-error:0.142971	valid-error:0.194104
# [118]	train-error:0.142836	valid-error:0.194012
# [119]	train-error:0.14245	valid-error:0.193979
# [120]	train-error:0.14235	valid-error:0.193796
# [121]	train-error:0.141318	valid-error:0.1921
# [122]	train-error:0.140799	valid-error:0.192216
# [123]	train-error:0.139888	valid-error:0.192116
# [124]	train-error:0.139351	valid-error:0.191534
# [125]	train-error:0.138882	valid-error:0.191061
# [126]	train-error:0.138467	valid-error:0.190337
# [127]	train-error:0.138005	valid-error:0.189963
# [128]	train-error:0.13688	valid-error:0.189664
# [129]	train-error:0.136702	valid-error:0.189863
# [130]	train-error:0.136425	valid-error:0.190005
# [131]	train-error:0.135936	valid-error:0.189473
# [132]	train-error:0.135292	valid-error:0.190129
# [133]	train-error:0.135165	valid-error:0.189855
# [134]	train-error:0.134877	valid-error:0.189764
# [135]	train-error:0.134933	valid-error:0.189863
# [136]	train-error:0.134163	valid-error:0.189946
# [137]	train-error:0.132923	valid-error:0.189265
# [138]	train-error:0.13222	valid-error:0.188874
# [139]	train-error:0.131679	valid-error:0.188691
# [140]	train-error:0.131283	valid-error:0.188284
# [141]	train-error:0.130498	valid-error:0.188583
# [142]	train-error:0.129841	valid-error:0.188225
# [143]	train-error:0.129231	valid-error:0.188001
# [144]	train-error:0.128889	valid-error:0.18751
# [145]	train-error:0.128423	valid-error:0.187436
# [146]	train-error:0.127993	valid-error:0.186879
# [147]	train-error:0.127765	valid-error:0.186687
# [148]	train-error:0.127345	valid-error:0.187186
# [149]	train-error:0.126739	valid-error:0.186804
# [150]	train-error:0.126404	valid-error:0.186712
# [151]	train-error:0.126189	valid-error:0.18618
# [152]	train-error:0.125353	valid-error:0.186388
# [153]	train-error:0.125039	valid-error:0.186064
# [154]	train-error:0.124909	valid-error:0.186039
# [155]	train-error:0.124651	valid-error:0.186089
# [156]	train-error:0.124299	valid-error:0.18633
# [157]	train-error:0.124146	valid-error:0.185897
# [158]	train-error:0.123978	valid-error:0.185715
# [159]	train-error:0.12318	valid-error:0.185723
# [160]	train-error:0.122984	valid-error:0.185357
# [161]	train-error:0.122723	valid-error:0.185074
# [162]	train-error:0.122474	valid-error:0.185033
# [163]	train-error:0.122147	valid-error:0.185008
# [164]	train-error:0.121673	valid-error:0.184733
# [165]	train-error:0.121457	valid-error:0.184642
# [166]	train-error:0.121034	valid-error:0.184659
# [167]	train-error:0.120994	valid-error:0.184559
# [168]	train-error:0.120442	valid-error:0.184384
# [169]	train-error:0.120087	valid-error:0.184551
# [170]	train-error:0.120012	valid-error:0.184534
# [171]	train-error:0.119589	valid-error:0.183894
# [172]	train-error:0.119566	valid-error:0.184251
# [173]	train-error:0.119567	valid-error:0.184359
# [174]	train-error:0.119128	valid-error:0.184891
# [175]	train-error:0.118544	valid-error:0.184559
# [176]	train-error:0.118121	valid-error:0.185074
# [177]	train-error:0.117923	valid-error:0.185232
# [178]	train-error:0.117643	valid-error:0.185257
# [179]	train-error:0.11756	valid-error:0.185216
# [180]	train-error:0.117403	valid-error:0.184925
# [181]	train-error:0.11729	valid-error:0.184883
# Stopping. Best iteration:
# [171]	train-error:0.119589	valid-error:0.183894

# %%
joblib.dump(model, 'data/models/clf_work_04.model')
# Out:
# ['data/models/clf_work_04.model']

# %% [markdown]
# ### Оценка модели

# %% [markdown]
# ### Train

# %%
model = joblib.load('data/models/clf_work_04.model')

# %%
train_set = xgb.DMatrix('data/sets/tmp/train_work.libsvm')

# %%
y_pred = model.predict(train_set)
y_pred.shape
# Out:
# (5554290,)

# %%
df = pd.read_csv('data/sets/tmp/train_work.labels', sep=',', encoding='utf-8')
df.columns = ['customer_id', 'work_lat', 'work_lon', 'lat', 'lon']
print df.shape
df.head()
# Out:
# (5554290, 5)
#                         customer_id  work_lat  work_lon        lat        lon
# 0  0dc0137d280a2a82d2dc89282450ff1b    59.847    30.177  59.844074  30.179153
# 1  0dc0137d280a2a82d2dc89282450ff1b    59.847    30.177  59.844074  30.199153
# 2  0dc0137d280a2a82d2dc89282450ff1b    59.847    30.177  59.824074  30.179153
# 3  0dc0137d280a2a82d2dc89282450ff1b    59.847    30.177  59.824074  30.199153
# 4  0dc0137d280a2a82d2dc89282450ff1b    59.847    30.177  59.864074  30.159153

# %%
df['is_work'] = y_pred

# %%
df_preds = []

for cust_i, group in df.groupby('customer_id'):
    pred_i = group['is_work'].idxmax()
    home_lat, home_lon, lat, lon = group.loc[pred_i, ['work_lat', 'work_lon', 'lat', 'lon']]
    df_preds.append((cust_i, home_lat, home_lon, lat, lon))
    
df_preds = pd.DataFrame(df_preds, columns=['customer_id', 'work_lat', 'work_lon', 'lat', 'lon'])
df_preds.head()
# Out:
#                         customer_id   work_lat   work_lon        lat  \
# 0  0001f322716470bf9bfc1708f06f00fc  44.735001  37.798000  44.735001
# 1  000b709c6c6fb1e8efcfd95e57c2a9de  54.983002  82.879997  54.983002
# 2  0031915eb230f772681fb5dc5a8d1c31  55.748001  37.601002  55.748001
# 3  003fa58414cc55531fcc38423bea8f8e  55.800999  37.633999  55.800999
# 4  005194bf7238734eb49c142258c5a263  51.680000  39.181000  51.680000
#
#          lon
# 0  37.798000
# 1  82.879997
# 2  37.601002
# 3  37.633999
# 4  39.181000

# %%
score = is_inside_area(df_preds['work_lat'], df_preds['work_lon'], df_preds['lat'], df_preds['lon'])
print "Train score: {}".format(score.sum() / float(score.shape[0]))
# Out:
# Train score: 0.987068965517

# %% [markdown]
# ### Valid

# %%
valid_set = xgb.DMatrix('data/sets/tmp/valid_work.libsvm')

# %%
y_pred = model.predict(valid_set)
y_pred.shape
# Out:
# (601380,)

# %%
df = pd.read_csv('data/sets/tmp/valid_work.labels', sep=',', encoding='utf-8')
df.columns = ['customer_id', 'work_lat', 'work_lon', 'lat', 'lon']
print df.shape
df.head()
# Out:
# (601380, 5)
#                         customer_id   work_lat   work_lon        lat  \
# 0  3209e87b652f46439784c4d254dd5d12  55.786999  37.629002  55.624607
# 1  3209e87b652f46439784c4d254dd5d12  55.786999  37.629002  55.604607
# 2  3209e87b652f46439784c4d254dd5d12  55.786999  37.629002  55.644607
# 3  3209e87b652f46439784c4d254dd5d12  55.786999  37.629002  55.664607
# 4  3209e87b652f46439784c4d254dd5d12  55.786999  37.629002  55.624607
#
#          lon
# 0  37.852997
# 1  37.832997
# 2  37.832997
# 3  37.872997
# 4  37.812997

# %%
df['is_work'] = y_pred

# %%
df_preds = []

for cust_i, group in df.groupby('customer_id'):
    pred_i = group['is_work'].idxmax()
    home_lat, home_lon, lat, lon = group.loc[pred_i, ['work_lat', 'work_lon', 'lat', 'lon']]
    df_preds.append((cust_i, home_lat, home_lon, lat, lon))
    
df_preds = pd.DataFrame(df_preds, columns=['customer_id', 'work_lat', 'work_lon', 'lat', 'lon'])
df_preds.head()
# Out:
#                         customer_id   work_lat  work_lon        lat     lon
# 0  007525af0bc3ce72137b586a298f7b98  55.743999    37.645  55.743999  37.645
# 1  00eee313c10e5496006273dcedca8633  60.235001    29.622  60.235001  29.622
# 2  00f6ac562cf73b8d8b8ab14abc1d1a95  55.771999    37.625  55.771999  37.625
# 3  0169fd91b58dda2f5da41713387d1796  59.801998    30.330  59.801998  30.330
# 4  021057dfdf04a4b8bab5528e8dc0f814  55.747002    37.534  55.747002  37.534

# %%
score = is_inside_area(df_preds['work_lat'], df_preds['work_lon'], df_preds['lat'], df_preds['lon'])
print "Valid score: {}".format(score.sum() / float(score.shape[0]))
# Out:
# Valid score: 0.984555984556

# %% [markdown]
# ### FAIR SCORE

# %%
model = joblib.load('data/models/clf_work_04.model')

# %%
df_valid = pd.read_csv('data/sets/tmp/valid_work.labels', sep=',', encoding='utf-8',
                       usecols=['customer_id', 'work_add_lat', 'work_add_lon'])
df_valid.drop_duplicates(inplace=True)
df_valid.head()
# Out:
#                            customer_id  work_add_lat  work_add_lon
# 0     3209e87b652f46439784c4d254dd5d12     55.786999     37.629002
# 640   9c8cf84c4bae8d5341f4fd06c964e8ed     59.942001     30.327000
# 1300  799b45bc4a4c48a17a6e28a878350420     56.007999     92.772003
# 1740  a89fca446f4c5dcf68820f22d4a5d424     59.945000     30.344000
# 2130  b0535ffedfd0679c7edd0ec137929dd5     48.773998     44.772999

# %%
df = pd.read_csv("data/sets/tmp/train_set_final.csv", sep=',', encoding='utf-8')
df.head()
# Out:
#      amount  city  country  currency                       customer_id  \
# 0  2.884034     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 1  2.775633     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 2  3.708368     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 3  2.787498     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 4  2.892510     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
#
#    home_add_lat  home_add_lon   mcc                       terminal_id  \
# 0     59.851002        30.232  5261  11606fde0c814ce78e0d726e39a0a5ee
# 1     59.851002        30.232  5261  e9647a5e1eacfb06713b6af755ccc595
# 2     59.851002        30.232  5992  df06c1fcd3718a514535ae822785f716
# 3     59.851002        30.232  5261  6c5e5793ebc984fb72875feffff62854
# 4     59.851002        30.232  5261  0576445d74e374c92c0902e612fca356
#
#    work_add_lat    ...      has_children  has_pet  amount_mean  amount_sub  \
# 0        59.847    ...                 0        0     3.552742   -0.668708
# 1        59.847    ...                 0        0     3.552742   -0.777109
# 2        59.847    ...                 0        0     3.552742    0.155626
# 3        59.847    ...                 0        0     3.552742   -0.765244
# 4        59.847    ...                 0        0     3.552742   -0.660232
#
#    amount_div  pct_term_counts  pct_mcc_g_counts  is_abroad   amount_true  \
# 0    0.811777         0.013889          0.138889          0   1914.141006
# 1    0.781265         0.013889          0.138889          0   1491.327772
# 2    1.043805         0.013889          0.013889          0  12773.452874
# 3    0.784605         0.013889          0.138889          0   1532.631571
# 4    0.814163         0.041667          0.138889          0   1951.865761
#
#    is_native
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 36 columns]

# %%
df = pd.merge(df_valid.loc[:, ["customer_id"]], df, how='left', on='customer_id', suffixes=('', ''))
df['lat_pred'] = df['lon_pred'] = np.nan
df.head()
# Out:
#                         customer_id    amount  city  country  currency  \
# 0  3209e87b652f46439784c4d254dd5d12  2.744375    84        0       643
# 1  3209e87b652f46439784c4d254dd5d12  3.979987   128        0       643
# 2  3209e87b652f46439784c4d254dd5d12  3.749979   128        0       643
# 3  3209e87b652f46439784c4d254dd5d12  2.926858     0        0       643
# 4  3209e87b652f46439784c4d254dd5d12  2.057587     0        0       643
#
#    home_add_lat  home_add_lon   mcc                       terminal_id  \
# 0     55.629002     37.863998  5411  f1fa9245477a6a5183fd48cdd51f51c4
# 1     55.629002     37.863998  5411  a5af0cb2a1c1ba1e589f589495fe8310
# 2     55.629002     37.863998  5411  6a16f0fa130e2d2475f0356ef37f32b6
# 3     55.629002     37.863998  5814  3b4607adc8746afd656fee00be2b8822
# 4     55.629002     37.863998  4111  27dd8a3db77635f597a65c4ef24d68d5
#
#    work_add_lat    ...     amount_mean  amount_sub  amount_div  \
# 0     55.786999    ...         3.37804   -0.633665    0.812416
# 1     55.786999    ...         3.37804    0.601947    1.178194
# 2     55.786999    ...         3.37804    0.371939    1.110105
# 3     55.786999    ...         3.37804   -0.451181    0.866437
# 4     55.786999    ...         3.37804   -1.320452    0.609107
#
#    pct_term_counts  pct_mcc_g_counts  is_abroad   amount_true  is_native  \
# 0         0.010638          0.191489          0   1387.761263          0
# 1         0.021277          0.191489          0  23874.094837          0
# 2         0.010638          0.191489          0  14057.853976          0
# 3         0.042553          0.276596          0   2112.507188          1
# 4         0.010638          0.010638          0    285.448099          1
#
#    lat_pred  lon_pred
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#
# [5 rows x 38 columns]

# %%
def choose_best(group):
    y_pred = group.loc[:, pred_columns].values
    index = np.unravel_index(np.argmax(y_pred, axis=None), y_pred.shape)
    lat, lon = group.iloc[index[0]].loc[["lat", "lon"]]
    lat_mul, lon_mul = multip[index[1]]
    lat += lat_mul * 0.02
    lon += lon_mul * 0.02
    return pd.Series([lat, lon], index=['lat', 'lon'])

# %%
features = [f for f in df.columns
    if f not in {'home_add_lon', 'home_add_lat',
                 'work_add_lon', 'work_add_lat',
                 'is_work', 'is_home',
                 'customer_id', 'terminal_id'} and f not in time_features]
features
# Out:
# [u'amount',
#  u'city',
#  u'country',
#  u'currency',
#  u'mcc',
#  u'access24h',
#  u'is_office',
#  u'lat',
#  u'lon',
#  u'n_points',
#  u'is_atm',
#  u'is_raiff',
#  u'is_partner',
#  u'pct_same',
#  u'neg_home',
#  u'neg_work',
#  u'pos_home',
#  u'pos_work',
#  u'mcc_group',
#  u'has_car',
#  u'has_children',
#  u'has_pet',
#  u'amount_mean',
#  u'amount_sub',
#  u'amount_div',
#  u'pct_term_counts',
#  u'pct_mcc_g_counts',
#  u'is_abroad',
#  u'amount_true',
#  u'is_native',
#  'lat_pred',
#  'lon_pred']

# %%
multip = [(lat_mul, lon_mul) for lat_mul in range(-2, 3) for lon_mul in range(-2, 3)]

# multip = [(0, 0)]

for i, (lat_mul, lon_mul) in enumerate(multip):
    df.loc[:, "lat_pred"] = df.loc[:, "lat"] * lat_mul
    df.loc[:, "lon_pred"] = df.loc[:, "lon"] * lon_mul
        
    y_pred = model.predict(xgb.DMatrix(df.loc[:, features].values))
    df["pred@{}".format(i)] = y_pred
        
    print i, "predicted..."

pred_columns = filter(lambda c: '@' in c, df.columns)
df_pred = df[['customer_id', 'lat', 'lon'] + pred_columns].groupby('customer_id').apply(choose_best)
df_pred.reset_index(drop=False, inplace=True)
df_pred.head()
# Out:
# 0 predicted...
# 1 predicted...
# 2 predicted...
# 3 predicted...
# 4 predicted...
# 5 predicted...
# 6 predicted...
# 7 predicted...
# 8 predicted...
# 9 predicted...
# 10 predicted...
# 11 predicted...
# 12 predicted...
# 13 predicted...
# 14 predicted...
# 15 predicted...
# 16 predicted...
# 17 predicted...
# 18 predicted...
# 19 predicted...
# 20 predicted...
# 21 predicted...
# 22 predicted...
# 23 predicted...
# 24 predicted...
#                         customer_id        lat         lon
# 0  007525af0bc3ce72137b586a298f7b98  55.973577   37.248717
# 1  00eee313c10e5496006273dcedca8633  59.793912   30.244891
# 2  00f6ac562cf73b8d8b8ab14abc1d1a95  59.796300   30.344815
# 3  0169fd91b58dda2f5da41713387d1796  59.882466   29.746236
# 4  021057dfdf04a4b8bab5528e8dc0f814  52.633781  103.825707

# %%
df = df.loc[:, filter(lambda c: '@' not in c, df.columns)]

# %%
df_pred = pd.merge(df_valid, df_pred, how='left', on='customer_id')

# %%
score = is_inside_area(df_pred['work_add_lat'], df_pred['work_add_lon'], df_pred['lat'], df_pred['lon'])
print "Valid score: {}".format(score.sum() / float(score.shape[0]))
# Out:
# Valid score: 0.00767754318618
