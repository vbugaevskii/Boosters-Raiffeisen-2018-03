# %%
import re
import json
import codecs

from datetime import datetime
from collections import Counter, OrderedDict
from operator import itemgetter

import numpy as np
import pandas as pd

import gmplot
import geopy.distance

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dtypes = {
    'amount': np.float32,
    'atm_address': str,
    'atm_address_lat': np.float32,
    'atm_address_lon': np.float32,
    'city': str,
    'country': str,
    'currency': np.float32,
    'customer_id': str,
    'home_add_lat': np.float32,
    'home_add_lon': np.float32,
    'mcc': str,
    'pos_address': str,
    'pos_address_lat': np.float32,
    'pos_address_lon': np.float32,
    'terminal_id': str,
    'transaction_date': str,
    'work_add_lat': np.float32,
    'work_add_lon': np.float32
}

# %%
use_columns = dtypes.keys()

df_1 = pd.read_csv("train_set.csv", sep=',', encoding='utf-8', dtype=dtypes, usecols=use_columns)
df_1["is_train"] = True
df_1.head()
# Out:
#      amount atm_address  atm_address_lat  atm_address_lon           city  \
# 0  2.884034         NaN              NaN              NaN  ST PETERSBURG
# 1  2.775633         NaN              NaN              NaN  ST PETERSBURG
# 2  3.708368         NaN              NaN              NaN  St Petersburg
# 3  2.787498         NaN              NaN              NaN  ST PETERSBURG
# 4  2.892510         NaN              NaN              NaN  ST PETERSBURG
#
#   country  currency                       customer_id  home_add_lat  \
# 0     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 1     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 2     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 3     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 4     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
#
#    home_add_lon   mcc                                        pos_address  \
# 0        30.232  5261                                                NaN
# 1        30.232  5261                                                NaN
# 2        30.232  5992  PR.MARSHALA ZHUKOVA,31St Petersburg190000    7...
# 3        30.232  5261                                                NaN
# 4        30.232  5261                                                NaN
#
#    pos_address_lat  pos_address_lon                       terminal_id  \
# 0        59.844074        30.179153  11606fde0c814ce78e0d726e39a0a5ee
# 1        59.844074        30.179153  e9647a5e1eacfb06713b6af755ccc595
# 2        59.858200        30.229023  df06c1fcd3718a514535ae822785f716
# 3        59.844074        30.179153  6c5e5793ebc984fb72875feffff62854
# 4        59.844074        30.179153  0576445d74e374c92c0902e612fca356
#
#   transaction_date  work_add_lat  work_add_lon is_train
# 0       2017-07-15        59.847        30.177     True
# 1       2017-10-27        59.847        30.177     True
# 2       2017-10-03        59.847        30.177     True
# 3       2017-09-09        59.847        30.177     True
# 4       2017-07-06        59.847        30.177     True

# %%
use_columns = filter(lambda k: not (k.startswith('home_') or k.startswith('work_')), dtypes.iterkeys())

df_2 = pd.read_csv("test_set.csv", sep=',', encoding='utf-8', dtype=dtypes, usecols=use_columns)
df_2["mcc"] = df_2["mcc"].map(lambda x: re.sub(',', '', x))
df_2["is_train"] = False
df_2.head()
# Out:
#      amount atm_address  atm_address_lat  atm_address_lon        city country  \
# 0  2.211818         NaN              NaN              NaN  IVANTEEVKA     RUS
# 1  1.331379         NaN              NaN              NaN  IVANTEEVKA     RUS
# 2  2.608004         NaN              NaN              NaN    PUSHKINO     RUS
# 3  1.916752         NaN              NaN              NaN  IVANTEEVKA     RUS
# 4  1.981067         NaN              NaN              NaN      MOSCOW     RUS
#
#    currency                       customer_id   mcc  \
# 0     643.0  00fd410f5c580c8351cafa88d82b60f3  5411
# 1     643.0  00fd410f5c580c8351cafa88d82b60f3  4111
# 2     643.0  00fd410f5c580c8351cafa88d82b60f3  5411
# 3     643.0  00fd410f5c580c8351cafa88d82b60f3  5411
# 4     643.0  00fd410f5c580c8351cafa88d82b60f3  5814
#
#                                          pos_address  pos_address_lat  \
# 0       2-1 TOLMACHEVA STRIVANTEEVKA141280    RUSRUS        55.967487
# 1            SOVETSKIJ, 32IVANTEEVKA141282    RUSRUS        55.971294
# 2      105,KRASOARMEYSKOE SHPUSHKINO141206    RUSRUS        56.016590
# 3  G. IVANTEEVKA, UL.TOLMACHEVA, D.6IVANTEEVKA141...        55.964508
# 4           5 KOMSOMOLSKAYA SQMOSCOW101000    RUSRUS        55.776802
#
#    pos_address_lon                       terminal_id transaction_date is_train
# 0        37.913681  ff0476dae4b098a7b16aabe93d4268df       2017-08-24    False
# 1        37.905186  7cfd9a60282459d4692ecc85b856072e       2017-08-12    False
# 2        37.909100  7e5a532f0029861d8a9c4f0479b9450b       2017-06-17    False
# 3        37.937912  2afe7d1bc61b86c449f413bdf2119032       2017-08-12    False
# 4        37.657352  ab4f00601ff1d949afc59ee3f804c79c       2017-04-26    False

# %%
df = pd.concat([df_1, df_2], axis=0)

# %%
def map_country(country):
    country = country.strip()
    map_c = {
         'AE': 'ARE',
         'AM': 'ARM',
         'AT': 'AUT',
         'AU': 'AUS',
         'AZ': 'AZE',
         'BG': 'BGR',
         'BH': 'BHR',
         'BS': 'BHS',
         'BY': 'BLR',
         'CA': 'CAN',
         'CH': 'CHE',
         'CN': 'CHN',
         'CU': 'CUB',
         'CV': 'CPV',
         'CY': 'CYP',
         'CZ': 'CZE',
         'DE': 'DEU',
         'DK': 'DNK',
         'DN': 'DNK',
         'DO': 'DOM',
         'EE': 'EST',
         'ES': 'ESP',
         'FI': 'FIN',
         'FR': 'FRA',
         'GB': 'GBR',
         'GE': 'GEO',
         'GR': 'GRC',
         'HK': 'HKG',
         'HR': 'HRV',
         'HU': 'HUN',
         'ID': 'IND',
         'IL': 'ISR',
         'IN': 'IND',
         'IS': 'ISL',
         'IT': 'ITA',
         'KG': 'KGZ',
         'KR': 'KOR',
         'KZ': 'KAZ',
         'LK': 'LKA',
         'LT': 'LTU',
         'LU': 'LUX',
         'LV': 'LVA',
         'MD': 'MDA',
         'ME': 'MNE',
         'MK': 'MKD',
         'MV': 'MDV',
         'MY': 'MYS',
         'NL': 'NLD',
         'NO': 'NOR',
         'PH': 'PHL',
         'PL': 'POL',
         'PT': 'PTR',
         'QA': 'QAT',
         'RU': 'RUS',
         'SE': 'SWE',
         'SG': 'SGP',
         'TH': 'THA',
         'TN': 'TUN',
         'TR': 'TUR',
         'TZ': 'TZA',
         'UA': 'UKR',
         'US': 'USA',
         'UZ': 'UZB',
         'VN': 'VNM',
         'ZZ"': '',
         '-bar Campus"': '',
    }
    return map_c[country] if country in map_c else country
    
df["country"] = df["country"].map(map_country)

# %%
df_atms = pd.read_csv("data/atm_features.csv", sep=',', encoding='utf-8')
# df_atms.set_index('terminal_id', inplace=True)
# df_atms["city"].fillna('', inplace=True)
df_atms.head()
# Out:
#                         terminal_id access24h            bank     city  \
# 0  c693dcbafb5e0c1f9a58ac0211d79ed8     False  Россельхозбанк  DERBENT
# 1  3ecc362617966cb7f4563c9e4e89b8a1      True  Россельхозбанк  DERBENT
# 2  cd614b782e35146bacbad19e800e0624     False  Россельхозбанк  DERBENT
# 3  fca99d9df0e01bdebca13824e1db1dfe     False  Россельхозбанк  DERBENT
# 4  fabf56c3e89566e248ea94636cead5cb     False         unknown      NaN
#
#   is_office        lat        lon  n_banks
# 0      True  42.056451  48.298047        4
# 1      True  42.056451  48.298047        4
# 2      True  42.056451  48.298047        4
# 3      True  42.056451  48.298047        4
# 4     False  42.061501  48.290501        5

# %%
df = pd.merge(
    df, df_atms[['terminal_id', 'city']], how='left',
    left_on=['terminal_id'], right_on=['terminal_id'],
    suffixes=('', '_')
)

mask = df["city_"].notnull()
df.loc[mask, "city"] = df.loc[mask, "city_"]
df.drop(labels='city_', axis=1, inplace=True)
df.head()
# Out:
#      amount atm_address  atm_address_lat  atm_address_lon           city  \
# 0  2.884034         NaN              NaN              NaN  ST PETERSBURG
# 1  2.775633         NaN              NaN              NaN  ST PETERSBURG
# 2  3.708368         NaN              NaN              NaN  St Petersburg
# 3  2.787498         NaN              NaN              NaN  ST PETERSBURG
# 4  2.892510         NaN              NaN              NaN  ST PETERSBURG
#
#   country  currency                       customer_id  home_add_lat  \
# 0     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 1     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 2     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 3     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 4     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
#
#    home_add_lon is_train   mcc  \
# 0        30.232     True  5261
# 1        30.232     True  5261
# 2        30.232     True  5992
# 3        30.232     True  5261
# 4        30.232     True  5261
#
#                                          pos_address  pos_address_lat  \
# 0                                                NaN        59.844074
# 1                                                NaN        59.844074
# 2  PR.MARSHALA ZHUKOVA,31St Petersburg190000    7...        59.858200
# 3                                                NaN        59.844074
# 4                                                NaN        59.844074
#
#    pos_address_lon                       terminal_id transaction_date  \
# 0        30.179153  11606fde0c814ce78e0d726e39a0a5ee       2017-07-15
# 1        30.179153  e9647a5e1eacfb06713b6af755ccc595       2017-10-27
# 2        30.229023  df06c1fcd3718a514535ae822785f716       2017-10-03
# 3        30.179153  6c5e5793ebc984fb72875feffff62854       2017-09-09
# 4        30.179153  0576445d74e374c92c0902e612fca356       2017-07-06
#
#    work_add_lat  work_add_lon
# 0        59.847        30.177
# 1        59.847        30.177
# 2        59.847        30.177
# 3        59.847        30.177
# 4        59.847        30.177

# %%
# http://vinfo.russianpost.ru/database/ops.html

df_pochta = pd.read_csv("data/pochta_index.csv", sep=';', encoding='utf-8')
df_pochta.columns = map(lambda s: re.sub(r"[^\w\d]+", "", s), df_pochta.columns)
df_pochta.set_index("INDEX", inplace=True)
df_pochta.head()
# Out:
#                OPSNAME OPSTYPE   OPSSUBM  REGION AUTONOM AREA CITY CITY_1  \
# INDEX
# 101000          МОСКВА       О  127950.0  МОСКВА     NaN  NaN  NaN    NaN
# 101300      МОСКВА-300      ТИ  101000.0  МОСКВА     NaN  NaN  NaN    NaN
# 101700  УФПС Г. МОСКВЫ    УФПС       NaN  МОСКВА     NaN  NaN  NaN    NaN
# 101749      МОСКВА-ДТИ     ДТИ  101000.0  МОСКВА     NaN  NaN  NaN    NaN
# 101751      МОСКВА-ДТИ     ДТИ  101000.0  МОСКВА     NaN  NaN  NaN    NaN
#
#            ACTDATE  INDEXOLD
# INDEX
# 101000  21.01.2011       NaN
# 101300  21.02.2012       NaN
# 101700  18.05.2017       NaN
# 101749  09.11.2006       NaN
# 101751  09.11.2006       NaN

# %%
class Translit(object):
    translit_table = {
        u'А': 'A',
        u'Б': 'B',
        u'В': 'V',
        u'Г': 'G',
        u'Д': 'D',
        u'Е': 'E',
        u'Ё': 'E',
        u'Ж': 'ZH',
        u'З': 'Z',
        u'И': 'I',
        u'Й': 'J',
        u'К': 'K',
        u'Л': 'L',
        u'М': 'M',
        u'Н': 'N',
        u'О': 'O',
        u'П': 'P',
        u'Р': 'R',
        u'С': 'S',
        u'Т': 'T',
        u'У': 'U',
        u'Ф': 'F',
        u'Х': 'KH',
        u'Ц': 'TS',
        u'Ч': 'CH',
        u'Ш': 'SH',
        u'Щ': 'SHCH',
        u'Ъ': '',
        u'Ы': 'Y',
        u'Ь': '',
        u'Э': 'E',
        u'Ю': 'JU',
        u'Я': 'JA'
    }

    @staticmethod
    def translit(word):
        word = word.upper()
        word = re.sub(ur'ЬЕ', u'YE', word, re.U)
        word = re.sub(ur'ЬИ', u'YI', word, re.U)

        word_ = []
        for c in word:
            if c in Translit.translit_table:
                c = Translit.translit_table[c]
            word_.append(c)
        return ''.join(word_)

print Translit.translit(u'ленинградская обл'.upper())
# Out:
# LENINGRADSKAJA OBL

# %%
def translit_region_or_city(region):
    region = re.sub(r'[^\w\s]+', ' ', region.upper(), flags=re.U)
    region = re.sub(r'\d+', ' ', region, flags=re.U)
    
    region = re.sub(u'ИМЕНИ', u'ИМ', region, flags=re.U)
    region = re.sub(u'РЕСПУБЛИКА', '', region, flags=re.U)
    region = re.sub(u'ОБЛАСТЬ', u'ОБЛ', region, flags=re.U)
    region = re.sub(u'АВТОНОМНЫЙ ОКРУГ', u'АО', region, flags=re.U)
    
    if u'ЯКУТИЯ' in region:
        region = u'ЯКУТИЯ'
    elif u'АЛАНИЯ' in region:
        region = u'СЕВЕРНАЯ ОСЕТИЯ'
    elif u'САНКТ ПЕТЕРБУРГ' == region:
        region = u'СТ ПЕТЕРБУРГ'
        
    region = re.sub(r'\s+', ' ', region.strip(), flags=re.U)
    return Translit.translit(region)

# %%
spellchekers_dict = set()

for s in df_pochta["OPSNAME"].unique():
    s = re.sub(ur'[^а-яА-Я ]+', ' ', s)
    s = re.sub(r'\s+', ' ', s.strip())
    if len(s.split()) == 1:
        s = translit_region_or_city(s)
        spellchekers_dict.add(s)
        
spellchekers_dict.add(translit_region_or_city(u'БОЛЬШОЙ ИСТОК'))
spellchekers_dict.add(translit_region_or_city(u'ЦЕМДОЛИНА'))

# %%
df_pochta.loc[df_pochta["CITY"].isnull(), "CITY"] = df_pochta.loc[df_pochta["CITY"].isnull(), "REGION"]
df_pochta.loc[df_pochta["CITY"].isnull(), "CITY"] = df_pochta.loc[df_pochta["CITY"].isnull(), "AUTONOM"]
df_pochta.loc[df_pochta["REGION"].isnull(), "REGION"] = df_pochta.loc[df_pochta["REGION"].isnull(), "AUTONOM"]
df_pochta.loc[df_pochta["CITY_1"].isnull(), "CITY_1"] = df_pochta.loc[df_pochta["CITY_1"].isnull(), "CITY"]

df_pochta = df_pochta[["REGION", "CITY", "CITY_1"]]
df_pochta.head()
# Out:
#         REGION    CITY  CITY_1
# INDEX
# 101000  МОСКВА  МОСКВА  МОСКВА
# 101300  МОСКВА  МОСКВА  МОСКВА
# 101700  МОСКВА  МОСКВА  МОСКВА
# 101749  МОСКВА  МОСКВА  МОСКВА
# 101751  МОСКВА  МОСКВА  МОСКВА

# %%
region_uniq = {i: translit_region_or_city(i) for i in df_pochta["REGION"].unique()}
cities_uniq = {i: translit_region_or_city(i) for i in df_pochta["CITY"].unique()}
cities_small_uniq = {i: translit_region_or_city(i) for i in df_pochta["CITY_1"].unique()}

# %%
df_pochta["REGION"] = df_pochta["REGION"].map(lambda x: region_uniq[x])
df_pochta["CITY"] = df_pochta["CITY"].map(lambda x: cities_uniq[x])
df_pochta["CITY_1"] = df_pochta["CITY_1"].map(lambda x: cities_small_uniq[x])

df_pochta.loc[188660:188665]
# Out:
#                     REGION              CITY            CITY_1
# INDEX
# 188660  LENINGRADSKAJA OBL             BUGRY             BUGRY
# 188661  LENINGRADSKAJA OBL  NOVOE DEVJATKINO  NOVOE DEVJATKINO
# 188662  LENINGRADSKAJA OBL            MURINO            MURINO
# 188663  LENINGRADSKAJA OBL      KUZMOLOVSKIJ      KUZMOLOVSKIJ
# 188664  LENINGRADSKAJA OBL           TOKSOVO           TOKSOVO
# 188665  LENINGRADSKAJA OBL            OSELKI            OSELKI

# %%
def correct_names(city):
    city = re.sub('\bNV\b', 'NOVO', city, flags=re.U)
    
    if city in {
        'ADYGEY',
        'RESP ADIGEYA',
        'ADYIGEYA',
        'ADIGEYA',
        'ADYGEJA',
        'ADYGEYA RESP'
    }:
        city = 'ADYGEJA'

    elif city in {
        'ATHENS',
        'ATIENS CENTER',
        'ATIENS REGION'
    }:
        city = 'ATHENS'

    elif city in {
        'AKSAI',
        'AKSAY',
        'AKSAIY',
        'AKSAIY S',
    }:
        city = 'AKSAJ'

    elif city in {
        'ALMETEVSK',
        'ALMETYEVSK'
    }:
        city = 'ALMETYEVSK'

    elif city in {
        'ANTALIA',
        'ANTALYA'
    }:
        city = 'ANTALJA'

    elif city in {
        'ANGARSK',
        'MITYSHCHY'
    }:
        city = 'ANGARSK'

    elif city in {
        'ARHANGEL SK',
        'ARHANGELSK',
        'ARKHANGELSK'
    }:
        city = 'ARKHANGELSK'

    elif city in {
        'ARCHANGELSKOE',
        'ARKHANGELSKOE'
    }:
        city = 'ARKHANGELSKOE'
        
    elif city in {
        'AHTIR',
        'AHTYRSKI',
        'AKHATYRSKIY',
        'AKHTYRSKIY'
    }:
        city = 'AKHTYRSKIJ'

    elif city in {
        'ASTRAHAN',
        'ASTRAKHAN'
    }:
        city = 'ASTRAKHAN'

    elif city in {
        'ATEPTSEVO',
        'ATEPTSEVO VIL'
    }:
        city = 'ATEPTSEVO'

    elif city in {
        'AVSIUNINO',
        'AVSJUNINO',
        'AVSYUNINO',
        'AVSYUNINO DO'
    }:
        city = 'AVSJUNINO'
        
    elif city in {
        'AKSAY',
        'AXAY',
        'AKSAJ'
    }:
        city = 'AKSAY'

    elif city in {
        'BALABANOVA',
        'BALABANOVO',
        'BALABANOVO 1'
    }:
        city = 'BALABANOVO'

    elif 'BALASHIKHA' in city:
        city = 'BALASHIKHA'
    elif city in {
        'BALAKHNA',
        'BALASHIHA',
        'BALASHIKHA',
        'BALASHICHA',
        'BALASHIKA'
    }:
        city = 'BALASHIKHA'

    elif city in {
        'BARNAU',
        'BARNAUL'
    }:
        city = 'BARNAUL'

    elif city in {
        'BARVIHA',
        'BARVIKHA',
        'BARVIKHA D'
    }:
        city = 'BARVIKHA'

    # Пробел важен
    elif 'BELGOROD ' in city:
        city = 'BELGOROD'
        
    elif city in {
        'BELGRAD',
        'BEOGRAD'
    }:
        city = 'BEOGRAD'

    elif city in {
        'FAUSTOVO',
        'BELOOZERSKIY',
        'BELOOZESKIJ'
    }:
        city = 'BELOOZERSKIJ'

    elif city in {
        'BYKOVO',
        'BYKOVO P',
        'BYKOVO RAMENS',
        'BYKOVO RP',
        'BIKOVO'
    }:
        city = 'BYKOVO'

    elif city in {
        'BRONNICE',
        'BRONNICY',
        'BRONNITSI',
        'BRONNITSY'
    }:
        city = 'BRONNITSY'

    elif city in {
        'CHEBOKSARY',
        'CHEBOKSARI',
        'CHEBOKSARYI'
    }:
        city = 'CHEBOKSARY'

    elif city in {
        'CHEREPOVEC',
        'CHEREPOVETS'
    }:
        city = 'CHEREPOVETS'

    elif city in {
        'CHELJABINSK',
        'CHELYABINSK',
        'CHELIABINSK',
        'CHELYABINSK R',
        'CHELYAINSK',
        'CHEKYABINSK',
        'HANTE MANSIIS'
    }:
        city = 'CHELJABINSK'

    elif city in {
        'CHECHOV',
        'CHEKHOV',
        'CHEHOV'
    }:
        city = 'CHEKHOV'

    elif city in {
        'DOLGOPRUDNIY',
        'DOLGOPRUDNYJ',
        'DOLGOPRUDNYY',
        'DOLGOPRUDNII',
        'DOLGOPA'
    }:
        city = 'DOLGOPRUDNYJ'

    elif city in {
        'DZERZHINSKIY',
        'DZERZHINSK'
    }:
        city = 'DZERZHINSKIJ'

    elif city in {
        'ELEKTROSTAL',
        'ELEKTROSTALE'
    }:
        city = 'ELEKTROSTAL'

    elif city in {
        'IRKUTS',
        'IRKUTSK'
    }:
        city = 'IRKUTSK'

    elif city in {
        'ILINSKIY',
        'ILYINSKIY'
    }:
        city = 'ILYINSKIJ'

    elif city in {
        'ISTRINSKII R',
        'LESHKOVO'
    }:
        city = 'LESHKOVO'

    elif city in {
        'FRJAZINO',
        'FRYAZINO'
    }:
        city = 'FRJAZINO'

    elif city in {
        'KAZAN',
        'KAZANE',
        'KAZANC',
        'GOTOD KAZAN',
        'GOROD KAZAN'
    }:
        city = 'KAZAN'

    elif city in {
        'KEMERV',
        'KEMEROVO'
    }:
        city = 'KEMEROVO'

    elif city in {
        'KHABAROVSK',
        'HABAROVSK'
    }:
        city = 'KHABAROVSK'

    # Пробел важен
    elif 'KHIMKI ' in city or city in {
        'KHIMKI',
        'HIMKI',
        'KHIMKI MKR P',
        'KHIMKINSKIY R',
        'KHIMKM'
    }:
        city = 'KHIMKI'

    elif city in {
        'KRASNOJARSK',
        'KRASNOYARSK'
    }:
        city = 'KRASNOJARSK'

    elif city in {
        'KUDROVO',
        'KUDROVO D'
    }:
        city = 'KUDROVO'

    elif city in {
        'KOTELNIKI',
        'KOTELNIKY'
    }:
        city = 'KOTELNIKI'

    elif city in {
        'KOROLEV',
        'KOROLYEV',
        'KOROLEV MKR',
        'KOROLEV MKR Y',
        'KOROLEV POS P',
        'KOROLEVA',
        'KOROLV'
    }:
        city = 'KOROLEV'

    elif city in {
        'LENINGR OBL',
        'LENINGRAD OB',
        'LENINGRAD OBL',
        'LENINGRAD REG',
        'LENINGRADSK O',
        'LENINGRADSKA',
        'LENINGRADSKAY',
        'LENINGRADSKII',
        'LEN OB MIS',
        'LEN OBLAST',
        'L O'
    }:
        city = 'LENINGRADSKAJA OBL'

    elif city in {
        'LIPECK',
        'LIPETSK'
    }:
        city = 'LIPETSK'

    elif city in {
        'LYUBERCY',
        'LYUBERTSY',
        'LYUBERTSI',
        'LYUBERCE',
        'LUBERTSY',
        'LUBERCY',
        'LYUBERCI'
    }:
        city = 'LJUBERTSY'

    elif city in {
        'MALAHOVKA',
        'MALAKHOVKA',
        'MALAKHOVKA P',
    }:
        city = 'MALAKHOVKA'

    elif 'MOSKVA' in city:
        city = 'MOSKVA'
    elif city in {
        'MSK',
        'MOSKOW',
        'MOSCOW',
        'MOSKOW',
        'MOSKWA',
        'MOSOCW',
        'MOSKV',
        'MOSKVA',
        'MOSKVE',
        'MOSKVY',
        'MOSVA',
        '77 MOSCOW',
        'MOSCVA',
        'MOSCOW POSEL',
        'MOSCOW POS',
        'ALTUFEVO',
        'ALTUFIEVO'
        # 'KOMMUNARKA'
        # 'LIPICY'
    }:
        city = 'MOSKVA'

    elif city in {
        'MO',
        'MOSCOW OBL',
        'MOSCOW OBLAST',
        'MOSCOW REG',
        'MOSCOW REGIO',
        'MOSCOW REGION',
        'MOSKOVKAYA OB',
        'MOSKOVSK OBL',
        'MOSKOVSKAYA',
        'MOSKOVSKAYA O',
        'MOSKOVSKAYA R',
        'MOSCOWSKAYA O',
        'MOSKOW REGION',
        'MOS OBL',
        'MOS REGION',
        'MOSKOVSKIIY R',
        'MOSOBL',
        'MOSKOVSKIY RE',
        'MOSKOWSKAYA O',
        'MO AEROPORT'
    }:
        city = 'MOSKOVSKAJA OBL'

    elif city in {
        'MOSKOVSKII',
        'MOSKOVSKIY',
        'MOSKOVSKIY P',
        'MOSKOVSKY',
        'MOSKOVSKYI'
    }:
        city = 'MOSKOVSKIJ'

    elif city in {
        'MOSREN',
        'MOSRENTGEN'
    }:
        city = 'MOSRENTGEN'

    elif city in {
        'MOZHAISK',
        'MOZHAJSK',
        'MOZHAYSK',
        'MOZHAYSKIY R'
    }:
        city = 'MOZHAJSK'

    elif city in {
        'MYTISCHI',
        'MYTISCHY',
        'MYTISHCHI',
        'MYTISHHI',
        'MYTISHI',
        'MYTICSHI',
        'MYTISHY',
        'METISHI',
        'MYTISHCHI'
    }:
        city = 'MYTISHCHI'

    elif city in {
        'NAB CHELNY',
        'NABEREZHNYE C',
        'NABEREZHNYYE',
        'NABER CHELNY',
        'NABCHE',
        'NABEREZH CHEL',
        'NABEREZHNIYE',
        'NABEREZHNUE C',
        'NABEREZHNYIE'
    }:
        city = 'NABEREZHNYE CHELNY'

    elif city in {
        'NAHABINO',
        'NAKHABINO'
    }:
        city = 'NAKHABINO'

    elif city in {
        'N NOVGOROD',
        'NIGNIY NOVGOR',
        'NIJNIY NOVGOR',
        'NIZH NOVGOROD',
        'NIZHNIY NOV',
        'NIZHNIY NOVG',
        'NIZHNIY NOVGO',
        'NIZHNY NOVGOR',
        'NIZJNIY NOVGO',
        'NIZHNIJ NOVGO',
        'NIGHNIY NOVGO',
        'NIJNII NOVGOR',
        'NIZHNII NOVG',
        'NIZHNII NOVGO',
        'NIZHNIIY NOVG',
        'NIZHNIY NO',
        'NIZNIY NOVGOR',
        'NNOVGOROD',
        'NIGNIY NOV',
        'NIZHNIYJ NOVG',
        'NOZHNIY NOVGO',
        'NUGNIY NOVGOR'
    }:
        city = 'NIZHNIY NOVGOROD'
        
    elif city in {
        'NIZVRT',
        'N VARTOVSK',
        'NIZHNEVARTOVSK'
    }:
        city = 'NIZHNEVARTOVSK'

    elif city in {
        'NOVAYA ADYGEY',
        'NOVAYA ADYGEYA',
        'NOV ADYGEYA',
        'AUL NOVAJA AD',
        'AUL NOVAYA AD'
    }:
        city = 'NOVAJA ADYGEJA'

    elif city in {
        'NOVOKUIBESHEV',
        'NOVOKUIBYSHEV',
        'NOVOKUYBYSHEV',
    }:
        city = 'NOVOKUYBYSHEV'

    elif city in {
        'NOVOROSSIISK',
        'NOVOROSSIIYSK',
        'NOVOROSSIJSK',
        'NOVOROSSIYSK',
        'NOVOROSIYSK',
        'NOVOROSSISK',
        'NOVOROSSYSK'
    }:
        city = 'NOVOROSSIYSK'

    elif city in {
        'NVSIBR',
        'NOVOSIBIRSK',
        'NOOSIBIRSK',
        'NOVOSIBISRK'
    }:
        city = 'NOVOSIBIRSK'

    elif city in {
        'ODINCOVO',
        'ODINTSOVO',
        'ODINTSOVSKIY',
        'MO ODINCOVO'
    }:
        city = 'ODINTSOVO'

    elif city in {
        'OREL',
        'ORYEL',
        'ORYOL',
        'LIVNY'
    }:
        city = 'OREL'

    elif city in {
        'OREHOVO ZUEVO',
        'OREKHOVO ZUEV'
    }:
        city = 'OREKHOVO ZUEVO'

    elif city in {
        'PERM',
        'PERME'
    }:
        city = 'PERM'

    elif city in {
        'PETERGOF',
        'PETRODVORETS'
    }:
        city = 'PETERGOF'

    elif city in {
        'PETROZAVODS',
        'PETROZAVODSK'
    }:
        city = 'PETROZAVODSK'

    elif city in {
        'PERESLAVL',
        'PERESLAVL ZAL'
    }:
        city = 'PERESLAVL'
        
    elif city in {
        'AGROLES',
        'PLAVSK'
    }:
        city = 'PLAVSK'

    elif city in {
        'PODLSK',
        'PODOLESK',
        'PODOLSK'
    }:
        city = 'PODOLSK'

    elif city in {
        'RYAZAN',
        'RYAZANE'
    }:
        city = 'RJAZAN'

    elif city in {
        'ROSTOV NA DON',
        'ROSTOV ON DON',
        'ROSTOV N',
        'ROSTOV NA',
        'ROSTOV NA DO',
        'ROSTOV ND',
        'ROSTOV DON'
    }:
        city = 'ROSTOV NA DONU'

    elif city in {
        'C PETERBURG',
        'PETERBURG',
        'S PETER',
        'S PETERBURG',
        'S PETERSBURG',
        'SAINT PETERBU',
        'SAINT PETERSB',
        'SAN PETERBURG',
        'SANK PETERBUR',
        'SANKT PERERBU',
        'SANKT PETE',
        'SANKT PETEBUR',
        'SANKT PETER',
        'SANKT PETERBO',
        'SANKT PETERBU',
        'SANKT PETERS',
        'SANKT PETERSB',
        'SANKT PETERUB',
        'SANKT PRTRRBU',
        'SANKT PTERBUR',
        'SANQT PETERBU',
        'SANT PETERBUR',
        'SNPETERBURG',
        'SPETERBURG',
        'SPETERSBURG',
        'SPETERSRURG',
        'SPB',
        'SPB POS SHUSH',
        'ST PERESBURG',
        'ST PETER',
        'ST PETERB',
        'ST PETERBUR',
        'ST PETERBURG',
        'ST PETERSBUR',
        'ST PETERSBURG',
        'ST PETERURG',
        'ST PETESBURG',
        'ST PETRESBURG',
        'ST PETRSBURG',
        'STPETERBURG',
        'STPETERSBURG',
        'CPB',
        'STPETE',
        'A KUZNETSOV'
        # 'KOLPINO'
        # 'KRASNOE SELO'
        # 'KRONSHTADT'
    }:
        city = 'ST PETERBURG'

    elif city in {
        'SERPUHOV',
        'SERPUKHOV'
    }:
        city = 'SERPUKHOV'

    elif 'SAMARA ' in city:
        city = 'SAMARA'

    elif city in {
        'RAMENSKOE',
        'RAMENSKOYE',
        'RAMENSKIY M',
        'FABRICHNAJA',
        'FABRICHNAYA'
    }:
        city = 'RAMENSKOE'
        
    elif city in {
        'UDELNAYA',
        'RAMENSKII'
    }:
        city = 'UDELNAJA'

    elif city in {
        'SESTRORECK',
        'SESTRORETSK'
    }:
        city = 'SESTRORETSK'

    elif city in {
        'SCHELKOVO',
        'SHCHEGLOVO',
        'SHELKOVO',
        'SHCHELKOVO 3',
        'SHCHELKOVO'
    }:
        city = 'SHCHELKOVO'

    elif city in {
        'SCHERBINKA',
        'SHCHERBINKA'
    }:
        city = 'SHCHERBINKA'

    elif 'SOCHI ' in city or city in {
        'ADLER',
        'ADLE',
        'ADLER POS K',
        'SOCHI',
        'SOCHY'
    }:
        city = 'SOCHI'

    elif city in {
        'SOLNETCHNOGOR',
        'SOLNECHNOGORS'
    }:
        city = 'SOLNECHNOGORSK'

    elif city in {
        'STAREI OSKOL',
        'STARYY OSKOL',
        'STARIY OSKOL',
        'OSKOL',
        'S OSKOL'
    }:
        city = 'STARYJ OSKOL'

    elif city in {
        'SYIKTYIVKAR',
        'SYKTYVKAR'
    }:
        city = 'SYKTYVKAR'

    elif city in {
        'TOGLIATTI',
        'TOLYATTI',
        'TOLJATTI',
        'TOLEYATTI'
    }:
        city = 'TOLJATTI'

    elif city in {
        'TROICK',
        'TROITSK'
    }:
        city = 'TROITSK'

    elif city in {
        'TEMRJUK',
        'TEMRYUK',
    }:
        city = 'TEMRJUK'

    elif city in {
        'TYUMEN',
        'TUMEN',
        'TJUMEN',
    }:
        city = 'TJUMEN'

    elif city in {
        'VEL NOVGOROD',
        'VELIKIE LUKI',
        'VELIKIY NOVGO',
        'VELIKY NOVGOR',
        'VELIKIIY NOVG',
        'VELIKIJ NOVGO',
        'VELIKIY NOV',
        'VELIKIY NOVGO',
        'VELIKY NOVGOR',
        'V NOVGOROD',
        'NOVGOROD VEL',
        'NOVGOROD'
    }:
        city = 'VELIKIJ NOVGOROD'

    elif city in {
        'VORONEJ',
        'VORONEZH',
        'VORONZ',
        'VORONEG'
    }:
        city = 'VORONEZH'

    elif city in {
        'VSEVOLOJSK',
        'VSEVOLOZHSK'
    }:
        city = 'VSEVOLOZHSK'

    elif city in {
        'YAROSLAVLE',
        'YAROSLAVL'
    }:
        city = 'JAROSLAVL'

    elif city in {
        'YEKATR',
        'YEKATERINBURG',
        'EKA BURG',
        'EKATERINB',
        'EKATERINBOURG',
        'EKATERINBUR',
        'EKATERINBURTG',
        'EKATERINBYRG',
        'EKATERNIBURG',
        'EKATERUBBYRG',
        'EKATR',
        'EKETERINBURG',
        'EKT',
        'ETATERINBURG'
    }:
        city = 'EKATERINBURG'

    elif city in {
        'ZELENOGRAD KR',
        'ZELENOGRAD'
    }:
        city = 'ZELENOGRAD'

    elif city in {
        'ZHELEZN',
        'ZHELEZN NII',
        'ZHELEZNOD',
        'ZHELEZNOD II',
        'ZHELEZNODOR',
        'ZHELEZNODORO',
        'ZHELEZNODOROD',
        'ZHELEZNODOROZ',
    }:
        city = 'ZHELEZNODOROZHNYJ'

    elif city in {
        'ZHUKOVSKIY',
        'ZHUKOVSKY',
        'ZHUKOVSKII',
        'ZHUKOVSKIIY',
        'ZHUKOVSKIJ',
        'ZHUKOSKIY'
    }:
        city = 'ZHUKOVSKIJ'

    elif city in {
        'NE ZADAN',
        'RUSSIA',
        'RUSSIAN FEDER',
        'RF',
        'UNKNOWN'
    }:
        city = ''

    return city

# %%
def default_modify_city(c):
    c = re.sub(r"'", '', c, flags=re.U)
    c = re.sub(r"[^\w\d\s]", " ", c, flags=re.U)
    c = re.sub(r"\d+", " ", c, flags=re.U)
    c = re.sub(r"\s+", " ", c, flags=re.U)
    c = c.strip().upper()
    return c


def modify_city(c):
    try:
        c = default_modify_city(c)
        
        c = re.sub(r'^M O ', '', c, flags=re.U)
        c = re.sub(r'^R N ', '', c, flags=re.U)
        c = re.sub(r' R N$', '', c, flags=re.U)
        
        # Удаляем город
        c = re.sub(r"\bG\b", "", c, flags=re.U)
        
        # Удаляем деревня
        c = re.sub(r"\bD\b", "", c, flags=re.U)
        
        # Удаляем поселок
        c = re.sub(r"\bP\b", "", c, flags=re.U)
        
        # Удаляем городской округ
        c = re.sub(r"\bGO\b", "", c, flags=re.U)
        
        c = correct_names(c)
        
        c_splited = c.split()
        c_splited = filter(
            lambda x: x not in {
                'DIS', 'DER', 'OKR', 'D', 'G', 'VILL', 'RESP', 'MKAD',
                'KM', 'MO', 'POSELOK', 'POS', 'S', 'SELO', 'PGT'
            }, c_splited)
        c_splited = map(
            lambda x: x if x not in {'REGION', 'REGIO', 'REGI', 'REG', 'RE'}\
                else 'OBL', c_splited
        )
        c = ' '.join(c_splited)
    except TypeError:
        c = ''
    return c

df["city"] = df["city"].map(modify_city)
df.loc[df["city"].isnull(), "city"] = ""

# %%
class Tie(object):
    def __init__(self, is_final=False, depth=0, threshold=1.6, reverse=False):
        self.is_final = is_final
        self.threshold = threshold
        self.reverse = reverse

        self.d = dict()
        self.depth = depth
        self.cache = dict()

        self.complex_pairs = {'ZH', 'KH', 'TS', 'CH', 'SH', 'HC', 'JU', 'JA'}
        self.substitutions = [
            ('CSH', 'SHCH'),
            ('SCH', 'SCHC'),
            ('SHH', 'SHCH'),
            ('SH', 'SHCH'),
            ('CH', 'KH'),
            ('IA', 'JA'),
            ('II', 'YJ'),
            ('IU', 'JU'),
            ('YU', 'JU'),
            ('IY', 'YJ'),
            ('IY', 'JA'),
            ('YA', 'JA'),
            ('YU', 'JU'),
            ('LI', 'LYI'),
            ('NV', 'NOVO'),
            ('YE', 'E'),
            ('YI', 'YJ'),
            ('YY', 'YJ'),
            ('YO', 'E'),
            ('ZH', 'Z'),
            ('A', 'O'),
            ('C', 'TS'),
            ('B', 'V'),
            ('E', 'I'),
            ('G', 'ZH'),
            ('H', 'KH'),
            ('I', 'E'),
            ('I', 'J'),
            ('I', 'Y'),
            ('J', 'ZH'),
            ('K', 'KH'),
            ('Y', 'I'),
            ('Y', 'U'),
            ('Y', 'J'),
            ('X', 'KH'),
            ('X', 'KS')
        ]

        if reverse:
            self.complex_pairs = set([s[::-1] for s in self.complex_pairs])
            self.substitutions = [(a[::-1], b[::-1]) for a, b in self.substitutions]

    def add(self, word):
        if self.reverse:
            word = word[::-1]

        curr = self
        for ch in word:
            if ch not in curr.d:
                curr.d[ch] = Tie(depth=curr.depth + 1, reverse=self.reverse)
            curr = curr.d[ch]
        curr.is_final = True

    def __contains__(self, word):
        curr = self
        for ch in word:
            if ch in curr.d:
                curr = curr.d[ch]
            else:
                return False
        return curr.is_final

    def find_words_with_prefix(self, prefix):
        items = []

        prefix_i = 0
        curr = self

        for ch in prefix:
            if ch in curr.d:
                prefix_i += 1
                curr = curr.d[ch]
            else:
                break

        if prefix_i == len(prefix):
            for ch in curr.d.iterkeys():
                found = curr.d[ch].find_words_with_prefix('')
                found = map(lambda x: ch + x, found)
                items.extend(found)

            if curr.is_final:
                items.append('')

            items = map(lambda x: prefix + x, items)

        items = sorted(items, key=lambda x: (len(x), x))
        return items

    def find_prefix(self, word):        
        prefix_i = 0

        curr = self
        for ch in word:
            if ch in curr.d:
                prefix_i += 1
                curr = curr.d[ch]
            else:
                break

        return word[:prefix_i]

    def find(self, word):
        if not self.reverse:
            word = correct_names(word)
        else:
            word = word[::-1]

        if word not in self.cache:
            result = self.find_process(word)
            result = sorted(
                result,
                key=lambda x: (x[1], abs(len(x[0]) - len(word)))
            )
            result = result[:5]
            if self.reverse:
                result = [(r[::-1], s) for r, s in result]

            self.cache[word] = result
        else:
            result = self.cache[word]
        return result

    def check_substitution(self, word, a, b):
        return word[:len(a)] == a and self.find_prefix(b) == b

    def get_node_for_path(self, path):
        curr = self
        for ch in path:
            curr = curr.d[ch]
        return curr

    def find_process(self, word, mistakes=0):
        penalty = 0.3 * mistakes
        entries = []

        if mistakes > self.threshold:
            pass
        elif len(word) > 0:
            if 0.75 * (self.depth + len(word)) < self.depth and self.is_final:
                entries.append(('', mistakes + 0.2 + \
                                float(self.depth + len(word)) / self.depth))

            for a, b in self.substitutions:
                if self.check_substitution(word, a, b):
                    curr = self.get_node_for_path(b)
                    found = curr.find_process(word[len(a):], mistakes + 0.1 + penalty)
                    found = map(lambda x: (b + x[0], x[1]), found)
                    entries.extend(found)

            ch_ = word[0]
            for ch in self.d.iterkeys():
                if ch == ch_:
                    # правильная буква
                    found = self.d[ch].find_process(word[1:], mistakes)
                    found = map(lambda x: (ch + x[0], x[1]), found)
                    entries.extend(found)
                else:
                    # заменяем букву на текущую
                    found = self.d[ch].find_process(word[1:], mistakes + 1 + penalty)
                    found = map(lambda x: (ch + x[0], x[1]), found)
                    entries.extend(found)
                    # текущая буква была пропущена
                    p = 0.1 if ch + word[0] in self.complex_pairs else 0.5
                    if ch_ == ' ':
                        p = 0.2 if len(self.d) > 1 else 0.1
                    found = self.d[ch].find_process(word, mistakes + p + penalty)
                    found = map(lambda x: (ch + x[0], x[1]), found)
                    entries.extend(found)

            # буква слова -- опечатка
            found = self.find_process(word[1:], mistakes + 1 + penalty)
            entries.extend(found)

            found = dict()
            for entry, rank in entries:
                if rank > self.threshold:
                    continue
                if entry not in found:
                    found[entry] = np.inf
                found[entry] = min(found[entry], rank)
            entries = list(found.iteritems())
        else:
            # буквы кончились
            if self.is_final:
                entries.append(('', mistakes))

            # не хватает букв в конце
            if len(self.d) > 1:
                for ch in self.d.iterkeys():
                    found = self.d[ch].find_process('', mistakes + 0.2 + penalty)
                    found = map(lambda x: (ch + x[0], x[1]), found)
                    entries.extend(found)
            elif len(self.d) == 1:
                ch = self.d.keys()[0]
                found = self.d[ch].find_process(word[1:], mistakes + 0.1 + penalty)
                found = map(lambda x: (ch + x[0], x[1]), found)
                entries.extend(found)

        return entries

# %%
spellchecker = Tie()

for elem in region_uniq.itervalues():
    spellchecker.add(elem)
    
for elem in cities_uniq.itervalues():
    spellchecker.add(elem)
    
for elem in cities_small_uniq.itervalues():
    spellchecker.add(elem)
    
for elem in spellchekers_dict:
    spellchecker.add(elem)
    
spellchecker.find(u'MOSKVA')
# Out:
# [(u'MOSKVA', 0),
#  (u'MOSKOVO', 0.75),
#  (u'MOSKOVKA', 1.15),
#  (u'MOSKVINA', 1.15),
#  (u'MOSHKOVO', 1.595)]

# %%
spellchecker_reverse = Tie(reverse=True)

for elem in region_uniq.itervalues():
    spellchecker_reverse.add(elem)
    
for elem in cities_uniq.itervalues():
    spellchecker_reverse.add(elem)
    
for elem in cities_small_uniq.itervalues():
    spellchecker_reverse.add(elem)
    
for elem in spellchekers_dict:
    spellchecker_reverse.add(elem)
    
spellchecker_reverse.find(u'MOSKVA')
# Out:
# [('MOSKVA', 0),
#  ('MOSKOVO', 0.63),
#  ('MOSHKOVO', 0.919),
#  (u'MOSKVINA', 1.15),
#  (u'MOSKOVKA', 1.15)]

# %%
processed_adresses = dict()

def proccess_index_case(index):
    try:
        index = int(index)        
        r_value = df_pochta.loc[index, "CITY_1"]
        return r_value
    except KeyError:
        return None


def find_tuple_in_index(city):
    if city in found_by_index:
        counter = found_by_index[city]
        return counter.most_common(1)[0][0]
    else:
        return None


def process_common_case(city):
    city = spellchecker.find(city)
    return city[0][0] if len(city) > 0 else None


def process_reversed_case(city):
    # print 'Z', city
    city_ = city
    city = spellchecker_reverse.find_words_with_prefix(city[::-1])
    city = sorted(map(lambda x: x[::-1], city), key=lambda x: (len(x), x))
    # print 'A', city
    if len(city) == 0:
        city = spellchecker_reverse.find(city_)
        city = map(itemgetter(0), city)
        # print 'B', city
    return city if len(city) > 0 else None


def process_russian_case(address):
    address = re.sub(r'"', '', address, flags=re.U)
    city = address.split(',')[0]
    city = translit_region_or_city(city)
    return city


def process_address(address, city_def, log=False):
    if address in processed_adresses:
        return processed_adresses[address]
    
    try:
        city_final = None
        city_variants = None
        
        is_russian = re.search(ur'[а-яА-Я]', address, flags=re.U) is not None
        if city_final is None and is_russian:
            city_final = process_russian_case(address)
        # print 0, city_final
        
        found_city = re.findall(r'g\.\s*([^\\,]+)', address, flags=re.U)
        if city_final is None and len(found_city) > 0:
            city = found_city[0]
            city = default_modify_city(city)
            city_final = process_common_case(city)
        # print 1, city_final
        
        prefix_str = re.search(r'^[\w-]+\s*,', address, flags=re.U)
        if city_final is None and prefix_str is not None:
            city = prefix_str.group(0)[:-1]
            city = default_modify_city(city)
            # print 1.5, city
            if len(city) > 4:
                city_variants = process_reversed_case(city)
    
        index = re.search(r'[1-9]\d{5}', address, flags=re.U)
        if city_final is None and index is not None:
            index = index.group(0)
            city_final = proccess_index_case(index)
            if city_variants is not None and city_final not in city_variants:
                city_final = city_variants[0]
        # print 2, city_final

        city = re.findall(r'\\([^\\]+)', address, flags=re.U)
        if city_final is None and len(city) > 0:
            city_final = process_common_case(city[0])
        # print 3, city_final
    except TypeError:
        city_final = None
        
    if city_final is None:
        city_final = process_common_case(city_def)
    
    city_final = city_final if city_final is not None else ''
    processed_adresses[address] = city_final
    
    if log:
        print u"'{}'\t'{}'\t->\t'{}'".format(address, city_def, city_final)
    return city_final

# %%
def address_has_index(address):
    try:
        return re.search(r'[1-9]\d{5}', address, flags=re.U) is not None
    except TypeError:
        return False

# %%
df["city_"] = ''

# %%
mask_russian = df["country"] == "RUS"
df.loc[np.logical_not(mask_russian), "city_"] = df.loc[np.logical_not(mask_russian), "city"]

# %%
cities_uniq_spellcheker = sorted(df.loc[mask_russian, "city"].unique())

cities_not_found_list = set(region_uniq.itervalues())
cities_correct_list = set()

for city in cities_uniq_spellcheker:
    if city == '':
        continue
        
    if city in spellchecker:
        cities_correct_list.add(city)
        continue

    city_m = spellchecker.find(city)
    if len(city_m) > 0:
        city_m, city_w = city_m[0]
        print "'{}' -> '{}' [{}]".format(city, city_m, city_w)
        cities_correct_list.add(city_m)
    else:
        cities_not_found_list.add(city)
        print "'{}' not found".format(city)
        
cities_not_found_list.add('')
cities_not_found_list.discard('MOSKVA')
cities_not_found_list.discard('ST PETERBURG')
cities_not_found_list.discard('MOSKOVSKAJA OBL')
cities_not_found_list.discard('LENINGRADSKAJA OBL')
cities_not_found_list.discard('SEVASTOPOL')
# Out:
# 'A M' -> 'AIM' [1.0]
# 'A VO' -> 'AROVO' [1.26]
# 'ABINSK OBL' not found
# 'ABRAMCEVO' -> 'ABRAMTSEVO' [0.1]
# 'ABRAU DYURSO' -> 'ABRAU DJURSO' [0.1]
# 'AD MOS' not found
# 'ADYGEYA' -> 'ADYGEJA' [0.1]
# 'ADYGEYSK' -> 'ADYGEJSK' [0.1]
# 'AEROPORT DOMO' not found
# 'AEROPORT KRAS' not found
# 'AEROPORT VORO' not found
# 'AEROPORTA DOM' not found
# 'AFIPSKIY' -> 'AFIPSKIJ' [0.1]
# 'AFON' -> 'AFONINO' [0.568]
# 'AGAFONIKHA' not found
# 'AGALATOVSKOE' not found
# 'AGOY' -> 'AGOJ' [0.1]
# 'AGROGOROD' -> 'AGROGORODOK' [0.23]
# 'AHTIR' -> 'AKHTYRSKIJ' [0]
# 'AHTUBINSK' -> 'AKHTUBINSK' [0.1]
# 'AHTYRSKI' -> 'AKHTYRSKIJ' [0]
# 'AISHA' -> 'AJSHA' [0.1]
# 'AKHLEBINO' -> 'KHLEBINO' [1.0]
# 'AKHTANIZOVSKA' -> 'AKHTANIZOVSKAJA' [0.23]
# 'AKSAJ OBL' not found
# 'AKSAY' -> 'AKSAJ' [0]
# 'AKSENO BUTYRS' not found
# 'AKYAR' -> 'AKJAR' [0.1]
# 'ALABINO' -> 'KALABINO' [0.5]
# 'ALABUSHEVO SO' -> 'ALABUSHEVO' [1.5]
# 'ALEKHOVSHCHIN' -> 'ALEKHOVSHCHINA' [0.1]
# 'ALEKSAND' -> 'ALEKSANDROV' [0.629]
# 'ALEKSANDRIYSK' -> 'ALEKSANDRIJSKIJ' [0.529]
# 'ALEKSANDRO NE' -> 'ALEKSANDRO NEVSKIJ' [1.03431]
# 'ALEKSEYEVKA' -> 'ALEKSEEVKA' [0.1]
# 'ALEKTROUGLI' -> 'ELEKTROUGLI' [1.0]
# 'ALENINO' -> 'OLENINO' [0.1]
# 'ALESHNYA' -> 'ALESHNJA' [0.1]
# 'ALEXANDROV' -> 'ALEKSANDROV' [0.1]
# 'ALEXIN' -> 'ALEKSIN' [0.1]
# 'ALEYSK' -> 'ALEJSK' [0.1]
# 'ALTAIYSKIIY R' not found
# 'ALTAYSKOE' -> 'ALTAJSKOE' [0.1]
# 'ALTUFYEVSKOE' not found
# 'AMEREVO' -> 'MEREVO' [1.0]
# 'ANAPA ST ANA' not found
# 'ANAPA SUKK' not found
# 'ANAPSKAYA' -> 'ANAPSKAJA' [0.1]
# 'ANAPSKAYA ST' not found
# 'ANAPSKIIY OBL' not found
# 'ANAPSKIY GOS' not found
# 'ANASTASIEVSKA' -> 'ANASTASIEVSKAJA' [0.23]
# 'ANDREEVKA SOL' not found
# 'ANDREYKOVO' -> 'ANDREJKOVO' [0.1]
# 'ANGRSK' -> 'ANGARSK' [0.5]
# 'ANICHKOVO' not found
# 'ANISKINO' -> 'ANISHINO' [1.0]
# 'ANNENKI' -> 'ANNENKA' [1.0]
# 'ANOSINO' -> 'ANOPINO' [1.0]
# 'ANSUDG' not found
# 'ANZHERO SUDZH' -> 'ANZHERO SUDZHENSK' [0.6187]
# 'APARINKI' -> 'APARINSKIJ' [0.75]
# 'APARNIKY' not found
# 'AREYSKOE' -> 'JARINSKOE' [1.299]
# 'ARGAYASH' -> 'ARGAJASH' [0.1]
# 'ARHANGELSK' -> 'ARKHANGELSK' [0]
# 'ARHIPO OSINOV' not found
# 'ARHIPOVO OSIP' not found
# 'ARHIZ' -> 'ARKHYZ' [0.23]
# 'ARHIZSKOE' not found
# 'ARKHANGELYSK' -> 'ARKHANGELSK' [1.0]
# 'ARKHIPO OSIPO' -> 'ARKHIPO OSIPOVKA' [0.399]
# 'ARKHNG' -> 'ARKHANGEL' [1.075]
# 'ARSENIEV' -> 'ARSENYEV' [0.1]
# 'ARTEMOVSKIY' -> 'ARTEMOVSKIJ' [0.1]
# 'ARTIL' -> 'ERTIL' [1.0]
# 'ARTYBASH' -> 'ARTSYBASHEVO' [1.5975]
# 'ARTYOM' -> 'ARTEM' [0.1]
# 'ARZAMAZ' -> 'ARZAMAS' [1.0]
# 'ASTAKHAN' -> 'ASTRAKHAN' [0.5]
# 'ASTRACHAN' -> 'ASTRAKHAN' [0.1]
# 'ASTRETCOVO' -> 'OSTRETSOVO' [1.13]
# 'ATIUREVSKIIY' not found
# 'ATYASHEVO' -> 'ATJASHEVO' [0.1]
# 'ATYUREVO' -> 'ATJURYEVO' [0.63]
# 'AVDOTINO' -> 'AVDOTYINO' [0.5]
# 'AVTO' -> 'AVDON' [1.5]
# 'AVTODOROGA' not found
# 'AVTOPOLIGON' not found
# 'AVTOZAPRAVOCH' not found
# 'AYA' -> 'AJA' [0.1]
# 'AYKINO' -> 'AJKINO' [0.1]
# 'AZOVSKAYA' -> 'AZOVSKAJA' [0.1]
# 'B KISELENKA' not found
# 'B SAMOVETS' not found
# 'B SCEBRUSYANS' not found
# 'BABYNINSKIY' not found
# 'BAGAEVSKAYA' -> 'BAGAEVSKAJA' [0.1]
# 'BAHCHISARA' -> 'BAKHCHISARAJ' [0.23]
# 'BAHCHISARAJ' -> 'BAKHCHISARAJ' [0.1]
# 'BAHCHISARAY' -> 'BAKHCHISARAJ' [0.23]
# 'BAHTA' -> 'BAKHTA' [0.1]
# 'BAKUNINO' -> 'VAKHONINO' [1.299]
# 'BALABA' -> 'VALAVA' [0.23]
# 'BALABANOVA' -> 'BALABANOVO' [0]
# 'BALAHNA' -> 'BALAKHNA' [0.1]
# 'BALASHIHA' -> 'BALASHIKHA' [0]
# 'BALTIYA' -> 'BALTIKA' [1.0]
# 'BALTIYA AVTOD' not found
# 'BALTIYSK' -> 'BALTIJSK' [0.1]
# 'BAOASHIKHA' -> 'BALASHIKHA' [1.0]
# 'BARABK' -> 'BOROVKI' [0.7187]
# 'BARANC' -> 'BARANTSEVO' [0.6187]
# 'BARANTSEVSKII' not found
# 'BARIBINO' -> 'BARYBINO' [0.1]
# 'BARIYSHEVO' -> 'BADRJASHEVO' [0.75]
# 'BARV KOE' not found
# 'BARYATINO' -> 'BARJATINO' [0.1]
# 'BATAREYNAYA' not found
# 'BATAYS' -> 'BATAJSK' [0.23]
# 'BATAYSK' -> 'BATAJSK' [0.1]
# 'BATETSKIY' -> 'BATETSKIJ' [0.1]
# 'BATOVKA' -> 'BRATOVKA' [0.5]
# 'BAYKALOVO' -> 'BAJKALOVO' [0.1]
# 'BAYKALS' -> 'BAJKALSK' [0.23]
# 'BAYKALSK' -> 'BAJKALSK' [0.1]
# 'BAYKALSKIY TR' not found
# 'BAZARNYE MATA' -> 'BAZARNYE MATAKI' [0.23]
# 'BELAYA BEREZK' -> 'BELAJA BEREZKA' [0.23]
# 'BELAYA GLINA' -> 'BELAJA GLINA' [0.1]
# 'BELAYA KALITV' -> 'BELAJA KALITVA' [0.23]
# 'BELAYA KOLP' -> 'BELAJA KOLP' [0.1]
# 'BELEBEY' -> 'BELEBEJ' [0.1]
# 'BELGORODSK OB' -> 'BELGORODSKAJA OBL' [0.8384]
# 'BELGORODSKAY' -> 'BELGORODSKOE' [1.13]
# 'BELGORODSKAYA' -> 'BELGORODSKAJA OBL' [0.90431]
# 'BELGORODSKIIY' not found
# 'BELGORODSKIY' not found
# 'BELINSKIY' -> 'BELINSKIJ' [0.1]
# 'BELIY YAR' -> 'BELYJ JAR' [0.23]
# 'BELKINO BOROV' not found
# 'BELOGORODSKII' not found
# 'BELOKURIHA' -> 'BELOKURIKHA' [0.1]
# 'BELOOZERSKII' -> 'BELOOZERSKIJ' [0.1]
# 'BELOYARSKIY' -> 'BELOJARSKIJ' [0.23]
# 'BELOYARSKY' -> 'BELOJARSKIJ' [0.399]
# 'BELOZERKI SEL' not found
# 'BELOZERNYY' -> 'BELOZERNYJ' [0.1]
# 'BELOZERSKIY' -> 'BELOOZERSKIJ' [0.75]
# 'BELOZERSKIY V' not found
# 'BELRSK' -> 'BELSK' [1.0]
# 'BELY YAR' -> 'BELYJ JAR' [0.36]
# 'BELYANAYA GOR' -> 'BELJANAJA GORA' [0.399]
# 'BELYANINOVO' -> 'BELJANINOVO' [0.1]
# 'BELYAR' -> 'BILJARSK' [0.7487]
# 'BELYI YAR' -> 'BELYJ JAR' [0.23]
# 'BELYJ YAR' -> 'BELYJ JAR' [0.1]
# 'BELYY' -> 'BELYJ' [0.1]
# 'BELYY YAR' -> 'BELYJ JAR' [0.23]
# 'BERAN' -> 'BEKAN' [1.0]
# 'BERDJUZHE' -> 'BERDJUZHYE' [0.5]
# 'BERDSK TER' not found
# 'BEREG KAMY K' not found
# 'BEREZNYAKI' -> 'BEREZNJAKI' [0.1]
# 'BEREZOVSKIIY' -> 'BEREZOVSKIJ' [1.13]
# 'BEREZOVSKIJJ' -> 'BEREZOVSKIJ' [1.0]
# 'BEREZOVSKIY' -> 'BEREZOVSKIJ' [0.1]
# 'BEREZOVSKIYI' -> 'BEREZOVSKIJ' [1.13]
# 'BEREZOVSKY' -> 'BEREZOVSKIJ' [0.23]
# 'BEREZOVYY' -> 'BEREZOVYJ' [0.1]
# 'BERNGARDOVKA' not found
# 'BERVSK' -> 'BERDSK' [1.0]
# 'BERYEZOVSKIY' -> 'BEREZOVSKIJ' [0.23]
# 'BERZNK' -> 'BEREZNIK' [1.15]
# 'BESEDY' -> 'BESEDINO' [0.399]
# 'BEYSKIY' -> 'BELSKIJ' [1.4]
# 'BEZENCHUKSKIY' not found
# 'BIISK' -> 'BIJSK' [0.1]
# 'BIKLYAN' -> 'BIKLJAN' [0.1]
# 'BILIMBAY' -> 'BILIMBAJ' [0.1]
# 'BIRYUCH' -> 'BIRJUCH' [0.1]
# 'BIRYULINO' not found
# 'BIRYULYA' -> 'BIRJULJA' [0.23]
# 'BIRZHEVOY' not found
# 'BISTROVKA' -> 'BYSTROVKA' [0.1]
# 'BITSA' -> 'BETTA' [1.13]
# 'BIYSK' -> 'BIJSK' [0.1]
# 'BLAGOVECSHENS' -> 'BLAGOVESHCHENSK' [0.23]
# 'BLAGOVESCHENS' -> 'BLAGOVESHCHENSK' [0.23]
# 'BLAGOVESHCHEN' -> 'BLAGOVESHCHENKA' [0.36]
# 'BLAGOVESHENSK' -> 'BLAGOVESHCHENSK' [0.1]
# 'BLORSK' -> 'BORSK' [1.0]
# 'BOBROVSK' -> 'BOBROVSKOE' [0.36]
# 'BODAYBO' -> 'BODAJBO' [0.1]
# 'BOGANDINSKIY' -> 'BOGANDINSKIJ' [0.1]
# 'BOGOLYUBOVO' -> 'BOGOLJUBOVO' [0.1]
# 'BOGORODS' -> 'BOGORODSK' [0.1]
# 'BOKOVAYA' -> 'BOKOVSKAJA' [1.595]
# 'BOL GRYZLOVO' -> 'BOLSHOE GRYZLOVO' [1.0684]
# 'BOLSHAYA IZHO' -> 'BOLSHAJA IZHORA' [0.399]
# 'BOLSHAYA ORLO' -> 'BOLSHAJA ORLOVKA' [0.6187]
# 'BOLSHAYA TARL' not found
# 'BOLSHEBRUSYAN' -> 'BOLSHEBRUSJANSKOE' [0.90431]
# 'BOLSHERECHIE' -> 'BOLSHERECHYE' [0.1]
# 'BOLSHIE KLYUC' -> 'BOLSHIE KLJUCHI' [0.399]
# 'BOLSHIE KOLPA' -> 'BOLSHIE KOLPANY' [0.23]
# 'BOLSHIE VIAZE' -> 'BOLSHIE VJAZEMY' [0.399]
# 'BOLSHIE VYAZE' -> 'BOLSHIE VJAZEMY' [0.399]
# 'BOLSHOE ALEKS' not found
# 'BOLSHOE IGNAT' -> 'BOLSHOE IGNATOVO' [0.399]
# 'BOLSHOE ISAKO' -> 'BOLSHOE ISAKOVO' [0.23]
# 'BOLSHOE KOZIN' -> 'BOLSHOE KOZINO' [0.1]
# 'BOLSHOE POLPI' -> 'BOLSHOE POLPINO' [0.23]
# 'BOLSHOE RUNOV' -> 'BOLSHOE RUNOVO' [0.1]
# 'BOLSHOE SAVIN' -> 'BOLSHOE SAVINO' [0.1]
# 'BOLSHOY ISTOK' -> 'BOLSHOJ ISTOK' [0.1]
# 'BOLSHOY LOG' -> 'BOLSHOJ LOG' [0.1]
# 'BOLSHOYE ISAK' -> 'BOLSHOE ISAKOVO' [0.6187]
# 'BOLTINO' -> 'BOLDINO' [1.0]
# 'BORISOBKA' -> 'BORISOVKA' [0.1]
# 'BORISOGLBEBSK' -> 'BORISOGLEBSK' [1.0]
# 'BORISOGLEBSKA' -> 'BORISOGLEBSKOE' [0.23]
# 'BORISOGLEBSKI' -> 'BORISOGLEBSKIJ' [0.1]
# 'BORISOVA GRIV' -> 'BORISOVA GRIVA' [0.1]
# 'BORODINSKIY' -> 'BORODINSKIJ' [0.1]
# 'BOROVSKIY' -> 'BOROVSKIJ' [0.1]
# 'BORZYE' -> 'BORZYNI' [0.75]
# 'BOTOVKA' -> 'KOTOVKA' [1.0]
# 'BOTOVO AEROPO' not found
# 'BOYARKINO' -> 'BOJARKINO' [0.1]
# 'BOYKOPONURA' -> 'BOJKOPONURA' [0.1]
# 'BOZOVO' -> 'BYZOVO' [1.0]
# 'BRAYNSK' -> 'BRJANSK' [1.13]
# 'BREKHOVO SOLN' not found
# 'BREYTOVO' -> 'BREJTOVO' [0.1]
# 'BRIANSK' -> 'BRJANSK' [0.1]
# 'BRIN' -> 'BRYN' [0.1]
# 'BRITOVO' -> 'BREJTOVO' [0.63]
# 'BRUHOVETSKAYA' -> 'BRJUKHOVETSKAJA' [0.399]
# 'BRYANSK' -> 'BRJANSK' [0.1]
# 'BRYANSK BEZHE' not found
# 'BRYANSK OBL' -> 'BRJANSKAJA OBL' [0.6187]
# 'BRYANSKIIY OBL' -> 'BRJANSKAJA OBL' [1.569]
# 'BRYANSKIY' -> 'BRUSJANSKIJ' [1.2947]
# 'BRYUHOVECKAYA' -> 'BRJUKHOVETSKAJA' [0.6187]
# 'BRYUKHOVETSKA' -> 'BRJUKHOVETSKAJA' [0.399]
# 'BUDENOVSK' -> 'BUDENNOVSK' [0.5]
# 'BUDOGOSCH' -> 'BUDOGOSHCH' [0.1]
# 'BUGRA' -> 'BUGROVOE' [0.7487]
# 'BUGRI' -> 'BUGRY' [0.1]
# 'BUGROVO' -> 'BUGROVOE' [0.1]
# 'BUKAREVSKOE' not found
# 'BULATNIKOVS' -> 'BULATNIKOVSKOE' [0.399]
# 'BULATNIKOVSKO' -> 'BULATNIKOVSKOE' [0.1]
# 'BUNYATINO' not found
# 'BURACHKI' -> 'BUDOCHKI' [1.4]
# 'BURDUGUZ' not found
# 'BURKOVSKIY' -> 'BURKOVSKIJ' [0.1]
# 'BURTULINOVKA' not found
# 'BUTYN' -> 'BUTUNTAJ' [0.6187]
# 'BUYNAKSK' -> 'BUJNAKSK' [0.1]
# 'BUZDYAK' -> 'BUZDJAK' [0.1]
# 'BUZLANOVO' -> 'BULANOVO' [1.0]
# 'BVYAZEMI' not found
# 'BYBORG' -> 'VYBORG' [0.1]
# 'BYLNIKI' not found
# 'BZHID' -> 'DZHIDA' [1.5]
# 'CANDRYPSH' not found
# 'CEMDO' -> 'TSEMDOLINA' [0.90431]
# 'CEMDOLIN' -> 'TSEMDOLINA' [0.23]
# 'CEMDOLINA' -> 'TSEMDOLINA' [0.1]
# 'CHALTIR' -> 'CHALTYR' [0.1]
# 'CHALTYR POSEL' not found
# 'CHAMZINSKIIY' not found
# 'CHANKI' -> 'CHANKO' [1.0]
# 'CHAPLIGIN' -> 'CHAPLYGIN' [0.1]
# 'CHASCY' -> 'CHASTSY' [0.1]
# 'CHASTOOZERE' -> 'CHASTOOZERYE' [0.5]
# 'CHAYKOVSKIY' -> 'CHAJKOVSKIJ' [0.23]
# 'CHAYKOVSKOGO' not found
# 'CHAYKV' -> 'CHAJKA' [1.13]
# 'CHEBOXARY' -> 'CHEBOKSARY' [0.1]
# 'CHEKHOVSKIY' not found
# 'CHEKHOVSKIY R' not found
# 'CHELBN' -> 'CHELVA' [1.13]
# 'CHELOBITEVO' -> 'CHELOBITYEVO' [0.5]
# 'CHELOKHOVO' not found
# 'CHELTABINSK' -> 'CHELJABINSK' [1.0]
# 'CHELYABINS' -> 'CHELJABINSK' [0.23]
# 'CHELYABINSK' -> 'CHELJABINSK' [0]
# 'CHELYABINSKII' -> 'CHELJABINSK' [1.48181818182]
# 'CHELYUSKINSKI' -> 'CHELJUSKINSKIJ' [0.23]
# 'CHEMDOLINA' -> 'TSEMDOLINA' [1.13]
# 'CHEMSA' -> 'CHEMSKOE' [1.075]
# 'CHEPELEVO' -> 'SHEPELEVO' [1.0]
# 'CHEPEPEVO' not found
# 'CHERDANTSEVO' -> 'CHERDYNTSEVO' [1.0]
# 'CHEREMHOVO' -> 'CHEREMKHOVO' [0.1]
# 'CHEREMYKINO' -> 'CHEREMUSHKINO' [1.319]
# 'CHEREP' -> 'CHEREPET' [0.36]
# 'CHEREPICHNYY' -> 'CHEREPICHNYJ' [0.1]
# 'CHEREPOVETC' -> 'CHEREPOVETS' [1.0]
# 'CHEREPOVETS R' -> 'CHEREPOVETS' [1.38181818182]
# 'CHEREPOVETSKI' -> 'CHEREPOVETS' [1.38181818182]
# 'CHERKIZOVO DP' -> 'CHERKIZOVO' [1.5]
# 'CHERKIZOVO PU' -> 'CHERKIZOVO' [1.5]
# 'CHERKIZOVSKIY' -> 'CHERKESOVSKIJ' [1.569]
# 'CHERNAYA' -> 'CHERNAJA' [0.1]
# 'CHERNAYA GRAZ' -> 'CHERNAJA GRJAZ' [0.23]
# 'CHERNAYA GRYA' -> 'CHERNAJA GRJAZ' [0.399]
# 'CHERNISHEVSKO' -> 'CHERNYSHEVSKOE' [0.23]
# 'CHERNOMORSKI' -> 'CHERNOMORSKIJ' [0.1]
# 'CHERNOMORSKIY' -> 'CHERNOMORSKIJ' [0.1]
# 'CHERNORECHE' -> 'CHERNORECHENSK' [0.399]
# 'CHERNORECHENS' -> 'CHERNORECHENSK' [0.1]
# 'CHERNOVSKIY' -> 'CHERNOVSKIJ' [0.1]
# 'CHERNY YAR' -> 'CHERNYJ JAR' [0.36]
# 'CHERNYAHOVSK' -> 'CHERNJAKHOVSK' [0.23]
# 'CHERNYAKHOVS' -> 'CHERNJAKHOVSK' [0.23]
# 'CHERNYAKHOVSK' -> 'CHERNJAKHOVSK' [0.1]
# 'CHERNYANKA' -> 'CHERNJANKA' [0.1]
# 'CHERNYSHKOVSK' -> 'CHERNYSHKOVSKIJ' [0.23]
# 'CHERTOVICI' -> 'CHERTOVITSY' [0.23]
# 'CHERTOVICY' -> 'CHERTOVITSY' [0.1]
# 'CHIMKI' -> 'KHIMKI' [0.1]
# 'CHIMSHI' not found
# 'CHIRSHKASY' -> 'CHIRICHKASY' [1.4]
# 'CHKALOVSKIY' -> 'CHKALOVSKIJ' [0.1]
# 'CHRPNV' not found
# 'CHUDTSY' not found
# 'CHUPRIAKOVO' -> 'CHUPRJAKOVO' [0.1]
# 'CHUPRYAKOVO' -> 'CHUPRJAKOVO' [0.1]
# 'CHUSOVOY' -> 'CHUSOVOJ' [0.1]
# 'CIMLYANSK' -> 'TSIMLJANSK' [0.23]
# 'COLNECHNOG' not found
# 'COLNECHNOGORS' -> 'SOLNECHNOGORSK' [1.4]
# 'CSHEKINO' -> 'SHCHEKINO' [0.1]
# 'CSHELKOVO' -> 'SHCHELKOVO' [0.1]
# 'DAGESTANSKIE' -> 'DAGESTANSKIE OGNI' [0.90431]
# 'DAGOMYS' not found
# 'DAKHOVSKAYA' -> 'DAKHOVSKAJA' [0.1]
# 'DALNEE KONSTA' not found
# 'DALNIY' -> 'DALNIJ' [0.1]
# 'DANKI' -> 'SANKI' [1.0]
# 'DAVIDOVO' -> 'DAVYDOVO' [0.1]
# 'DAVIDOVSKOE' -> 'DAVYDOVSKOE' [0.1]
# 'DAVIYDOVO' -> 'DAVYDOVO' [1.0]
# 'DAVYDOVO DAV' not found
# 'DEDENOVO' -> 'DEDINOVO' [0.1]
# 'DEDILOVSKIE V' -> 'DEDILOVSKIE VYSELKI' [1.275603]
# 'DEDOVETS' not found
# 'DEDOVSK ISTRI' not found
# 'DEGTYARSK' -> 'DEGTJARSK' [0.1]
# 'DEMYANSK' -> 'DEMJANSK' [0.1]
# 'DEREVNYA KORO' not found
# 'DEREVYANKA' -> 'DEREVJANKA' [0.1]
# 'DEREVYANNOE' -> 'DEREVJANNOE' [0.1]
# 'DERJENSK' -> 'DZERZHINSK' [1.075]
# 'DERJINSK' -> 'DZERZHINSK' [0.75]
# 'DEULINO' -> 'DULINO' [1.0]
# 'DIASYERYA' -> 'DIASERJA' [0.23]
# 'DIMITROV' -> 'DIMITROVSKIJ' [0.8384]
# 'DINSKAYA' -> 'DINSKAJA' [0.1]
# 'DINSKOIY OBL' not found
# 'DIVENSKIY' -> 'DIVENSKIJ' [0.1]
# 'DIVNOMORSK' -> 'DIVNOMORSKOE' [0.23]
# 'DIVRSK' not found
# 'DIVYA' -> 'DIVJA' [0.1]
# 'DMITRIEV' -> 'DMITRIEVO' [0.2]
# 'DMITROVSK' -> 'DMITROVSKOE' [0.36]
# 'DMITROVSKIJ' -> 'DIMITROVSKIJ' [0.5]
# 'DMITROVSKIY' -> 'DIMITROVSKIJ' [0.75]
# 'DOBRINSKIY RA' not found
# 'DOBROVSKIIY R' not found
# 'DOBRYANKA' -> 'DOBRJANKA' [0.1]
# 'DOBRYNKA' -> 'DOBRINKA' [0.1]
# 'DOLGI MOST' -> 'DOLGIJ MOST' [0.2]
# 'DOLGIY MOST' -> 'DOLGIJ MOST' [0.1]
# 'DOLGO NII' not found
# 'DOLGODEREVENS' -> 'DOLGODEREVENSKOE' [0.399]
# 'DOLGOPROUDNIY' -> 'DOLGOPRUDNYJ' [1.4]
# 'DOLGOPRUDNNYY' -> 'DOLGOPRUDNYJ' [1.4]
# 'DOLGOPRUDNY' -> 'DOLGOPRUDNYJ' [0.1]
# 'DOLGOPRUDNYI' -> 'DOLGOPRUDNYJ' [0.1]
# 'DOLGOPRUDNYIY' -> 'DOLGOPRUDNYJ' [1.13]
# 'DOLZHANSKAYA' -> 'DOLZHANSKAJA' [0.1]
# 'DOMBAY' -> 'DOMBAJ' [0.1]
# 'DOMODEDO' -> 'DOMODEDOVO' [0.23]
# 'DOMODEDOV' -> 'DOMODEDOVO' [0.1]
# 'DOMODEDOVO M' -> 'DOMODEDOVO' [1.4]
# 'DOMODEDOVO MK' -> 'DOMODEDOVO' [1.5]
# 'DOMODEDOVO SE' -> 'DOMODEDOVO' [1.5]
# 'DOMODEDOVSKIY' not found
# 'DOMODEVOVO' -> 'DOMODEDOVO' [1.0]
# 'DOMOVEDOVSKIY' not found
# 'DONSKOY' -> 'DONSKOJ' [0.1]
# 'DONSKOYE' -> 'DONSKOE' [0.1]
# 'DONU' -> 'DONGUZ' [0.75]
# 'DOROHOVO' -> 'DOROKHOVO' [0.1]
# 'DOROKHOVO RUZ' not found
# 'DOROZHNYY' -> 'DOROZHNYJ' [0.1]
# 'DOSKINO' -> 'OSKINO' [1.0]
# 'DOUBNA' -> 'DUBNA' [1.0]
# 'DP POVAROVO' not found
# 'DRANISHNIKI' not found
# 'DROJJINO' -> 'DROZHZHINO' [0.23]
# 'DROKINO' -> 'DROFINO' [1.0]
# 'DROZDI' not found
# 'DROZDY' not found
# 'DROZHZHI' -> 'DROZHZHINO' [0.23]
# 'DROZHZHINO LE' -> 'DROZHZHINO' [1.5]
# 'DROZHZHINO V' -> 'DROZHZHINO' [1.4]
# 'DRUZHNAYA GOR' -> 'DRUZHNAJA GORKA' [0.399]
# 'DRUZHNYY' -> 'DRUZHNYJ' [0.1]
# 'DUBOE' -> 'DUBOVETS' [1.075]
# 'DUBOVOYE' -> 'DUBOVOE' [0.1]
# 'DUBROVSKIY' -> 'DUBROVSKIJ' [0.1]
# 'DUBYAZY' -> 'DUBJAZY' [0.1]
# 'DUHOVCSHINA' -> 'DUKHOVSHCHINA' [0.23]
# 'DUPLENSKAYA' -> 'DUPLENSKAJA' [0.1]
# 'DUPLEVO' not found
# 'DUYUOVOE' not found
# 'DVURECHE' -> 'DVURECHENSK' [0.399]
# 'DYADKOVO' -> 'DJADKOVO' [0.1]
# 'DYAGILEVO' not found
# 'DYAKOVO' -> 'DJATKOVO' [0.63]
# 'DYATKOVO' -> 'DJATKOVO' [0.1]
# 'DYATLITSY' not found
# 'DYURTYULI' -> 'DJURTJULI' [0.23]
# 'DZER II' not found
# 'DZERJINSK' -> 'DZERZHINSK' [0.1]
# 'DZERZGINSK' -> 'DZERZHINSK' [1.0]
# 'DZERZH' -> 'DZERZHINSK' [0.6187]
# 'DZERZHINSKII' -> 'DZERZHINSKIJ' [0.1]
# 'DZERZHINSKIIY' -> 'DZERZHINSKIJ' [1.13]
# 'DZERZHINSKIYI' -> 'DZERZHINSKIJ' [1.13]
# 'DZERZHINSKY' -> 'DZERZHINSKIJ' [0.23]
# 'DZHANKOI' -> 'DZHANKOJ' [0.1]
# 'DZHEMETE' not found
# 'DZUBGA' -> 'DZHUBGA' [0.5]
# 'EDROVSKOE' -> 'FEDOROVSKOE' [1.15]
# 'EFIMOVSKIY' -> 'EFIMOVSKIJ' [0.1]
# 'EGERUKHAY' -> 'EGERUKHAJ' [0.1]
# 'EGOREVSK' -> 'EGORYEVSK' [0.5]
# 'EGOREVSKOE' -> 'EGORYEVSKOE' [0.5]
# 'EGORIEVSK' -> 'EGORYEVSK' [0.1]
# 'EGORLYKSKAYA' -> 'EGORLYKSKAJA' [0.1]
# 'EKATERINBU' -> 'EKATERINBURG' [0.23]
# 'EKATERINBUR' -> 'EKATERINBURG' [0]
# 'EKATERINDURG' -> 'EKATERINBURG' [1.0]
# 'EKATERINOS' -> 'EKATERINOSLAVKA' [0.90431]
# 'EKATIRINBURG' -> 'EKATERINBURG' [0.1]
# 'ELEC' -> 'ELETS' [0.1]
# 'ELECTROSTAL' -> 'ELEKTROSTAL' [1.0]
# 'ELEETS' -> 'ELETS' [1.0]
# 'ELEKTROGORS' -> 'ELEKTROGORSK' [0.1]
# 'ELEKTROIZOLYA' -> 'ELEKTROIZOLJATOR' [0.6187]
# 'ELEKTROSLAL' -> 'ELEKTROSTAL' [1.0]
# 'ELEKTROUGLI M' -> 'ELEKTROUGLI' [1.38181818182]
# 'ELETSK' -> 'ELETSKOE' [0.36]
# 'ELETZ' -> 'ELETS' [1.0]
# 'ELISTRA' -> 'ELISTA' [1.0]
# 'ELIZAVATENSKA' not found
# 'ELIZAVETINSKA' -> 'ELIZAVETINSKOE' [0.23]
# 'ELKHOVKA ELKH' not found
# 'ELNA' -> 'ELNJA' [0.1]
# 'ELNYA' -> 'ELNJA' [0.1]
# 'EMB CHELNY' not found
# 'EMELYANOVO' -> 'EMELJANOVO' [0.1]
# 'EMELYANOVSK R' not found
# 'EMELYANOVSKII' not found
# 'ENGEL' -> 'ENGELS' [0.2]
# 'ENGELSSKIY' not found
# 'ERISHI' -> 'ERYSHI' [0.1]
# 'ERMOLAEVSKIY' not found
# 'ESAULOVKA' -> 'ESAULOVO' [1.4]
# 'ESAULSKIY' -> 'ESAULSKIJ' [0.1]
# 'ESSENTOUKI' -> 'ESSENTUKI' [1.0]
# 'ESSENTUKSKAYA' -> 'ESSENTUKSKAJA' [0.1]
# 'ESSENTUKY' -> 'ESSENTUKI' [0.1]
# 'ESSOYLA' -> 'ESSOJLA' [0.1]
# 'ESTO SADOK' not found
# 'ESTOSADOK' not found
# 'EVGENEVKA' -> 'EVGENYEVKA' [0.5]
# 'EVPATORIA' -> 'EVPATORIJA' [0.1]
# 'EVPATORIIA' -> 'EVPATORIJA' [0.1]
# 'EVPATORIYA' -> 'EVPATORIJA' [0.1]
# 'EYSK' -> 'EJSK' [0.1]
# 'FABRIKI IM' -> 'FABRIKI IM MAJA' [0.90431]
# 'FABRIKI IMENI' not found
# 'FEDINO' -> 'FEDKINO' [0.5]
# 'FEDINO VOSKRE' not found
# 'FEDINSKOE' -> 'FILINSKOE' [1.13]
# 'FEDOROVSKIY' -> 'FEDOROVSKIJ' [0.1]
# 'FEDOSKINSKOE' not found
# 'FEDURINO FED' not found
# 'FEDYAKOVA' -> 'FEDJUKOVO' [1.569]
# 'FEDYAKOVO' -> 'FEDJUKOVO' [1.13]
# 'FEDYUKOVO' -> 'FEDJUKOVO' [0.1]
# 'FEODOSIIA' -> 'FEODOSIJA' [0.1]
# 'FEODOSIYA' -> 'FEODOSIJA' [0.1]
# 'FIDIAK' -> 'FEDJAKINO' [0.90431]
# 'FINEEVO' -> 'MINEEVO' [1.0]
# 'FINLYANDSKIJ' not found
# 'FOMINSKIY' -> 'FOMINSKIJ' [0.1]
# 'FONOV' -> 'ZONOVO' [1.4]
# 'FRIANOVO' -> 'FRJANOVO' [0.1]
# 'FROLOVA' -> 'FROLOVO' [0.1]
# 'FRYANOVO' -> 'FRJANOVO' [0.1]
# 'FRYAZEVO' -> 'FRJAZEVO' [0.1]
# 'FRYAZINO' -> 'FRJAZINO' [0]
# 'FRYZINO' -> 'FRJAZINO' [0.63]
# 'FYEDOROVSKIY' -> 'FEDOROVSKIJ' [0.23]
# 'FYODOROVSKIY' -> 'FEDOROVSKIJ' [0.23]
# 'GABOVSKOE' not found
# 'GAGARINA MKR' not found
# 'GAIDUK' -> 'GAJDUK' [0.1]
# 'GALCHINO' -> 'GOLOVCHINO' [1.319]
# 'GAT' -> 'GATI' [0.2]
# 'GATCHINSKIY' not found
# 'GATCHINSKIY R' not found
# 'GATCHN' -> 'GATCHINA' [0.75]
# 'GAVRILOV YAM' -> 'GAVRILOV JAM' [0.1]
# 'GAVRILOVSKAYA' -> 'GAVRILOVSKAJA' [0.1]
# 'GAVRILOVSKIIY' -> 'GAVRILOVSKIJ' [1.13]
# 'GAY' -> 'GAJ' [0.1]
# 'GAY KODZOR' -> 'GAJ KODZOR' [0.1]
# 'GAYDUK' -> 'GAJDUK' [0.1]
# 'GAZIMURSKIY Z' -> 'GAZIMURSKIJ ZAVOD' [0.90431]
# 'GELEND' -> 'ZHILINDA' [0.6187]
# 'GELENDGIK' -> 'GELENDZHIK' [0.1]
# 'GELENDJIK' -> 'GELENDZHIK' [0.1]
# 'GELENDZGIK' -> 'GELENDZHIK' [1.0]
# 'GELENJIK' -> 'GELENDZHIK' [0.75]
# 'GELENZHIK' -> 'GELENDZHIK' [0.5]
# 'GELEZNODOROGN' -> 'ZHELEZNODOROZHNYJ' [0.7487]
# 'GELEZNYA' -> 'ZHELEZNYJ' [1.13]
# 'GEOFIZIKOV' not found
# 'GHELEZNODOROJ' not found
# 'GHIMKI' -> 'KHIMKI' [1.0]
# 'GIAGINSKAYA' -> 'GIAGINSKAJA' [0.1]
# 'GIDRO' -> 'GIDROTORF' [0.8384]
# 'GIDROUZLA IM' not found
# 'GJACHRYPSH' not found
# 'GJHELSKOE' not found
# 'GLAZGOV' -> 'GLAZOV' [1.0]
# 'GLEBOVSKIJ' not found
# 'GLEBOVSKIY' not found
# 'GLINKOVO' -> 'GLEBKOVO' [1.13]
# 'GLUBOKIY' -> 'GLUBOKIJ' [0.1]
# 'GOLEVO' -> 'GOREVO' [1.0]
# 'GOLICYNO' -> 'GOLITSYNO' [0.1]
# 'GOLIEVO' not found
# 'GOLITCYNO' -> 'GOLITSYNO' [1.0]
# 'GOLITSINO ODI' not found
# 'GOLITSYNO ODI' not found
# 'GOLOKHVASTOVO' not found
# 'GOLOVACHEVO' not found
# 'GOLOVLEV' not found
# 'GOLUBITSKAYA' -> 'GOLUBITSKAJA' [0.1]
# 'GORACHY KLUCH' -> 'GORJACHIJ KLJUCH' [0.7487]
# 'GORALT' not found
# 'GORBATO' -> 'GORBATOV' [0.1]
# 'GORCHAKOVO' not found
# 'GORJACHIJ KLJ' -> 'GORJACHIJ KLJUCH' [0.399]
# 'GORKI LENINSK' -> 'GORKI LENINSKIE' [0.23]
# 'GORKI SUKHARE' not found
# 'GORKIY' -> 'GORSKIJ' [0.75]
# 'GORKOGO' not found
# 'GORNO ALTAYSK' -> 'GORNO ALTAJSK' [0.1]
# 'GORNY' -> 'GORNYJ' [0.2]
# 'GORNYAK' -> 'GORNJAK' [0.1]
# 'GORNYATSKIY' -> 'GORNJATSKIJ' [0.23]
# 'GORNYIY SCHIT' -> 'GORNYJ SHCHIT' [1.569]
# 'GORNYY' -> 'GORNYJ' [0.1]
# 'GORNYY SHCHIT' -> 'GORNYJ SHCHIT' [0.1]
# 'GORODEC' -> 'GORODETS' [0.1]
# 'GORODISHCHENS' -> 'GORODISHCHE' [1.38181818182]
# 'GORODISHE' -> 'GORODISHCHE' [0.1]
# 'GORODKOVO' -> 'GOROKHOVO' [1.4]
# 'GORODSKOY' -> 'GORODSKOJ' [0.1]
# 'GOROHOVEC' -> 'GOROKHOVETS' [0.23]
# 'GORYACHEVODSK' -> 'GORJACHEVODSKIJ' [0.399]
# 'GORYACHIIY KL' not found
# 'GORYACHIY KLU' -> 'GORJACHIJ KLJUCH' [0.90431]
# 'GORYACHIY KLY' -> 'GORJACHIJ KLJUCH' [1.275603]
# 'GOSTAGAEVSKAY' -> 'GOSTAGAEVSKAJA' [0.23]
# 'GP LYUBERTSY' not found
# 'GP ROSCHINO' not found
# 'GPB KRASNOJAR' not found
# 'GPZ' not found
# 'GRAYVORON' -> 'GRAJVORON' [0.1]
# 'GREMYACHEE' -> 'GREMJACHEE' [0.1]
# 'GRIBANOVSKIY' -> 'GRIBANOVSKIJ' [0.1]
# 'GRIBKI' -> 'GRIVKI' [0.1]
# 'GRIGORCHIKOVO' not found
# 'GRISHANKI' not found
# 'GRITSOVSKIY' -> 'GRITSOVSKIJ' [0.1]
# 'GROZNIY' -> 'GROZNYJ' [0.1]
# 'GROZNY' -> 'GROZNYJ' [0.1]
# 'GROZNYY' -> 'GROZNYJ' [0.1]
# 'GRYADY' -> 'GRJADY' [0.1]
# 'GRYAZI' -> 'GRJAZI' [0.1]
# 'GRYAZOVEC' -> 'GRJAZOVETS' [0.23]
# 'GUBAXA' -> 'GUBAKHA' [0.1]
# 'GUREVSK' -> 'GURYEVSK' [0.5]
# 'GURIEVSK' -> 'GURYEVSK' [0.1]
# 'GURYEV' -> 'GURYEVO' [0.2]
# 'GUS HRUSTALNI' -> 'GUS KHRUSTALNYJ' [0.399]
# 'GUS HRUSTALNY' -> 'GUS KHRUSTALNYJ' [0.23]
# 'GUS KHRUSTALN' -> 'GUS KHRUSTALNYJ' [0.23]
# 'GVARDEYSK' -> 'GVARDEJSK' [0.1]
# 'GZHEL RAMENSK' not found
# 'GZHELSKOGO KI' not found
# 'H VERHNEADAG' not found
# 'HADYZHENSK' -> 'KHADYZHENSK' [0.1]
# 'HANTY MANSIJS' -> 'KHANTY MANSIJSK' [0.23]
# 'HANTY MANSIYS' -> 'KHANTY MANSIJSK' [0.399]
# 'HASAVYURT' -> 'KHASAVJURT' [0.23]
# 'HATUN' -> 'KHATUN' [0.1]
# 'HIMKI' -> 'KHIMKI' [0]
# 'HIMKY' -> 'KHIMKI' [0.23]
# 'HLEVNOE' -> 'KHLEVNOE' [0.1]
# 'HOHLOVO' -> 'KHOKHLOVO' [0.23]
# 'HOLSCHYOVIKI' -> 'KHOLSHCHEVIKI' [0.399]
# 'HOMAKOVO' -> 'KHOMJAKOVO' [0.23]
# 'HOMUTOVO' -> 'KHOMUTOVO' [0.1]
# 'HORLOVO' -> 'KHORLOVO' [0.1]
# 'HOSTA' -> 'ZHOSTOVO' [0.6187]
# 'HOTKOVO' -> 'KHOTKOVO' [0.1]
# 'HRABROVO' -> 'KHRABROVO' [0.1]
# 'HUTOR IMENY L' not found
# 'HVOROSTJANKA' -> 'KHVOROSTJANKA' [0.1]
# 'IALTA' -> 'JALTA' [0.1]
# 'IGEVSK' -> 'IZHEVSK' [0.1]
# 'IGLINSKIIY OBL' not found
# 'IGNATOVO' -> 'IGNATKOVO' [0.5]
# 'IGNATOVO O' not found
# 'IIVANTEEVKA' -> 'IVANTEEVKA' [1.0]
# 'IJEVSK' -> 'IZHEVSK' [0.1]
# 'IKRYANOE' -> 'IKRJANOE' [0.1]
# 'IKSHA DMITROV' not found
# 'ILANSKIY' -> 'ILANSKIJ' [0.1]
# 'ILICH' -> 'ILYICH' [0.1]
# 'ILINKA' -> 'ILYINKA' [0.1]
# 'ILINO' -> 'ELINO' [0.1]
# 'ILINOGORSK' -> 'ILYINOGORSK' [0.1]
# 'ILINSKIJ' -> 'ILYINSKIJ' [0.1]
# 'ILINSKIY POGO' -> 'ILYINSKIJ POGOST' [0.6187]
# 'ILINSKOE' -> 'ILYINSKOE' [0.1]
# 'ILINSKOE USOV' -> 'ILYINSKOE USOVO' [0.23]
# 'ILOVLYA' -> 'ILOVLJA' [0.1]
# 'ILSKIY' -> 'ILSKIJ' [0.1]
# 'ILYINSKOE H' -> 'ILYINSKOE' [1.42222222222]
# 'IM SVERDL' -> 'IM SVERDLOVA' [0.399]
# 'IM TSYURUPY' -> 'IM TSJURUPY' [0.1]
# 'IMENI LENINA' not found
# 'IMENI MOROZOV' not found
# 'IMENI TELMANA' not found
# 'INDUSTRIALNYY' -> 'INDUSTRIALNYJ' [0.1]
# 'INNOVATS TSE' not found
# 'INOZEMTZEVO' -> 'INOZEMTSEVO' [1.0]
# 'INSHINSKIY' -> 'INSHINSKIJ' [0.1]
# 'IRK' -> 'ERIK' [0.63]
# 'IRKUSK' -> 'IRKUTSK' [0.1]
# 'IRKUTSKIY' -> 'IRKUTSK' [1.48571428571]
# 'IRTYSHSKIY' -> 'IRTYSHSKIJ' [0.1]
# 'ISAKOV' -> 'ISAKOVO' [0.2]
# 'ISHIMBAY' -> 'ISHIMBAJ' [0.1]
# 'ISKITM' -> 'ISKITIM' [0.5]
# 'ISTE' -> 'ISTYE' [0.5]
# 'ISTRA OBL' not found
# 'ISTRINSKIY' -> 'STRINSKIJ' [1.4]
# 'ISTRINSKIY PA' not found
# 'ITS SKOLKOVO' not found
# 'IUKHNOV' -> 'JUKHNOV' [0.1]
# 'IVANA' -> 'IVANOV' [0.33]
# 'IVANOVKA PUD' not found
# 'IVANOVSKAYA' -> 'IVANOVSKAJA' [0.1]
# 'IVANOVSKOE PO' -> 'IVANOVSKOE' [1.5]
# 'IVANOVSKOYE' -> 'IVANOVSKOE' [0.1]
# 'IVANTELEEVKA' not found
# 'IVNYA' -> 'IVNJA' [0.1]
# 'IVNYAKI' -> 'IVNJAKI' [0.1]
# 'IYOSHKAR OLA' -> 'JOSHKAR OLA' [1.13]
# 'IZHEVS' -> 'IZHEVSK' [0.1]
# 'IZHORA' -> 'EZHOVO' [1.569]
# 'IZMAKOVO' -> 'IZMALKOVO' [0.5]
# 'IZOBILNIY' -> 'IZOBILNYJ' [0.1]
# 'IZOBILNYY' -> 'IZOBILNYJ' [0.1]
# 'JARCEVO' -> 'JARTSEVO' [0.1]
# 'JAVORONK' -> 'ZHAVORONKI' [0.23]
# 'JELEZNODOROJN' -> 'ZHELEZNODOROZHNYJ' [0.7487]
# 'JELEZNOGORSK' -> 'ZHELEZNOGORSK' [0.1]
# 'JIRNOVSK' -> 'ZHIRNOVSK' [0.1]
# 'JUTOVO' -> 'BUTOVO' [1.0]
# 'JUZHNO SAHALI' -> 'JUZHNO SAKHALINSK' [0.6187]
# 'K LIBKNEKHTA' -> 'KARLA LIBKNEKHTA' [1.2374]
# 'K ZNAMENSK' not found
# 'KABARDINA' -> 'KABARDINKA' [0.5]
# 'KABITSINO' -> 'KALITSINO' [1.0]
# 'KABITSYNO' -> 'KOROBITSYNO' [1.319]
# 'KADUY' -> 'KADUJ' [0.1]
# 'KADYY' -> 'KADYJ' [0.1]
# 'KAGALNICKAYA' -> 'KAGALNITSKAJA' [0.23]
# 'KAGALNITS' -> 'KAGALNITSKAJA' [0.6187]
# 'KAGALNITSKAYA' -> 'KAGALNITSKAJA' [0.1]
# 'KAINSKAYA' -> 'KHANSKAJA' [1.569]
# 'KAINSKAYA ZAI' not found
# 'KALACH NA DON' -> 'KALACH NA DONU' [0.1]
# 'KALACHINCK' -> 'KALACHINSK' [1.0]
# 'KALINIGRAD' -> 'KALININGRAD' [0.5]
# 'KALININEC' -> 'KALININETS' [0.1]
# 'KALININGAD' -> 'KALININGRAD' [0.5]
# 'KALININGRADS' -> 'KALININGRAD' [1.0]
# 'KALININGRADSK' -> 'KALININGRAD' [1.38181818182]
# 'KALININSKAYA' -> 'KALININSKAJA' [0.1]
# 'KALOUGA' -> 'KALUGA' [1.0]
# 'KALUGA MSTI' not found
# 'KALUGA OBL' not found
# 'KALUGA TOVA' not found
# 'KALUZHS' -> 'KALUZHSKOE' [0.529]
# 'KALUZHSKAYA' -> 'KALUZHSKAJA' [0.1]
# 'KALUZHSKAYA O' -> 'KALUZHSKAJA OBL' [0.529]
# 'KALUZHSKAYA R' -> 'KALUZHSKAJA' [1.48181818182]
# 'KALYAZIN' -> 'KALJAZIN' [0.1]
# 'KAM POLYANY' -> 'KAMSKIE POLJANY' [1.48892]
# 'KAMEN NA OBY' -> 'KAMEN NA OBI' [0.1]
# 'KAMENNAYA BAL' -> 'KAMENNAJA BALKA' [0.399]
# 'KAMENNOMOSTSK' -> 'KAMENNOMOSTSKIJ' [0.36]
# 'KAMENSK SHAHT' not found
# 'KAMENSK SHAKH' not found
# 'KAMENSK URALS' -> 'KAMENSK URALSKIJ' [0.399]
# 'KAMISHLA' -> 'KAMYSHLA' [0.1]
# 'KAMYISHLOV' -> 'KAMYSHLOV' [1.0]
# 'KAMYSHLOVSKIY' -> 'KAMYSHLOVSKIJ' [0.1]
# 'KANAEVSKAYA' -> 'KANEVSKAJA' [1.4]
# 'KANEVSKAYA' -> 'KANEVSKAJA' [0.1]
# 'KANTEMIROVK' -> 'KANTEMIROVKA' [0.1]
# 'KAPITANSHCHIN' not found
# 'KAPITOLOVO' not found
# 'KAPOTNYA' not found
# 'KARABASIKHA' not found
# 'KARABIKHA' -> 'KOROLIKHA' [1.299]
# 'KARABUDAKHKEN' -> 'KARABUDAKHKENT' [0.1]
# 'KARACHIKHA' not found
# 'KARASINSKOE' -> 'KRASINSKOE' [1.0]
# 'KARASK' -> 'KARASUK' [0.5]
# 'KARATUN' -> 'KORATUN' [0.1]
# 'KARELIYA' -> 'KARELIJA' [0.1]
# 'KARPSK' -> 'KARPINSK' [1.15]
# 'KARTMAZOVO' not found
# 'KASHIRSKIY RA' not found
# 'KASIMOVO' -> 'KASILOVO' [1.0]
# 'KASPIYSK' -> 'KASPIJSK' [0.1]
# 'KASPL' -> 'KASPLJA' [0.23]
# 'KATAYSK' -> 'KATAJSK' [0.1]
# 'KATELNIKI' -> 'KOTELNIKI' [0.1]
# 'KATUN' -> 'KHATUN' [0.1]
# 'KAYGORODOVO' not found
# 'KAYSATSKOE' -> 'KAJSATSKOE' [0.1]
# 'KAZACHINSKOYE' -> 'KAZACHINSKOE' [0.1]
# 'KAZACHIY BROD' not found
# 'KAZACHYA SLOB' -> 'KAZACHJA SLOBODA' [0.6187]
# 'KAZAN SCHERB' not found
# 'KAZAROVO' -> 'NAZAROVO' [1.0]
# 'KELOZI' not found
# 'KEMEROVSKAYA' -> 'KEMEROVSKAJA OBL' [0.90431]
# 'KH MANSIYSK' not found
# 'KHABRV' -> 'KHRABROVO' [1.595]
# 'KHANTY MANSIY' -> 'KHANTY MANSIJSK' [0.399]
# 'KHATUN STUPIN' not found
# 'KHELYULYA' -> 'KHELJULJA' [0.23]
# 'KHIMKINSKIY' not found
# 'KHIMKY' -> 'KHIMKI' [0.1]
# 'KHIYDENSELGA' -> 'KHIJDENSELGA' [0.1]
# 'KHLYUPINO' -> 'KHLJUPINO' [0.1]
# 'KHOLMSKAYA' -> 'KHOLMSKAJA' [0.1]
# 'KHOLYAZINO' -> 'KHOLJAZINO' [0.1]
# 'KHOMUTOVO R' -> 'KHOMUTOVO' [1.42222222222]
# 'KHOSTA' -> 'KHOKTA' [1.0]
# 'KHOTKOVO SERG' not found
# 'KHUDYAKOVO' not found
# 'KHVOROSTYANKA' -> 'KHVOROSTJANKA' [0.1]
# 'KICHMENGSKIY' not found
# 'KICHMENSKIY' not found
# 'KIEVSKIY' -> 'KIEVSKIJ' [0.1]
# 'KIEVSKO' -> 'KIEVSKOE' [0.1]
# 'KIMRYI' -> 'KIMRY' [1.0]
# 'KINDERI' -> 'KINDER' [1.0]
# 'KINEL ALEKSEE' not found
# 'KINTSY' -> 'KLINTSY' [0.5]
# 'KIPARISNOE' not found
# 'KIRKKOLAKHTA' not found
# 'KIRKKOLAKHTI' not found
# 'KIROVETS' not found
# 'KIROVO CHEPET' -> 'KIROVO CHEPETSK' [0.23]
# 'KIROVOGRAD' -> 'KIROVGRAD' [1.0]
# 'KISELNYA' -> 'KISELNJA' [0.1]
# 'KISHTIM' -> 'KYSHTYM' [0.23]
# 'KISLINO' -> 'KISLENKA' [1.569]
# 'KIZIL' -> 'KIZEL' [0.1]
# 'KIZILYURT' -> 'KIZILJURT' [0.1]
# 'KIZLYAR' -> 'KIZLJAR' [0.1]
# 'KKRASNODAR' -> 'KRASNODAR' [1.0]
# 'KLEMENTEVO' -> 'KLEMENTYEVO' [0.5]
# 'KLEOPINO' not found
# 'KLETNYA' -> 'KLETNJA' [0.1]
# 'KLINCY' -> 'KLINTSY' [0.1]
# 'KLINSKIY POK' not found
# 'KLINTSI' -> 'KLINTSY' [0.1]
# 'KLISHEVA' -> 'KLESHCHEVO' [0.399]
# 'KLYAZMA' -> 'KLJAZMA' [0.1]
# 'KLYUCHI' -> 'KLJUCHI' [0.1]
# 'KLYUCHISHCHE' -> 'KLJUCHISHCHI' [0.23]
# 'KNYAZHE' -> 'KNJAZHE' [0.1]
# 'KOBRINO' -> 'KOVRINO' [0.1]
# 'KOBYAKOVO' -> 'KOBJAKOVO' [0.1]
# 'KOCHKUROVSKII' not found
# 'KODOSHKINSKII' not found
# 'KOGALIM' -> 'KOGALYM' [0.1]
# 'KOGHINO' -> 'KOZHINO' [1.0]
# 'KOKKOREVO' -> 'KOKOREVO' [1.0]
# 'KOLCOVO' -> 'KOLTSOVO' [0.1]
# 'KOLINOVA' -> 'KALINOVO' [1.4]
# 'KOLIVAN' -> 'KOLYVAN' [0.1]
# 'KOLODEZNYY' -> 'KOLODEZNYJ' [0.1]
# 'KOLODKINO' -> 'KOLODINO' [1.0]
# 'KOLOMENSKIY' not found
# 'KOLOMN' -> 'KOLOMNO' [0.2]
# 'KOLONTAEVO' -> 'KOLONTAEVKA' [1.4]
# 'KOLOSISTYY' -> 'KOLOSISTYJ' [0.1]
# 'KOLOTOV BUERA' not found
# 'KOLPIN' -> 'KOLPINO' [0.1]
# 'KOLTSV' -> 'KOLTSOVO' [0.85]
# 'KOLYANOVO' -> 'KOLJUPANOVO' [1.319]
# 'KOLYUBAKINO' -> 'KOLJUBAKINO' [0.1]
# 'KOMI SYK' not found
# 'KOMMUNALNAYA' not found
# 'KOMMUNARK' -> 'KOMMUNARKA' [0.1]
# 'KOMMUNARKA PO' -> 'KOMMUNARKA' [1.5]
# 'KOMS NA AMURE' not found
# 'KOMSOM NA AMU' not found
# 'KOMSOMOLSKIY' -> 'KOMSOMOLSKIJ' [0.1]
# 'KOMSOMOLSKY' -> 'KOMSOMOLSKIJ' [0.23]
# 'KOMUNAR' -> 'KOMMUNAR' [0.5]
# 'KOMUNARKA' -> 'KOMMUNARKA' [0.5]
# 'KONAKHOVO' -> 'KONAKOVO' [1.0]
# 'KONAKOVA' -> 'KONAKOVO' [0.1]
# 'KONAKOVSKIY' not found
# 'KONDRATEVO' -> 'KONDRATYEVO' [0.5]
# 'KONECBOR' not found
# 'KONSTANTINOVK' -> 'KONSTANTINOVKA' [0.1]
# 'KONSTANTINOVS' -> 'KONSTANTINOVSK' [0.1]
# 'KOOPERATIVNYY' not found
# 'KOPEISK' -> 'KOPEJSK' [0.1]
# 'KOPEIYSK' -> 'KOPEJSK' [1.13]
# 'KOPEYS' -> 'KOPEJSK' [0.23]
# 'KOPEYSK' -> 'KOPEJSK' [0.1]
# 'KOPORE' -> 'KOPORYE' [0.5]
# 'KORABSELKI' not found
# 'KORGASHINO' -> 'TORGASHINO' [1.0]
# 'KOROBITSINO' -> 'KOROBITSYNO' [0.1]
# 'KOROL' -> 'KHOROL' [0.1]
# 'KOROLYOV' -> 'KOROLEV' [0.1]
# 'KORYAGMA' -> 'KORJAZHMA' [0.23]
# 'KORYAZHMA' -> 'KORJAZHMA' [0.1]
# 'KORZHEVSKIY' -> 'KORZHEVSKIJ' [0.1]
# 'KOSAYA GORA' -> 'KOSAJA GORA' [0.1]
# 'KOSHEHABL' -> 'KOSHEKHABL' [0.1]
# 'KOSTRM' -> 'KOSTROMA' [0.85]
# 'KOSTROVSKOE' -> 'KOSTROMSKOE' [1.0]
# 'KOTEL NIKI' -> 'KOTELNIKI' [1.0]
# 'KOTELN' -> 'KOTELNICH' [0.529]
# 'KOTELNIC' -> 'KOTELNICH' [0.1]
# 'KOTELNIK' -> 'KOTELNIKI' [0.2]
# 'KOTELNIKO' -> 'KOTELNIKOV' [0.1]
# 'KOTELSKIY' -> 'KOTELSKIJ' [0.1]
# 'KOTELYNIKI' -> 'KOTELNIKI' [1.0]
# 'KOTLYAKOVO' -> 'KOTLJAKOVO' [0.1]
# 'KOTRKEROS' not found
# 'KOURILOVO' -> 'KURILOVO' [1.0]
# 'KOURSK' -> 'KOURAK' [1.0]
# 'KOVERSHI' not found
# 'KOVYILKINO' -> 'KOVYLKINO' [1.0]
# 'KOZITSYNO' not found
# 'KOZLOVSKIY RA' -> 'KOZLOVSKIJ' [1.6]
# 'KOZMODEMYANSK' -> 'KOZMODEMJANSK' [0.1]
# 'KRACNOGORSK' -> 'KRASNOGORSK' [1.0]
# 'KRANOGORSK' -> 'KRASNOGORSK' [0.5]
# 'KRANSODAR' not found
# 'KRAPIVINSKOE' not found
# 'KRASGK' -> 'KRASKI' [1.5]
# 'KRASHODAR' -> 'KRASNODAR' [1.0]
# 'KRASKOVO M' -> 'KRASKOVO' [1.45]
# 'KRASN NSK' not found
# 'KRASNAYA' -> 'KRASNAJA' [0.1]
# 'KRASNAYA DOLI' -> 'KRASNAJA DOLINA' [0.399]
# 'KRASNAYA GLIN' -> 'KRASNAJA GLINKA' [0.399]
# 'KRASNAYA GORA' -> 'KRASNAJA GORA' [0.1]
# 'KRASNAYA GORK' -> 'KRASNAJA GORKA' [0.23]
# 'KRASNAYA PAHR' -> 'KRASNAJA PAKHRA' [0.399]
# 'KRASNAYA PAKH' -> 'KRASNAJA PAKHRA' [0.399]
# 'KRASNAYA POLY' -> 'KRASNAJA POLJANA' [0.90431]
# 'KRASNAYA POYM' -> 'KRASNAJA POJMA' [0.399]
# 'KRASNAYA ZARY' -> 'KRASNAJA ZARJA' [0.399]
# 'KRASND' -> 'KRASNODAR' [1.205]
# 'KRASNGOZNAMEN' not found
# 'KRASNIY' -> 'KRASNYJ' [0.1]
# 'KRASNIY BOR' -> 'KRASNYJ BOR' [0.1]
# 'KRASNO SK' -> 'KRASNOOBSK' [1.26]
# 'KRASNOARMEYSK' -> 'KRASNOARMEJSK' [0.1]
# 'KRASNODAR KAR' not found
# 'KRASNODAR KRA' -> 'KRASNODARSKIJ KRAJ' [1.07331]
# 'KRASNODAR OBL' not found
# 'KRASNODARSKI' -> 'KRASNODARSKIJ' [0.1]
# 'KRASNODARSKII' -> 'KRASNODARSKIJ' [0.1]
# 'KRASNODARSKIY' -> 'KRASNODARSKIJ' [0.1]
# 'KRASNOE NA VO' -> 'KRASNOE NA VOLGE' [0.399]
# 'KRASNOGORS' -> 'KRASNOGORSK' [0.1]
# 'KRASNOGORSK R' -> 'KRASNOGORSK' [1.38181818182]
# 'KRASNOGORSKAY' -> 'KRASNOGORSKAJA' [0.23]
# 'KRASNOGORSKI' -> 'KRASNOGORSKIJ' [0.1]
# 'KRASNOGORSKIY' -> 'KRASNOGORSKIJ' [0.1]
# 'KRASNOGOSK' -> 'KRASNOGORSK' [0.5]
# 'KRASNOGR' -> 'KRASNOGOR' [0.5]
# 'KRASNOGRSKIY' -> 'KRASNOGORSKIJ' [0.75]
# 'KRASNOLESNYY' not found
# 'KRASNOOBSK PO' -> 'KRASNOOBSK' [1.5]
# 'KRASNOPAKHORS' -> 'KRASNOPAKHORSKOE' [0.399]
# 'KRASNORECHENS' -> 'KRASNORECHENSKIJ' [0.529]
# 'KRASNORYASK' not found
# 'KRASNOSHCHEKO' -> 'KRASNOSHCHEKOVO' [0.23]
# 'KRASNOSLOBODS' -> 'KRASNOSLOBODSK' [0.1]
# 'KRASNOYARS' -> 'KRASNOJARSK' [0.23]
# 'KRASNOYARSK' -> 'KRASNOJARSK' [0]
# 'KRASNOYARSKAY' -> 'KRASNOJARSKAJA' [0.399]
# 'KRASNOYARSKI' -> 'KRASNOJARSKIJ' [0.23]
# 'KRASNOYARSKIY' -> 'KRASNOJARSKIJ' [0.23]
# 'KRASNOYASK' -> 'KRASNOJARSK' [0.63]
# 'KRASNOYASRK' -> 'KRASNOJARKA' [1.569]
# 'KRASNOYASRSK' -> 'KRASNOJARSK' [1.13]
# 'KRASNOZATONSK' -> 'KRASNOZATONSKIJ' [0.23]
# 'KRASNOZN' -> 'KRASNOZNAMENSK' [1.405603]
# 'KRASNOZNAM' -> 'KRASNOZNAMENSK' [0.7487]
# 'KRASNOZNAME' -> 'KRASNOZNAMENKA' [0.529]
# 'KRASNOZNAMEN' -> 'KRASNOZNAMENKA' [0.36]
# 'KRASNOZNAMENS' -> 'KRASNOZNAMENSK' [0.1]
# 'KRASNOZNAMESK' -> 'KRASNOZNAMENSK' [0.5]
# 'KRASNY SULIN' -> 'KRASNYJ SULIN' [0.2]
# 'KRASNYE BARRI' -> 'KRASNYE BARRIKADY' [0.6187]
# 'KRASNYE CHETA' -> 'KRASNYE CHETAI' [0.1]
# 'KRASNYE TKACH' -> 'KRASNYE TKACHI' [0.1]
# 'KRASNYI BOR' -> 'KRASNYJ BOR' [0.1]
# 'KRASNYI SULIN' -> 'KRASNYJ SULIN' [0.1]
# 'KRASNYJ YAR' -> 'KRASNYJ JAR' [0.1]
# 'KRASNYKH ZOR' not found
# 'KRASNYY' -> 'KRASNYJ' [0.1]
# 'KRASNYY BOR' -> 'KRASNYJ BOR' [0.1]
# 'KRASNYY KHOLM' -> 'KRASNYJ KHOLM' [0.1]
# 'KRASNYY KUT' -> 'KRASNYJ KUT' [0.1]
# 'KRASNYY PAKHA' -> 'KRASNYJ PAKHAR' [0.23]
# 'KRASNYY TKACH' -> 'KRASNYE TKACHI' [1.4]
# 'KRASNYY YAR' -> 'KRASNYJ JAR' [0.23]
# 'KRASTU' not found
# 'KRASYK' -> 'KRASUKHA' [0.399]
# 'KRESTI' -> 'KRESTY' [0.1]
# 'KRIMSK' -> 'KRYMSK' [0.1]
# 'KRIVANDINO SH' -> 'KRIVANDINO' [1.5]
# 'KRIVODANOVK' -> 'KRIVODANOVKA' [0.1]
# 'KRIVODANOVSKI' not found
# 'KRIVOPOLYANE' -> 'KRIVOPOLJANYE' [0.63]
# 'KRIVSK' -> 'KRIVSKOE' [0.23]
# 'KRS BARRIKADY' not found
# 'KRSANOGORSK' not found
# 'KRSBSK' not found
# 'KRSK' -> 'KURSK' [0.5]
# 'KRUTAYA' -> 'KRUTOJAR' [0.399]
# 'KRUTOVA' -> 'KRUTOVO' [0.1]
# 'KRYAZH' -> 'KRJAZHLY' [0.529]
# 'KRYIMSK' -> 'KRYMSK' [1.0]
# 'KRYIMSKIIY OBL' not found
# 'KRYLOVSKAYA' -> 'KRYLOVSKAJA' [0.1]
# 'KRYUCHKOVO' -> 'KRJUCHKOVO' [0.1]
# 'KRYUKOVO' -> 'KRJUKOVO' [0.1]
# 'KSHENSKIY' -> 'KSHENSKIJ' [0.1]
# 'KSTOVSKIY RAY' not found
# 'KUBINKA ODIN' not found
# 'KUDEPSTA' not found
# 'KUDRYASHOVSKI' -> 'KUDRJASHOVSKIJ' [0.23]
# 'KUKSOVO' -> 'KUKTOVO' [1.0]
# 'KULIKOVSKIY' -> 'KULIKOVSKIJ' [0.1]
# 'KUMENII' -> 'KUMENY' [1.13]
# 'KUMYONY' -> 'KUMENY' [0.1]
# 'KUNYA' -> 'KUNJA' [0.1]
# 'KURCHANSKAYA' -> 'KURCHANSKAJA' [0.1]
# 'KURCHATOVSKIY' not found
# 'KURGANSKAYA O' -> 'KURGANSKAJA OBL' [0.399]
# 'KURILOVO ZD M' not found
# 'KUROVSKOY' -> 'KUROVSKOJ' [0.1]
# 'KURSAKOVO' -> 'KURLAKOVO' [1.0]
# 'KURSK OBL' -> 'KURSKAJA OBL' [0.568]
# 'KURSKAYA OBLA' -> 'KURSKAJA OBL' [1.13]
# 'KURSKIIY OBL' -> 'KURSKAJA OBL' [1.4]
# 'KURSKIJ' -> 'KURSKAJA' [1.4]
# 'KUSCHEVSKAYA' -> 'KUSHCHEVSKAJA' [0.23]
# 'KUSHCHEVS' -> 'KUSHCHEVSKAJA' [0.6187]
# 'KUSHCHEVSKAYA' -> 'KUSHCHEVSKAJA' [0.1]
# 'KUSRK' -> 'KUSAK' [1.0]
# 'KUTUZOVO' -> 'KUTUKOVO' [1.0]
# 'KUTUZOVS' -> 'KUTUZOVSKIJ' [0.399]
# 'KUYBYSHEV' -> 'KUJBYSHEV' [0.1]
# 'KUYBYSHEVSKIY' -> 'KUJBYSHEVSKIJ' [0.23]
# 'KUYTUN' -> 'KUJTUN' [0.1]
# 'KUYUMBA' -> 'KUJUMBA' [0.1]
# 'KUZMINSKIE' -> 'KUZMINSKOE' [1.0]
# 'KUZMINSKIE OT' not found
# 'KUZMOLOVO' not found
# 'KUZMOLOVSKIIY' -> 'KUZMOLOVSKIJ' [1.13]
# 'KUZMOLOVSKIY' -> 'KUZMOLOVSKIJ' [0.1]
# 'KUZMOLOVSKYY' -> 'KUZMOLOVSKIJ' [0.23]
# 'KUZNECHIKHINS' not found
# 'KUZNETSO' -> 'KUZNETSOV' [0.1]
# 'KUZNTSK' -> 'KUZNETSK' [0.5]
# 'KYAPPESELGA' -> 'KJAPPESELGA' [0.1]
# 'KYLEBAKI' -> 'KULEBAKI' [0.1]
# 'L TOLSTOGO' not found
# 'LADOZHSKAYA' -> 'LADOZHSKAJA' [0.1]
# 'LADOZHSKOE OZ' -> 'LADOZHSKOE OZERO' [0.399]
# 'LAGOVSKOE' -> 'LOGOVSKOE' [0.1]
# 'LAHDENPOHYA' -> 'LAKHDENPOKHJA' [0.399]
# 'LAISHEVSKIJ R' not found
# 'LAKHDENPOKHYA' -> 'LAKHDENPOKHJA' [0.1]
# 'LAKHTA' -> 'BAKHTA' [1.0]
# 'LAMBERG' -> 'LJAMBIR' [1.299]
# 'LAPSHINKA' -> 'LAPSHINSKAJA' [1.075]
# 'LAREVO' -> 'OLAREVO' [0.5]
# 'LAVROVSKOE' -> 'LAVROVSK' [1.45]
# 'LAZAREVSKO' -> 'LAZAREVSKIJ' [1.4]
# 'LAZAREVSKOE' not found
# 'LAZOR' -> 'LAZO' [1.0]
# 'LAZURNYY' -> 'LAZURNYJ' [0.1]
# 'LEBEDYAN' -> 'LEBEDJAN' [0.1]
# 'LEBEDYAN LIPE' not found
# 'LEBYAZHE' -> 'LEBJAZHIJ' [0.399]
# 'LEBYAZHIE' -> 'LEBJAZHYE' [0.23]
# 'LEBYAZHIY' -> 'LEBJAZHIJ' [0.23]
# 'LECHISCHEVO' not found
# 'LECHISHCHEVO' not found
# 'LEJNEVO' -> 'LEZHNEVO' [0.1]
# 'LEN OB MIS' -> 'LENINGRADSKAJA OBL' [0]
# 'LENINAKAN' -> 'LENINAVAN' [1.0]
# 'LENINSK KUZNE' -> 'LENINSK KUZNETSKIJ' [0.90431]
# 'LENINSKII' -> 'LENINSKIJ' [0.1]
# 'LENINSKIY' -> 'LENINSKIJ' [0.1]
# 'LENINSKIY RAY' not found
# 'LENINSKIY TUL' not found
# 'LENINSKUZNETS' not found
# 'LENINSKY' -> 'LENINSKIJ' [0.23]
# 'LENSOVETOVSKI' -> 'LENSOVETOVSKIJ' [0.1]
# 'LENTEVO' -> 'LENTYEVO' [0.5]
# 'LEPESHKI' not found
# 'LESHKOVO' -> 'ALESHKOVO' [0.5]
# 'LESKALOVO' -> 'LESKOLOVO' [0.1]
# 'LESNAYA POLYA' -> 'LESNAJA POLJANA' [0.6187]
# 'LESNOI' -> 'LESNOJ' [0.1]
# 'LESNOJ GOROD' -> 'LESNOJ GORODOK' [0.23]
# 'LESNOJ GORODO' -> 'LESNOJ GORODOK' [0.1]
# 'LESNOY' -> 'LESNOJ' [0.1]
# 'LESNOY GORODO' -> 'LESNOJ GORODOK' [0.23]
# 'LESNOYGOROD' -> 'LESNOJ GORODOK' [1.2947]
# 'LESNYE POLYAN' -> 'LESNYE POLJANY' [0.23]
# 'LESSIB' not found
# 'LETNIY OTDYKH' -> 'LETNIJ OTDYKH' [0.1]
# 'LETOSHNIKY' -> 'LETOSHNIKI' [0.1]
# 'LEV TOLSTOY' -> 'LEV TOLSTOJ' [0.1]
# 'LEZYM' not found
# 'LGORODOK' -> 'GORODOK' [1.0]
# 'LIKINO DULEV' -> 'LIKINO DULEVO' [0.1]
# 'LIKINODULEVO' -> 'LIKINO DULEVO' [0.5]
# 'LIKOVA' -> 'LYKOVO' [0.23]
# 'LINDA LINDOV' not found
# 'LIPETS' -> 'LIPETSK' [0.2]
# 'LIPETSK OBL' -> 'LIPETSKAJA OBL' [0.399]
# 'LIPETSKAYA OB' -> 'LIPETSKAJA OBL' [0.23]
# 'LIPETSKIIY OBL' -> 'LIPETSKAJA OBL' [1.4]
# 'LIPETZK' -> 'LIPETSK' [1.0]
# 'LIPICY' -> 'LIPITSY' [0.1]
# 'LIPITCI' -> 'LIPITSY' [1.4]
# 'LIPITSI' -> 'LIPITSY' [0.1]
# 'LIPTSK' -> 'LIPETSK' [0.5]
# 'LISIY NOS' -> 'LISIJ NOS' [0.1]
# 'LISKINSKIY L' not found
# 'LISTVYANKA' -> 'LISTVJANKA' [0.1]
# 'LISTVYANKA R' -> 'LISTVJANKA' [1.5]
# 'LISTVYANKA RP' -> 'LISTVJANKA' [1.6]
# 'LITARINO' -> 'LYTKARINO' [0.63]
# 'LITKARINO' -> 'LYTKARINO' [0.1]
# 'LIUBERTSY' -> 'LJUBERTSY' [0.1]
# 'LIUDINOVO' -> 'LJUDINOVO' [0.1]
# 'LIVADIA' -> 'LIVADIJA' [0.1]
# 'LIVADIIA' -> 'LIVADIJA' [0.1]
# 'LIVADIYA' -> 'LIVADIJA' [0.1]
# 'LJUBERCY' -> 'LJUBERTSY' [0.1]
# 'LOBNIA' -> 'LOBNJA' [0.1]
# 'LOBNY' -> 'LOBNJA' [0.23]
# 'LOBNYA' -> 'LOBNJA' [0.1]
# 'LOBNYA MKR KA' not found
# 'LODEINOE POL' -> 'LODEJNOE POLE' [0.23]
# 'LODEYNOE POLE' -> 'LODEJNOE POLE' [0.1]
# 'LODEYNOPOLSKI' not found
# 'LOKNYA' -> 'LOKNJA' [0.1]
# 'LOKOMOTIVNYY' -> 'LOKOMOTIVNYJ' [0.1]
# 'LOO' -> 'LOBOK' [0.85]
# 'LOPATINO LENI' not found
# 'LOSIN' -> 'LOSINYJ' [0.36]
# 'LOSINO PETR' -> 'LOSINO PETROVSKIJ' [1.275603]
# 'LOSINO PETROV' -> 'LOSINO PETROVSKIJ' [0.6187]
# 'LOSINOOSTROVS' not found
# 'LOTOSHIN' -> 'LOTOSHINO' [0.1]
# 'LOTOSOVO' -> 'LOKOSOVO' [1.0]
# 'LSTVNK' not found
# 'LUBAN' -> 'LJUBAN' [0.1]
# 'LUBERCI' -> 'LJUBERTSY' [0.399]
# 'LUBERCY' -> 'LJUBERTSY' [0]
# 'LUBERTHY' -> 'LJUBERTSY' [1.13]
# 'LUBERTSYI' -> 'LJUBERTSY' [1.13]
# 'LUBRTS' -> 'LJUBERTSY' [0.919]
# 'LUCHINSKIY' not found
# 'LUG' -> 'LUGI' [0.2]
# 'LUGOVAYA' -> 'LUGOVAJA' [0.1]
# 'LUHOVICY' -> 'LUKHOVITSY' [0.23]
# 'LUHOVITSY' -> 'LUKHOVITSY' [0.1]
# 'LUKOYANOV' -> 'LUKOJANOV' [0.1]
# 'LUKYANOVO' -> 'LUKJANOVO' [0.1]
# 'LUNEVSKOE' -> 'LINEVSKOE' [1.0]
# 'LUPPOLOVO' not found
# 'LVA TOLSTOGO' not found
# 'LVOVSKIY' -> 'LVOVSKIJ' [0.1]
# 'LVOVSKIY R' -> 'LVOVSKIJ' [1.55]
# 'LYADY' -> 'LJADY' [0.1]
# 'LYAMBIRSKIIY' not found
# 'LYANGASOVO MK' -> 'LJANGASOVO' [1.6]
# 'LYANTOR' -> 'LJANTOR' [0.1]
# 'LYASKELYA' -> 'LJASKELJA' [0.23]
# 'LYBERTSY' -> 'LJUBERTSY' [0.63]
# 'LYISVA' -> 'LYSVA' [1.0]
# 'LYITKARINO' -> 'LYTKARINO' [1.0]
# 'LYUBAN' -> 'LJUBAN' [0.1]
# 'LYUBERCI' -> 'LJUBERTSY' [0]
# 'LYUBERETS' -> 'LJUBIMETS' [1.299]
# 'LYUBERETSKIY' not found
# 'LYUBERTCU' not found
# 'LYUBERTSI' -> 'LJUBERTSY' [0]
# 'LYUBERTSY' -> 'LJUBERTSY' [0]
# 'LYUBERTSY E' -> 'LJUBERTSY' [1.52222222222]
# 'LYUBERTSY GOR' not found
# 'LYUBERTSY PO' not found
# 'LYUBERTSYI' -> 'LJUBERTSY' [1.13]
# 'LYUBINSKIJ' -> 'LJUBINSKIJ' [0.1]
# 'LYUBINSKIY' -> 'LJUBINSKIJ' [0.23]
# 'LYUBNYA' -> 'LUBNJA' [1.4]
# 'LYUBOKHNA' -> 'LJUBOKHNA' [0.1]
# 'LYUBUCHANY' -> 'LJUBUCHANY' [0.1]
# 'LYUBUCHATSY' not found
# 'LYUBYTINO' -> 'LJUBYTINO' [0.1]
# 'LYUDINOVO' -> 'LJUDINOVO' [0.1]
# 'M' -> 'MIR' [0.46]
# 'M O' -> 'MAGO' [1.26]
# 'M VODY' not found
# 'MAGANSKIY' -> 'MAGANSK' [1.48571428571]
# 'MAGNIT' -> 'MAGNITKA' [0.36]
# 'MAGNITNYY' -> 'MAGNITNYJ' [0.1]
# 'MAGNITOGORS' -> 'MAGNITOGORSK' [0.1]
# 'MAGSUD' not found
# 'MAHACHKALA' -> 'MAKHACHKALA' [0.1]
# 'MAIKOP' -> 'MAJKOP' [0.1]
# 'MAIMA' -> 'MAJMA' [0.1]
# 'MAISKI' -> 'MAJSKIJ' [0.23]
# 'MAKARE' -> 'MAKARIJ' [0.33]
# 'MALAHOVO' -> 'MALAKHOVO' [0.1]
# 'MALAKHOVKA LY' -> 'MALAKHOVKA' [1.5]
# 'MALAYA DUBNA' -> 'MALAJA DUBNA' [0.1]
# 'MALAYA LAYA' not found
# 'MALAYA PURGA' -> 'MALAJA PURGA' [0.1]
# 'MALAYA RUKAVI' not found
# 'MALAYA VISHER' -> 'MALAJA VISHERA' [0.23]
# 'MALCEVO' -> 'MALTSEVO' [0.1]
# 'MALECHKINO PO' -> 'MALECHKINO' [1.5]
# 'MALEVANNYY' not found
# 'MALINUKHA' not found
# 'MALOARHANGELS' -> 'MALOARKHANGELSK' [0.23]
# 'MALOARKHANGEL' -> 'MALOARKHANGELSK' [0.23]
# 'MALOBRUSYANSK' -> 'MALOBRUSJANSKOE' [0.399]
# 'MALOE ISAK' not found
# 'MALOE IVANOVS' not found
# 'MALOE LEDOVO' not found
# 'MALOE LUGOVOE' not found
# 'MALOJAROSLAVE' -> 'MALOJAROSLAVETS' [0.23]
# 'MALORECHENS' -> 'MALORECHENSKOE' [0.399]
# 'MALOYA' -> 'MALOJAZ' [0.33]
# 'MALOYAAROSLAV' not found
# 'MALOYAROSLAVE' -> 'MALOJAROSLAVETS' [0.399]
# 'MALOYE KARLIN' -> 'MALOE KARLINO' [0.23]
# 'MALYAROSLAVEC' -> 'MALOJAROSLAVETS' [1.075]
# 'MALYE KOLPANY' not found
# 'MALYE VYAZEMY' not found
# 'MALYE VYAZYOM' not found
# 'MALYSHEVO RAM' not found
# 'MAMADISH' -> 'MAMADYSH' [0.1]
# 'MAMADYSHSKIJ' not found
# 'MAMAY' -> 'MAMONY' [0.63]
# 'MAMONOVA' -> 'MAMONOVO' [0.1]
# 'MAMONY MKR' not found
# 'MAMONY MKR Z' not found
# 'MAMYRI' -> 'MAMYR' [1.0]
# 'MANSKIY' -> 'UMANSKIJ' [0.75]
# 'MANYAR' -> 'MINJAR' [1.4]
# 'MARCHUGI' not found
# 'MARIANOVKA' -> 'MARJANOVKA' [0.1]
# 'MARINA ROSHCH' -> 'MARYINA ROSHCHA' [0.75]
# 'MARINO' -> 'MORINO' [0.1]
# 'MARTA' -> 'MARTOVKA' [0.6187]
# 'MARTEMYANOVO' not found
# 'MARTYUSH' -> 'MARTJUSH' [0.1]
# 'MARUSINO LYUB' not found
# 'MARYANSKAYA' -> 'MARJANSKAJA' [0.23]
# 'MASLOVA PR' -> 'MASLOVA PRISTAN' [0.90431]
# 'MASLOVA PRIST' -> 'MASLOVA PRISTAN' [0.23]
# 'MASLOVSKIY O' -> 'MASLOVSKIJ' [1.5]
# 'MASSIV MSHINS' not found
# 'MATKASELKYA' -> 'MATKASELKJA' [0.1]
# 'MATOXA' -> 'MATOKSA' [0.1]
# 'MATYR' -> 'MATUR' [0.1]
# 'MATYRSKIY' -> 'MATYRSKIJ' [0.1]
# 'MATYUSHINO' -> 'MATJUSHKINO' [0.63]
# 'MAURINO' -> 'MAKURINO' [0.5]
# 'MAYAK' -> 'MAJAK' [0.1]
# 'MAYAKOVSKOGO' not found
# 'MAYANGA' -> 'MAJANGA' [0.1]
# 'MAYKOP' -> 'MAJKOP' [0.1]
# 'MAYMA' -> 'MAJMA' [0.1]
# 'MAYNILO' not found
# 'MAYSKIY' -> 'MAJSKIJ' [0.23]
# 'MCENSK' -> 'MTSENSK' [0.1]
# 'MECHETINSKAYA' -> 'MECHETINSKAJA' [0.1]
# 'MECHNIKOVO' -> 'MECHNIKOVA' [1.0]
# 'MEDIKO INSTRU' not found
# 'MEDOVEEVKA' not found
# 'MEDVEDOVSKAYA' -> 'MEDVEDOVSKAJA' [0.1]
# 'MEDVEOZERY' not found
# 'MEDVEZHEGORSK' -> 'MEDVEZHYEGORSK' [0.5]
# 'MEDVEZHI OZER' -> 'MEDVEZHYI OZERA' [0.529]
# 'MEDYIN' -> 'MEDYN' [1.0]
# 'MEKHANIZATORO' not found
# 'MELIORATIVNYY' -> 'MELIORATIVNYJ' [0.1]
# 'MELKOVODNYY' not found
# 'MERKULEVO' -> 'MERKULYEVO' [0.5]
# 'MESHCHEVSK' -> 'MESHCHOVSK' [1.0]
# 'MESHKOVO' -> 'MESHKOVOE' [0.1]
# 'METALLOPLOSHC' not found
# 'METALLOSTROY' -> 'METALLOSTROJ' [0.1]
# 'METALLPLOSHCH' -> 'METALLPLOSHCHADKA' [0.6187]
# 'METRO BELORUS' not found
# 'MEZHDU' not found
# 'MEZHDURECHENS' -> 'MEZHDURECHENSK' [0.1]
# 'MICHURINSKIY' -> 'MICHURINSKIJ' [0.1]
# 'MIHAILOVKA' -> 'MIKHAJLOVKA' [0.23]
# 'MIHAJLOVKA' -> 'MIKHAJLOVKA' [0.1]
# 'MIHAJLOVSKOE' -> 'MIKHAJLOVSKOE' [0.1]
# 'MIHAYLOVKA' -> 'MIKHAJLOVKA' [0.23]
# 'MIHNEVO' -> 'MIKHNEVO' [0.1]
# 'MIKHAILOVKA' -> 'MIKHAJLOVKA' [0.1]
# 'MIKHAIYLOVKA' -> 'MIKHAJLOVKA' [1.13]
# 'MIKHAIYLOVSK' -> 'MIKHAJLOVSK' [1.13]
# 'MIKHAYLOV' -> 'MIKHAJLOV' [0.1]
# 'MIKHAYLOVKA' -> 'MIKHAJLOVKA' [0.1]
# 'MIKHAYLOVSK' -> 'MIKHAJLOVSK' [0.1]
# 'MIKHAYLOVSKAY' -> 'MIKHAJLOVSKAJA' [0.399]
# 'MIKHNEVO STUP' not found
# 'MILYUTINSKAYA' -> 'MILJUTINSKAJA' [0.23]
# 'MIN VODY' not found
# 'MINERALNYE VO' -> 'MINERALNYE VODY' [0.23]
# 'MINERALOVODSK' not found
# 'MINSKO' -> 'MINSKOE' [0.1]
# 'MINVODY' not found
# 'MINYAR' -> 'MINJAR' [0.1]
# 'MIRNYY' -> 'MIRNYJ' [0.1]
# 'MIS' -> 'MYS' [0.1]
# 'MISAYLOVO' -> 'MISAJLOVO' [0.1]
# 'MISHKIN' -> 'MYSHKIN' [0.1]
# 'MISHUTKINO' -> 'MISHUTINO' [1.0]
# 'MITICSHI' -> 'MYTISHCHI' [0.23]
# 'MITISCHI' -> 'MYTISHCHI' [0.23]
# 'MITISHCHI' -> 'MYTISHCHI' [0.1]
# 'MITISHCI' -> 'MYTISHCHI' [0.63]
# 'MITISHI' -> 'MYTISHCHI' [0.23]
# 'MITISHY' -> 'MYTISHCHI' [0.399]
# 'MIYTISCHI' -> 'MYTISHCHI' [1.4]
# 'MKR KOMMUNAR' not found
# 'MKR SALTYKOVK' not found
# 'MLSKVA' -> 'MOSKVA' [1.0]
# 'MOCKVA' -> 'MOSKVA' [1.0]
# 'MODENOVO' -> 'IZMODENOVO' [1.15]
# 'MODKOVSKIIY R' not found
# 'MOGAYSK' -> 'MOZHAJSK' [0.23]
# 'MOKROVO' -> 'MOKHOVO' [1.0]
# 'MOKSHINO KONA' not found
# 'MOLCHANOVKA' -> 'MOLCHANOVO' [1.4]
# 'MOLKINO' -> 'MOLVINO' [1.0]
# 'MOLODEZHNYI' -> 'MOLODEZHNYJ' [0.1]
# 'MOLODEZHNYY' -> 'MOLODEZHNYJ' [0.1]
# 'MOLOKOVSK' -> 'MOLODOVSK' [1.0]
# 'MOLOKOVSKOE' not found
# 'MONASTYRSHCHI' -> 'MONASTYRSHCHINA' [0.23]
# 'MONETNYY' -> 'MONETNYJ' [0.1]
# 'MOROVO' -> 'MORSOVO' [0.5]
# 'MORYAKOVSKIY' not found
# 'MOSCOVSKIY' -> 'MOSTOVSKIJ' [1.4]
# 'MOSCOW MOS' not found
# 'MOSCOW R N K' not found
# 'MOSCOW SCHER' not found
# 'MOSCOWG ZHELE' not found
# 'MOSCOWSKIY' not found
# 'MOSHKOVO RP' not found
# 'MOSK OBL' not found
# 'MOSKOV' -> 'MOSKOVO' [0.2]
# 'MOSKOVSKIY' -> 'MOSKOVSKIJ' [0]
# 'MOSKOW' -> 'MOSKVA' [0]
# 'MOSTO' -> 'MOSTOVKA' [0.698]
# 'MOSTOVAYA' -> 'MOSTOVAJA' [0.1]
# 'MOSTOVSKIIY R' -> 'MOSTOVSKIJ' [1.6]
# 'MOSTOVSKOY' -> 'MOSTOVSKOJ' [0.1]
# 'MOVOSIBIRSK' -> 'NOVOSIBIRSK' [1.0]
# 'MOZHAYSK' -> 'MOZHAJSK' [0]
# 'MOZHAYSKIY' -> 'MOZHAJSKIJ' [0.23]
# 'MSHINSKAYA' -> 'MSHINSKAJA' [0.1]
# 'MSTIHINO' -> 'MSTIKHINO' [0.1]
# 'MUCHKAPSKIY' -> 'MUCHKAPSKIJ' [0.1]
# 'MUEZERSKIY' -> 'MUEZERSKIJ' [0.1]
# 'MUHINO' -> 'MUKHINO' [0.1]
# 'MURAVINO' -> 'MURAVLENKO' [1.475]
# 'MURIN' -> 'MURINO' [0.1]
# 'MURMANS' -> 'MURMANSK' [0.1]
# 'MURMNS' -> 'MURMANSK' [0.75]
# 'MYACHKOVO' -> 'MJACHKOVO' [0.1]
# 'MYAKININO' not found
# 'MYAKSA' -> 'MJAKSA' [0.1]
# 'MYASNIKOVSKIY' not found
# 'MYATLEVO' -> 'MJATLEVO' [0.1]
# 'MYITISCHI' -> 'MYTISHCHI' [1.4]
# 'MYITISCHINSKI' not found
# 'MYITYISHI' not found
# 'MYLYE KOLPANY' not found
# 'MYTISCHI' -> 'MYTISHCHI' [0]
# 'MYTISCHI MOS' not found
# 'MYTISH' -> 'MYTISHCHI' [0.23]
# 'MYTISHCHIN R' not found
# 'MYTISHCHINSK' not found
# 'MYTISHCHINSKI' not found
# 'MYTISHCHY' -> 'MYTISHCHI' [0.1]
# 'MYTISHCI' -> 'MYTISHCHI' [0.5]
# 'MYTYSHCI' -> 'MYTISHCHI' [0.63]
# 'N CHELNY' not found
# 'N FOMINSK' -> 'NARO FOMINSK' [0.798]
# 'N IVANOVSKOE' -> 'NOVO IVANOVSKOE' [0.798]
# 'N MOSCOWSKIY' not found
# 'N MYSHASTOVS' not found
# 'N NOVGOROD OBL' not found
# 'N SORTIMSKIY' not found
# 'N SORTYMSKIY' not found
# 'N TAGIL' not found
# 'N USMAN' not found
# 'N ZAVIDOVSKIY' not found
# 'NABEREZHNIE C' -> 'NABEREZHNYE CHELNY' [1.275603]
# 'NABEREZNIE CH' not found
# 'NAGORE' -> 'NAGORYE' [0.5]
# 'NAGORNII' -> 'NAGORNYJ' [0.1]
# 'NAGORNIY' -> 'NAGORNYJ' [0.1]
# 'NAGORNY' -> 'NAGORNYJ' [0.1]
# 'NAGORNYIY' -> 'NAGORNYJ' [1.13]
# 'NAGORNYY' -> 'NAGORNYJ' [0.1]
# 'NAHABN' -> 'NAKHABINO' [0.919]
# 'NAKHABINO KRA' not found
# 'NAKHABINO RP' not found
# 'NAOR FOMINSK' -> 'NARO FOMINSK' [1.5]
# 'NARFOM' not found
# 'NARISHKINO' -> 'NARYSHKINO' [0.1]
# 'NARO FOMIN' -> 'NARO FOMINSK' [0.23]
# 'NARO FOMINS' -> 'NARO FOMINSK' [0.1]
# 'NARO FOMINSKI' -> 'NARO FOMINSK' [1.0]
# 'NAROFOMINSK' -> 'NARO FOMINSK' [0.5]
# 'NARYAN MAR' -> 'NARJAN MAR' [0.1]
# 'NASHEKOVO' not found
# 'NATALINO' -> 'NATALYINO' [0.1]
# 'NATUHAEVSKAYA' -> 'NATUKHAEVSKAJA' [0.23]
# 'NATUKHAEVSKAY' -> 'NATUKHAEVSKAJA' [0.23]
# 'NAVLYA' -> 'NAVLJA' [0.1]
# 'NAYDORF' -> 'NAJDORF' [0.1]
# 'NAZAREVO' -> 'NAZARYEVO' [0.5]
# 'NAZAREVSKIY' -> 'LAZAREVSKIJ' [1.4]
# 'NAZARIEVO' -> 'NAZARYEVO' [0.1]
# 'NAZIYA' -> 'NAZIJA' [0.1]
# 'NEFTEYUGANSK' -> 'NEFTEJUGANSK' [0.1]
# 'NEFTUG' not found
# 'NEKHAEVSKAYA' -> 'NEKHAEVSKAJA' [0.1]
# 'NEKLYUDOVO' -> 'NEKLJUDOVO' [0.1]
# 'NEKRASOVSKII' -> 'NEKRASOVSKIJ' [0.1]
# 'NEKRASOVSKIY' -> 'NEKRASOVSKIJ' [0.1]
# 'NEMCHANOVKA' -> 'NEMCHINOVKA' [1.0]
# 'NEMCHINOVKA O' -> 'NEMCHINOVKA' [1.38181818182]
# 'NEMETSKAYA DE' not found
# 'NEMTSOVO' -> 'NEMTSEVO' [1.0]
# 'NERYUNGRI' -> 'NERJUNGRI' [0.1]
# 'NESTUKOVO' not found
# 'NET' -> 'VET' [1.0]
# 'NEVINNOMYSK' -> 'NEVINNOMYSSK' [0.5]
# 'NEVINOMYSSK' -> 'NEVINNOMYSSK' [0.5]
# 'NEVSKAYA DUBR' not found
# 'NEVYANSK' -> 'NEVJANSK' [0.1]
# 'NEZAMAEVSKAYA' -> 'NEZAMAEVSKAJA' [0.1]
# 'NIGNEKAMSK' -> 'NIZHNEKAMSK' [0.1]
# 'NIGNEVARTOVSK' -> 'NIZHNEVARTOVSK' [0.1]
# 'NIGNIY NOV' -> 'NIZHNIJ NOVGOROD' [0.1]
# 'NIGNIY TAGIL' -> 'NIZHNIJ TAGIL' [0.23]
# 'NIJIY NOVGORO' -> 'NIZHNIJ NOVGOROD' [1.2947]
# 'NIKANOVSKAYA' not found
# 'NIKOLO PAVLOV' -> 'NIKOLO PAVLOVSKOE' [0.6187]
# 'NIKOLO RAMENE' -> 'NIKOLO RAMENYE' [0.5]
# 'NIKOLO URYUPI' not found
# 'NIKOLSKIE KHU' not found
# 'NIKOLSKIY' -> 'NIKOLSKIJ' [0.1]
# 'NIKOLSKOE ENO' -> 'NIKOLSKOE E' [1.38181818182]
# 'NIKULICHI' not found
# 'NITVA' -> 'NYTVA' [0.1]
# 'NIZGNIY NOVGO' not found
# 'NIZHEGOROD OB' not found
# 'NIZHEGORODSK' -> 'NIZHEGORODSKAJA' [0.399]
# 'NIZHEGORODSKA' -> 'NIZHEGORODSKAJA' [0.23]
# 'NIZHEGORODSKI' -> 'NIZHEGORODSKAJA' [1.075]
# 'NIZHHIY NOVGO' not found
# 'NIZHN NOVGORD' -> 'NIZHNIJ NOVGOROD' [1.098]
# 'NIZHNEBAKANSK' -> 'NIZHNEBAKANSKAJA' [0.399]
# 'NIZHNEE ELKIN' not found
# 'NIZHNESORTYMS' -> 'NIZHNESORTYMSKIJ' [0.399]
# 'NIZHNEVARTOVS' -> 'NIZHNEVARTOVSK' [0.1]
# 'NIZHNEVATORSK' not found
# 'NIZHNIY INGAS' -> 'NIZHNIJ INGASH' [0.23]
# 'NIZHNIY NOV' -> 'NIZHNIJ NOVGOROD' [0.1]
# 'NIZHNIY NOVGOROD' -> 'NIZHNIJ NOVGOROD' [0.1]
# 'NIZHNIY PALNI' not found
# 'NIZHNIY TAGIL' -> 'NIZHNIJ TAGIL' [0.1]
# 'NIZHNJAJA TUR' -> 'NIZHNJAJA TURA' [0.1]
# 'NIZHNY TAGIL' -> 'NIZHNIJ TAGIL' [0.33]
# 'NIZHNYAYA TUR' -> 'NIZHNJAJA TURA' [0.399]
# 'NIZHNYI NOVGO' -> 'NIZHNIJ NOVGOROD' [0.90431]
# 'NIZKMK' not found
# 'NIZNIJ TAGIL' -> 'NIZHNIJ TAGIL' [0.5]
# 'NIZNIY LOMOV' -> 'NIZHNIJ LOMOV' [0.75]
# 'NIZNOV' -> 'NEZHNOVO' [0.919]
# 'NIZTAG' not found
# 'NOGINSK OBL' not found
# 'NOGINSKIY' -> 'NOGINSKAJA' [0.75]
# 'NOGINSKIY OB' not found
# 'NORSHI' -> 'KORSHIK' [1.4]
# 'NOSCOW OBL' not found
# 'NOVAJA U' -> 'NOVAJA UDA' [0.36]
# 'NOVALT' not found
# 'NOVAY' -> 'NOVAJA' [0.23]
# 'NOVAYA' -> 'NOVAJA' [0.1]
# 'NOVAYA KUPAVN' not found
# 'NOVAYA LADOGA' -> 'NOVAJA LADOGA' [0.1]
# 'NOVAYA OTRA' -> 'NOVAJA OTRADOVKA' [1.275603]
# 'NOVAYA SLOBOD' -> 'NOVAJA SLOBODA' [0.33]
# 'NOVAYA TURA' -> 'NOVAJA BURA' [1.13]
# 'NOVAYA USMAN' -> 'NOVAJA USMAN' [0.1]
# 'NOVEE PS' not found
# 'NOVGOROD OBL' -> 'NOVGORODSKAJA OBL' [1.35892]
# 'NOVGOROD OBLR' not found
# 'NOVII BIT' -> 'NOVYJ BYT' [0.23]
# 'NOVIY BIT' -> 'NOVYJ BYT' [0.23]
# 'NOVKCHEBOKSAR' not found
# ...
# 'TSENTRALNYY' -> 'TSENTRALNYJ' [0.1]
# 'TSENTRALNYY M' -> 'TSENTRALNYJ' [1.48181818182]
# 'TSENTRALNYY Z' -> 'TSENTRALNYJ' [1.48181818182]
# 'TSIBINO' not found
# 'TSIMLYANSK' -> 'TSIMLJANSK' [0.1]
# 'TSOVB MKR' not found
# 'TSURYUPY' not found
# 'TSVETKOVSKIY' -> 'TSVETKOVSKIJ' [0.1]
# 'TSVETOCHN' -> 'TSVETOCHNYJ' [0.36]
# 'TSYBANOBALKA' -> 'TSIBANOBALKA' [0.1]
# 'TSYVILSK' -> 'TSIVILSK' [0.1]
# 'TUAPSE OBL' not found
# 'TUCHKOVO RUZ' not found
# 'TUCHKOVO RUZS' not found
# 'TUGOLESSKIY B' -> 'TUGOLESSKIJ BOR' [0.399]
# 'TUGULYIM' -> 'TUGULYM' [1.0]
# 'TUGURGOIY A' not found
# 'TULA MEND' not found
# 'TULA OBL' not found
# 'TULA SKUR' not found
# 'TULSKAYA OBL' -> 'TULSKAJA OBL' [0.1]
# 'TULSKAYA OBLA' -> 'TULSKAJA OBL' [1.13]
# 'TULSKIIY OBL' -> 'TULSKAJA OBL' [1.4]
# 'TURAI' -> 'TURAN' [1.0]
# 'TURGOYAK' -> 'TURGOJAK' [0.1]
# 'TUTAYEV' -> 'TUTAEV' [0.1]
# 'TUUGOLESS' not found
# 'TUYMAZY' -> 'TUJMAZY' [0.1]
# 'TVER OBL' -> 'TVERSKAJA OBL' [1.35892]
# 'TVER PRIGOROD' not found
# 'TVERITINO' not found
# 'TVERSKAYA OBL' -> 'TVERSKAJA OBL' [0.1]
# 'TVERSKOIY OBL' -> 'TVERSKAJA OBL' [1.4]
# 'TVOROGOVO' -> 'TVOROZHKOVO' [0.63]
# 'TYAMSHA' -> 'TJAMSHA' [0.1]
# 'TYARLEVO' -> 'TJARLEVO' [0.1]
# 'TYLA' -> 'TULA' [0.1]
# 'TYLYACHI' -> 'TJULJACHI' [0.919]
# 'TYMEN' -> 'TIMINO' [0.399]
# 'TYUBUK' -> 'TJUBUK' [0.1]
# 'TYULYACHI' -> 'TJULJACHI' [0.23]
# 'TYUMEN' -> 'TJUMEN' [0]
# 'TYUMEN A' -> 'TJUMENJAK' [1.569]
# 'TYUMEN ISHIM' not found
# 'TYUMEN NP' not found
# 'TYUMENSKAYA O' -> 'TJUMENSKAJA OBL' [0.6187]
# 'U SAHALINSK' not found
# 'UCHASTOK FEOF' not found
# 'UDELNAIA' -> 'UDELNAJA' [0.1]
# 'UDELNAYA' -> 'UDELNAJA' [0]
# 'UDOBNAYA' -> 'UDOBNAJA' [0.1]
# 'UDOMLYA' -> 'UDOMLJA' [0.1]
# 'UGLYANETS' -> 'UGLJANETS' [0.1]
# 'UGNO SAKHALIN' -> 'JUZHNO SAKHALINSK' [0.6187]
# 'UHTA' -> 'UKHTA' [0.1]
# 'UL YANOVSK' -> 'ULJANOVSK' [1.4]
# 'ULIYANOVSKAYA' -> 'ULJANOVSKAJA' [1.569]
# 'ULT YAGUN' -> 'ULT JAGUN' [0.1]
# 'ULYANOVKA' -> 'ULJANOVKA' [0.1]
# 'ULYANOVSK' -> 'ULJANOVSK' [0.1]
# 'UMRISHENKA' not found
# 'UPORNYY' -> 'UPORNYJ' [0.1]
# 'UPRAVLENCHE' not found
# 'UPRAVLENCHESK' not found
# 'URAY' -> 'URAJ' [0.1]
# 'URIEV POLSKIY' -> 'JURYEV POLSKIJ' [0.399]
# 'URSHELSKIY' -> 'URSHELSKIJ' [0.1]
# 'URYUPINSK' -> 'URJUPINSK' [0.1]
# 'USOLE SIBIRSK' -> 'USOLYE SIBIRSKOE' [1.075]
# 'USOLIE SIBIRS' -> 'USOLYE SIBIRSKOE' [0.6187]
# 'USOLSKIY' -> 'USOVSKIJ' [1.4]
# 'USSURIYSK' -> 'USSURIJSK' [0.1]
# 'UST DONETSKIY' -> 'UST DONETSKIJ' [0.1]
# 'UST KINELSKIY' -> 'UST KINELSKIJ' [0.1]
# 'UST KURDYUM' -> 'UST KURDJUM' [0.1]
# 'UST ORDYNSKIY' -> 'UST ORDYNSKIJ' [0.1]
# 'UST REN SEL' not found
# 'USTE' -> 'USTYE' [0.5]
# 'USTE NARO FOM' not found
# 'USTINSKIY' -> 'USTYINSKIJ' [0.75]
# 'USTIYNSKIY' -> 'USTYINSKIJ' [0.399]
# 'USTOUZHNA' -> 'USTJUZHNA' [1.0]
# 'USTUZHINA' -> 'USTJUZHNA' [1.13]
# 'USTYUG' -> 'USTJUG' [0.1]
# 'USTYUZHNA' -> 'USTJUZHNA' [0.1]
# 'UVELSKIY' -> 'UVELSKIJ' [0.1]
# 'UYAR' -> 'UJAR' [0.1]
# 'UYUTNOE' -> 'UJUTNOE' [0.1]
# 'UZHNIY' -> 'JUZHNYJ' [0.23]
# 'UZHURL' -> 'UZHUR' [1.0]
# 'UZLOVAYA' -> 'UZLOVAJA' [0.1]
# 'UZUNOV' -> 'UZUNOVO' [0.1]
# 'V ETKUL' not found
# 'V KRIVODANOV' not found
# 'V PYSHMA' not found
# 'V SADOVYJJ' not found
# 'V USTUG' not found
# 'V VOLOCHEK' not found
# 'VAKHROMEEVO' not found
# 'VALDAY' -> 'VALDAJ' [0.1]
# 'VALUYKI' -> 'VALUJKI' [0.1]
# 'VARDANE' not found
# 'VARDANE VERIN' not found
# 'VARENIKOVSKAY' -> 'VARENIKOVSKAJA' [0.23]
# 'VARNITSY' not found
# 'VARTEMYAGI' not found
# 'VASILEVSKIY' -> 'VASILYEVSKIJ' [0.75]
# 'VASILEVSKOE' -> 'VASILYEVSKOE' [0.5]
# 'VASILIEVO' -> 'VASILYEVO' [0.1]
# 'VASYURINSKAYA' -> 'VASJURINSKAJA' [0.23]
# 'VAYYALOVO' not found
# 'VEKHNYAYA PYS' not found
# 'VEL USTUG' not found
# 'VELIKIY NOV' -> 'VELIKIJ NOVGOROD' [0]
# 'VELIKIY USTUG' -> 'VELIKIJ USTJUG' [0.23]
# 'VELIKIY USTYU' -> 'VELIKIJ USTJUG' [0.399]
# 'VELIKIY USYUG' -> 'VELIKIJ USTJUG' [0.919]
# 'VELYAMINOVO' -> 'VELJAMINOVO' [0.1]
# 'VER USLON' not found
# 'VERBILI' -> 'VERBILKI' [0.5]
# 'VEREIA' -> 'VEREJA' [0.1]
# 'VERESCHAGINO' -> 'VERESHCHAGINO' [0.1]
# 'VERESHAGINO' -> 'VERESHCHAGINO' [0.1]
# 'VERETE' -> 'VERETEVO' [0.36]
# 'VEREYA' -> 'VEREJA' [0.1]
# 'VERH CHEBULA' -> 'VERKH CHEBULA' [0.1]
# 'VERHNEABAKANS' not found
# 'VERHNESADOV' -> 'VERKHNESADOVOE' [0.399]
# 'VERHNEYARKEEV' -> 'VERKHNEJARKEEVO' [0.399]
# 'VERHNIE TATIS' -> 'VERKHNIE TATYSHLY' [0.90431]
# 'VERHNJAJA PYS' -> 'VERKHNJAJA PYSHMA' [0.6187]
# 'VERHOSHIZHEME' -> 'VERKHOSHIZHEMYE' [0.63]
# 'VERHOVIE' -> 'VERKHOVYE' [0.23]
# 'VERKH NEYVINS' -> 'VERKH NEJVINSKIJ' [0.6187]
# 'VERKHN KHAVA' -> 'VERKHNJAJA KHAVA' [0.9684]
# 'VERKHN PYSHM' -> 'VERKHNJAJA PYSHMA' [1.35892]
# 'VERKHN PYSHMA' -> 'VERKHNJAJA PYSHMA' [0.9684]
# 'VERKHNE BAKAN' -> 'VERKHNIJ BAKSAN' [0.929]
# 'VERKHNEBAKANS' -> 'VERKHNEBAKANSKIJ' [0.399]
# 'VERKHNEE JEME' not found
# 'VERKHNEPASHIN' -> 'VERKHNEPASHINO' [0.1]
# 'VERKHNERUSSKO' -> 'VERKHNERUSSKOE' [0.1]
# 'VERKHNETEMERN' not found
# 'VERKHNEZEYSK' -> 'VERKHNEZEJSK' [0.1]
# 'VERKHNIE OSEL' not found
# 'VERKHNIY BOR' -> 'VERKHNIJ DVOR' [0.919]
# 'VERKHNIY USLO' -> 'VERKHNIJ USLON' [0.23]
# 'VERKHNYAYA KH' -> 'VERKHNJAJA KHILA' [1.07331]
# 'VERKHNYAYA MA' -> 'VERKHNJAJA MARA' [0.7487]
# 'VERKHNYAYA PY' -> 'VERKHNJAJA PYSHMA' [1.275603]
# 'VERKHNYAYA SY' -> 'VERKHNJAJA SUN' [0.6187]
# 'VERKHNYYA PYS' not found
# 'VERKHOTURIE' -> 'VERKHOTURYE' [0.1]
# 'VERKHOVE' -> 'VERKHOVINO' [0.399]
# 'VERKHOVIE' -> 'VERKHOVYE' [0.1]
# 'VERKHYAYA SIN' not found
# 'VERZILOVO' -> 'VERBILOVO' [1.0]
# 'VESEGONSK' -> 'VESYEGONSK' [0.5]
# 'VESELAYA ZHIZ' -> 'VESELAJA ZHIZN' [0.23]
# 'VESELO VOZNES' -> 'VESELO VOZNESENOVKA' [1.275603]
# 'VETLUZHSKIY' -> 'VETLUZHSKIJ' [0.1]
# 'VIBORG' -> 'VYBORG' [0.1]
# 'VICHYGA' -> 'VICHUGA' [0.1]
# 'VIEZDNOE' -> 'VYEZDNOE' [0.1]
# 'VILLAGE CHUPR' not found
# 'VILLAGE VINOG' not found
# 'VILLOZSKOE SE' not found
# 'VINOGRADNIY' -> 'VINOGRADNYJ' [0.1]
# 'VINOGRADNYY' -> 'VINOGRADNYJ' [0.1]
# 'VINZILI RP' not found
# 'VIRITSA' -> 'VYRITSA' [0.1]
# 'VISELKI' -> 'VYSELKI' [0.1]
# 'VISOKOVSK' -> 'VYSOKOVSK' [0.1]
# 'VITEBSKIJ' -> 'VITIMSKIJ' [1.13]
# 'VITENEVO' -> 'MITENEVO' [1.0]
# 'VITYAZEVO' -> 'VITJAZEVO' [0.1]
# 'VIYBORGSKIIY' not found
# 'VLADIKVKAZ' -> 'VLADIKAVKAZ' [0.5]
# 'VLADIMIR OBL' -> 'VLADIMIRSKAJA OBL' [1.35892]
# 'VLADIMIRSK O' -> 'VLADIMIRSKAJA OBL' [1.18992]
# 'VLADIMIRSK OB' -> 'VLADIMIRSKAJA OBL' [0.8384]
# 'VLADIMIRSKAYA' -> 'VLADIMIRSKAJA' [0.1]
# 'VLADIMIRSKIY' -> 'VLADIMIRSKIJ' [0.1]
# 'VLADMR' -> 'VLADIMIR' [1.15]
# 'VLADVS' not found
# 'VNIISOK' -> 'VNIISSOK' [0.5]
# 'VNUKOVO AEROP' not found
# 'VODOISTOCHNIK' not found
# 'VOEYKOVO' -> 'VOEJKOVO' [0.1]
# 'VOJEGA' -> 'VOZHEGA' [0.1]
# 'VOLDYNSKOE' not found
# 'VOLGINSKIY' -> 'VOLGINSKIJ' [0.1]
# 'VOLGOGRAD OB' -> 'VOLGOGRADSKAJA OBL' [1.275603]
# 'VOLGOGRAD OBL' -> 'VOLGOGRADSKAJA OBL' [0.90431]
# 'VOLGOGRADSKII' not found
# 'VOLGORAD' -> 'VOLGOGRAD' [0.5]
# 'VOLGRD' not found
# 'VOLHOV' -> 'VOLKHOV' [0.1]
# 'VOLJSKII' -> 'VOLZHSKIJ' [0.23]
# 'VOLJSKIY' -> 'VOLZHSKIJ' [0.23]
# 'VOLJSKY' -> 'VOLZHSKIJ' [0.399]
# 'VOLKHOVSKIY' -> 'VOLKHOVSKIJ' [0.1]
# 'VOLKHOVSKIY R' -> 'VOLKHOVSKIJ' [1.48181818182]
# 'VOLNO NADEZHD' -> 'VOLNO NADEZHDINSKOE' [1.275603]
# 'VOLOCHAEVSKOE' not found
# 'VOLODARSKO' -> 'VOLODARSKOE' [0.2]
# 'VOLODARSKOG' -> 'VOLODARSKOGO' [0.1]
# 'VOLODARSKY' -> 'VOLODARSKIJ' [0.23]
# 'VOLOGOD OBL' -> 'VOLOGODSKAJA OBL' [0.90431]
# 'VOLOGODSKAYA' -> 'VOLOGODSKAJA OBL' [0.90431]
# 'VOLOGOGRAD' -> 'VOLGOGRAD' [1.0]
# 'VOLOVSKIY' -> 'VOROVSKIJ' [1.4]
# 'VOLZHSKIIY' -> 'VOLZHSKIJ' [1.13]
# 'VOLZHSKIY' -> 'VOLZHSKIJ' [0.1]
# 'VOLZHSKIY UTE' -> 'VOLZHSKIJ UTES' [0.23]
# 'VOLZHSKY' -> 'VOLZHSKIJ' [0.23]
# 'VOLZHSQII' -> 'VOLZHSKIJ' [1.4]
# 'VOLZSHSKIY' -> 'VOLZHSKIJ' [1.4]
# 'VOLZSK' -> 'VOLZHSK' [0.5]
# 'VOROBEVKA' -> 'VOROBYEVKA' [0.5]
# 'VOROBINO' -> 'DOROBINO' [1.0]
# 'VORONAZH' -> 'VORONEZH' [1.0]
# 'VORONEGH' -> 'VORONEZH' [1.0]
# 'VORONEZH OBL' -> 'VORONEZHSKAJA OBL' [1.07331]
# 'VORONEZH SHI' not found
# 'VORONEZHSKAY' -> 'VORONEZHSKAJA' [0.23]
# 'VORONEZHSKAYA' -> 'VORONEZHSKAJA' [0.1]
# 'VORONEZHSKIIY' -> 'VORONEZHSKIJ' [1.13]
# 'VORONKI' -> 'VORONYE' [1.4]
# 'VOROTINSK' -> 'VOROTYNSK' [0.1]
# 'VOROTYNSK BAB' not found
# 'VORSINO R N B' not found
# 'VORYPAEVO' -> 'VARYPAEVO' [1.0]
# 'VOSKRESE' -> 'VOSKRESENKA' [0.529]
# 'VOSKRESENSKIY' -> 'VOSKRESENSKIJ' [0.1]
# 'VOSTOCHNYY' -> 'VOSTOCHNYJ' [0.1]
# 'VOSTRYAKOVO' -> 'VOSTRJAKOVO' [0.1]
# 'VOYSKOVITSY' -> 'VOJSKOVITSY' [0.1]
# 'VOZDVIZHENSKO' -> 'VOZDVIZHENSKOE' [0.1]
# 'VOZHSKIY' -> 'VOZHSKIJ' [0.1]
# 'VPYSHMA' -> 'PYSHMA' [1.0]
# 'VRACHOVO' -> 'GRAKHOVO' [1.4]
# 'VSEVLZ' not found
# 'VSEVOL' -> 'VSEVOLOZHSK' [1.12401]
# 'VSEVOLJSK' -> 'VSEVOLOZHSK' [0.75]
# 'VSEVOLOJSKII' -> 'VSEVOLOZHSK' [1.48181818182]
# 'VSEVOLOZHSK R' -> 'VSEVOLOZHSK' [1.38181818182]
# 'VSEVOLOZHSKI' -> 'VSEVOLOZHSK' [1.0]
# 'VSEVOLOZHSKIY' -> 'VSEVOLOZHSK' [1.38181818182]
# 'VSEVOLZHSK' -> 'VSEVOLOZHSK' [0.5]
# 'VSEVOLZHSKIY' not found
# 'VSKRSK' not found
# 'VYALKI' -> 'VALKI' [1.0]
# 'VYATKINSKOE' not found
# 'VYATSKIE POLY' -> 'VJATSKIE POLJANY' [0.90431]
# 'VYATSKOE' -> 'VJATSKOE' [0.1]
# 'VYAZEMSKIY' -> 'VJAZEMSKIJ' [0.23]
# 'VYAZMA' -> 'VJAZMA' [0.1]
# 'VYAZNIKI' -> 'VJAZNIKI' [0.1]
# 'VYAZNINI' -> 'VJAZNIKI' [1.13]
# 'VYBORG OBL' not found
# 'VYBORGSKIIY R' not found
# 'VYEZD IZ YA' not found
# 'VYGONICHSKIY' not found
# 'VYIBORG' -> 'VYBORG' [1.0]
# 'VYISOKOGORSKI' -> 'VYSOKOGORSKIJ' [1.4]
# 'VYRA' -> 'VIRGA' [0.63]
# 'VYRMANKASU' -> 'VURMANKASY' [1.13]
# 'VYS GORA' -> 'VYSOKAJA GORA' [1.57862]
# 'VYSHESTEBLIEV' -> 'VYSHESTEBLIEVSKAJA' [0.90431]
# 'VYSHNIY VOLOC' -> 'VYSHNIJ VOLOCHEK' [0.6187]
# 'VYSOKAYA GORA' -> 'VYSOKAJA GORA' [0.1]
# 'VYSOKINSKIIY' -> 'VYSOKINSKIJ' [1.13]
# 'VYSOVSK' -> 'VYSOTSK' [1.0]
# 'VYTERGA' not found
# 'VZMORIE' -> 'VZMORYE' [0.1]
# 'XTOVO' -> 'KSTOVO' [0.1]
# 'Y A M' not found
# 'Y SAKHALINSK' not found
# 'Y YAROS' not found
# 'YA MOKVA' not found
# 'YABEDINO' -> 'POBEDINO' [1.4]
# 'YABLONOVS' -> 'JABLONOVSKIJ' [0.6187]
# 'YABLONOVSKIIY' -> 'JABLONOVSKIJ' [1.299]
# 'YABLONOVSKIY' -> 'JABLONOVSKIJ' [0.23]
# 'YABLONOVSKY' -> 'JABLONOVSKIJ' [0.399]
# 'YADRINSKIY' not found
# 'YAGANOVO' -> 'JAGANOVO' [0.1]
# 'YAGODNOE' -> 'JAGODNOE' [0.1]
# 'YAGUNOVSKIY' -> 'JAGUNOVSKIJ' [0.23]
# 'YAHROMA' -> 'JAKHROMA' [0.23]
# 'YAKHROMA' -> 'JAKHROMA' [0.1]
# 'YAKIMANSKOE' -> 'JAKIMOVSKOE' [1.299]
# 'YAKOVLEVSKOE' -> 'JAKOVLEVSKOE' [0.1]
# 'YAKUTSK' -> 'JAKUTSK' [0.1]
# 'YALGELEVO' -> 'JALGELEVO' [0.1]
# 'YALTA' -> 'JALTA' [0.1]
# 'YALTA KO' not found
# 'YALUTOROVSK' -> 'JALUTOROVSK' [0.1]
# 'YALYUTOROVSK' -> 'JALUTOROVSK' [1.13]
# 'YAM' -> 'JAM' [0.1]
# 'YAM IZHORA' not found
# 'YAM TESOVO' -> 'JAM TESOVO' [0.1]
# 'YAMIGORA' not found
# 'YAMM' -> 'JAMM' [0.1]
# 'YAMNOE' -> 'JAMNOE' [0.1]
# 'YAMONTOVO' -> 'MAMONTOVO' [1.0]
# 'YANAUL' -> 'JANAUL' [0.1]
# 'YANGANTAU' not found
# 'YANINO' -> 'JANINO' [0.1]
# 'YANISHPOLE' -> 'JANISHPOLE' [0.1]
# 'YANTAL' -> 'JANTAL' [0.1]
# 'YANTARNIY' -> 'JANTARNYJ' [0.23]
# 'YANTARNYY' -> 'JANTARNYJ' [0.23]
# 'YARANSK' -> 'JARANSK' [0.1]
# 'YARCEVO' -> 'JARTSEVO' [0.23]
# 'YARENSK' -> 'JARENSK' [0.1]
# 'YARINO' -> 'JARINO' [0.1]
# 'YARKOVO' -> 'JARKOVO' [0.1]
# 'YAROSLAVL' -> 'JAROSLAVL' [0]
# 'YAROSLAVL OBL' not found
# 'YAROSLAVSK O' -> 'JAROSLAVSKAJA OBL' [1.561213]
# 'YAROSLAVSKAYA' -> 'JAROSLAVSKAJA' [0.23]
# 'YAROSLAVSKIY' -> 'JAROSLAVSKIJ' [0.23]
# 'YAROSLAVSKOE' -> 'JAROSLAVSKOE' [0.1]
# 'YAROVOE' -> 'JAROVOE' [0.1]
# 'YARSLV' not found
# 'YARTSEVO' -> 'JARTSEVO' [0.1]
# 'YARTSV' -> 'JARTSEVO' [0.919]
# 'YASENEVO' -> 'OSENEVO' [1.4]
# 'YASNAYA POLYA' -> 'JASNAJA POLJANA' [0.90431]
# 'YASNOGORSK' -> 'JASNOGORSK' [0.1]
# 'YASNOGORSKIY' -> 'JASNOGORSKIJ' [0.23]
# 'YAZOVO' -> 'JAZOVO' [0.1]
# 'YEISK' -> 'EJSK' [0.23]
# 'YELETS' -> 'ELETS' [0.1]
# 'YENISEYSK' -> 'ENISEJSK' [0.23]
# 'YEYSK' -> 'EJSK' [0.23]
# 'YOSHKAR OLA' -> 'JOSHKAR OLA' [0.1]
# 'YOSHKAROLA' -> 'JOSHKAR OLA' [0.63]
# 'YOSHKOR OLA' -> 'JOSHKAR OLA' [1.13]
# 'YOSHOL' not found
# 'YU SAKHALINSK' -> 'JUZHNO SAKHALINSK' [1.52301]
# 'YUBIL' -> 'JUBILEJNYJ' [1.405603]
# 'YUBILEINII' -> 'JUBILEJNYJ' [0.399]
# 'YUBILEYN' -> 'JUBILEJNYJ' [0.7487]
# 'YUBILEYNIY' -> 'JUBILEJNYJ' [0.399]
# 'YUBILEYNY' -> 'JUBILEJNYJ' [0.399]
# 'YUBILEYNYI' -> 'JUBILEJNYJ' [0.399]
# 'YUBILEYNYY' -> 'JUBILEJNYJ' [0.399]
# 'YUBILEYNYY MK' not found
# 'YUDINO' -> 'JUDINO' [0.1]
# 'YUDINO ZH' not found
# 'YUGANETS' -> 'JUGANETS' [0.1]
# 'YUGO KAMSKIY' -> 'JUGO KAMSKIJ' [0.23]
# 'YUKHNOV' -> 'JUKHNOV' [0.1]
# 'YUKHOT' -> 'JUKHTA' [1.569]
# 'YUKKI' -> 'JUKKI' [0.1]
# 'YULA' -> 'JURLA' [0.63]
# 'YUMAGUZINO' -> 'JUMAGUZINO' [0.1]
# 'YUMATOVO' not found
# 'YUOSHKAR OLA' -> 'JOSHKAR OLA' [1.13]
# 'YUREVETS' -> 'JURYEVETS' [0.63]
# 'YURGA' -> 'JURGA' [0.1]
# 'YURGAMYSH' -> 'JURGAMYSH' [0.1]
# 'YURLOVO' -> 'KURLOVO' [1.0]
# 'YUROVKA' -> 'JUROVKA' [0.1]
# 'YUROVO' -> 'JUROVO' [0.1]
# 'YURTSOVO' -> 'JURTSOVO' [0.1]
# 'YURYEV POLSKI' -> 'JURYEV POLSKIJ' [0.23]
# 'YURYUZAN' -> 'JURJUZAN' [0.23]
# 'YUSHKOVO' -> 'JUSHKOVO' [0.1]
# 'YUTSA' -> 'JUTSA' [0.1]
# 'YUZHNAYA OZER' not found
# 'YUZHNEE DEREV' not found
# 'YUZHNO SAHALI' -> 'JUZHNO SAKHALINSK' [0.90431]
# 'YUZHNO SAKHA' -> 'JUZHNO SAKHALINSK' [1.275603]
# 'YUZHNO SAKHAL' -> 'JUZHNO SAKHALINSK' [0.90431]
# 'YUZHNOURALSK' -> 'JUZHNOURALSK' [0.1]
# 'YUZHNYY' -> 'JUZHNYJ' [0.23]
# 'YUZHNYY GOROD' not found
# 'YUZHOURALSK' -> 'JUZHNOURALSK' [0.63]
# 'ZA RAMENSKO' not found
# 'ZA RODINU' not found
# 'ZABOLOTE' -> 'ZABOLOTYE' [0.5]
# 'ZABOLOTIE' -> 'ZABOLOTYE' [0.1]
# 'ZABORIE' -> 'ZABORYE' [0.1]
# 'ZADONSKIY' -> 'ZADONSKIJ' [0.1]
# 'ZAGORYANSKIY' -> 'ZAGORJANSKIJ' [0.23]
# 'ZAKHARTSOVO' not found
# 'ZAKLINE ZAKL' not found
# 'ZALAVIE' not found
# 'ZALEG' -> 'ZALEGOSHCH' [0.90431]
# 'ZALESNAYA' not found
# 'ZAMOSTE' -> 'ZAMOSTYE' [0.5]
# 'ZAMULYANKA' not found
# 'ZANEVKA' -> 'KANEVKA' [1.0]
# 'ZAOKSKIY' -> 'ZAOKSKIJ' [0.1]
# 'ZAOKSKIY RP' not found
# 'ZAOZERE' -> 'ZAOZERYE' [0.5]
# 'ZAPAD KOMMUNA' not found
# 'ZAPADN DVINA' -> 'ZAPADNAJA DVINA' [0.568]
# 'ZAPADNAYA DVI' -> 'ZAPADNAJA DVINA' [0.399]
# 'ZAPADNII' -> 'ZAPADNYJ' [0.1]
# 'ZAPADNYY' -> 'ZAPADNYJ' [0.1]
# 'ZAPOLE' -> 'ZAPOLYE' [0.5]
# 'ZAPOLYARNYY' -> 'ZAPOLJARNYJ' [0.23]
# 'ZAPOROZHSKAYA' -> 'ZAPOROZHSKAJA' [0.1]
# 'ZAPRUDNYA' -> 'ZAPRUDNJA' [0.1]
# 'ZARAISK' -> 'ZARAJSK' [0.1]
# 'ZARAYSK' -> 'ZARAJSK' [0.1]
# 'ZARECH' -> 'ZARECHYE' [0.36]
# 'ZARECHE' -> 'ZARECHYE' [0.5]
# 'ZARECHE R' not found
# 'ZARECHENSKIY' -> 'ZARECHENSKIJ' [0.1]
# 'ZARECHIE' -> 'ZARECHYE' [0.1]
# 'ZARECHNIY' -> 'ZARECHNYJ' [0.1]
# 'ZARECHNYY' -> 'ZARECHNYJ' [0.1]
# 'ZARECHYE RP' not found
# 'ZARYA' -> 'ZARJA' [0.1]
# 'ZASECHNOYE' -> 'ZASECHNOE' [0.1]
# 'ZASTOLBE' -> 'ZASTOLBYE' [0.5]
# 'ZATO ZVEZDNYY' not found
# 'ZAURALSKIY' -> 'ZAURALSKIJ' [0.1]
# 'ZAVETY ILYICH' -> 'ZAVETY ILYICHA' [0.1]
# 'ZAVIDOVO KONA' not found
# 'ZAVODA MOSREN' not found
# 'ZAVOLJYE' -> 'ZAVOLZHYE' [0.1]
# 'ZAVOLZHIE' -> 'ZAVOLZHYE' [0.1]
# 'ZAVOLZHIYE' -> 'ZAVOLZHYE' [0.23]
# 'ZAVYALOVO' -> 'ZAVJALOVO' [0.1]
# 'ZAVYALOVSKIY' not found
# 'ZELDLS' not found
# 'ZELENAYA POLY' -> 'ZELENAJA POLJANA' [0.90431]
# 'ZELENCHUKSKAY' -> 'ZELENCHUKSKAJA' [0.23]
# 'ZELENOGRADSKI' -> 'ZELENOGRADSKIJ' [0.1]
# 'ZELENOGRD' -> 'ZELENOGRAD' [0.5]
# 'ZELENOVK' -> 'ZELENOVKA' [0.1]
# 'ZELENYY' -> 'ZELENYJ' [0.1]
# 'ZELENYY BEREG' not found
# 'ZELGRD' not found
# 'ZERKALNYY' not found
# 'ZEYA' -> 'ZEJA' [0.1]
# 'ZH STANTSII' not found
# 'ZHARKOVSKIY' -> 'ZHARKOVSKIJ' [0.1]
# 'ZHAVORONKI OD' -> 'ZHAVORONKI' [1.5]
# 'ZHDANOVSKIY' -> 'ZHDANOVSKIJ' [0.1]
# 'ZHEL DOR' not found
# 'ZHEL NII' -> 'ZELENYJ' [1.569]
# 'ZHELDOR' not found
# 'ZHELEZHNOGORS' -> 'ZHELEZNOGORSK' [0.23]
# 'ZHELEZNDOROZH' not found
# 'ZHELEZNODO' not found
# 'ZHELEZNODOR' -> 'ZHELEZNODOROZHNYJ' [0]
# 'ZHELEZNODORZH' not found
# 'ZHELEZNODOZ' not found
# 'ZHELEZNOGOR' -> 'ZHELEZNOGORSK' [0.23]
# 'ZHELEZNOGOROS' -> 'ZHELEZNOGORSK' [1.4]
# 'ZHELEZNOGORS' -> 'ZHELEZNOGORSK' [0.1]
# 'ZHELEZNYY' -> 'ZHELEZNYJ' [0.1]
# 'ZHELTSY' -> 'ZEMTSY' [1.13]
# 'ZHELZN' -> 'ZHIZN' [1.13]
# 'ZHEMCHUZHNYY' -> 'ZHEMCHUZHNYJ' [0.1]
# 'ZHESTYLEVO' not found
# 'ZHILGORODOK' not found
# 'ZHILKINO' -> 'ZHILINO' [1.0]
# 'ZHLRSK' not found
# 'ZHUKLINO' -> 'SHUKLINO' [1.0]
# 'ZHUKOVSKII' -> 'ZHUKOVSKIJ' [0]
# 'ZHUKOVSKIY' -> 'ZHUKOVSKIJ' [0]
# 'ZHUKOVSKIY PL' -> 'ZHUKOVSKIJ' [1.6]
# 'ZHURAVLYOVO' -> 'ZHURAVLEVO' [0.1]
# 'ZIMOVNIKO' -> 'ZIMOVNIKI' [1.0]
# 'ZININO' -> 'ZENINO' [0.1]
# 'ZIZINO' -> 'ZJUZINO' [0.63]
# 'ZJILINO' -> 'ZHILINO' [1.0]
# 'ZNAMENSKIY' -> 'ZNAMENSKIJ' [0.1]
# 'ZNAMYA OKTYAB' -> 'ZNAMJA OKTJABRJA' [0.90431]
# 'ZONALNAJA STA' -> 'ZONALNAJA STANTSIJA' [1.275603]
# 'ZONALNAYA STA' not found
# 'ZONALNYY' -> 'ZONALNYJ' [0.1]
# 'ZORKALCEVO' -> 'ZORKALTSEVO' [0.1]
# 'ZRECHN' -> 'ZARECHNYJ' [1.205]
# 'ZUBANYA' not found
# 'ZUBAREVA' -> 'ZUBAREVO' [0.1]
# 'ZUBCHANINOVKA' not found
# 'ZUBOVA POLANA' -> 'ZUBOVO POLJANA' [0.23]
# 'ZUBOVA POLYAN' -> 'ZUBOVO POLJANA' [0.399]
# 'ZUYA' -> 'ZUJA' [0.1]
# 'ZUYEVKA' -> 'ZUEVKA' [0.1]
# 'ZVYAGINO' -> 'ZVJAGINO' [0.1]

# %%
mask_not_found = [c in cities_not_found_list for c in df["city"]]

# %%
def spellchecker_modify(city):
    try:
        city = spellchecker.find(city)
        if len(city) > 0:
            return city[0][0]
        else:
            return ''
    except TypeError:
        return ''

mask = np.logical_and(np.logical_not(mask_not_found), mask_russian)
df.loc[mask, "city_"] = df.loc[mask, "city"].map(spellchecker_modify)

# %% [raw]
# spellchecker = Tie()
# spellchecker_reverse = Tie(reverse=True)
#
# for item in cities_correct_list:
#     spellchecker.add(item)
#     spellchecker_reverse.add(item)

# %%
mask_curr = np.logical_and(mask_russian, mask_not_found)

def modify_cities_address_by_mask(mask_curr):
    mask = np.logical_and(df["atm_address"].notnull(), mask_curr)
    df.loc[mask, "city_"] = df[mask].apply(
        lambda x: process_address(x['atm_address'], x['city'], True), axis=1)

    mask = np.logical_and(df["pos_address"].notnull(), mask_curr)
    df.loc[mask, "city_"] = df[mask].apply(
        lambda x: process_address(x['pos_address'], x['city'], True), axis=1)

    mask = np.logical_and(df["pos_address"].isnull(), df["atm_address"].isnull())
    mask = np.logical_and(mask, mask_curr)
    df.loc[mask, "city_"] = df[mask].apply(
        lambda x: process_address(x['atm_address'], x['city'], True), axis=1)
    
modify_cities_address_by_mask(mask_curr)
# Out:
# '.ZONA\GPB KRASNOJAR\660049    RUSRUS'	'GPB KRASNOJAR'	->	'KRASNOJARSK'
# 'EBR.PRUDI\             RUS'	'SEREBR PRUDI'	->	''
# 'kaya, 35      >  Esto-\Esto-Sadok\00000     RUSRUS'	'ESTO SADOK'	->	''
# 'ICHA 30\PERVRL\623100    RUSRUS'	'PERVRL'	->	'PERVOURALSK'
# 'TYABRSKAYA 20A\NOVALT\658087    RUSRUS'	'NOVALT'	->	'NOVOALTAJSK'
# 'TUTINA 44\PERVRL\623100    RUSRUS'	'PERVRL'	->	'PERVOURALSK'
# '. PABRATIMO\127018    RUSRUS'	'ST PABRATIMO'	->	'MOSKVA'
# 'R\NOVOSHCHERBIN\353632    RUSRUS'	'NOVOSHCHERBIN'	->	'NOVOSHCHERBINOVSKAJA'
# 'KM KASHIRSKOGO SH.\APARNIKY\142715    RUSRUS'	'APARNIKY'	->	'SOVKHOZ IM LENINA'
# 'ONO\140155    RUSRUS'	'NOVOKHARITONO'	->	'ELEKTROIZOLJATOR'
# 'EREG STR\SYUKTERKA\429526    RUSRUS'	'SYUKTERKA'	->	'KHYRKASY'
# 'Электросталь, пос. Случайный, Массив 1'	'SLUCHAJNYJ'	->	'ELEKTROSTAL'
# 'STAN ST\ZELDLS\420126    RUSRUS'	'ZELDLS'	->	'KAZAN'
# 'BURTULINOVKA\397500    RUSRUS'	'BURTULINOVKA'	->	'BUTURLINOVKA'
# 'G 100 LET VLADIVOSTOKU PR\VLADVS\690090    RUSRUS'	'VLADVS'	->	'VLADIVOSTOK'
# 'atornaya, 13    >  Verkh\Verkhnetemern\00000     RUSRUS'	'VERKHNETEMERN'	->	''
# '\ST. LADOZHSKA\352320    RUSRUS'	'ST LADOZHSKA'	->	'LADOZHSKAJA'
# 'ERSKAYA 28/1\******\0026         RUS'	''	->	''
# 'TELEY ST\ZELDLS\423570    RUSRUS'	'ZELDLS'	->	'NIZHNEKAMSK'
# 'LENINGRADSKIY 1B\ZHLRSK\656003    RUSRUS'	'ZHLRSK'	->	'BARNAUL'
# 'KOVSKOE, STR.1A\SGONNIKOVSKIY\141014    RUSRUS'	'SGONNIKOVSKIY'	->	'JAKOVSKOE'
# 'YA\MOSHKOVO RP\633130    54 RUS'	'MOSHKOVO RP'	->	'MOSHKOVO'
# 'MATROSOVA ST KRASNOYARSK\LESSIB\656003    RUSRUS'	'LESSIB'	->	'BARNAUL'
# '665932    38 RUS'	'GAGARINA MKR'	->	'BAJKALSK'
# 'M2\PODOLSKY DIST\142143    RUSRUS'	'PODOLSKY DIST'	->	'BYKOVO'
# 'LENINGRADSKIY PR\ZHLRSK\662978    RUSRUS'	'ZHLRSK'	->	'ZHELEZNOGORSK'
# 'KIJ RAJON, 33-J KM A-D MOSKVA-\DOMOVEDOVSKIY\142712    RUSRUS'	'DOMOVEDOVSKIY'	->	'GORKI LENINSKIE'
# 'LYANOY VAL 25 STR.1A, OTD ZEMLYANOY VAL\******\0127         RUS'	''	->	''
# 'A\POVAROVO DP\141540    50 RUS'	'POVAROVO DP'	->	'POVAROVO'
# 'MARKSA 26\KRASTU\624440    RUSRUS'	'KRASTU'	->	'KRASNOTURYINSK'
# 'STR\SLAVYANSK-NA-\353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# 'LICA 7\PERVRL\623100    RUSRUS'	'PERVRL'	->	'PERVOURALSK'
# 'EZHNAYA PANORAMA,4\SOCHI\354392    RUSRUS'	'ESTOSADOK'	->	'KRASNAJA POLJANA'
# 'OGINSKIY, OB\142440    50 RUS'	'NOGINSKIY OB'	->	'OLGINSKIJ'
# 'SHKOLNAYA ST\ZHLRSK\662971    RUSRUS'	'ZHLRSK'	->	'ZHELEZNOGORSK'
# 'NCEV DOM 12 KORPUS C BC DVINCEV\******\0067         RUS'	''	->	''
# 'SKAYA STREET\p.TSURYUPY\157505    RUSRUS'	'TSURYUPY'	->	'SHARJA'
# ', 35\VER.USLON,\422570    RUSRUS'	'VER USLON'	->	'VERKHNIJ USLON'
# 'STR\PERESLAVL-ZAL\152025    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '27\resp. Adigeya\385100    01 RUS'	'ADYGEJA'	->	'TAKHTAMUKAJ'
# 'YA STR\TREKHGORKA\143005    RUSRUS'	'TREKHGORKA'	->	'ODINTSOVO'
# '\DAVYDOVO (DAV\142641    RUSRUS'	'DAVYDOVO DAV'	->	'DAVYDOVO'
# 'R\D/O BEKASOVO\143380    RUSRUS'	'O BEKASOVO'	->	'BEKASOVO'
# 'AVIDOVSKIY\             RUS'	'N ZAVIDOVSKIY'	->	''
# 'RUSEL'\ESTO-SADOK S\354392    23 RUS'	'ESTO SADOK'	->	'KRASNAJA POLJANA'
# '>  Verkh\Verkhnetemern\00000     RUSRUS'	'VERKHNETEMERN'	->	''
# '111\ST. SEVERSKAY\353235    RUSRUS'	'ST SEVERSKAY'	->	'AFIPSKIJ'
# 'IEV HIGHWAY, 23TH KM\N. MOSCOWSKIY\142784000    RUS'	'N MOSCOWSKIY'	->	''
# 'KARUSEL, 5\ESTO-SADOK\350000    RUSRUS'	'ESTO SADOK'	->	'KRASNODAR'
# 'DYSHSKIJ\422165    RUSRUS'	'MAMADYSHSKIJ'	->	'KRASNAJA GORKA'
# 'ADYSHSKIJ\422165    RUSRUS'	'MAMADYSHSKIJ'	->	'KRASNAJA GORKA'
# '42451    RUSRUS'	'SLUCHAYNYY'	->	''
# 'KAYA, 35      >  Esto-\Esto-Sadok\00000     RUSRUS'	'ESTO SADOK'	->	''
# '143421    50 RUS'	'BALTIYA AVTOD'	->	'ILYINSKOE USOVO'
# 'HERIZON\MO COLNECHNOG\107078    RUSRUS'	'COLNECHNOG'	->	'MOSKVA'
# 'A STR\RODIONOVO-NES\346580    RUSRUS'	'RODIONOVO NES'	->	'RODIONOVO NESVETAJSKAJA'
# 'NAYA\VERKHNEE JEME\353456    23 RUS'	'VERKHNEE JEME'	->	'ANAPA'
# 'A\SELYATINO RP\143345    50 RUS'	'SELYATINO RP'	->	'SELJATINO'
# 'AYA STR\VERKHNETEMERN\346735    RUSRUS'	'VERKHNETEMERN'	->	'RASSVET'
# 'AHITOVA\NIZKMK\423570    RUSRUS'	'NIZKMK'	->	'NIZHNEKAMSK'
# '18\V.Pyshma\624090    66 RUS'	'V PYSHMA'	->	'VERKHNJAJA PYSHMA'
# 'TR\GRISHANKI\427421    RUSRUS'	'GRISHANKI'	->	'SVETLOE'
# 'M\141051    RUSRUS'	''	->	'KRASNAJA GORKA'
# 'KHOZA IM L\142715    RUSRUS'	'SOVKHOZA IM L'	->	'SOVKHOZ IM LENINA'
# 'INSKOE,VBLIZI D.MIKHALKOVO\SP.ILINSKOE\143420    RUSRUS'	'SP ILINSKOE'	->	'MINSKOE'
# 'UBILEYNYY MK\141091    50 RUS'	'YUBILEYNYY MK'	->	'JUBILEJNYJ'
# 'RESLAVL-ZAL\             RUS'	'PERESLAVL'	->	''
# '8\N-SORTYMSKIY\628447    RUSRUS'	'N SORTYMSKIY'	->	'NIZHNESORTYMSKIJ'
# 'Mkr.Kommunar\600023    33 RUS'	'MKR KOMMUNAR'	->	'KOMMUNAR'
# 'SH BLD B\LUPPOLOVO\188653    RUSRUS'	'LUPPOLOVO'	->	'AGALATOVO'
# 'A M7 SH\YADRINSKIY\429075    RUSRUS'	'YADRINSKIY'	->	'STRELETSKAJA'
# '1\SOVKHOZ IMENI\142715    RUSRUS'	'SOVKHOZ IMENI'	->	'SOVKHOZ IM LENINA'
# 'VOLOCHEK\             RUS'	'V VOLOCHEK'	->	''
# 'NINSKOGO KOMSOMOLA 25\KRASTU\624440    RUSRUS'	'KRASTU'	->	'KRASNOTURYINSK'
# 'STR\SVKH RAMENSKO\140128    RUSRUS'	'SVKH RAMENSKO'	->	'RAMENSKOE'
# 'STR\S-ZA RAMENSKO\140128    RUSRUS'	'ZA RAMENSKO'	->	'RAMENSKOE'
# 'OS PERESL\PERESLAVL-ZAL\152024    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '. STAVROPOLSKAJA\M.- VODY\101000    RUSRUS'	'M VODY'	->	'MOSKVA'
# '2\R.P. RAMON\             RUS'	'R RAMON'	->	''
# 'STR\KAMENSK-SHAKH\347805    RUSRUS'	'KAMENSK SHAKH'	->	'KAMENSK SHAKHTINSKIJ'
# 'A PR-T\KAMENSK-SHAKH\347810    RUSRUS'	'KAMENSK SHAKH'	->	'KAMENSK SHAKHTINSKIJ'
# 'TEMYANOVO\143362    RUSRUS'	'MARTEMYANOVO'	->	'APRELEVKA'
# 'KLI-MAKTB\             RUS'	'TEREKLI MAKTB'	->	''
# 'TR BLD KAFE "TU\BOLSHAYA TARL\423634    RUSRUS'	'BOLSHAYA TARL'	->	'BOLSHAJA KACHKA'
# '\188660    47 RUS'	'KORABSELKI'	->	'BUGRY'
# 'ZORGE PR\ROSTDN\344000    RUSRUS'	'ROSTDN'	->	'ROSTOV NA DONU'
# 'MARA, AERADROMNAY 41 A TC AVRORA\******\0376         RUS'	''	->	''
# '1, P KRASNOOBSK\KRSBSK\630501    RUSRUS'	'KRSBSK'	->	'KRASNOOBSK'
# 'RSKAYA 28/1\******\0154         RUS'	''	->	''
# 'mmunisticheskaya st.1\village Vinog\140230    RUSRUS'	'VILLAGE VINOG'	->	'VINOGRADOVO'
# 'A GAZETNAYA ST\NIZTAG\622036    RUSRUS'	'NIZTAG'	->	'NIZHNIJ TAGIL'
# 'GAZETNAYA ST\NIZTAG\622036    RUSRUS'	'NIZTAG'	->	'NIZHNIJ TAGIL'
# 'STR\NEVSKAYA DUBR\188684    RUSRUS'	'NEVSKAYA DUBR'	->	'DUBROVKA'
# 'AINOVA 33A\N.SORTIMSKIY\628447    86 RUS'	'N SORTIMSKIY'	->	'NIZHNESORTYMSKIJ'
# '\357200    RUSRUS'	'MIN VODY'	->	'MINERALNYE VODY'
# 'GEYA\350000    RUSRUS'	'ADYGEJA'	->	'KRASNODAR'
# 'NATORNAYA, 10\TARASKUL\625000    RUSRUS'	'TARASKUL'	->	'TJUMEN'
# 'KM A-D "MOSKVA-DON"\TARYCHEVO\142703    RUSRUS'	'TARYCHEVO'	->	'VIDNOE'
# 'VKA\188681    RUSRUS'	'NOVOSARATOVKA'	->	'KHAPO OE'
# 'KM KIEVSKOGO SH.\MOSCOWSKIY\119027    RUSRUS'	'MOSCOWSKIY'	->	'MOSKVA'
# 'IS.53ZH\RODIONOVO-NSV\             RUS'	'RODIONOVO NSV'	->	''
# 'SLAVYANSK-N-K\             RUS'	'SLAVYANSK N K'	->	''
# 'NAPA, ST.ANA\353451    RUSRUS'	'ANAPA ST ANA'	->	'ANAPA'
# 'AMENSK-SHAKH\             RUS'	'KAMENSK SHAKH'	->	''
# '\YOSHOL\424000    RUSRUS'	'YOSHOL'	->	'JOSHKAR OLA'
# 'VAYA 1\DER. KONECBOR\000111    RUSRUS'	'KONECBOR'	->	''
# 'NINA 8\PERVRL\623100    RUSRUS'	'PERVRL'	->	'PERVOURALSK'
# 'PN\PERESLAVL-ZAL\152024    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# 'lage Chupryakovo,7\village Chupr\143075    RUSRUS'	'VILLAGE CHUPR'	->	'CHUPRJAKOVO'
# '148\ST. VARENIKOV\353370    RUSRUS'	'ST VARENIKOV'	->	'VARENIKOVSKAJA'
# 'MITROVA, D.14\KOMS-NA-AMURE\681013    RUSRUS'	'KOMS NA AMURE'	->	'DMITROVO'
# 'M 6700-DO MOLODEZHNYY\45268\123456    RUSRUS'	''	->	''
# 'BUDENNOVSKIY PR\ROSTDN\115172    RUSRUS'	'ROSTDN'	->	'MOSKVA'
# 'KI, SOVETSKAYA STR., 17/1\RESPUBLIKA TA\420075    RUSRUS'	'RESPUBLIKA TA'	->	'KAZAN'
# 'ISHIM-\625525    RUSRUS'	'TYUMEN ISHIM'	->	'KAMENKA'
# 'TORIJ PODMOSKOVE\SANATORIJ POD\142072    46 RUS'	'SANATORIJ POD'	->	'SANATORIJ PODMOSKOVJA'
# '\SL RODIONOVO-\346580    RUSRUS'	'SL RODIONOVO'	->	'RODIONOVO NESVETAJSKAJA'
# 'Lazo, 36      >  Uprav\Upravlenchesk\00000     RUSRUS'	'UPRAVLENCHESK'	->	''
# 'Хотьково, ул. Михеенко, д. 14'	''	->	'KHOTKOVO'
# 'AYA STR BLD 3\SHUSHARY,SLAV\196634    RUSRUS'	'SHUSHARY SLAV'	->	'DETSKOSELSKIJ'
# ', 15\LISKINSKIY, L\397901    36 RUS'	'LISKINSKIY L'	->	'LISKI'
# 'KM MKAD 1\SGONNIKOVSKIY\141031    RUSRUS'	'SGONNIKOVSKIY'	->	'BORODINO'
# 'AS\663021    RUSRUS'	'AEROPORT KRAS'	->	'AEROPORT KRASNOJARSK'
# 'POVSKAJA 22\NOVALT\658080    RUSRUS'	'NOVALT'	->	'NOVOALTAJSK'
# '\ANAPSKIY, GOS\353400    23 RUS'	'ANAPSKIY GOS'	->	'GOSTAGAEVSKAJA'
# 'S-13 GPN\PERESLAVL-ZAL\152024    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# 'дер. Новые Псарьки, ул. Парковая, д. 4, Московская область, Ногинский район, сельское поселение Аксено-Бутырское'	'NOVEE PS'	->	'DER NOVYE PSARKI'
# '0 LET VL 150V\VLADVS\115172    RUSRUS'	'VLADVS'	->	'MOSKVA'
# '. KRASNYH ZOR, 21\******\0085         RUS'	''	->	''
# '\NAKHABINO RP\143430    50 RUS'	'NAKHABINO RP'	->	'NAKHABINO'
# 'SOVA\LEBEDYAN LIPE\107078    RUSRUS'	'LEBEDYAN LIPE'	->	'MOSKVA'
# 'GEYA\115054    RUSRUS'	'ADYGEJA'	->	'MOSKVA'
# 'TAROE MARTYA\427006    RUSRUS'	'STAROE MARTYA'	->	'OKTJABRSKIJ'
# ', 56\R.P.KOLIVAN\633161    RUSRUS'	'R KOLIVAN'	->	'KOLYVAN'
# '\NEVSKAYA DUBR\188640    47 RUS'	'NEVSKAYA DUBR'	->	'VSEVOLOZHSK'
# 'KOMSOMOLSKY\NEFTUG\628300    RUSRUS'	'NEFTUG'	->	''
# 'MOSK.OBL.\143500    RUSRUS'	'MOSK OBL'	->	'ISTRA'
# '1A\OSINOVAYA GOR\300041    RUSRUS'	'OSINOVAYA GOR'	->	'TULA'
# 'HASTOVS.\             RUS'	'N MYSHASTOVS'	->	''
# 'YDOVO (DAV\142641    RUSRUS'	'DAVYDOVO DAV'	->	'DAVYDOVO'
# 'COVSKIY R-N PGT LESNOY GORODOK UL.SHKOLNAY D.1\********\0082         RUS'	''	->	''
# 'AMAN ST-TSA\353555    23 RUS'	'TAMAN ST TSA'	->	'TAMAN'
# 'ENINSKUZNETS\             RUS'	'LENINSKUZNETS'	->	''
# 'EN\108820    RUSRUS'	'ZAVODA MOSREN'	->	'MOSRENTGEN'
# 'AVE.\SANKET PETERB\107078    RUSRUS'	'SANKET PETERB'	->	'MOSKVA'
# '.,286\SLAVJANSK-NA-\353560    RUSRUS'	'SLAVJANSK NA'	->	'SLAVJANSK NA KUBANI'
# 'OVOY 4\******\0068         RUS'	''	->	''
# 'A\VINZILI RP\625530    72 RUS'	'VINZILI RP'	->	'VINZILI'
# 'ECHNAYA\350000    RUSRUS'	'SOLNECHNAYA'	->	'KRASNODAR'
# 'KRS.BARRIKADY\             RUS'	'KRS BARRIKADY'	->	''
# 'MINVODY\357207    RUSRUS'	'MINVODY'	->	'MINERALNYE VODY'
# '8\N.MYSHASTOVS.\             RUS'	'N MYSHASTOVS'	->	''
# 'OZ\140765    RUSRUS'	'SANATORIYA OZ'	->	'SANATORIJ OZERO BELOE'
# 'VYANSK-KUB\             RUS'	'SLAVYANSK KUB'	->	''
# 'SSIV "SORZHA-RYZHIKY"\SORZHA-RYZHIK\188640    RUSRUS'	'SORZHA RYZHIK'	->	'VSEVOLOZHSK'
# '2\PERESLAVL\111111    RUSRUS'	'PERESLAVL'	->	''
# '36\v.Sadovyjj\620907    66 RUS'	'V SADOVYJJ'	->	'SADOVYJ'
# 'V.Pyshma\624096    66 RUS'	'V PYSHMA'	->	'VERKHNJAJA PYSHMA'
# '6\N.CHELNY\423810    RUSRUS'	'N CHELNY'	->	'NABEREZHNYE CHELNY'
# 'CHELNY\628600    RUSRUS'	'EMB CHELNY'	->	'NIZHNEVARTOVSK'
# 'OE SH\OSINOVAYA GOR\300001    RUSRUS'	'OSINOVAYA GOR'	->	'TULA'
# 'TRA\420029    RUSRUS'	'SIBIRSKIY TRA'	->	'KAZAN'
# 'FTUG\628300    RUSRUS'	'NEFTUG'	->	''
# '3B\GLEBOVSKIJ\143500    46 RUS'	'GLEBOVSKIJ'	->	'ISTRA'
# '7\ST. KALININSK\353780    RUSRUS'	'ST KALININSK'	->	'KALININSKAJA'
# 'KAYA STREET\NOVO-PETROVSK\157505    RUSRUS'	'NOVO PETROVSK'	->	'SHARJA'
# 'KREMLEVSKAYA ST\YOSHOL\424003    RUSRUS'	'YOSHOL'	->	'JOSHKAR OLA'
# 'UPRAVLENCHE\443000    RUSRUS'	'UPRAVLENCHE'	->	'SAMARA'
# 'ATOROV STR\MEKHANIZATORO\602209    RUSRUS'	'MEKHANIZATORO'	->	'JAKIMANSKAJA SLOBODA'
# 'KOGO SH.\KARTMAZOVO\142784    RUSRUS'	'KARTMAZOVO'	->	''
# 'STR\PERESLAVL-ZAL\152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# 'MIRA, 106\U-SAHALINSK\693000    RUSRUS'	'U SAHALINSK'	->	'JUZHNO SAKHALINSK'
# 'KM MKAD\MYAKININO\143400    RUSRUS'	'MYAKININO'	->	''
# 'SKAYA, 26\NOVURE\629303    RUSRUS'	'NOVURE'	->	'PLOSKAJA'
# 'GIL\622001    66 RUS'	'N TAGIL'	->	'NIZHNIJ TAGIL'
# 'PORTA STR\KUZMINSKIE OT\398501    RUSRUS'	'KUZMINSKIE OT'	->	'KOPTSEVY KHUTORA'
# '6218-OOO ALIYANS+\MOSCOWSKIY\123456    RUSRUS'	'MOSCOWSKIY'	->	''
# 'ORO\602209    RUSRUS'	'MEKHANIZATORO'	->	'JAKIMANSKAJA SLOBODA'
# 'YY BYSTR\PERESLAVL-ZAL\152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# 'LAVYANSK NA\350000    RUSRUS'	'SLAVYANSK NA'	->	'KRASNODAR'
# '13\Petushinskiy \601125    33 RUS'	'PETUSHINSKIY'	->	'VOLGINSKIJ'
# 'NA  REKI  ARHIZ  (LEVIY  BEREG)\ARHIZSKOE\369152    RUSRUS'	'ARHIZSKOE'	->	'ARKHYZ'
# 'STR BLD A\GLEBOVSKIY\143517    RUSRUS'	'GLEBOVSKIY'	->	'KHOLSHCHEVIKI'
# 'TUFYEVSKOE \141031    50 RUS'	'ALTUFYEVSKOE'	->	'BORODINO'
# 'RUZSKIIY R\143160    RUSRUS'	'RUZSKIIY R'	->	'DOROKHOVO'
# '36028    RUSRUS'	'SHOSSEYNOE'	->	''
# 'KOMMUNISTICHESKY PR\MEZHDU\652870    RUSRUS'	'MEZHDU'	->	'MEZHDURECHENSK'
# '\R-N SURGUTSKI\628452    86 RUS'	'SURGUTSKI'	->	'SOLNECHNYJ'
# 'tr., 5\SHCHELKOVSKIY\141140    50 RUS'	'SHCHELKOVSKIY'	->	'SVERDLOVSKIJ'
# 'HINSKOE HW.\MKR.SALTYKOVK\109012    RUSRUS'	'MKR SALTYKOVK'	->	'MOSKVA'
# 'LENINA STR ANSUDG\ANSUDG\656003    RUSRUS'	'ANSUDG'	->	'BARNAUL'
# 'OVO, AEROPORT\U-SAHALINSK\693000    RUSRUS'	'U SAHALINSK'	->	'JUZHNO SAKHALINSK'
# 'ITROVSKOE SH D101 HC\******\0214         RUS'	''	->	''
# 'STR\YUZHNYY GOROD\443085    RUSRUS'	'YUZHNYY GOROD'	->	'SAMARA'
# 'KVA, SEREBRJANICHESKAJA NABEREZHNAJA, D. 29, AO RN\******\0147         RUS'	''	->	''
# 'TR., 7\ANAPA, S.SUKK\353407    RUSRUS'	'ANAPA SUKK'	->	'SUKKO'
# 'ZOLIATOR\NOVOHARITONOV\140100    46 RUS'	'NOVOHARITONOV'	->	'RAMENSKOE'
# 'R OOO 'VEGA-LINE' (RIGA-LAND)\MOSCOW R-N, K\143082    50 RUS'	'MOSCOW R N K'	->	'BARVIKHA'
# 'NOVOSELOV ST\SOSBSK\662601    RUSRUS'	'SOSBSK'	->	'MINUSINSK'
# 'ROMANOVA ST\CHRPNV\658200    RUSRUS'	'CHRPNV'	->	'RUBTSOVSK'
# 'skazka"\v.Etkul\456560    74 RUS'	'V ETKUL'	->	'ETKUL'
# 'A KYRLI ST\YOSHOL\424918    RUSRUS'	'YOSHOL'	->	'SEMENOVKA'
# '\141271    50 RUS'	'SOFRINO NP'	->	'SOFRINO'
# 'SKANDINAVIYA\TORFYANOVKA P\188800    47 RUS'	'TORFYANOVKA'	->	'VYBORG'
# ', NEVSKOGO ST\KRSBSK\630075    RUSRUS'	'KRSBSK'	->	'NOVOSIBIRSK'
# 'M 6204-RADUZHNAYA 13\MOSCOWSKIY\123456    RUSRUS'	'MOSCOWSKIY'	->	''
# 'TR\GORCHAKOVO\108807    RUSRUS'	'GORCHAKOVO'	->	'PTICHNOE'
# 'Krivodanov\630511    54 RUS'	'V KRIVODANOV'	->	'KRIVODANOVKA'
# '4, SOTSIALISTICHESKYI\GORALT\656003    RUSRUS'	'GORALT'	->	'BARNAUL'
# 'VETSKAYA 32A\SRDURA\620000    RUSRUS'	'SRDURA'	->	'EKATERINBURG'
# 'TR\ZH-D STANTSII\422700    RUSRUS'	'ZH STANTSII'	->	'ZHELEZNODOROZHNOJ STANTSII VYSOKAJA GORA'
# 'TMAZOVO\142784    RUSRUS'	'KARTMAZOVO'	->	''
# 'HESKIY BYSTR BL\KAMENSK-SHAKH\347809    RUSRUS'	'KAMENSK SHAKH'	->	'KAMENSK SHAKHTINSKIJ'
# '6586-KARTMAZOVO 7\KARTMAZOVO\123456    RUSRUS'	'KARTMAZOVO'	->	''
# '-TSA LENING\353740    RUSRUS'	'ST TSA LENING'	->	'LENINGRADSKAJA'
# 'OXOVO GP\188664    47 RUS'	'TOXOVO GP'	->	'TOKSOVO'
# 'ST.\TAYALTTI\445000    RUSRUS'	'TAYALTTI'	->	'TOLJATTI'
# 'OLETARSKAYA\CHRPNV\656003    RUSRUS'	'CHRPNV'	->	'BARNAUL'
# 'OSSE STR\SLAVYANSK-NA-\353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# 'e sh.,26\Yalta, pgt.Ko\298600    91 RUS'	'YALTA KO'	->	'JALTA'
# 'STR\UCHASTOK FEOF\665375    RUSRUS'	'UCHASTOK FEOF'	->	'KIMILTEJ'
# 'GABOVSKOE\141800    RUSRUS'	'GABOVSKOE'	->	'DMITROV'
# 'PRIVOKZALNAYA PLOSHCHAD STRMALYSHEVO,RAM141000    RUSRUS'	'MALYSHEVO RAM'	->	'MYTISHCHI'
# 'LENINA, 74PAVLOVSKAY SL143581    RUSRUS'	'PAVLOVSKAY SL'	->	'LENINA'
# '2, YUBILEIYNAYATULA REGION301246    RUSRUS'	'TULA OBL'	->	'SHCHEKINO'
# '. 191 KM AD MOSKVA-KRYM SH,300000    RUSRUS'	''	->	'TULA'
# '19A, YUBILEIYNAYATULA REGION301246    RUSRUS'	'TULA OBL'	->	'SHCHEKINO'
# '3, SPORTIVNAYATULA REGION301247    RUSRUS'	'TULA OBL'	->	'SHCHEKINO'
# '4B, MOLODEZHNAYATULA REGION301247    RUSRUS'	'TULA OBL'	->	'SHCHEKINO'
# '52, LENINATULA REGION301245    RUSRUS'	'TULA OBL'	->	'SHCHEKINO'
# '1 B KOROLEVA STRZONALNAYA STA634507    RUSRUS'	'ZONALNAYA STA'	->	'ZONALNAJA STANTSIJA'
# 'AEROPORT, -LAISHEVSKIJ R420017    RUSRUS'	'LAISHEVSKIJ R'	->	'AEROPORT'
# 'KOMINTERNA, 18TVER-PRIGOROD141600    RUSRUS'	'TVER PRIGOROD'	->	'KOMINTERN'
# '20 ADMIRALA FOKINA STVLADVS690091    RUSRUS'	'VLADVS'	->	'VLADIVOSTOK'
# '61 NEKRASOVSKAYA STVLADVS690014    RUSRUS'	'VLADVS'	->	'VLADIVOSTOK'
# 'O.RUSSKIY _ STR BLD 1MELKOVODNYY690000    RUSRUS'	'MELKOVODNYY'	->	'VLADIVOSTOK'
# '217 GRINYA STRSLAVYANSK-NA-353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# '22 LENINGRADSKAYA STRVERKHNIE OSEL188665    RUSRUS'	'VERKHNIE OSEL'	->	'OSELKI'
# '- STRPLEMZAVOD KON142032    RUSRUS'	'PLEMZAVOD KON'	->	'ZAPADNYJ'
# '38 PUSHKINA STRLVA TOLSTOGO249842    RUSRUS'	'LVA TOLSTOGO'	->	'IM LVA TOLSTOGO'
# ', STR BLD 1 MKADSOVKHOZ IMENI142715    RUSRUS'	'SOVKHOZ IMENI'	->	'SOVKHOZ IM LENINA'
# '1 DMITRIYA DONSKOGO BLVDSEVERNOE BUTO117216    RUSRUS'	'SEVERNOE BUTO'	->	'MOSKVA'
# '12-2, MIRAPOSELENIE KRA140100    RUSRUS'	'POSELENIE KRA'	->	'RAMENSKOE'
# '4 KRASNYKH ZOR STR BLD 3KRASNYKH ZOR121374    RUSRUS'	'KRASNYKH ZOR'	->	'MOSKVA'
# 'MKAD 26 KM TER BLD 9MKAD 26 KM141000    RUSRUS'	''	->	'MYTISHCHI'
# '30A, LENINAKRASNODAR REG353365    RUSRUS'	'KRASNODAR OBL'	->	'NIZHNEBAKANSKAJA'
# '14, MIRA, KHOLMSKAYAABINSK REGION353802    RUSRUS'	'ABINSK OBL'	->	''
# 'H. VERHNEADAGUMH. VERHNEADAG353351    RUSRUS'	'H VERHNEADAG'	->	'ADAGUM'
# 'PERESLAVL-ZALESSKIJ, KARDOVSKOGO, 92PERESLAVL-ZAL152024    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '48 SVOBODY STRPERESLAVL-ZAL152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '28 SVOBODY STRPERESLAVL-ZAL152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '- STR33-Y KM YAROS141200    RUSRUS'	'Y YAROS'	->	'PUSHKINO'
# 'KOLOMENSKII PROEZD, VL.3ARUSSIA115446    RUSRUS'	''	->	'MOSKVA'
# '4 YUZHNAYA STRBERNGARDOVKA188643    RUSRUS'	'BERNGARDOVKA'	->	'VSEVOLOZHSK'
# '1 PRIVOKZALNAYA PLVOLGRD400131    RUSRUS'	'VOLGRD'	->	'VOLGOGRAD'
# 'OLIMPIYSKAYA STRBELGORODSKIY,308519    RUSRUS'	'BELGORODSKIY'	->	'SEVERNYJ'
# '1 BELGORODSKAYA STRSEVERO-ZAPADN308000    RUSRUS'	'SEVERO ZAPADN'	->	'BELGOROD'
# '. 289 KM A-D MOSKVA-DON SH,301570    RUSRUS'	''	->	'VOLOVO'
# '27 LENINA STRLYUBERETSKIY140060    RUSRUS'	'LYUBERETSKIY'	->	'OKTJABRSKIJ'
# '46 TEKSTILSHCHIKOV STRLYUBERETSKIY,140060    RUSRUS'	'LYUBERETSKIY'	->	'OKTJABRSKIJ'
# 'NOVORYAZANSKOE, 24 KM SH.143000    RUSRUS'	''	->	'ODINTSOVO'
# 'VOSTOCHNAJART, TUKAEVSKI423887    RUSRUS'	'RT TUKAEVSKI'	->	'MALAJA SHILNA'
# '37 - STRNOVO-KULIKOVO141833    RUSRUS'	'NOVO KULIKOVO'	->	'KULIKOVO'
# '. DMITROVSKIY R-NBUNYATINO141896    RUSRUS'	'BUNYATINO'	->	'ABRAMTSEVO'
# 'POSELOCHNAYA 5ZUBANYA606910    RUSRUS'	'ZUBANYA'	->	'SHAKHUNJA'
# 'LENINGRADSKAYA,AVTOSTOYANKAZAVIDOVO KONA171275    RUSRUS'	'ZAVIDOVO KONA'	->	'LENINGRADSKAJA'
# '12 LENINGRADSKAYA STRMOKSHINO,KONA171266    RUSRUS'	'MOKSHINO KONA'	->	'MOKSHINO'
# 'MKRN 2RZHAVKI RP.  141552    RUSRUS'	'RZHAVKI RP'	->	'RZHAVKI'
# '. MENDELEEVA -50 LET KOMSOMOPERESLAVL-ZAL152025    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '2 MENDELEEVA STRPERESLAVL-ZAL152025    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '73, KOMSOMOLSKAYAANAPSKIIY REG353900    RUSRUS'	'ANAPSKIIY OBL'	->	'NOVOROSSIJSK'
# 'STARYE PETUSHKISTARYE PETUSH601144    RUSRUS'	'STARYE PETUSH'	->	'PETUSHKI'
# '1 AKRIKHINOVSKOE SH NOGINSKI,142450    RUSRUS'	''	->	'STARAJA KUPAVNA'
# 'MIRA ST.4ARESP.KOMI SYK167018    RUSRUS'	'KOMI SYK'	->	'SYKTYVKAR'
# 'A-P DOMODEDOVO TERDOMODEDOVSKIY142015    RUSRUS'	'DOMODEDOVSKIY'	->	'DOMODEDOVO'
# 'CENTRNOVOSARATOVKA188681    RUSRUS'	'NOVOSARATOVKA'	->	'KHAPO OE'
# 'A.SHIPUNOVA UL.,1AOSINOVAYA GOR300045    RUSRUS'	'OSINOVAYA GOR'	->	'TULA'
# '1A A.SHIPUNOVA STROSINOVAYA GOR300045    RUSRUS'	'OSINOVAYA GOR'	->	'TULA'
# '61, TARASA SHEVCHENKORUSSIAN FEDER350000    RUSRUS'	''	->	'KRASNODAR'
# 'KIYEVSKAYA STR., 189MagSud295000    RUSRUS'	'MAGSUD'	->	'SIMFEROPOL'
# 'VOLKOVSKOE MKRNTARUSSKIY249000    RUSRUS'	'TARUSSKIY'	->	'BALABANOVO'
# 'Noviy lane 6LODEYNOPOLSKI187729    47 RUS'	'LODEYNOPOLSKI'	->	'STARAJA SLOBODA'
# 'RINOCHNAYA 61ST. IVANOVSKA353821    RUSRUS'	'ST IVANOVSKA'	->	'IVANOVSKAJA'
# '70, SOVETSKAYAOREL REGION302520    RUSRUS'	'OREL OBL'	->	'ZNAMENKA'
# '24G, SOVETSKAYAOREL REGION302520    RUSRUS'	'OREL OBL'	->	'ZNAMENKA'
# '32-1 GOGOLYA STRLYUBERETSKIY140070    RUSRUS'	'LYUBERETSKIY'	->	'TOMILINO'
# '18-4, GOGOLYALYUBERETSKIY140070    RUSRUS'	'LYUBERETSKIY'	->	'TOMILINO'
# '9 KRASNOSELSKOE SHVAYYALOVO188300    RUSRUS'	'VAYYALOVO'	->	'GATCHINA'
# 'M4 117 KMUMRISHENKA142915    RUSRUS'	'UMRISHENKA'	->	'PJATNITSA'
# '66 LAZAREVA STRLAZAREVSKOE354200    RUSRUS'	'LAZAREVSKOE'	->	'SOCHI'
# '17 SHKOLNAYA STRKAYGORODOVO454053    RUSRUS'	'KAYGORODOVO'	->	'CHELJABINSK'
# 'SOLNECHNAYA,12D.BYLNIKI214213    RUSRUS'	'BYLNIKI'	->	''
# '1, POM.17,18 , STRANICHKOVO141142    RUSRUS'	'ANICHKOVO'	->	'BIOKOMBINATA'
# 'Narodnaya st, 7vKAMENSK-SHAKH347800    RUSRUS'	'KAMENSK SHAKH'	->	'KAMENSK SHAKHTINSKIJ'
# 'FRYANOVSKOE SHOSSEMALOE LEDOVO141112    RUSRUS'	'MALOE LEDOVO'	->	'SHCHELKOVO'
# '3 . STR LITERA AANICHKOVO141142    RUSRUS'	'ANICHKOVO'	->	'BIOKOMBINATA'
# '4, PARKOVAYAAKSENO-BUTYRS142434    RUSRUS'	'AKSENO BUTYRS'	->	'RADIOTSENTR'
# '. . STR BLD 4,5,5AOZNOBISHENO101000    RUSRUS'	'OZNOBISHENO'	->	'MOSKVA'
# 'KOMAROVA 111PROMYISHLENNA652380    RUSRUS'	'PROMYISHLENNA'	->	'PROMYSHLENNAJA'
# 'POKROVSKAYA DOROGANOVOSARATOVKA188681    RUSRUS'	'NOVOSARATOVKA'	->	'KHAPO OE'
# 'MKAD 52KM TER BLD 3MKAD 52KM121471    RUSRUS'	''	->	'MOSKVA'
# 'p.Mehanich. zavoda 1s/p Peshkovsk141532    RUSRUS'	'PESHKOVSK'	->	'RADUMLJA'
# '5A - STRSOVKHOZA IM.L142715    RUSRUS'	'SOVKHOZA IM L'	->	'SOVKHOZ IM LENINA'
# '22 TRAKTOVAYA STRNOVOLISIKHA660000    RUSRUS'	'NOVOLISIKHA'	->	'KRASNOJARSK'
# '20 TRAKTOVAYA STRNOVOLISIKHA664511    RUSRUS'	'NOVOLISIKHA'	->	'PIVOVARIKHA'
# '. AD MOSKVA-DON 261 KM SH,300000    RUSRUS'	''	->	'TULA'
# '94A S. NOVOGUSLEVO TERTALDOMSKIY141930    RUSRUS'	'TALDOMSKIY'	->	'VERBILKI'
# 'MASSIV 1SLUCHAIYNYIY 142451    RUSRUS'	'SLUCHAIYNYIY'	->	'BISEROVO'
# '6 A KALININGRADSKOE SHSHOSSEYNOE236028    RUSRUS'	'SHOSSEYNOE'	->	'KALININGRAD'
# '9, KALININGRADSKOE SH.SHOSSEYNOE238326    RUSRUS'	'SHOSSEYNOE'	->	'ZELENOGRADSK'
# 'FADEEVATRASSA ROSTOV350010    RUSRUS'	'TRASSA ROSTOV'	->	'KRASNODAR'
# '1-2 B-U STRRYUTTYU186792    RUSRUS'	'RYUTTYU'	->	'SORTAVALA'
# 'D. ZALAVIEZALAVIE181520       RUS'	'ZALAVIE'	->	'NOVYJ IZBORSK'
# 'OSINOVAYA GORA BLD 2OSINOVAYA GOR300045    RUSRUS'	'OSINOVAYA GOR'	->	'TULA'
# '11 TOLSTOGO STRTULA, P. MEND300026    RUSRUS'	'TULA MEND'	->	'TULA'
# 'RUMYANTSEVO BLD 1LENINSKIY RAY142784    RUSRUS'	'LENINSKIY RAY'	->	''
# '3 SKHODNENSKAYA STR BLD POM.PUTILKOVO,KRA143400    RUSRUS'	'PUTILKOVO KRA'	->	''
# 'TC ZOLOTOY VAVILON127562127562    RUSRUS'	''	->	'MOSKVA'
# 'BUGRYVSEVLZ188660    RUSRUS'	'VSEVLZ'	->	'BUGRY'
# 'SOVETSKAYA 2VST.GOSTGAEVSK353410    RUSRUS'	'ST GOSTGAEVSK'	->	''
# '125,EVPATORIYSKAYARF350000    RUSRUS'	''	->	'KRASNODAR'
# '1A B-U STRCHUDTSY187630    RUSRUS'	'CHUDTSY'	->	'KOLI'
# 'VBLIZI FENINOGJHELSKOE140145    RUSRUS'	'GJHELSKOE'	->	'RECHITSY'
# '10A ZAVODSKAYA STRLYUBUCHATSY142300    RUSRUS'	'LYUBUCHATSY'	->	'CHEKHOV'
# '4, NOVOSLOBODSKAYASOBOLIKHA143985    RUSRUS'	'SOBOLIKHA'	->	'SAVVINO'
# '17 NOVOSLOBODSKAYA STRSOBOLIKHA140162    RUSRUS'	'SOBOLIKHA'	->	'KONSTANTINOVO'
# 'CHERNAYA GRYAZNOSCOW REGION141580    RUSRUS'	'NOSCOW OBL'	->	'LUNEVO'
# 'PYATNITSKOE SHSVETLYE GORY141000    RUSRUS'	'SVETLYE GORY'	->	'MYTISHCHI'
# '- STRFABRIKI IMENI140405    RUSRUS'	'FABRIKI IMENI'	->	'KOLOMNA'
# '91, MYASNIKYANAROSTOVSKIIY R346800    RUSRUS'	'ROSTOVSKIIY R'	->	'CHALTYR'
# 'ROSTOVSKAYA, 47CHALTYR POSEL346800    RUSRUS'	'CHALTYR POSEL'	->	'CHALTYR'
# 'TRANSPORTNAYA,32ST. KUSCHOVSK352030    RUSRUS'	'ST KUSCHOVSK'	->	'KUSHCHEVSKAJA'
# '91, MYASNIKYANA,TCHALTYRROSTOVSKAYA R346800    RUSRUS'	'ROSTOVSKAYA R'	->	'CHALTYR'
# '55E - STRYUDINO,S.P.ZH143081    RUSRUS'	'YUDINO ZH'	->	'JUDINO'
# ', RAMENSKIY R-NNOVOKHARITONO140155    RUSRUS'	'NOVOKHARITONO'	->	'ELEKTROIZOLJATOR'
# '3 MAYAKOVSKOGO PASSIVANTELEEVKA141280    RUSRUS'	'IVANTELEEVKA'	->	'IVANTEEVKA'
# 'GLAZOVO VILLAGESELSKOE POSEL141895    RUSRUS'	'SELSKOE POSEL'	->	'OSTANKINO'
# '4012 P., BUGRY POSVSEVOLZHSKIY188660    RUSRUS'	'VSEVOLZHSKIY'	->	'BUGRY'
# 'RAVENSTVOMASSIV MSHINS188268    RUSRUS'	'MASSIV MSHINS'	->	'MSHINSKAJA'
# 'Peschanaya st, 2LECHISHCHEVO143513    RUSRUS'	'LECHISHCHEVO'	->	'GIDROUZLA IM KUJBYSHEVA'
# 'PESCHANAYA UL., 2LECHISCHEVO D143513    RUSRUS'	'LECHISCHEVO'	->	'GIDROUZLA IM KUJBYSHEVA'
# 'MOSCOWSCOE SHOSSE, 21RYAZAN REGION390013    RUSRUS'	'RYAZAN OBL'	->	'RJAZAN'
# 'MKAD SH BLD 3, STR. 1TPZ ALTUFEVO141031    RUSRUS'	'TPZ ALTUFEVO'	->	'BORODINO'
# '(350055), Krasnodarskii krai, KrasnodarKransodar350055    03 RUS'	'KRANSODAR'	->	'ZNAMENSKIJ'
# 'M4 116 KMUMRISHENKA142915    RUSRUS'	'UMRISHENKA'	->	'PJATNITSA'
# 'SOVETSKAYA 5ZHELDOR143980    RUSRUS'	'ZHELDOR'	->	'ZHELEZNODOROZHNYJ'
# '7 POBRATIMOV STRGP.LYUBERTSY141551    RUSRUS'	'GP LYUBERTSY'	->	'ANDREEVKA'
# '61 VSEVOLOZHSKIY PRVSEVLZ188640    RUSRUS'	'VSEVLZ'	->	'VSEVOLOZHSK'
# '24 PARIZHSKOY KOMMUNY STRUPRAVLENCHESK443026    RUSRUS'	'UPRAVLENCHESK'	->	'SAMARA'
# '2 MOLODEZHNAYA STRNAKHABINO KRA143433    RUSRUS'	'NAKHABINO KRA'	->	'NAKHABINO'
# 'p.Mehanich. zavoda 1Peshkovskoe141532    RUSRUS'	'PESHKOVSKOE'	->	'RADUMLJA'
# '25 VOKZALNAYA STRNAKHABINO,KRA143430    RUSRUS'	'NAKHABINO KRA'	->	'NAKHABINO'
# '25 RODNIKOVAYA STRMAMONY, MKR.Z664000    RUSRUS'	'MAMONY MKR Z'	->	'IRKUTSK'
# 'VAKHONINO VILLAGEKONAKOVSKIY171285    RUSRUS'	'KONAKOVSKIY'	->	'VAKHONINO'
# '3 4-Y KVARTALKAPOTNYA141000    RUSRUS'	'KAPOTNYA'	->	'MYTISHCHI'
# 'LO, v. Pokrovskaya, 3 AGATCHINSKIY R188320    47 RUS'	'GATCHINSKIY R'	->	'KOMMUNAR'
# '3 POKROVSKAYA DOROGA STRNOVOSARATOVKA188681    RUSRUS'	'NOVOSARATOVKA'	->	'KHAPO OE'
# 'A-P DOMODEDOVO TER BLD 1DOMODEDOVSKIY142015    RUSRUS'	'DOMODEDOVSKIY'	->	'DOMODEDOVO'
# '27 TSENTRALNAYA STRS.P.OBUSHKOVS143582    RUSRUS'	'OBUSHKOVS'	->	'POKROVSKOE'
# 'LENINSKIY R-NIMENI LENINA142715    RUSRUS'	'IMENI LENINA'	->	'SOVKHOZ IM LENINA'
# '13KM SHZAMULYANKA614530    RUSRUS'	'ZAMULYANKA'	->	'FROLY'
# 'VANEEVANIZGNIY NOVGO603105    RUSRUS'	'NIZGNIY NOVGO'	->	'NIZHNIJ NOVGOROD'
# '14A . MKRNGLEBOVSKIY143517    RUSRUS'	'GLEBOVSKIY'	->	'KHOLSHCHEVIKI'
# '1A -AVTOZAPRAVOCH214530    RUSRUS'	'AVTOZAPRAVOCH'	->	'PECHERSK'
# '24 2-YA ZAVODSKAYA STRLYUBERTSY, PO141000    RUSRUS'	'LYUBERTSY PO'	->	'MYTISHCHI'
# 'TCUKEROVA BALKATCUKEROVA BAL353090    RUSRUS'	'TCUKEROVA BAL'	->	'NOVOROSSIJSK'
# '3, DRUZHBYIPERM' REGION618703    RUSRUS'	'PERM OBL'	->	'POLAZNA'
# '11, NEFTYANIKOV PER.PERM' REGION618703    RUSRUS'	'PERM OBL'	->	'POLAZNA'
# 'AEROPORT DOMODEDOVO TER BLDDOMODEDOVSKIY141000    RUSRUS'	'DOMODEDOVSKIY'	->	'MYTISHCHI'
# 'NET NET STRKOZITSYNO157505    RUSRUS'	'KOZITSYNO'	->	'SHARJA'
# '(142322), Moskovskaya obl, CHehovskii rBarantsevskii142322    46 RUS'	'BARANTSEVSKII'	->	'NOVYJ BYT'
# '1, GENERALA IVANOVASOURGOUT628408    RUSRUS'	'SOURGOUT'	->	'SURGUT'
# '1, LUGOVAYAODINTSOVO REG143026    RUSRUS'	'ODINTSOVO OBL'	->	'NOVOIVANOVSKOE'
# 'PYTALOBSKY DISTR UBYLINKA VILLPSKOVSKAYA R181425    RUSRUS'	'PSKOVSKAYA R'	->	'GAVRY'
# '4 LUGOVAYA STR BLD 2INNOVATS. TSE143026    RUSRUS'	'INNOVATS TSE'	->	'NOVOIVANOVSKOE'
# 'VERHNEABAKANSKIYVERHNEABAKANS353970    RUSRUS'	'VERHNEABAKANS'	->	'VERKHNEBAKANSKIJ'
# 'M-8PERESLAVL-ZAL150000    RUSRUS'	'PERESLAVL'	->	'JAROSLAVL'
# '88 1YA RYBNAYA STSERPOS141313    RUSRUS'	'SERPOS'	->	'SERGIEV POSAD'
# '3 MICHURINSKIY PR-T BLD 1OLIMPIYSKAYA119602    RUSRUS'	'OLIMPIYSKAYA'	->	'MOSKVA'
# '61 SOVETSKAYA STRB. SAMOVETS399000    RUSRUS'	'B SAMOVETS'	->	'IZMALKOVO'
# 'PP PSOUCANDRYPSH384900    RUSRUS"'	'CANDRYPSH'	->	''
# 'CHYORNAYA GRYAZ DER.UNKNOWN      141580    RUSRUS'	''	->	'LUNEVO'
# '7A RABOCHAYA STRSTARO-PANOVO198205    RUSRUS'	'STARO PANOVO'	->	'ST PETERBURG'
# '1 MAGISTRALNAYA STRSTARO-ALEKSAN461038    RUSRUS'	'STARO ALEKSAN'	->	'STAROALEKSANDROVKA'
# '14 NIKOLAEVSKIY PR-TYUZHNYY GOROD443085    RUSRUS'	'YUZHNYY GOROD'	->	'SAMARA'
# '9 NIKOLAEVSKIY PR-TYUZHNYY GOROD443000    RUSRUS'	'YUZHNYY GOROD'	->	'SAMARA'
# '5 NAROFOMINSKOE SHKUBINKA  ODIN143070    RUSRUS'	'KUBINKA ODIN'	->	'KUBINKA'
# 'D. NESTUKOVONESTUKOVO614531    RUSRUS'	'NESTUKOVO'	->	'FERMA'
# '21 KM KALUZHSKOE SHLENINSKIY RAY142704    RUSRUS'	'LENINSKIY RAY'	->	'MOSKVA'
# 'AEROPORT DOMODEDOVO TER BLDAEROPORT DOMO142015    RUSRUS'	'AEROPORT DOMO'	->	'DOMODEDOVO'
# '4 TREKHGORNAYA STRTREKHGORKA143005    RUSRUS'	'TREKHGORKA'	->	'ODINTSOVO'
# '4 TREKHGORSKAYA STRTREKHGORKA143005    RUSRUS'	'TREKHGORKA'	->	'ODINTSOVO'
# '10, MOLODEZHNAYAODINTSOVO REG143080    RUSRUS'	'ODINTSOVO OBL'	->	'LESNOJ GORODOK'
# '- MESHCHERSKOE VILLAGE BLD 4CHEKHOVSKIY142360    RUSRUS'	'CHEKHOVSKIY'	->	'MESHCHERSKOE'
# 'GOLYBEVA 3NIZGNIY NOVGO603132    RUSRUS'	'NIZGNIY NOVGO'	->	'NIZHNIJ NOVGOROD'
# '30, MIRATCHEREPOVETC162600    RUSRUS'	'TCHEREPOVETC'	->	'CHEREPOVETS'
# ', A-D MOSKVA-S.PETERBURG, 19,170000    RUSRUS'	''	->	'TVER'
# '4 KASIMOVSKOE SHLYUBERETSKIY141000    RUSRUS'	'LYUBERETSKIY'	->	'MYTISHCHI'
# 'ER KOLTOVOKASHIRSKIY RA142900    RUSRUS"'	'KASHIRSKIY RA'	->	'KASHIRA'
# '9 SOVETSKAYA STRKALUGA,P.TOVA249856    RUSRUS'	'KALUGA TOVA'	->	'TOVARKOVO'
# '20, KOMSOMOLSKAYAALTAIYSKIIY R659820    RUSRUS'	'ALTAIYSKIIY R'	->	'KOSIKHA'
# ', LUGOVAYA STR BLD 20A, STR.ROGOZININO143397    RUSRUS'	'ROGOZININO'	->	''
# '4 ROSTOVSKAYA STRPERESLAVL-ZAL152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '14 UROZHAYNAYA STRSVECHINO152037    RUSRUS'	'SVECHINO'	->	'KOPNINO'
# 'DEREVNYA KOROTKOVODEREVNYA KORO152044    RUSRUS'	'DEREVNYA KORO'	->	'BOLSHAJA BREMBOLA'
# '52 URITSKOGO STRPERESLAVL-ZAL152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '20 RECHNAYA STRKRSANOGORSK140400    RUSRUS'	'KRSANOGORSK'	->	'KOLOMNA'
# '96 KARDOVSKOGO STRPERESLAVL152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '10 SOVETSKAYA STRPERESLAVL-ZAL152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '25 MENDELEEVA STRPERESLAVL-ZAL152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '20A, KHANTY-MANSIYSKAYANIZHNEVATORSK628605    RUSRUS'	'NIZHNEVATORSK'	->	'NIZHNEVARTOVSK'
# '- STRIGNATOVO S.O.141851    RUSRUS'	'IGNATOVO O'	->	'PODOSINKI'
# '3 LESNAYA STRMETRO BELORUS125047    RUSRUS'	'METRO BELORUS'	->	'MOSKVA'
# 'SHCHERBININO D., STR. 16SHCHERBININO142632    RUSRUS'	'SHCHERBININO'	->	'DEMIKHOVO'
# '40 RUBLEVSKIY PASS BLD 4ROMASHKOVO143025    RUSRUS'	'ROMASHKOVO'	->	'NEMCHINOVKA'
# 'CENTRALNAYA, 37DROZDI306230    RUSRUS'	'DROZDI'	->	'OBOJAN'
# 'VBLIZI KH.RZHAVETS STRSHEBEKINSKIY309276    RUSRUS'	'SHEBEKINSKIY'	->	'MASLOVA PRISTAN'
# 'DOM 87NOVOSIDORIHA140702    RUSRUS'	'NOVOSIDORIHA'	->	'SHATURA'
# 'BATUMSKOE SHOSSE 34ADAGOMYS354207    RUSRUS'	'DAGOMYS'	->	'SOCHI'
# '22 PRIOZERSKOE SH BLD BLUPPOLOVO188653    RUSRUS'	'LUPPOLOVO'	->	'AGALATOVO'
# 'PIONERSKAYA-MOLODEZHNAYANOVOROOSIIYSK353900    RUSRUS'	'NOVOROOSIIYSK'	->	'NOVOROSSIJSK'
# '32 KOMMUNISTICHESKIY PRROSTDN344000    RUSRUS'	'ROSTDN'	->	'ROSTOV NA DONU'
# '26 AVTOMOBILISTOV STRTULA,POS.SKUR300911    RUSRUS'	'TULA SKUR'	->	'JUZHNYJ'
# '26 BATUMSKOE SHDAGOMYS354207    RUSRUS'	'DAGOMYS'	->	'SOCHI'
# '38, POLEZHAEVAROMODANOVSKII431600    RUSRUS'	'ROMODANOVSKII'	->	'ROMODANOVO'
# '36 PUSHKINA STRRODIONO-NESVE346580    RUSRUS'	'RODIONO NESVE'	->	'RODIONOVO NESVETAJSKAJA'
# '24A KOMAROVAROSTDN344000    RUSRUS'	'ROSTDN'	->	'ROSTOV NA DONU'
# '115A, 302 DIVIZIIKRASNODAR REG353740    RUSRUS'	'KRASNODAR OBL'	->	'LENINGRADSKAJA'
# '106, LENINAKRASNODAR REG353485    RUSRUS'	'KRASNODAR OBL'	->	'ARKHIPO OSIPOVKA'
# 'BATUMSKOE SHOSSE 63 3DAGOMYS354207    RUSRUS'	'DAGOMYS'	->	'SOCHI'
# '92 LVOVSKAYA STRVARDANE354209    RUSRUS'	'VARDANE'	->	'SOCHI'
# '(350040), Krasnodarskii krai, KrasnodarKransodar350040    03 RUS'	'KRANSODAR'	->	'KRASNODAR'
# '1 A KOOPERATIVNAYA STRSHCHELKOVSKIY141180    RUSRUS'	'SHCHELKOVSKIY'	->	'ZAGORJANSKIJ'
# '15A LESNAYA STRSHCHELKOVSKIY141134    RUSRUS'	'SHCHELKOVSKIY'	->	'OBOLDINO'
# 'MKAD 21 KM TER BLD 14MKAD 21 KM141000    RUSRUS'	''	->	'MYTISHCHI'
# 'KRASNOGORSK-4 TERMYAKININO141000    RUSRUS'	'MYAKININO'	->	'MYTISHCHI'
# '47 POLE LINEDYATLITSY188500    RUSRUS'	'DYATLITSY'	->	''
# '44, MOSKOVSKAYAMALOYAAROSLAV249096    RUSRUS'	'MALOYAAROSLAV'	->	'MALOJAROSLAVETS'
# '1A GAGARINA STRSTEPNYANSKIY346752    RUSRUS'	'STEPNYANSKIY'	->	'KAJALSKIJ'
# '30, LENINGRADSKAYAPRIOZERSKIY R188731    RUSRUS'	'PRIOZERSKIY R'	->	'SOSNOVO'
# '120 ENGELSA STR BLD LIT.APROSPEKT190000    RUSRUS'	'PROSPEKT'	->	'ST PETERBURG'
# '4 RECHNOY MKRNMALYE KOLPANY188302    RUSRUS'	'MALYE KOLPANY'	->	'GATCHINA'
# '8 BELOBORODOVA STRNAKHABINO KRA143430    RUSRUS'	'NAKHABINO KRA'	->	'NAKHABINO'
# '2 B TSENTRALNAYA STRSUORANDA188689    RUSRUS'	'SUORANDA'	->	'JANINO'
# '- STRTARYCHEVO142703    RUSRUS'	'TARYCHEVO'	->	'VIDNOE'
# 'GHURAVLEVOV. USTUG162394    RUSRUS'	'V USTUG'	->	'VELIKIJ USTJUG'
# '82 A PRIOZERSKOE SHVARTEMYAGI188653    RUSRUS'	'VARTEMYAGI'	->	'AGALATOVO'
# '2A BISEROVSKOE SHRYBKHOZ142451    RUSRUS'	'RYBKHOZ'	->	'BISEROVO'
# '.GP. STARAYA KUPAVNA NOGINSKRYBKHOZ142461    RUSRUS'	'RYBKHOZ'	->	'VISHNJAKOVSKIE DACHI'
# '68 PIMENOVKA STRTSIBINO140250    RUSRUS'	'TSIBINO'	->	'BELOOZERSKIJ'
# '3 VREMENA GODA ESTOSADOKESTOSADOK354392    RUSRUS'	'ESTOSADOK'	->	'KRASNAJA POLJANA'
# 'OSTASHKOVSKOE HIGHWAY 2,1MYTISCHI MOS141014    RUSRUS'	'MYTISCHI MOS'	->	'MYTISHCHI'
# '1 PUTILKOVSKOE SH BLD 3PUTILKOVO, KR141000    RUSRUS'	'PUTILKOVO KR'	->	'MYTISHCHI'
# '25A NAKHIMOVSKIY PR-T117209117209    RUSRUS'	''	->	'MOSKVA'
# 'KRASNOSLUDSKOE STRZALESNAYA618719    RUSRUS'	'ZALESNAYA'	->	'PALNIKI'
# 'BOTOVOBOTOVO AEROPO162000    RUSRUS'	'BOTOVO AEROPO'	->	'GRJAZOVETS'
# '1B GAGARINA STRSTEPNYANSKIY346752    RUSRUS'	'STEPNYANSKIY'	->	'KAJALSKIJ'
# '24 ENTUZIASTOV STRPUSHKINO, MKR141200    RUSRUS'	'PUSHKINO MKR'	->	'PUSHKINO'
# 'GORODOK 17 STRMALYE VYAZEMY143000    RUSRUS'	'MALYE VYAZEMY'	->	'ODINTSOVO'
# 'MOZHAYSKOE SH BLD 8MALYE VYAZEMY143050    RUSRUS'	'MALYE VYAZEMY'	->	'BOLSHIE VJAZEMY'
# '124 PRIOZERSKOE SH BLD AVARTEMYAGI188653    RUSRUS'	'VARTEMYAGI'	->	'AGALATOVO'
# '(142715), Moskovskaya obl, Leninskii r-Sov-z Lenina142715    46 RUS'	'SOV Z LENINA'	->	'SOVKHOZ IM LENINA'
# 'SOROKINSKOE SH., STR.7-141000    RUSRUS'	''	->	'MYTISHCHI'
# '00 TSENTRALNAYA STRKELOZI190000    RUSRUS'	'KELOZI'	->	'ST PETERBURG'
# 'MOLODEZHNAYA 48PAVLOSLOBODS143581    RUSRUS'	'PAVLOSLOBODS'	->	'PAVLOVSKAJA SLOBODA'
# '20 KMROSTOV TAGANR346800    RUSRUS'	'ROSTOV TAGANR'	->	'CHALTYR'
# '13 OBSERVATORNAYA STRVERKHNETEMERN346735    RUSRUS'	'VERKHNETEMERN'	->	'RASSVET'
# 'MIRA 24ST. ANAPSKAY353450    RUSRUS'	'ST ANAPSKAY'	->	''
# '1 POSELKOVAYA STRSTARO-PANOVO198205    RUSRUS'	'STARO PANOVO'	->	'ST PETERBURG'
# 'LESNAYA, 33P.G.T. GRIBAN397242    RUSRUS'	'T GRIBAN'	->	'LESNAJA'
# '1, MASSIVSLUCHAYNIY142451    RUSRUS'	'SLUCHAYNIY'	->	'BISEROVO'
# '- SHEKSNINSKIY R-NMALINUKHA162565    RUSRUS'	'MALINUKHA'	->	'CHUROVSKOE'
# 'NET NET STRMALAYA RUKAVI162600    RUSRUS'	'MALAYA RUKAVI'	->	'CHEREPOVETS'
# '34A,MIRATEMRIUKSKIIY353540    RUSRUS'	'TEMRIUKSKIIY'	->	'SENNOJ'
# '1, SEDOVAYAROSLAVL' RE152241    RUSRUS'	'YAROSLAVL OBL'	->	'GAVRILOV JAM'
# 'A-108TVERITINO142203    RUSRUS'	'TVERITINO'	->	'SERPUKHOV'
# '46 KM MINSKOE SH,143044    RUSRUS'	''	->	'GOLITSYNO'
# '1A,LUNACHARSKOGORYAZANSKIIY R391351    RUSRUS'	'RYAZANSKIIY R'	->	'ELATMA'
# 'NOGINSKIY R-NKOVERSHI142402    RUSRUS'	'KOVERSHI'	->	'NOGINSK'
# '28-G GVARDEYTSEV-TANKISTOV SRODIONOVO-NES346580    RUSRUS'	'RODIONOVO NES'	->	'RODIONOVO NESVETAJSKAJA'
# '16 KIROVA STRRODIONOVO-NES346580    RUSRUS'	'RODIONOVO NES'	->	'RODIONOVO NESVETAJSKAJA'
# '2KM ROSTOV-NOVOSHAKHTINSK SHMYASNIKOVSKIY346800    RUSRUS'	'MYASNIKOVSKIY'	->	'CHALTYR'
# 'MICHURINA, 26RODIONOVO NES346580    RUSRUS'	'RODIONOVO NES'	->	'MICHURINA'
# '9 SOVETSKAYA STRKHATUN,STUPIN142845    RUSRUS'	'KHATUN STUPIN'	->	'KHATUN'
# '32 D KURCHATOVA STRVORONEZH, SHI394000    RUSRUS'	'VORONEZH SHI'	->	'VORONEZH'
# '228 POLKOVAYA STRSLAVYANSK-NA-353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# '60 KOVTYUKHA STRSLAVYANSK-NA-353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# '21 KOVTYUKHA STRSLAVYANSK-NA-353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# 'B.N SNT RAVENSTVO TERMASSIV MSHINS188236    RUSRUS'	'MASSIV MSHINS'	->	'LUGA'
# '17 PLESHCHEEVSKAYA STRPERESLAVL-ZAL152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '58 KARDOVSKOGO STRPERESLAVL-ZAL152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '6A LENINA STRZATO ZVEZDNYY614575    RUSRUS'	'ZATO ZVEZDNYY'	->	'ZVEZDNYJ'
# '2 NOVOKARPOVKA STRVYATKINSKOE601362    RUSRUS'	'VYATKINSKOE'	->	'BARAKI'
# 'STROGINSKAYA POYMA TER BLD 3STROGINSKAYA101000    RUSRUS'	'STROGINSKAYA'	->	'MOSKVA'
# ', A-D MOSKVA-S.PETERBURG, 20,170000    RUSRUS'	''	->	'TVER'
# '(143581), Moskovskaya obl, Istrinskii rPavlo-Sl-koe143581    46 RUS'	'PAVLO SL KOE'	->	'PAVLOVSKAJA SLOBODA'
# '1271500 DON SHMALEVANNYY353158    RUSRUS'	'MALEVANNYY'	->	''
# '30A, LENINAKRYIMSKIIY RE353356    RUSRUS'	'KRYIMSKIIY OBL'	->	'PLAVNENSKIJ'
# '13 ZAPADNAYA STRMALYE KOLPANY188302    RUSRUS'	'MALYE KOLPANY'	->	'GATCHINA'
# '16 EVSEEVSKAYA STRKHUDYAKOVO664511    RUSRUS'	'KHUDYAKOVO'	->	'PIVOVARIKHA'
# '124-A PRIOZERSKOE SHVARTEMYAGI188653    RUSRUS'	'VARTEMYAGI'	->	'AGALATOVO'
# '6 EVROPEYSKIY BLVDROMASHKOVO143025    RUSRUS'	'ROMASHKOVO'	->	'NEMCHINOVKA'
# 'MOSKOW23, 1, OPOLCH123154    RUSRUS'	'OPOLCH'	->	'MOSKVA'
# 'TRASPORTNAYA 11ST. KUSHEVSKA352030    RUSRUS'	'ST KUSHEVSKA'	->	'KUSHCHEVSKAJA'
# '148-3, GAGARINAADYIGEYA385141    RUSRUS'	'ADYGEJA'	->	'JABLONOVSKIJ'
# 'DOM 93NOVOGUSLEVO141930    RUSRUS'	'NOVOGUSLEVO'	->	'VERBILKI'
# '11 TSENTRALNAYA STRBABYNINSKIY P249201    RUSRUS'	'BABYNINSKIY'	->	'VOROTYNSK'
# '51 KARLA MARKSA PR-T BLD AKAMENSK-SHAKH347800    RUSRUS'	'KAMENSK SHAKH'	->	'KAMENSK SHAKHTINSKIJ'
# '33 ZORGE ST ROSTDNROSTDN344000    RUSRUS'	'ROSTDN'	->	'ROSTOV NA DONU'
# '51 KRUPSKOY BYSTRKAMENSK-SHAKH347800    RUSRUS'	'KAMENSK SHAKH'	->	'KAMENSK SHAKHTINSKIJ'
# '1, FABRICHNAYAMYITISCHINSKI141033    RUSRUS'	'MYITISCHINSKI'	->	'PIROGOVSKIJ'
# 'MORSKOGO DESANTA UL. 3UNKNOWN      198516    RUSRUS'	''	->	'PETERGOF'
# 'ZHELEZNODOROZHNAYA STRMOSCOW, SCHER142172    RUSRUS'	'MOSCOW SCHER'	->	''
# '2, YUBILEYNAYAVERKHNYYA PYS624090    RUSRUS'	'VERKHNYYA PYS'	->	'VERKHNJAJA PYSHMA'
# 'Yubileinaya, 17AMO, Lyubertcu140011    RUSRUS'	'LYUBERTCU'	->	'LJUBERTSY'
# 'PROLETARSKAYASLAVYANSK NA353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# '2 VOSTOCHNYY PR-TNOVOGLAGOLEVO143345    RUSRUS'	'NOVOGLAGOLEVO'	->	'SELJATINO'
# '56 TSENTRALNAYA STRDROZDY306230    RUSRUS'	'DROZDY'	->	'OBOJAN'
# '111, PUSHKINASEVERSKIIY RE353235    RUSRUS'	'SEVERSKIIY OBL'	->	'AFIPSKIJ'
# '11 DOROGA ZHIZNI STVSEVLZ188643    RUSRUS'	'VSEVLZ'	->	'VSEVOLOZHSK'
# '10A MYTISHCHINSKIY R-N UL. S,141006    RUSRUS'	''	->	'MYTISHCHI'
# 'VAKHROMEEVO D. 50VAKHROMEEVO142050    RUSRUS'	'VAKHROMEEVO'	->	'BELYE STOLBY'
# '5A STAROCHKALOVSKAYA STRSEVERNOE BUTO117216    RUSRUS'	'SEVERNOE BUTO'	->	'MOSKVA'
# 'LENINAARHIPOVO-OSIP353465    RUSRUS'	'ARHIPOVO OSIP'	->	'GELENDZHIK'
# '72, MIRA, SMOLENSKAYAKRASNODAR REG353254    RUSRUS'	'KRASNODAR OBL'	->	'SMOLENSKAJA'
# 'MKAD BLD 3TPZ ALTUFEVO141031    RUSRUS'	'TPZ ALTUFEVO'	->	'BORODINO'
# '28, PLASTUNSKAYAKRASNODAR REG350037    RUSRUS'	'KRASNODAR OBL'	->	'LENINA'
# '2 KURORTNAYA STRPLYAKHO352857    RUSRUS'	'PLYAKHO'	->	'VOSTOK'
# '2 IM. ORLOVA STRSHCHEMILOVO142450    RUSRUS'	'SHCHEMILOVO'	->	'STARAJA KUPAVNA'
# '6 STEPNOY TUPIKDZHEMETE353450    RUSRUS'	'DZHEMETE'	->	''
# '48 LUNCHARSKOGO STRROSTOV VELIKI152151    RUSRUS'	'ROSTOV VELIKI'	->	'ROSTOV'
# 'OSINOVAYA STRKAZAN, SCHERB420140    RUSRUS'	'KAZAN SCHERB'	->	'KAZAN'
# '56 MOSKOVSKAYA STRPERESLAVL-ZAL152150    RUSRUS'	'PERESLAVL'	->	'ROSTOV'
# 'YAroslavskaya obl, g Pereslavl-ZalesskiPereslavl152025    78 RUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# 'S.Z. S.VLADIMIROVKA TERBEZENCHUKSKIY443000    RUSRUS'	'BEZENCHUKSKIY'	->	'SAMARA'
# 'KRASNAYA 141SLAVYANSK-NA-353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# '5 KHESINA STRIMENI MOROZOV188679    RUSRUS'	'IMENI MOROZOV'	->	'IM MOROZOVA'
# '. A-D MOSKVA-SIMFEROPOL 136,300000    RUSRUS'	''	->	'TULA'
# '61 VSEVOLZHSKIY PRVSEVLZ188640    RUSRUS'	'VSEVLZ'	->	'VSEVOLOZHSK'
# '29 ZARECHNAYA STRMARUSINO LYUB140009    RUSRUS'	'MARUSINO LYUB'	->	'LJUBERTSY'
# 'OSINOVAYA GORA SET BLD 1OSINOVAYA GOR300045    RUSRUS'	'OSINOVAYA GOR'	->	'TULA'
# '35 KIROVSKIY PRROSTDN344006    RUSRUS'	'ROSTDN'	->	'ROSTOV NA DONU'
# '(141552), Moskovskaya obl, SolnechnogorrpRzhavki141552    46 RUS'	'RPRZHAVKI'	->	'RZHAVKI'
# '160 MOZHAYSKOE SHGOLITSYNO,ODI143041    RUSRUS'	'GOLITSYNO ODI'	->	'GOLITSYNO'
# '77 POBEDY STR BLD BLAZAREVSKOE354200    RUSRUS'	'LAZAREVSKOE'	->	'SOCHI'
# '8 LUNNAYA STRBREKHOVO,SOLN141544    RUSRUS'	'BREKHOVO SOLN'	->	'BREKHOVO'
# 'STROITELNAYA STR BLD 6ORLOVKA GOROD403014    RUSRUS'	'ORLOVKA GOROD'	->	'ORLOVKA'
# 'STEPNAYAELIZAVATENSKA350916    RUSRUS'	'ELIZAVATENSKA'	->	'ELIZAVETINSKAJA'
# '13, GUR'YANOVAKALUGA REGION249160    RUSRUS'	'KALUGA OBL'	->	'BELOUSOVO'
# '7, TSENTRALNAYAYAROSLAVL REG150507    RUSRUS'	'YAROSLAVL OBL'	->	'IVNJAKI'
# '153 A POBEDY STRLAZAREVSKOE354200    RUSRUS'	'LAZAREVSKOE'	->	'SOCHI'
# 'ul. Chaiykovskogo, 37V.Pyshma624090    66 RUS'	'V PYSHMA'	->	'VERKHNJAJA PYSHMA'
# 'PBIKLYAN VILL AIRPORT ""BEGISHEVO""TATARSTAN423832       RUS"'	'TATARSTAN'	->	'NABEREZHNYE CHELNY'
# '9 KALININGRADSKOE SHSHOSSEYNOE238350    RUSRUS'	'SHOSSEYNOE'	->	''
# 'UCH.50 SERGIEVO-POSADSKIY R-RADONEZH141300    RUSRUS'	'RADONEZH'	->	'SERGIEV POSAD'
# '34 TSENTRALNAYA STRVOLOCHAEVSKOE238715    RUSRUS'	'VOLOCHAEVSKOE'	->	'LUNINO'
# ',,,MALOE LUGOVOE238325    39 RUS'	'MALOE LUGOVOE'	->	'LUGOVOE'
# '- STR155 KM AD MOS300000    RUSRUS'	'AD MOS'	->	'TULA'
# 'S.ZOLINONIZHEGOROD.OB606083    RUSRUS'	'NIZHEGOROD OB'	->	'MULINO'
# '195, 50 LET OKTYABRYAKRASNODAR REG352700    RUSRUS'	'KRASNODAR OBL'	->	'TIMASHEVSK'
# 'PRIVOKZALNAYA SQVNUKOVO AEROP119027    RUSRUS'	'VNUKOVO AEROP'	->	'MOSKVA'
# '.,.TRASSA M-10 1.         RUSRUS'	'TRASSA M'	->	''
# '1 ZAMYATINSKAYA STRKLINSKIY, POK141661    RUSRUS'	'KLINSKIY POK'	->	'POKROVKA'
# '29-1 SHOSSEYNAYA STRSOVKHOZA RAME140102    RUSRUS'	'SOVKHOZA RAME'	->	'NOVOE'
# '. RAMENSKIY R-NST.BRONNITSY140152    RUSRUS'	'ST BRONNITSY'	->	'MALYSHEVO'
# '16A KOMMUNALNAYA STR BLD 2BELOZERSKIY,V140145    RUSRUS'	'BELOZERSKIY V'	->	'RECHITSY'
# '1-A POBEDY STRLAZAREVSKOE354200    RUSRUS'	'LAZAREVSKOE'	->	'SOCHI'
# '81 PAVLOVA STRLAZAREVSKOE354200    RUSRUS'	'LAZAREVSKOE'	->	'SOCHI'
# '110 POBEDY STR BLD ALAZAREVSKOE354200    RUSRUS'	'LAZAREVSKOE'	->	'SOCHI'
# 'OBEDY STR., 153LAZAREVSKOE354535    RUSRUS"'	'LAZAREVSKOE'	->	''
# '5 TSENTRALNAYA STRBOLSHOE ALEKS142260    RUSRUS'	'BOLSHOE ALEKS'	->	'KIRPICHNYJ ZAVOD'
# '10 KOOPERATIVNAYA STRBOLSHOE ALEKS142853    RUSRUS'	'BOLSHOE ALEKS'	->	'BOLSHOE ALEKSEEVSKOE'
# 'S.B.ALEKSEEVSKOE TERS.O. BOLSHEAL142853    RUSRUS'	'O BOLSHEAL'	->	'BOLSHOE ALEKSEEVSKOE'
# 'SOVKHOZ IMENI LENINA, 24 KMSOVKHOZ IMENI142715    RUSRUS'	'SOVKHOZ IMENI'	->	'SOVKHOZ IM LENINA'
# 'SPB, LENINA, 6FINLYANDSKIJ195009    RUSRUS'	'FINLYANDSKIJ'	->	'ST PETERBURG'
# '1 A POBEDY STRLAZAREVSKOE354200    RUSRUS'	'LAZAREVSKOE'	->	'SOCHI'
# '1,OSTASHKOVSKOE SH.MYITYISHI114014    RUSRUS'	'MYITYISHI'	->	''
# '17 OKTYABRSKAYA STVSKRSK140200    RUSRUS'	'VSKRSK'	->	'VOSKRESENSK'
# '.,D. MILKOVO LENINSKIY R-N BRAZVILKOVSKOE142715    RUSRUS'	'RAZVILKOVSKOE'	->	'SOVKHOZ IM LENINA'
# 'GOLOVLEVODER. GOLOVLEV303026    RUSRUS'	'GOLOVLEV'	->	'NOVOVOLKOVSKIJ'
# '8 GYETE PR-TNEMETSKAYA DE350000    RUSRUS'	'NEMETSKAYA DE'	->	'KRASNODAR'
# '11 TSENTRALNAYA STRKALUGA,D.MSTI249000    RUSRUS'	'KALUGA MSTI'	->	'BALABANOVO'
# '19 MEDOVEEVSKAYA STRMEDOVEEVKA354390    RUSRUS'	'MEDOVEEVKA'	->	'KEPSHA'
# '4 A NAUGORSKAYA STRNIKULICHI302501    RUSRUS'	'NIKULICHI'	->	'BIOFABRIKA'
# '(143050), Moskovskaya obl, OdintsovskiiBVyazemi143050    46 RUS'	'BVYAZEMI'	->	'BOLSHIE VJAZEMY'
# '(350018), Krasnodarskii krai, KrasnodarKransodar350018    03 RUS'	'KRANSODAR'	->	'KRASNODAR'
# '6 KOLKHOZNAYA STRSTRUBKOVO, KL141600    RUSRUS'	'STRUBKOVO KL'	->	''
# '2 A VETERINARNAYA STRDALNEE KONSTA606310    RUSRUS'	'DALNEE KONSTA'	->	'DALNEE KONSTANTINOVO'
# '1 SOLNECHNYY BYSTRDALNEE KONSTA606310    RUSRUS'	'DALNEE KONSTA'	->	'DALNEE KONSTANTINOVO'
# 'P.INSHINSKIYLENINSKIY-TUL115419    71 RUS'	'LENINSKIY TUL'	->	'MOSKVA'
# 'A-D OREL-BRYANSK-SMOLENSK BR.241524    RUSRUS'	''	->	'MICHURINSKIJ'
# '1V POSELKOVAYA STRSTARO-PANOVO198205    RUSRUS'	'STARO PANOVO'	->	'ST PETERBURG'
# '2, SADOVAYAOREL REGION303620    RUSRUS'	'OREL OBL'	->	'KHOMUTOVO'
# '35 STEKLYANNIYVSEVLZ188654    RUSRUS'	'VSEVLZ'	->	'STEKLJANNYJ'
# 'DER PERSHUTINO H 2PERSHUTINO141604    RUSRUS'	'PERSHUTINO'	->	'KLIN'
# 'TRTS RIGA MOLL TERNOVORIZHSKOE143420    RUSRUS'	'NOVORIZHSKOE'	->	'ARKHANGELSKOE'
# 'Samarskaya str.,30GATCHINSKIY R188380    47 RUS'	'GATCHINSKIY R'	->	'VYRITSA'
# 'CHERNAYA GRYAZSNGRSK109004    RUSRUS'	'SNGRSK'	->	'MOSKVA'
# 'ALTUFEVSKOE SH BLD 3, STR. 1MYTISHCHINSKI141031    RUSRUS'	'MYTISHCHINSKI'	->	'BORODINO'
# '62 - STRSAFONTEVO143513    RUSRUS'	'SAFONTEVO'	->	'GIDROUZLA IM KUJBYSHEVA'
# '100 KOVTYUKHA STRSLAVYANSK-NA-353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# '2 MOSTOVAYA STRSHAMONINO450005    RUSRUS'	'SHAMONINO'	->	'UFA'
# 'P SERTOLOVOVSEVOLZHSKIY188650    RUSRUS'	'VSEVOLZHSKIY'	->	'SERTOLOVO'
# '138A,TSENTRALNAYALYAMBIRSKIIY431524    RUSRUS'	'LYAMBIRSKIIY'	->	'ATEMAR'
# '29 ESSENTUKSKAYA STPYATGR357500    RUSRUS'	'PYATGR'	->	'PJATIGORSK'
# '3 MIRAPYATGR357500    RUSRUS'	'PYATGR'	->	'PJATIGORSK'
# 'SOVETSKAYA 20 3MINERALOVODSK357204    RUSRUS'	'MINERALOVODSK'	->	'KRASNYJ PAKHAR'
# '7, SNEZHNAYAPENZENSKIIY R614520    RUSRUS'	'PENZENSKIIY R'	->	'KULTAEVO'
# 'RAMONSKIY R-NAEROPORT VORO396023    RUSRUS'	'AEROPORT VORO'	->	'CHERTOVITSY'
# '- KASHIRSKOE 118 KM SH-142900    RUSRUS'	''	->	'KASHIRA'
# '53, DOMNY KALIKOVOYSYKTYVKAR REG168220    RUSRUS'	'SYKTYVKAR OBL'	->	'VYLGORT'
# 'LENINA 65ANOVGOROD OBLR173015    53 RUS'	'NOVGOROD OBLR'	->	'VELIKIJ NOVGOROD'
# '4A ROSTOVSKAYA STRPERESLAVL152025    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '1A ROSTOVSKAYA STRPERESLAVL-ZAL152025    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '3, TSENTRALNOE SHOSSEVYBORG REGION188840    RUSRUS'	'VYBORG OBL'	->	'KRASNAJA DOLINA'
# '10, LESNAYAODINTSOVO REG143005    RUSRUS'	'ODINTSOVO OBL'	->	'ODINTSOVO'
# '13 KM SHOSSEOSECHENKI D. 140100    RUSRUS'	'OSECHENKI'	->	'RAMENSKOE'
# 'TVERSKOE SHOSSE, 1NOVOLOTOSHINO143801    RUSRUS'	'NOVOLOTOSHINO'	->	'LOTOSHINO'
# '9 KRASNYY BYSTRPERESLAVL152025    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# 'BEREG KAMY STRBEREG KAMY (K614506    RUSRUS'	'BEREG KAMY K'	->	'KONDRATOVO'
# '95 A SVOBODY STRPERESLAVL-ZAL152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '1 VBLIZI STRPERESLAVL-ZAL152024    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '35 MAGISTRALNAYA STRPERESLAVL-ZAL152023    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '41 STROITELEY STRPERESLAVL-ZAL152150    RUSRUS'	'PERESLAVL'	->	'ROSTOV'
# '10 MAGISTRALNAYA STRPERESLAVL-ZAL152023    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '27 ROSTOVSKAYA STRPERESLAVL-ZAL152020    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '21A 50 LET KOMSOMOLA STRPERESLAVL152025    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '41 ROSTOVSKAYA STRPERESLAVL-ZAL152025    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '57,KIROVAPODOLSKIY REG142117    RUSRUS'	'PODOLSKIY OBL'	->	'PODOLSK'
# '118 KOMMUNAROV STR BLD AVILLOZSKOE SE188508    RUSRUS'	'VILLOZSKOE SE'	->	'VILLOZI'
# '54 KRASNOSELSKOE SH BLD 3VILLOZSKOE SE188800    RUSRUS'	'VILLOZSKOE SE'	->	'VYBORG'
# 'IVANOVKA.11IVANOVKA (PUD188352    47 RUS'	'IVANOVKA PUD'	->	'PUDOST'
# '1A SOVETSKAYA STR BLD POM. 1TUCHKOVO, RUZ143131    RUSRUS'	'TUCHKOVO RUZ'	->	'TUCHKOVO'
# '1A DRUZHBY STR NOVYEKHIMKI TST KHIMKI101000    RUSRUS'	'ST KHIMKI'	->	'MOSKVA'
# 'TSENTRALNAYA STR BLD 13MALOE IVANOVS141052    RUSRUS'	'MALOE IVANOVS'	->	'MARFINO'
# '13 LUGOVAYA STRPODOLNIKHA141052    RUSRUS'	'PODOLNIKHA'	->	'MARFINO'
# 'ST. RADAST. RADA392515    RUSRUS'	'ST RADA'	->	'NOVAJA LJADA'
# '64, SCHORSABELGORODSKIIY308501    RUSRUS'	'BELGORODSKIIY'	->	'DUBOVOE'
# 'ZALESNAYA AZS NA DOROGEZALESNAYA618710    RUSRUS'	'ZALESNAYA'	->	'TABORY'
# '2 DOROZHNAYA STR BLD ANOVOUSMANSKIY396335    RUSRUS'	'NOVOUSMANSKIY'	->	'OTRADNOE'
# '39B SHOSSEYNAYA STRBRYANSK BEZHE241040    RUSRUS'	'BRYANSK BEZHE'	->	'BRJANSK'
# 'ZAPADNAYA, 1-4SLAVYANSK-NA-123456    RUSRUS'	'SLAVYANSK NA'	->	''
# ', LENINSKIY R-NMOLOKOVSKOE142714    RUSRUS'	'MOLOKOVSKOE'	->	'MOLOKOVO'
# '18 B-U STRKARABASIKHA606551    RUSRUS'	'KARABASIKHA'	->	'VYSOKAJA'
# '14-1 SOVKHOZNAYA STRTIMOKHOVA142400    RUSRUS'	'TIMOKHOVA'	->	'NOGINSK'
# 'LAVANDY NAB., 3ESTOSADOK S. 354392    RUSRUS'	'ESTOSADOK'	->	'KRASNAJA POLJANA'
# ', PERVOMAYSKAYAGP ROSCHINO188820    RUSRUS'	'GP ROSCHINO'	->	'ROSHCHINO'
# '154A,LENINSKAYADOBROVSKIIY R399162    RUSRUS'	'DOBROVSKIIY R'	->	'KALIKINO'
# 'PR-T SHOLOKHOVA, D. 31ROSTOV/DONU344029       RUS'	'ROSTOV DONU'	->	'ROSTOV NA DONU'
# '78 LENINA STOREKHZ142600    RUSRUS'	'OREKHZ'	->	'OREKHOVO ZUEVO'
# 'Petrovskaya, d.14Rastushii624030    RUSRUS'	'RASTUSHII'	->	'PETROVSKAJA'
# '3A SANINSKOE SHZHILGORODOK187501    RUSRUS'	'ZHILGORODOK'	->	'CHEMIKHINO'
# '53-KM MINSKOGO SHOSSE TER-143060    RUSRUS'	''	->	'CHASTSY'
# '2 ORLOVA STR POM.2SHCHEMILOVO142450    RUSRUS'	'SHCHEMILOVO'	->	'STARAJA KUPAVNA'
# 'NOVODEREVENSKAYA VILLAGE BLDNOVODEREVENSK627087    RUSRUS'	'NOVODEREVENSK'	->	'OKUNEVSKOE'
# '41 ZAVODSKAYA STRMAYAKOVSKOGO346703    RUSRUS'	'MAYAKOVSKOGO'	->	'LENINA'
# 'TURGENEVSKOE HW, 27ADYGEYA RESP385000    RUSRUS'	'ADYGEJA'	->	'MAJKOP'
# '1A PERVOMAYSKAYA STRIMENI MOROZOV188679    RUSRUS'	'IMENI MOROZOV'	->	'IM MOROZOVA'
# ...
# '300 KRUPSKOY STRSLAVYANSK-NA-353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# '. OSTASHKOVSKOE SH BLD 1B,STMYTISHCHINSKI141014    RUSRUS'	'MYTISHCHINSKI'	->	'MYTISHCHI'
# 'LENINAARHIPO-OSINOV353488    RUSRUS'	'ARHIPO OSINOV'	->	'ARKHIPO OSIPOVKA'
# '21-1 NARODNAYA STRRAMENSKAYA140105    RUSRUS'	'RAMENSKAYA'	->	'RAMENSKOE'
# 'KPP PSOUPSANDRIPSH384900    RUSRUS'	'PSANDRIPSH'	->	''
# 'TSENTRALNAYA ST. 2BMYTISHCHINSK141033    RUSRUS'	'MYTISHCHINSK'	->	'PIROGOVSKIJ'
# ', KRYM, 72 KM. SHCHEKHOVSKIY R142300    RUSRUS'	'CHEKHOVSKIY R'	->	'CHEKHOV'
# '- - STRMARTEMYANOVO141000    RUSRUS'	'MARTEMYANOVO'	->	'MYTISHCHI'
# '39B SOVETSKAYA STRROMASHKOVO143025    RUSRUS'	'ROMASHKOVO'	->	'NEMCHINOVKA'
# 'A-D BRYANSK-NOVOZYBKOV TER BPOCHEPSKIY243400    RUSRUS'	'POCHEPSKIY'	->	'POCHEP'
# '7, LENINGRADSKAYAYAM-IZHORA187033    RUSRUS'	'YAM IZHORA'	->	'VOJSKOROVO'
# '(141707), Moskovskaya obl, DolgoprudniiDolgo-nii141707    46 RUS'	'DOLGO NII'	->	'DOLGOPRUDNYJ'
# 'LENINA, 64KH-MANSIYSK628012    RUSRUS'	'KH MANSIYSK'	->	'LENINA'
# '31 DOROZHNAYA STRN. USMAN394000    RUSRUS'	'N USMAN'	->	'VORONEZH'
# 'ZAIYTSEVA UL.3SANKPETERBURG190000    RUSRUS'	'SANKPETERBURG'	->	'ST PETERBURG'
# '1 TOPOLINAYA STR BLDCHIMSHI452170    RUSRUS'	'CHIMSHI'	->	'CHISHMY'
# '13B LIKHACHEVSKOE SH,141707    RUSRUS'	''	->	'DOLGOPRUDNYJ'
# '1-Y KM AVTODOROGA ROSTOV-NOVMYASNIKOVSKIY344000    RUSRUS'	'MYASNIKOVSKIY'	->	'ROSTOV NA DONU'
# 'MOLODEZHNAYAVOLGOGRADSKII403010    RUSRUS'	'VOLGOGRADSKII'	->	'ERZOVKA'
# '1 - STRNOVYE KUZMENK142271    RUSRUS'	'NOVYE KUZMENK'	->	'PROLETARSKIJ'
# '2A,BOLDINAKODOSHKINSKII431900    RUSRUS'	'KODOSHKINSKII'	->	'KADOSHKINO'
# '2 CHUYSKAYA STGORALT649010    RUSRUS'	'GORALT'	->	'GORNO ALTAJSK'
# 'MOLODEZHNAYA UL.,1/1MALAYA LAYA S622933    RUSRUS'	'MALAYA LAYA'	->	'LAJA'
# '4A - STRVORSINO,R-N B249020    RUSRUS'	'VORSINO R N B'	->	'VORSINO'
# '21 PARIZHSKOY KOMMUNY STRUPRAVLENCHESK443026    RUSRUS'	'UPRAVLENCHESK'	->	'SAMARA'
# 'B-N B-U STRONEZHETS-2186100    RUSRUS'	'ONEZHETS'	->	''
# '3 MICHURINSKIY PR-T BLD 1OLIMPIYSKAYA141000    RUSRUS'	'OLIMPIYSKAYA'	->	'MYTISHCHI'
# '2A GOGOLYA STZELGRD124575    RUSRUS'	'ZELGRD'	->	'ZELENOGRAD'
# '8 LENINA STRZATO ZVEZDNYY614575    RUSRUS'	'ZATO ZVEZDNYY'	->	'ZVEZDNYJ'
# '2-6 LISTVENNAYA STRPLODORODNYY350029    RUSRUS'	'PLODORODNYY'	->	''
# 'NOVO_GREBNEVONOVO GREBNEVO141196    RUSRUS'	'NOVO GREBNEVO'	->	'FRJAZINO'
# 'STR. SEREBRYANNOE OZERO 1KAINSKAYA ZAI630117    RUSRUS'	'KAINSKAYA ZAI'	->	'NOVOSIBIRSK'
# 'SAMARA-OTRADNYY,SAMARA-BOGATSAMARSKAYA SK446410    RUSRUS'	'SAMARSKAYA SK'	->	'KINELSKIJ'
# '. ZAOKSKIY R-NSTRAKHOVSKOE301011    RUSRUS'	'STRAKHOVSKOE'	->	'STRAKHOVO'
# '1A POBEDY STRLAZAREVSKOE354200    RUSRUS'	'LAZAREVSKOE'	->	'SOCHI'
# '67.2 - STRGORKI SUKHARE141865    RUSRUS'	'GORKI SUKHARE'	->	'NEKRASOVSKIJ'
# 'TORGOVAYA UL.,4,STR.1ZARECHE R.P. 143085    RUSRUS'	'ZARECHE R'	->	'ZARECHYE'
# '38 LENINGRADSKAYA STVSEVLZ188643    RUSRUS'	'VSEVLZ'	->	'VSEVOLOZHSK'
# 'P. OTRADNOE, VL.1-143442    RUSRUS'	''	->	'OTRADNOE'
# '34 - STR BLD 1CHAYKOVSKOGO141663    RUSRUS'	'CHAYKOVSKOGO'	->	'IM CHAJKOVSKOGO'
# '21 KARDOVSKOGO STRPERESLAVL- ZA152020    RUSRUS'	'PERESLAVL ZA'	->	'PERESLAVL ZALESSKIJ'
# 'NOVAYA STRKOLOMENSKIY D140492    RUSRUS'	'KOLOMENSKIY'	->	'ZARUDNJA'
# '- STRPETROVO,BOROV249018    RUSRUS'	'PETROVO BOROV'	->	'SOVJAKI'
# '316 OTDELSKAYA STRSLAVYANSK-NA-353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# 'SOVETSKAYA 9ZHELDOR143980    RUSRUS'	'ZHELDOR'	->	'ZHELEZNODOROZHNYJ'
# 'NOVOABZAKOVO VILL KIZILSKAYA STR 23RESPUBLIKA B453565    RUSRUS'	'RESPUBLIKA B'	->	'ABZAKOVO'
# '78 KRUPSKOY BYSTRKAMENSK-SHAKH347800    RUSRUS'	'KAMENSK SHAKH'	->	'KAMENSK SHAKHTINSKIJ'
# 'BELOZERSKIY R-NNIKANOVSKAYA161200    RUSRUS'	'NIKANOVSKAYA'	->	'BELOZERSK'
# '3, ZAVODSKAYAZA RODINU353522    RUSRUS'	'ZA RODINU'	->	'PERESYP'
# '1 , STRLEPESHKI141290    RUSRUS'	'LEPESHKI'	->	'KRASNOARMEJSK'
# 'NOVOTITOROVSKAYANOVOTITOROVSK353212    RUSRUS'	'NOVOTITOROVSK'	->	'NOVOVELICHKOVSKAJA'
# '77 SKLADSKOY KOMPLEKS TERNIZHNEE ELKIN301138    RUSRUS'	'NIZHNEE ELKIN'	->	'INSHINSKIJ'
# '1 NOVAYA STRNOVAYA KUPAVN142450    RUSRUS'	'NOVAYA KUPAVN'	->	'STARAJA KUPAVNA'
# 'MKAD SH66 KM141000    RUSRUS'	''	->	'MYTISHCHI'
# '123 KM TORZHOK-OSTASHKOV SHOSTASHKOVSKIY172730    RUSRUS'	'OSTASHKOVSKIY'	->	'OSTASHKOV'
# '- STR98-Y KM A/D M249000    RUSRUS'	'Y A M'	->	'BALABANOVO'
# ',B/N,18,D.KAPITOLOVO188000    47 RUS'	'KAPITOLOVO'	->	''
# '- STRVYEZD IZ G.YA150000    RUSRUS'	'VYEZD IZ YA'	->	'JAROSLAVL'
# '64, SCHORSABELGORODSKIY308501    RUSRUS'	'BELGORODSKIY'	->	'DUBOVOE'
# '1 TSENTRALNAYA STRTOLBUKHINSKIY150000    RUSRUS'	'TOLBUKHINSKIY'	->	'JAROSLAVL'
# '3 B-U STRLUPPOLOVO188653    RUSRUS'	'LUPPOLOVO'	->	'AGALATOVO'
# 'KORENEVSHCHINSKIY SELSOVET RKAPITANSHCHIN399171    RUSRUS'	'KAPITANSHCHIN'	->	'KORENEVSHCHINO'
# '1-6, DZERZHINSKOGO PR.N.NOVGOROD RE606407    RUSRUS'	'N NOVGOROD OBL'	->	'BALAKHNA'
# '6A SEVERNYY SETSP LUCHINSKOE143500    RUSRUS'	'SP LUCHINSKOE'	->	'ISTRA'
# '29, RESPUBLIKANSKAYACHAMZINSKIIY431720    RUSRUS'	'CHAMZINSKIIY'	->	'KOMSOMOLSKIJ'
# '19, K.MARKSAROSTOVSKIIY R346751    RUSRUS'	'ROSTOVSKIIY R'	->	'SAMARSKOE'
# 'SKOROSTNAYA DOROGA M-11, 258TORZHOKSKIY170000    RUSRUS'	'TORZHOKSKIY'	->	'TVER'
# '9 PRIVOKZALNAYA SQTUCHKOVO,RUZS143130    RUSRUS'	'TUCHKOVO RUZS'	->	'TUCHKOVO'
# '2A DOROZHNAYA STRNOVO-LISIKHA664000    RUSRUS'	'NOVO LISIKHA'	->	'IRKUTSK'
# '63, MOSKOVSKAYAODINTSOVO REG143025    RUSRUS'	'ODINTSOVO OBL'	->	'NEMCHINOVKA'
# 'SNT DRUZHNOE-4,3,,SNT DRUZHNOE-188640    47 RUS'	'SNT DRUZHNOE'	->	'VSEVOLOZHSK'
# 'd. Reshetnikovo, d. b/n, lit. AVyborgskiiy r188842    47 RUS'	'VYBORGSKIIY R'	->	'RESHETNIKOVO'
# '36 MOLODEZHNAYA STR BLD AVARDANE-VERIN354395    RUSRUS'	'VARDANE VERIN'	->	'OREL IZUMRUD'
# 'TRELKOVSKOE S/PPODOLSKIY RAY142143       RUS"'	'PODOLSKIY RAY'	->	'BYKOVO'
# 'MIRA UL,. 35BANAPSKAYA ST.353440    RUSRUS'	'ANAPSKAYA ST'	->	'ANAPA'
# '66 B SADOVAYA STROSTDN344000    RUSRUS'	'ROSTDN'	->	'ROSTOV NA DONU'
# 'LENINGRADSKIY TRAKTVYTERGA162900    RUSRUS'	'VYTERGA'	->	'VYTEGRA'
# 'ANAKHINO SETTLOKTYABRSKIY R307202    RUSRUS'	'OKTYABRSKIY R'	->	'MITROFANOVO'
# 'MICHURINA 18RODIONOVO-NES346580    RUSRUS'	'RODIONOVO NES'	->	'RODIONOVO NESVETAJSKAJA'
# '11 LIPOVYY PARK STRSOSENSKOE, PO142770    RUSRUS'	'SOSENSKOE PO'	->	''
# '2 NOVAYA STRPRIVETNAYA644903    RUSRUS'	'PRIVETNAYA'	->	'VKHODNOJ'
# '5, PETROVSKOEMALYE VYAZYOM143050    RUSRUS'	'MALYE VYAZYOM'	->	'BOLSHIE VJAZEMY'
# '2 PETROVSKOE SHMALYE VYAZEMY143050    RUSRUS'	'MALYE VYAZEMY'	->	'BOLSHIE VJAZEMY'
# '12, MURMANSKOE SHVSEVOLZHSKIY188689    RUSRUS'	'VSEVOLZHSKIY'	->	'JANINO'
# '14 A PERVOMAYSKAYA STRERMOLAEVSKIY662525    RUSRUS'	'ERMOLAEVSKIY'	->	'ERMOLAEVO'
# '16 KM.,LIT.A,MURMANSKOE SH.VSEVOLZHSKIY188800    RUSRUS'	'VSEVOLZHSKIY'	->	'VYBORG'
# '1 YABLONEVAYA STRRAZVILKOVSKOE142700    RUSRUS'	'RAZVILKOVSKOE'	->	'VIDNOE'
# 'GORKOGO 21TUUGOLESS140741    RUSRUS'	'TUUGOLESS'	->	'TUGOLESSKIJ BOR'
# '1 PETROVSKIY PASSMALYE VYAZEMY140100    RUSRUS'	'MALYE VYAZEMY'	->	'RAMENSKOE'
# '13 AEROPORT DOMODEDOVO SH,142015    RUSRUS'	''	->	'DOMODEDOVO'
# '16A SOVETSKAYA STRBUKAREVSKOE143500    RUSRUS'	'BUKAREVSKOE'	->	'ISTRA'
# 'DOROGNAYA, 31S.N.USMAN396310    RUSRUS'	'N USMAN'	->	'PRIDOROZHNAJA'
# '22 LENINGRADSKOE SHNOVOE TOKSOVO188664    RUSRUS'	'NOVOE TOKSOVO'	->	'TOKSOVO'
# '17 50 LET VLKSM STRRAMONSKIY, RA396020    RUSRUS'	'RAMONSKIY RA'	->	'RAMON'
# 'PETRYAIHAPETRYAIHA143056    RUSRUS'	'PETRYAIHA'	->	''
# '43 TSENTRALNAYA STRVOROTYNSK,BAB248000    RUSRUS'	'VOROTYNSK BAB'	->	'KALUGA'
# '11,REPINANOVORUYBYSHEV446200    RUSRUS'	'NOVORUYBYSHEV'	->	'NOVOKUJBYSHEVSK'
# '2 TSENTRALNAYA STR BLD ASHMIDTOVO450521    RUSRUS'	'SHMIDTOVO'	->	'RUSSKIJ JURMASH'
# '2 PROMYSHLENNAYA STRPODOLSKIY(D.B142153    RUSRUS'	'PODOLSKIY B'	->	'ROMANTSEVO'
# 'OKTYABRSKIYRP OKTYABRSKI140060       RUS'	'RP OKTYABRSKI'	->	'OKTJABRSKIJ'
# '4,9 ZAVYALOVO-GOLYANY STRZAVYALOVSKIY426000    RUSRUS'	'ZAVYALOVSKIY'	->	'IZHEVSK'
# '(143090), Moskovskaya obl, KrasnoznamenKrasn-nsk143090    46 RUS'	'KRASN NSK'	->	'KRASNOZNAMENSK'
# 'Stepankovo, AKOPYAN L.R.G.O. MYTISHCH141051       RUS'	'O MYTISHCH'	->	'STEPANKOVO'
# '12 TURGENEVSKOE SHADYGEY385140    RUSRUS'	'ADYGEJA'	->	'JABLONOVSKIJ'
# '(143421), Moskovskaya obl, KrasnogorskiNikolo-Uryupi143421    46 RUS'	'NIKOLO URYUPI'	->	'ILYINSKOE USOVO'
# '-TTS MEGA, D FEDYAKOVOKSTOVSKIY RAY607686    RUSRUS'	'KSTOVSKIY RAY'	->	'SELEKTSIONNOJ STANTSII'
# '1, LENINAISTRA REGION143581    RUSRUS'	'ISTRA OBL'	->	'PAVLOVSKAJA SLOBODA'
# '49, SOVETSKAYANOGINSK REGIO142440    RUSRUS'	'NOGINSK OBL'	->	'OBUKHOVO'
# '(143082), Moskovskaya obl, OdintsovskiiBarv-koe143082    46 RUS'	'BARV KOE'	->	'BARVIKHA'
# '13 SVOBODY SQNARFOM143300    RUSRUS'	'NARFOM'	->	'NARO FOMINSK'
# '- STRKURILOVO ZD.M142100    RUSRUS'	'KURILOVO ZD M'	->	'PODOLSK'
# 'DON 443 KM SHAVTODOROGA399260    RUSRUS'	'AVTODOROGA'	->	'KHLEVNOE'
# '. . STRMEDIKO-INSTRU143220    RUSRUS'	'MEDIKO INSTRU'	->	'MEDIKO INSTRUMENTALNOGO ZAVODA'
# '180, B.KHMELNITSKOGO PR.SEVERNIY-PERV308010    RUSRUS'	'SEVERNIY PERV'	->	'BELGOROD'
# '1 SHOSSEYNAYA STSKOTNO188653    RUSRUS'	'SKOTNO'	->	'AGALATOVO'
# '110, TURGENEVAOREL REGION303030    RUSRUS'	'OREL OBL'	->	'MTSENSK'
# '.,50M SEVERO-ZAP. ZAOKSKIY R.301005    RUSRUS'	''	->	'RUSJATINO'
# '16, ZAVODSKAYATULA REGION301032    RUSRUS'	'TULA OBL'	->	'JASNOGORSK'
# 'PR.MIKHAILA NAGIBINA,32EROSTOV/DONU344068       RUS'	'ROSTOV DONU'	->	'ROSTOV NA DONU'
# '2-1 MOLODEZHNAYA STRKRASNGOZNAMEN143090    RUSRUS'	'KRASNGOZNAMEN'	->	'KRASNOZNAMENSK'
# '12,RODIONOVSKAYA125466MOSKVA    RUSRUS'	''	->	'MOSKVA'
# '9 MENDELEEVA STRPERESLAVL152025    RUSRUS'	'PERESLAVL'	->	'PERESLAVL ZALESSKIJ'
# '65-1 DRUZHBY NARODOV STRSLAVYANSK-NA-353560    RUSRUS'	'SLAVYANSK NA'	->	'SLAVJANSK NA KUBANI'
# '14A MARSH ZHUKOVA STNARFOM143300    RUSRUS'	'NARFOM'	->	'NARO FOMINSK'
# 'MO, Odintsovskii r-n, pos Trehgorka, ulTrehgorka143005    46 RUS'	'TREHGORKA'	->	'ODINTSOVO'
# '14B . STRNOVYE DOMA140341    RUSRUS'	'NOVYE DOMA'	->	'NOVYJ'
# '- NOVOSLABODSKAYA STR BLD 19SOBOLIKHA(G.O143985    RUSRUS'	'SOBOLIKHA O'	->	'SAVVINO'
# '40 TSENTRALNAYA STROPKH ERMOLINO141850    RUSRUS'	'OPKH ERMOLINO'	->	'DEDENEVO'
# '2 3-GO INTERNATSIONALA STRBURTULINOVKA397505    RUSRUS'	'BURTULINOVKA'	->	'BUTURLINOVKA'
# '40, KRASNAYATEMRYUK REGIO353525    RUSRUS'	'TEMRYUK OBL'	->	'KURCHANSKAJA'
# 'KUBANSKIY PER., 102ST. KUSHCHEVS352030    RUSRUS'	'ST KUSHCHEVS'	->	'KUSHCHEVSKAJA'
# '11 KOMSOMOLSKAYA STRSTAROKAMYSHIN456618    RUSRUS'	'STAROKAMYSHIN'	->	'KOPEJSK'
# 'PUSHKINSKAYA, 45 AP. MALOE ISAK238310    RUSRUS'	'MALOE ISAK'	->	'VASILKOVO'
# '10 NEVSKAYA STRKINEL ALEKSEE446441    RUSRUS'	'KINEL ALEKSEE'	->	'ALEKSEEVKA'
# 'GERTSENA 12PAVL POSAD142500    RUSRUS'	'PAVL POSAD'	->	'PAVLOVSKIJ POSAD'
# '60 SOVETSKAYA STRGOLITSINO ODI143040    RUSRUS'	'GOLITSINO ODI'	->	'GOLITSYNO'
# '41 POBEDY ST YARSLVYARSLV150003    RUSRUS'	'YARSLV'	->	'JAROSLAVL'
# '00 TSENTRALNAYA STRZERKALNYY188840    RUSRUS'	'ZERKALNYY'	->	'KRASNAJA DOLINA'
# '1 TSENTRALNAYA STR1-YA MOKVA305520    RUSRUS'	'YA MOKVA'	->	'MOKVA JA'
# 'Birzhevoy st, 2BIRZHEVOY199004    RUSRUS'	'BIRZHEVOY'	->	'ST PETERBURG'
# '13 LUNACHARSKOGO STR BLD POMISTRINSKIY,PA143500    RUSRUS'	'ISTRINSKIY PA'	->	'ISTRA'
# '53 3 POCHTOVOE OTDELENIE STRLYUBERTSY GOR140000    RUSRUS'	'LYUBERTSY GOR'	->	'LJUBERTSY'
# ', LENINSKIY R-NGRIGORCHIKOVO142713    RUSRUS'	'GRIGORCHIKOVO'	->	'VOLODARSKOGO'
# '3 LETA STRYUZHNYY GOROD443028    RUSRUS'	'YUZHNYY GOROD'	->	'MEKHZAVOD'
# '3 MIRA STRIMENI MOROZOV188800    RUSRUS'	'IMENI MOROZOV'	->	'VYBORG'
# '107, KOMSOMOLSKAYASEVERSKIIY RE353235    RUSRUS'	'SEVERSKIIY OBL'	->	'AFIPSKIJ'
# '15 ZHELEZNODOROZHNAYA STRDEDOVSK,ISTRI141000    RUSRUS'	'DEDOVSK ISTRI'	->	'MYTISHCHI'
# 'NETST. SOLOGUBOV188640    RUSRUS'	'ST SOLOGUBOV'	->	'VSEVOLOZHSK'
# '139, TELMANADINSKOIY REGI353200    RUSRUS'	'DINSKOIY OBL'	->	'DINSKAJA'
# '2A, KOMSOMOLSKAYAKICHMENGSKIY161400    RUSRUS'	'KICHMENGSKIY'	->	'KICHMENGSKIJ GORODOK'
# '2A, KOMSOMOLSKAYAKICHMENSKIY G161400    RUSRUS'	'KICHMENSKIY'	->	'KICHMENGSKIJ GORODOK'
# '12 SADOVAYA STROSORGINO450000    RUSRUS'	'OSORGINO'	->	'UFA'
# '101 SOVETSKAYA STRCHELOKHOVO140300    RUSRUS'	'CHELOKHOVO'	->	'EGORYEVSK'
# 'FLOTSKAYA STR BLD 1 STR.1 KOPODOLNIKHA  S141052    RUSRUS'	'PODOLNIKHA'	->	'MARFINO'
# '(141850), Moskovskaya obl, DmitrovskiiSHukolovo141850    46 RUS'	'SHUKOLOVO'	->	'DEDENEVO'
# '119 SOVETSKAYA STRNOVOUSMANSKIY396331    RUSRUS'	'NOVOUSMANSKIY'	->	'VOLJA'
# '1,SHKOLNIY PER.DALNEE KONSTA606310    RUSRUS'	'DALNEE KONSTA'	->	'DALNEE KONSTANTINOVO'
# '1-1 NEVINNOMYSSKAYA STRTEMNORECHENSK355000    RUSRUS'	'TEMNORECHENSK'	->	'STAVROPOL'
# 'PR-T M.NAGIBINA, D. 17BROSTOV/DONU344068       RUS'	'ROSTOV DONU'	->	'ROSTOV NA DONU'
# '6 PERVOMAYSKIY SETLUCHINSKIY143550    RUSRUS'	'LUCHINSKIY'	->	'PERVOMAJSKIJ'
# 'S.Z. S.VLADIMIROVKA TERBEZENCHUKSKIY446233    RUSRUS'	'BEZENCHUKSKIY'	->	'VLADIMIROVKA'
# 'Sadovaya str., 22G TYUMEN, NP 625000    72 RUS'	'TYUMEN NP'	->	'TJUMEN'
# '5 KOMMUNISTICHESKAYA STR BLDKRASNOLESNYY394080    RUSRUS'	'KRASNOLESNYY'	->	'VORONEZH'
# '13 ANDREEVKA STR BLD 1ANDREEVKA,SOL141551    RUSRUS'	'ANDREEVKA SOL'	->	'ANDREEVKA'
# '- 11 KM. SHBAYKALSKIY TR664000    RUSRUS'	'BAYKALSKIY TR'	->	'IRKUTSK'
# 'BAYKALSKIY TRAKT, 12KM TRAKT-664038    RUSRUS'	''	->	'MOLODEZHNYJ'
# 'ZHILINSKAYA STR BLD 1ANDREEVKA,SOL141551    RUSRUS'	'ANDREEVKA SOL'	->	'ANDREEVKA'
# '(140090), Moskovskaya obl, DzerzhinskiiDzer-ii140090    46 RUS'	'DZER II'	->	'DZERZHINSKIJ'
# 'M7 1050NABEREZNIE CH423800    RUSRUS'	'NABEREZNIE CH'	->	'NABEREZHNYE CHELNY'
# '48 KOMSOMOLSKAYA STR BLD ASTAROKAMYSHIN454000    RUSRUS'	'STAROKAMYSHIN'	->	'CHELJABINSK'
# '1 TSENTRALNAYA STRPAVLENSKAYA142700    RUSRUS'	'PAVLENSKAYA'	->	'VIDNOE'
# 'ANADYRSKIY PASSLOSINOOSTROVS141000    RUSRUS'	'LOSINOOSTROVS'	->	'MYTISHCHI'
# '24 KOMMUNISTICHESKAYA STVOLGRD400131    RUSRUS'	'VOLGRD'	->	'VOLGOGRAD'
# '22 LENINGRADSKOE SH BLDNOVOE TOKSOVO188664    RUSRUS'	'NOVOE TOKSOVO'	->	'TOKSOVO'
# 'LENINGRADSKAYA 3YAMIGORA187032    RUSRUS'	'YAMIGORA'	->	'TELMANA'
# '6, KOMMUNISTICHESKAYAATIUREVSKIIY431050    RUSRUS'	'ATIUREVSKIIY'	->	'ATJURYEVO'
# '9, 8 PEREULOKAKSAJ REGION346702    RUSRUS'	'AKSAJ OBL'	->	'OLGINSKAJA'
# '32 OLONSKAYA STRGORKOGO660000    RUSRUS'	'GORKOGO'	->	'KRASNOJARSK'
# '116 TSENTRALNAYA STRZAKHARTSOVO391740    RUSRUS'	'ZAKHARTSOVO'	->	'ZAKHAROVO'
# '101V, LENINAROSTOVSKIIY R347570    RUSRUS'	'ROSTOVSKIIY R'	->	'PESCHANOKOPSKOE'
# 'LENINA 65BST. BRUHOVECK352750    RUSRUS'	'ST BRUHOVECK'	->	'BRJUKHOVETSKAJA'
# '8, VESELAYAROSTOVSKIIY R346751    RUSRUS'	'ROSTOVSKIIY R'	->	'SAMARSKOE'
# '7 SHKOLNAYA STROPYTNAYA STAN249142    RUSRUS'	'OPYTNAYA STAN'	->	'KALUZHSKAJA OPYTNAJA SELSKOKHOZJAJSTVENNAJA STANTSIJA'
# '27 ROSTOVSKAYA STRPERESLAVSL152020    RUSRUS'	'PERESLAVSL'	->	'PERESLAVL ZALESSKIJ'
# 'R-152DYAGILEVO153000    RUSRUS'	'DYAGILEVO'	->	'IVANOVO'
# 'LENINA, 39KH-MANSIYSK628011    RUSRUS'	'KH MANSIYSK'	->	'LENINA'
# 'OBEZDNAYA, 7KH-MANSIYSK628001    RUSRUS'	'KH MANSIYSK'	->	'KHANTY MANSIJSK'
# 'SOKOLINAYA 4S SOLNECHNAYA298025    RUSRUS'	'SOLNECHNAYA'	->	'SOLNECHNAJA DOLINA'
# '31 KIROVSKAYA STRKIROVETS-3187322    RUSRUS'	'KIROVETS'	->	''
# 'LAPSHINKA VILLAGEMOSCOW, P.MOS108811    RUSRUS'	'MOSCOW MOS'	->	'J'
# 'Priozerskoe shosse,124aVartemyagi188653    RUSRUS'	'VARTEMYAGI'	->	'AGALATOVO'
# '1 SOSNOVAYA STRDRANISHNIKI190000    RUSRUS'	'DRANISHNIKI'	->	'ST PETERBURG'
# '1-1 PARKOVAYA STROSECHENKI140163    RUSRUS'	'OSECHENKI'	->	'DUBKI'
# 'SHKOLNAYA UL., 5TUGURGOIY A. 385130    RUSRUS'	'TUGURGOIY A'	->	'ENEM'
# '1A AKADEMICHESKAYA STLSTVNK664520    RUSRUS'	'LSTVNK'	->	'LISTVJANKA'
# '. ZD.BYVSHAYA SHKOLA STRGOLOKHVASTOVO142160    RUSRUS'	'GOLOKHVASTOVO'	->	''
# '13 TSENTRALNAYA STRNIKOLSKIE KHU249191    RUSRUS'	'NIKOLSKIE KHU'	->	'ZHUKOV'
# 'NOVAYA D.34/2YUMATOVO     450557    RUSRUS'	'YUMATOVO'	->	''
# 'OKTYABRSKAYA 1ZHELEZNODORZH143980    RUSRUS'	'ZHELEZNODORZH'	->	'ZHELEZNODOROZHNYJ'
# '2 MELIORATORA STRSARATOV, P DA410000    RUSRUS'	'SARATOV DA'	->	'SARATOV'
# '11 YUBILEYNAYA STRMEDVEOZERY141143    RUSRUS'	'MEDVEOZERY'	->	'MEDVEZHYI OZERA'
# '4 SOLNECHNYY BLVDLOPATINO,LENI142702    RUSRUS'	'LOPATINO LENI'	->	'VIDNOE'
# '68 - STRUSTE,NARO-FOM143332    RUSRUS'	'USTE NARO FOM'	->	'USTYE'
# 'MIKRORAION N8KHIMKINSKIY 141400    RUSRUS'	'KHIMKINSKIY'	->	'KHIMKI'
# '2 - 6 LISTVENNAYA STRPLODORODNYY350038    RUSRUS'	'PLODORODNYY'	->	'KRASNODAR'
# 'nan'	'OSINOVAYA GOR'	->	''

# %%
spellchecker = Tie()
spellchecker_reverse = Tie(reverse=True)

mask_msc_obl = np.logical_or(
    df_pochta["REGION"] == 'MOSKOVSKAJA OBL',
    df_pochta["REGION"] == 'MOSKVA'
)

for item in df_pochta.loc[mask_msc_obl, "CITY"].unique():
    spellchecker.add(item)
    spellchecker_reverse.add(item)
    
for item in df_pochta.loc[mask_msc_obl, "CITY_1"].unique():
    spellchecker.add(item)
    spellchecker_reverse.add(item)

mask_msc_obl = df["city_"] == 'MOSKOVSKAJA OBL'
mask_curr = np.logical_and(mask_msc_obl, mask_russian)

modify_cities_address_by_mask(mask_curr)
# Out:
# 'ja oblast', Solnechnogorskij rajon, d. Elino, str.20/2\MO\141580    46 RUS'	'MOSKOVSKAJA OBL'	->	'LUNEVO'
# 'dol'sk, ul. Klementa Gotval'da, 8\MO\142110    46 RUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# 'sovskij r-n, selskoe pos.Nazare\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'ja oblast', g. Himki, kvartal Mezhdunarodnyj, ul. Pokr\MO\141400    46 RUS'	'MOSKOVSKAJA OBL'	->	'KHIMKI'
# 'AVSKOGO SH\MOSKOVSKAYA O\142718    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IZMAJLOVO'
# 'aja obl., Krasnogorskij r-n, vblizi p. Svetlye Gory\MO\143442    46 RUS'	'MOSKOVSKAJA OBL'	->	'OTRADNOE'
# 'mskij r-n, p. Verbilki, ul. Zab\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'TYSHI NOVOMITYSHINSKY PR 34/2 OTDELENYE\MOSCOW REGION\0904         RUS'	'MOSKOVSKAJA OBL'	->	''
# 'anteevka, ul. Zarechnaya, d. 2\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'IVANTEEVKA'
# 'ja oblast', Odincovskij rajon, poselok Trehgorka, ulic\MO\143005    46 RUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# 'tishhi, Novomytishhinskij pr-t, d. 3/12\MO\141002    46 RUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'vlovskij Posad, ul. Bolshaya Po\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'ekhov ul. Uglovaya, vl. 2/1\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'ro-Fominsk, pl. Svobody, Torgovyj centr *Zarech'e*, po\MO\143300    46 RUS'	'MOSKOVSKAJA OBL'	->	'NARO FOMINSK'
# 'modedovo, mkr-n Zapadnyj, ul. L\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# '"Московская обл., Дмитровский район, дер. Глазово, с/п Габовское, в районе д. Глазово, территория ООО ""Индустриальный парк ""Северное Шереметьево"", складской комплекс №7"'	'MOSKOVSKAJA OBL'	->	'MOSKOVSKAJA OBL'
# 'kij r-n, g. Vysokovsk, ul. Vlad\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'VYSOKOVSK'
# 'lgoprudnyj, prosp. Likhachevski\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'DOLGOPRUDNYJ'
# ', AEROPORT DOMODEDOVO, STR.1\MO, AEROPORT\142000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'kovskij r-n, p. Monino, ul. Aviacionnaja, d. 6, pom. I\MO\141170    46 RUS'	'MOSKOVSKAJA OBL'	->	'MONINO'
# 'aja oblast', Odincovskij rajon, g. Kubinka, Naro-Fomin\MO\143070    46 RUS'	'MOSKOVSKAJA OBL'	->	'KUBINKA'
# 'asnogorsk, ul. Lenina, d.13, pom. VIII\MO\143400    46 RUS'	'MOSKOVSKAJA OBL'	->	'KRASNOGORSK'
# 'rovskoe, ul. Sovetskaya, d. 105\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'KUROVSKOE'
# 'skij r-n, Lagovskij s.o., vbliz\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'ro-Fominsk, ul. Polubojarova\MO\143302    46 RUS'	'MOSKOVSKAJA OBL'	->	'NARO FOMINSK'
# 'utov, Nosovikhinskoe sh., vl. 1\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'otvino, ul. Lenina, d.7\MO\142281    46 RUS'	'MOSKOVSKAJA OBL'	->	'PROTVINO'
# 'ovsk,ul.Nogina,d.4\MO\143530    46 RUS'	'MOSKOVSKAJA OBL'	->	'DEDOVSK'
# 'ukovskij, ul. Gagarina, d. 35\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'ZHUKOVSKIJ'
# 'Himki, ul. Moskovskaja, str. 14A\MO\141400    46 RUS'	'MOSKOVSKAJA OBL'	->	'KHIMKI'
# '\Moscow Region\142100    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# 'covskij rajon, sp. Gorskoe, poselok Gorki 2, d. 11\MO\143033    46 RUS'	'MOSKOVSKAJA OBL'	->	'GORKI'
# 'MKI UL PANFILOVA VL19 STR 1 BC KANTRY PARK\MOSCOW REGION\0470         RUS'	'MOSKOVSKAJA OBL'	->	''
# 'N KM  AZS TAT\MOSKOVSKAYA O\142700    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VIDNOE'
# 'rasnogorsk, Podmoskovnyj bul'var, d.13, pom.*1, komnat\MO\143400    46 RUS'	'MOSKOVSKAJA OBL'	->	'KRASNOGORSK'
# 'rpukhov, Borisovskoe shosse, d.\MO\143907    45 RUS'	'MOSKOVSKAJA OBL'	->	'SERPUKHOV'
# 'ovskij r-n, p.VNIISSOK, ul. Denisa Davydova, d. 7\MO\143080    46 RUS'	'MOSKOVSKAJA OBL'	->	'LESNOJ GORODOK'
# 'tischi, SHarapovskij pr-zd, vl.\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'eloozerskij , ul. Molodezhnaya,\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BELOOZERSKIJ'
# 'ja obl., Krasnogorskij r-n, p. Otradnoe\MO\143442    46 RUS'	'MOSKOVSKAJA OBL'	->	'OTRADNOE'
# 'dincovo, Mozhajskoe shosse, d. 22 , pom. I (1-21)\MO\143005    46 RUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# ', ul. Moskovskaja, d.5, pom. 003, 006\MO\141402    46 RUS'	'MOSKOVSKAJA OBL'	->	'KHIMKI'
# 'hhi ul. Kommunisticheskaja 10.k1.\MO\141011    46 RUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'KM KASHIRSKOGO SH.\MOSCOW OBLAST\142718    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IZMAJLOVO'
# 'OSADSKIJ R-N, D. BEREZNYAKI\MOSKOVSKAYA O\141357    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BEREZNJAKI'
# 'nodorozhnyj, ul. Granichnaja, d.22, k.2\MO\143989    46 RUS'	'MOSKOVSKAJA OBL'	->	'ZHELEZNODOROZHNYJ'
# 'hhinskij r-on, Altuf'evskoe sh., 1-j km, vl. 3, str. 1\MO\141031    46 RUS'	'MOSKOVSKAJA OBL'	->	'BORODINO'
# 'modedovo, mkr.Zapadnyj, ul. Dru\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'D.FENINO\MOSKOVSKAYA O\140145    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RECHITSY'
# 'R-N, VBLIZI D. ZHIROSHKINO\MOSKOVSKAYA O\140170    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BRONNITSY'
# 'rolev, ul. Gorkogo, d. 33A\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'KOROLEV'
# 'dolsk, ul. YUbilejnaya, d. 32A\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# 'Novoivanovskoe, ul. Ambulatornaja, d. 49a, 50\MO\143025    46 RUS'	'MOSKOVSKAJA OBL'	->	'NOVOIVANOVSKOE'
# 'ja obl., g. Zhukovskij, ul. Lomonosova, d. 10\MO\140185    46 RUS'	'MOSKOVSKAJA OBL'	->	'ZHUKOVSKIJ'
# 'helkovo, Gagarina ul., d. 3\MO\141103    46 RUS'	'MOSKOVSKAJA OBL'	->	'SHCHELKOVO'
# 'lektrostal, ul. Tevosjana, d. 25\MO\144012    46 RUS'	'MOSKOVSKAJA OBL'	->	'ELEKTROSTAL'
# 'kiy rayon, 11 km RublYovo-Uspenskogo shosse, p. Usovo-\MO\143084    46 RUS'	'MOSKOVSKAJA OBL'	->	'USOVO TUPIK'
# 'modedovo, mkr. Zapadnyj, ul. 25\MO\143907    45 RUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'ja obl., gorodskoj okrug g. Krasnoznamenska, g. Krasno\MO\143090    46 RUS'	'MOSKOVSKAJA OBL'	->	'KRASNOZNAMENSK'
# 'shkino, ul. Griboedova, d. 7\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'PUSHKINO'
# 'ovskij rajon, p.VNIISSOK, ul. Mihaila Kutuzova, d.5a\MO\143080    46 RUS'	'MOSKOVSKAJA OBL'	->	'LESNOJ GORODOK'
# 'rsk,ul.Lenina,d.13,pom.VIII\MO\143404    46 RUS'	'MOSKOVSKAJA OBL'	->	'KRASNOGORSK'
# 'OSKVA-KRYM\MOSKOVSKAYA O\142152    RUSRUS'	'MOSKOVSKAJA OBL'	->	'FEDJUKOVO'
# 'okurovo,79 km Moskva-Don\MO\142840    46 RUS'	'MOSKOVSKAJA OBL'	->	'MIKHNEVO'
# 'modedovo, mkr.TSentralnyj, Kash\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'skresensk, pl.Lenina, 5\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'VOSKRESENSK'
# 'Ramenskoe, Doninskoe shosse d.16\MO\140104    46 RUS'	'MOSKOVSKAJA OBL'	->	'RAMENSKOE'
# 'sovskij rajon, der. Malye Vyaze\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'skij r-n,d.Sharapovo,vl.55\MO\142380    46 RUS'	'MOSKOVSKAJA OBL'	->	'LJUBUCHANY'
# 'ul.Poligrafistov,1b\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'ja oblast', Odincovskij rajon, g. Golicyno, pr-kt Kera\MO\143044    46 RUS'	'MOSKOVSKAJA OBL'	->	'GOLITSYNO'
# 'Fominskij r-n, g.p. Aprelevka, g.  Aprelevka, ul. Sent\MO\143360    46 RUS'	'MOSKOVSKAJA OBL'	->	'APRELEVKA'
# '.d.7\Moskovskaya o\115114    77 RUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'E SHOSSE, 5KM\MOSKOVSKAYA O\141211    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PUSHKINO'
# 'SKOE, KORENKI\MOSKOVSKAYA O\143570    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOVOPETROVSKOE'
# ',ul.Chehova,d.1, k.2,pom.003,004\MO\141207    46 RUS'	'MOSKOVSKAJA OBL'	->	'PUSHKINO'
# 'nogorskij r-n, 26 km a/d ''Balt\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'menskoe, ul. Mikhalevicha, Prom\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'KAMENSKOE'
# 'ul. Chistjakovoj d.3\MO\143005    46 RUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# 'mki, ul. Leningradskaja, vl. 39, str. 6\MO\141400    46 RUS'	'MOSKOVSKAJA OBL'	->	'KHIMKI'
# 'ukovskij, ul. Naberezhnaya TSio\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'ZHUKOVSKIJ'
# 'inskij r-n, s.p.\MO\143316    46 RUS'	'MOSKOVSKAJA OBL'	->	'TASHIROVO'
# '-Fominskij r-n,\MO\143330    46 RUS'	'MOSKOVSKAJA OBL'	->	'VEREJA'
# 'odok, Centralnaya str., 8\Moskowskaya o\143080    50 RUS'	'MOSKOVSKAJA OBL'	->	'LESNOJ GORODOK'
# 'ginsk, ul. Sobornaya, d. 12, li\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'NOGINSK'
# 'lgoprudnyj, ul. ZHukovskogo, d.\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'DOLGOPRUDNYJ'
# 'ovskij r-n, s. Nemchinovka,\MO\143026    46 RUS'	'MOSKOVSKAJA OBL'	->	'NOVOIVANOVSKOE'
# 'nskij r-n, Butovo der., mikrorajon Butovo-Park, 23, ko\MO\142718    46 RUS'	'MOSKOVSKAJA OBL'	->	'IZMAJLOVO'
# 'ilino, ul. Garshina, d. 11, lit\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'TOMILINO'
# 'ekhovo-Zuevskij r-n, g.Drezna,\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'DREZNA'
# 'NINGRADSKOE SHOSSE, VL. 39, STR. 5\MOSCOW REGION\0384         RUS'	'MOSKOVSKAJA OBL'	->	''
# 'hhinskij r-n, pos. Borodino Ostashkovskoe sh. d. 59\MO\141031    46 RUS'	'MOSKOVSKAJA OBL'	->	'BORODINO'
# 'RAJON, PAVLOVO-SLOBODSKOE POS\MOSKOVSKAYA O\143581    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PAVLOVSKAJA SLOBODA'
# 'tishhi, Jaroslavskoe shosse, vl.2V, str.3\MO\141001    46 RUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'ovskij r-n, Bol'shie Vjazemy pgt, Mozhajskoe sh., str.\MO\143050    46 RUS'	'MOSKOVSKAJA OBL'	->	'BOLSHIE VJAZEMY'
# 'skij r-n, pos.Selkhoztekhnika,\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'kovskij r-n, d. Ogudnevo, d. 198\MO\141135    46 RUS'	'MOSKOVSKAJA OBL'	->	'OGUDNEVO'
# 'vo-Zuevskij r-n,\MO\142631    46 RUS'	'MOSKOVSKAJA OBL'	->	'MALAJA DUBNA'
# 'gorsk, Krasnogorskij b-r, d.4\MO\143444    46 RUS'	'MOSKOVSKAJA OBL'	->	'NOVOGORSK'
# 'vo, bul. Ljuby Novoselovoj, d.17\MO\143003    46 RUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# 'skij r-n, s. Bykovo, ul. Teatra\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'ja oblast', g. Serpuhov, b-r 65 let Pobedy, d. 4\MO\142203    46 RUS'	'MOSKOVSKAJA OBL'	->	'SERPUKHOV'
# 'ektrostal, prospekt Lenina, d.\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'ELEKTROSTAL'
# 'ja obl., g. Odincovo Ul. Govorova d. 163\MO\143081    46 RUS'	'MOSKOVSKAJA OBL'	->	'JUDINO'
# '(PRAVAYA STORONA)\MOSKOVSKAYA O\143600    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VOLOKOLAMSK'
# 'lashikha, Zapadnaya kommunalnay\MO\143907    45 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'nsk,ul.Oktjabr'skaja,d.8\MO\109052    46 RUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'aja oblast', Noginskij rajon, p. Sluchajnyj, massiv 1\MO\142451    46 RUS'	'MOSKOVSKAJA OBL'	->	'BISEROVO'
# ', AEROPORT DOMODEDOVO, STR.9\MO, AEROPORT\142000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'ja obl., Krasnogorskij r-n, r.p. Nahabino, ul. Chkalov\MO\143432    46 RUS'	'MOSKOVSKAJA OBL'	->	'NAKHABINO'
# 'OVO, AD DON 129 KM\MOSKOVSKAYA O\142917    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BARABANOVO'
# 'utov, 3-j km. MKAD\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'skovo, ul. Karla Marksa, d. 109\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'KRASKOVO'
# 'ja oblast', Odincovskij rajon, s. Zhavoronki, ul. 1-ja\MO\143020    46 RUS'	'MOSKOVSKAJA OBL'	->	'ZHAVORONKI'
# '-KASHRSKOE SH\MOSKOVSKAYA O\142000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# ', S. YAM\MOSKOVSKAYA O\142030    RUSRUS'	'MOSKOVSKAJA OBL'	->	'JAM'
# 'inskij,Dzerzhinskoe sh,3\MO\140090    46 RUS'	'MOSKOVSKAJA OBL'	->	'DZERZHINSKIJ'
# '3\MOSKOVSKAYA O\140126    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOFYINO'
# 'intsovskij r-n, p.Gorki-10, d.\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'RAYON\MOSKOVSKAYA O\107078    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'ro-Fominsk, pl.Svobody\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'NARO FOMINSK'
# 'ovo g., 9-j mikrorajon, ul. Belorusskaja, 3\MO\143006    46 RUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# 'ja obl., g. Frjazino, pr-t Mira, d. 18\MO\141195    46 RUS'	'MOSKOVSKAJA OBL'	->	'FRJAZINO'
# 'echnogorskij rajon, s.p. Lunevskoe, v rajone d. Cherna\MO\141580    46 RUS'	'MOSKOVSKAJA OBL'	->	'LUNEVO'
# 'heleznodorozhnyj,\MO\143985    46 RUS'	'MOSKOVSKAJA OBL'	->	'ZHELEZNODOROZHNYJ'
# 'MOSKVA-CHELYABINSK, 89KM\MOSKOVSKAYA O\140209    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VOSKRESENSK'
# 'tischi, ul. YUbilejnaya, d. 3,\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'r-n, 50 km+400 m avtomobil'noj dorogi M-7 'VOLGA', d.\MO\142410    46 RUS'	'MOSKOVSKAJA OBL'	->	'NOGINSK'
# 'sovskij r-n, Novoivanovskoe s.o\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'alnaia St.\Moscow Region\142100    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# 'ja oblast', Odincovskij rajon, r.p. Zarech'e, ul. Kash\MO\143085    46 RUS'	'MOSKOVSKAJA OBL'	->	'ZARECHYE'
# 'Fominskij r-n, g.p. Seljatino,  r.p. Seljatino, ul. Sp\MO\143345    46 RUS'	'MOSKOVSKAJA OBL'	->	'SELJATINO'
# 'ja obl., g. Krasnogorsk, ul. Shkol'naja, d. 9\MO\143402    46 RUS'	'MOSKOVSKAJA OBL'	->	'KRASNOGORSK'
# 'lnechnogorsk, ul. Krasnaya, d.\MO\143907    45 RUS'	'MOSKOVSKAJA OBL'	->	'SOLNECHNOGORSK'
# 'alashiha, ul. Sovetskaja, d. 33\MO\143900    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'inskij r-n, g. Staraja Kupavna, ul. Kirova, d. 19\MO\142450    46 RUS'	'MOSKOVSKAJA OBL'	->	'STARAJA KUPAVNA'
# 'ja oblast', Odincovskij rajon, g. Kubinka, Naro-Fomins\MO\143070    46 RUS'	'MOSKOVSKAJA OBL'	->	'KUBINKA'
# 'ogorskij rajon, p/o Il'inskoe-Usovo, a/d "Baltija", 26\MO\143421    46 RUS'	'MOSKOVSKAJA OBL'	->	'ILYINSKOE USOVO'
# 'milino, Egorevskoe sh., str. 2\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'TOMILINO'
# 'alashiha, mkr-n COVB, d. 20, pom. Iib\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'ARKH-SKOE 25 KM AM BALTIYA\MOS. OBL.\143420    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ARKHANGELSKOE'
# 'ektrougli, ul. SHkolnaya, d. 5\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'ELEKTROUGLI'
# 'ja obl.,  Solnechnogorskij r-n, s.p. Lunevskoe, d. Che\MO\141580    46 RUS'	'MOSKOVSKAJA OBL'	->	'LUNEVO'
# 'nskij r-n, d. Elnja, AZS\MO\142439    46 RUS'	'MOSKOVSKAJA OBL'	->	'MAMONTOVO'
# 'skij r-n, g. Vidnoe, pr-t Lenin\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'VIDNOE'
# 'VORIZHSKOGO SH.\MOSCOW OBLAST\143500    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ISTRA'
# 'ja oblast', g. Odincovo, Krasnogorskoe shosse, d. 15\MO\143007    46 RUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# 'shhinskij r-n, s.p. Fedoskinskoe, Dmitrovskoe shosse,\MO\141052    46 RUS'	'MOSKOVSKAJA OBL'	->	'MARFINO'
# 'rgiev Posad, ul. Voznesenskaya,\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'rostal', pr-kt Juzhnyj, d.10\MO\144004    46 RUS'	'MOSKOVSKAJA OBL'	->	'ELEKTROSTAL'
# 'KIY R - N., POVAROVO DP., UL. LE\MOSKOVSKAYA O\141540    RUSRUS'	'MOSKOVSKAJA OBL'	->	'POVAROVO'
# 'ja oblast', Leninskij rajon, d.Blizhnie Prudishhi, MKA\MO\142715    46 RUS'	'MOSKOVSKAJA OBL'	->	'SOVKHOZ IM LENINA'
# 'hnogorsk, ul. Krasnaja, d.22\MO\141505    46 RUS'	'MOSKOVSKAJA OBL'	->	'SOLNECHNOGORSK'
# 'A, 104 KM, KLINSKIJ R-N\MOSKOVSKAYA O\141602    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KLIN'
# 'lgoprudnyj, ul. Likhachevskoe s\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'DOLGOPRUDNYJ'
# 'sovskij r-n, p. Lesnoj Gorodok,\MO\143907    45 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# ',ul.Sovetskaja,d.41/5,p.6\MO\142116    46 RUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# 'KM NOVORYAZANSKOGO SH.\MOSCOW OBLAST\140126    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOFYINO'
# 'itrov, ul. Professionalnaya, d.\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'DMITROV'
# 'ja obl., Krasnogorskij rajon, g. Krasnogorsk, ul. Svet\MO\143409    46 RUS'	'MOSKOVSKAJA OBL'	->	'KRASNOGORSK'
# 'rougli, ul. Shkol'naja d.38, lit.B\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'ELEKTROUGLI'
# 'KM YAROSLAVSKOGO SH.\MOSCOW OBLAST\141315    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SERGIEV POSAD'
# 'A\MOSCOW OBLAST\141551    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ANDREEVKA'
# 'reja, ploshhad' Sovetskaja, stroenie 20\MO\143330    46 RUS'	'MOSKOVSKAJA OBL'	->	'VEREJA'
# 'in, Leningradskoe sh., d. 8\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'IMKI UL PANFILOVA 19 STR 1 BC KANTRI PARK O\MOSCOW REGION\0660         RUS'	'MOSKOVSKAJA OBL'	->	''
# 'insk,ul.Marshala\MO\143300    46 RUS'	'MOSKOVSKAJA OBL'	->	'NARO FOMINSK'
# 'ja obl., g. Podol'sk, pr-t Junyh Lenincev, d. 34/2, po\MO\142111    46 RUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# 'ovskij rajon, rabochij poselok Novoivanovskoe, ulica A\MO\143041    46 RUS'	'MOSKOVSKAJA OBL'	->	'GOLITSYNO'
# 'DOLSK REVOLYCIONNIY PR 64/105 OTDELENYE UNI\MOSCOW REGION\0905         RUS'	'MOSKOVSKAJA OBL'	->	''
# 'R-N, D. STANOVOE\MOSKOVSKAYA O\140127    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DUBOVAJA ROSHCHA'
# 'm. Ilinskoe shosse, str.,\Moskovskaya o\143420    50 RUS'	'MOSKOVSKAJA OBL'	->	'ARKHANGELSKOE'
# 'SKOE SHOSSE, 89 KM\MOSKOVSKAYA O\140000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# 'HINSKIY BOUL., SP OTRADNENSKOE\MOSCOW REGION\143441    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PUTILKOVO'
# 'Zarech'e, ul. Zarechnaja, d.2\MO\143085    46 RUS'	'MOSKOVSKAJA OBL'	->	'ZARECHYE'
# 'azanovskoe Hw.\Moscow Region\142100    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# 'OE, D. BYKOVKA\MOSKOVSKAYA O\142143    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BYKOVO'
# 'ogorskij r-on, pos. Putilkovo,\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'kovskij r-n, d. Medvezh'i ozera, d. 2\MO\141143    46 RUS'	'MOSKOVSKAJA OBL'	->	'MEDVEZHYI OZERA'
# 'skij r-n,d.Novye Psarki\MO\142434    46 RUS'	'MOSKOVSKAJA OBL'	->	'RADIOTSENTR'
# 'ja obl., Naro-Fominskij rajon, g. Naro-Fominsk, ul. Ko\MO\143300    46 RUS'	'MOSKOVSKAJA OBL'	->	'NARO FOMINSK'
# 'kovskij rajon,sel'skoe poselenie Aniskinskoe, pos. Bio\MO\141142    46 RUS'	'MOSKOVSKAJA OBL'	->	'BIOKOMBINATA'
# 'osad, ul. Rybnaja 1-ja, d. 18/2\MO\141300    46 RUS'	'MOSKOVSKAJA OBL'	->	'SERGIEV POSAD'
# 'Leningradskoe sh., 23 km\MO\141408    46 RUS'	'MOSKOVSKAJA OBL'	->	'PLANERNAJA'
# 't.\Moscow Region\140600    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZARAJSK'
# '/2, Dzerzhinskiy St.\Moscow Region\141200    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PUSHKINO'
# 'osad,pr-t Kr Armii,143\MO\141301    46 RUS'	'MOSKOVSKAJA OBL'	->	'SERGIEV POSAD'
# 'helkovo-4, ul. Beljaeva, d. 23\MO\141104    46 RUS'	'MOSKOVSKAJA OBL'	->	'SHCHELKOVO'
# 'ja obl., g. Shhjolkovo, mkr-n *Bogorodskij*, d. 10, ko\MO\141107    46 RUS'	'MOSKOVSKAJA OBL'	->	'SHCHELKOVO'
# 'OE KM 16\MOSKOVSKAYA O\143300    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NARO FOMINSK'
# 'skij rajon, pos.Razvilka, d. 46\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'helkovo, ul. Talsinskaja, d.23, pom.10\MO\141100    46 RUS'	'MOSKOVSKAJA OBL'	->	'SHCHELKOVO'
# 'J R-N, V RAJONE D. ERMOLINO\MOSKOVSKAYA O\141863    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ERMOLINO'
# 'OSKVA-DON D.TARYCHEVO\MOSCOW OBLAST\142703    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VIDNOE'
# 'olkovskij r-n, Litvinovo pos., 13\MO\141138    46 RUS'	'MOSKOVSKAJA OBL'	->	'LITVINOVO'
# 'iha, mkr-n 1 Maya, d.4\MO\143912    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# ', sh. Lipkinskoe, 2-j km,territorija TPZ *Altuf'evo*,\MO\141000    46 RUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'covskij r-n, r.p.\MO\143050    46 RUS'	'MOSKOVSKAJA OBL'	->	'BOLSHIE VJAZEMY'
# 'helkovo, ul. Pushkina, d. 22\MO\141102    46 RUS'	'MOSKOVSKAJA OBL'	->	'SHCHELKOVO'
# 'aja oblast', Odincovskij rajon, s. Nikol'skoe,  Nikol'\MO\143079    46 RUS'	'MOSKOVSKAJA OBL'	->	'STARYJ GORODOK'
# 'hikhinskij r-on, Zapadnaya komm\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'chnogorskij rajon, g. Solnechnogorsk, ul. Krasnaja, d.\MO\141505    46 RUS'	'MOSKOVSKAJA OBL'	->	'SOLNECHNOGORSK'
# 'inskij r-on, s/p Stepanovskoe, p. Frjazevo, ul. Zhelez\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'nskij r-n, s/pos. Pavlo-Slobodskoe, d. Novinki, d.115,\MO\143581    46 RUS'	'MOSKOVSKAJA OBL'	->	'PAVLOVSKAJA SLOBODA'
# 'ul. Sovetskaja, d. 5a\MO\143007    46 RUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# 'OSADSKIJ RAJON, MISHUTINSKIJ S\MOSKOVSKAYA O\142505    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PAVLOVSKIJ POSAD'
# 'nskij r-n, d. Pokrovskoe\MO\143582    46 RUS'	'MOSKOVSKAJA OBL'	->	'POKROVSKOE'
# 'menskoe, ul. Krasnoarmejskaya,\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'KAMENSKOE'
# 'KIJ RAJON, 35-J KM TRASSY MOSK\MOSKOVSKAYA O\142034    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MESHCHERINO'
# 'ja oblast', Krasnogorskij r-n, u d. Putilkovo\MO\143441    46 RUS'	'MOSKOVSKAJA OBL'	->	'PUTILKOVO'
# 'ul.Radiocentra 5,9A,p.15\MO\141103    46 RUS'	'MOSKOVSKAJA OBL'	->	'SHCHELKOVO'
# 'KRASNOGORSKIJ R-ON, 26 KM AVTODOROGI BALTIJ\MOSCOW REGION\0128         RUS'	'MOSKOVSKAJA OBL'	->	''
# 'olkovskij r-n, Monino pgt, ul. Juzhnaja, 9\MO\141171    46 RUS'	'MOSKOVSKAJA OBL'	->	'MONINO'
# 'VOSELKI\MOSCOW OBLAST\142153    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ROMANTSEVO'
# 'aja oblast', g. Odincovo, ul. Molodezhnaja, d. 15\MO\143003    46 RUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# 'W OBLAST\115597    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'lgoprudnyj, Likhachevskoe sh.,\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'DOLGOPRUDNYJ'
# 'skij r-n, p. Vatutinki - 1\MO\142793    46 RUS'	'MOSKOVSKAJA OBL'	->	''
# 'ja obl., Istrinskij r-n, Buzharovskij s.o., d. Buzharo\MO\143514    46 RUS'	'MOSKOVSKAJA OBL'	->	'BUZHAROVO'
# 'omsomolskaya St.\Moscow Region\142100    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# 'M-7 VOLGA-1\MOSKOVSKAYA O\142450    RUSRUS'	'MOSKOVSKAJA OBL'	->	'STARAJA KUPAVNA'
# 'asnopoljanskij pr.,d.2\MO\141733    46 RUS'	'MOSKOVSKAJA OBL'	->	'LOBNJA'
# 'mki, mikrorajon *IKEA*, k. 2\MO\119192    46 RUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'KM EGOR'EVSKOGO SH.\MOSCOW OBLAST\140145    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RECHITSY'
# 'ovskoj r-n,d.Vshody,d.100-A\MO\142200    46 RUS'	'MOSKOVSKAJA OBL'	->	'SERPUKHOV'
# 'ovskij r-n, p. Gorki-10, Pansionat "Lesnye dali"\MO\143222    46 RUS'	'MOSKOVSKAJA OBL'	->	'GORETOVO'
# 'JON, KOSMODEM`YANSKIJ S.O., 86\MOSKOVSKAYA O\143160    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOROKHOVO'
# 'skij r-n,Gorshkovo,s.1\MO\143582    46 RUS'	'MOSKOVSKAJA OBL'	->	'POKROVSKOE'
# 'hhinskij r-n, g. Mytishhi, 85-j km MKAD, Blok A\MO\141031    46 RUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'rasnoznamensk, ul. Svjazistov, d. 9/4\MO\143090    46 RUS'	'MOSKOVSKAJA OBL'	->	'KRASNOZNAMENSK'
# ',mkr Bogorodskij,vl.9\MO\141107    46 RUS'	'MOSKOVSKAJA OBL'	->	'SHCHELKOVO'
# 'rovskij r-n, g/p Iksha, pos. OP\MO\143907    45 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'm.Lenina,25km MKAD,vl.4,1\MO\142715    46 RUS'	'MOSKOVSKAJA OBL'	->	'SOVKHOZ IM LENINA'
# '\MOSKOVSKAYA O\141544    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BREKHOVO'
# 'helkovo, ul. Central'naja, d. 17\MO\141108    46 RUS'	'MOSKOVSKAJA OBL'	->	'SHCHELKOVO'
# 'lashikha, Zapadnaya kommunalnay\MO\143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'dol'sk, pr-t Junyh Lenincev, d. 1I\MO\142111    46 RUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# 'skoj okrug Vlasiha, pos. Vlasiha, ul. Marshala Zhukova\MO\143010    46 RUS'	'MOSKOVSKAJA OBL'	->	'VLASIKHA'
# ', VL. 1\MOSKOVSKAYA O\125599    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'otel'niki,\MO\140054    46 RUS'	'MOSKOVSKAJA OBL'	->	'KOVROVYJ KOMBINAT'
# 'ogorskij r-n,a/d Baltija,23km,vl.2,d.1\MO\143421    46 RUS'	'MOSKOVSKAJA OBL'	->	'ILYINSKOE USOVO'
# 'AIRPORT DOMODEDOVOMOSCOW REG.142015    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# '1 LESNOY GORODOK,SHKOLNAYAMOSKOVSKAYA O143080    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LESNOJ GORODOK'
# 'TERMINAL D A-P SHEREMETEVOMOSKOVSKIIY R142015    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'Zhukovskiy, Naberezhnaya, TsiolkovsMOSCOW REGION140180    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZHUKOVSKIJ'
# 'D POKROVMOSKOVSK.OBL.142143    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BYKOVO'
# 'Balashiha, Shosse Entuziastov, 54AMOSCOW REGION143900    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'Noginsk 2, Trudovaya, 11MOSCOW REGION142400    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOGINSK'
# '71KM RYAZANSKOGO SHMOSKOVSK.OBL.140167    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ULJANINO'
# 'SIMFEROPOLSKOE SH. 50 KMMOSCOW OBL.142153    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ROMANTSEVO'
# 'VOKZALNAYA STR.MOSCOW REGION140120    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ILYINSKIJ'
# 'ST.PAVSHINOMOSCOW REGION143400    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'Bratev Gorozhankinyh str., 23a, KraMOSCOW REGION143409    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KRASNOGORSK'
# 'LENINA 2, KRASNOGORSKMOSCOWSKAYA O143404    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KRASNOGORSK'
# '5,SUKROMKAMOSCOW REGION141018    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'KASHIRSKOE SH, 23 KMMOSKOVSK.OBL.142793    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# '3,1,LENINAMOSCOW REGION140060    RUSRUS'	'MOSKOVSKAJA OBL'	->	'OKTJABRSKIJ'
# '84-IY KM. MKADMOSCOW REGION141031    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BORODINO'
# '36,YUBILEIYNYIIY AVE.MOSCOW REGION141411    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LEVOBEREZHNYJ'
# 'R-N ODINTSOVSKIY, USPENSKOE S., D. 62 AMOSKOVSKAYA 143030    RUSRUS'	'MOSKOVSKAJA OBL'	->	'USPENSKOE'
# 'Elektrostal, str. Tevosyana, 19MOSCOW REGION144012    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ELEKTROSTAL'
# 'SIMFEROPOLSKOE SH. 25 KMMOSCOW OBL.142790    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# '4A-D ""URAL"" 124 KMMOSCOW OBL.140542    RUSRUS"'	'MOSKOVSKAJA OBL'	->	'FRUKTOVAJA'
# 'UL VOKZALNAYAMOSKOVSKAYA O141221    RUSRUS'	'MOSKOVSKAJA OBL'	->	'CHERKIZOVO'
# 'P.RZHAVKI, MKR. NR.2,SOLNECHNOGORSKMOSCOW REGION141552    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RZHAVKI'
# 'AIRPORT DOMODEDOVOMOSKOVSKAYA 142015    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'MOSKOVSKIY LAPSHINKA VILL BLD 30/16MOSCOW REG.142784       RUS'	'MOSKOVSKAJA OBL'	->	''
# 'ESIPOVOMOSCOW OBL.141595    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LOZHKI'
# 'SHEREMETEVOMOSKOW REGION141400    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KHIMKI'
# '25,GOGOLYAMOSCOW REGION140070    RUSRUS'	'MOSKOVSKAJA OBL'	->	'TOMILINO'
# 'Klin, str. Karla Marksa, 2AMOSCOW REGION141607    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KLIN'
# '2,1-YA SOVETSKAYAMOSCOW REGION143020    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZHAVORONKI'
# '83, MOSKOVSKAYAMOSCOW REGION142306    RUSRUS'	'MOSKOVSKAJA OBL'	->	'CHEKHOV'
# 'STR.2, POM.13, ANICHKOVO MIK.MOSCOW REGION141142    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BIOKOMBINATA'
# 'p.Sverdlovskiy, str. Zavodskaya, 1AMOSCOW REGION141140    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SVERDLOVSKIJ'
# 'SH LENINGRADSKOE 32KMMOSKOVSK.OBL.141591    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOVAJA'
# 'SH. LENINGRADSKOE 49KMMOSKOVSK.OBL.141591    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOVAJA'
# 'D BREKHOVOMOSKOVSK.OBL.141544    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BREKHOVO'
# 'Stupino, str. Frunze, 4MOSCOW REGION142803    RUSRUS'	'MOSKOVSKAJA OBL'	->	'STUPINO'
# '2A,PIONERSKAYAMOSCOW REGION141070    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOROLEV'
# 'BEREZNYAKIMOSCOW OBL.141327    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MUKHANOVO'
# '14, DEREVNYA GOLYGINOMOSCOW REGION141362    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZARECHNYJ'
# 'LENINGRADSKOE HW 16 A BLD 4MOSCOW REG.125171    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'Pavlovskiy Posad, str. Bolshaya, PoMOSCOW REGION142502    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PAVLOVSKIJ POSAD'
# 'SH KIEVSKOE 19 KMMOSKOVSKAYA O142793    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# '21KM VARSHAVSKOGO SHMOSKOVSK.OBL.143000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# '30A GORKIMOSKOVSKAYA O143000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# 'VOROVSKOGO STR.MOSCOW REGION140105    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RAMENSKOE'
# '17 GORKI-2MOSKOVSKAYA O143000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# '(143395), Moskovskaya obl, Naro-FominskMO143395    46 RUS'	'MOSKOVSKAJA OBL'	->	'PETROVSKOE'
# 'Korolev, str. Frunze, 4MOSCOW REGION141068    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOROLEV'
# 'Chehov, str. Chehova,2MOSCOW REGION142306    RUSRUS'	'MOSKOVSKAJA OBL'	->	'CHEKHOV'
# 'Balashihinskoe shosse, 16, BalashihMOSCOW REGION143905    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'MOSKOVSKIY LAPSHINKA VILL BLD 30/16MOSCOW REG.142784    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'KRASNOGORSKIY REG., BALTIA AVTODOROGA, 23 KM. 2MOSKOVSKAYA 143241    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'SH NOVORIZHSKOE 75 KM HUTORKIMOSKOVSKAYA O143560    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOVOPETROVSKOE'
# '31-A, PROSPEKT LENINAMOSKOVSKIIY R143900    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'Domodedovo, prospekt Akademika, TupMOSCOW REGION142000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'Voinov-Internatsionalistov str., 3,MOSCOW REGION140013    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# '6, TUPOLEVAMOSCOW REGION140180    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZHUKOVSKIJ'
# 'G.APRELEVKA, TSVETOCHNAYAMoskovskaya o143362    50 RUS'	'MOSKOVSKAJA OBL'	->	'APRELEVKA'
# 'Egorevsk, prospekt Lenina, 6aMOSCOW REGION140304    RUSRUS'	'MOSKOVSKAJA OBL'	->	'EGORYEVSK'
# 'SIMFEROPOLSKOE SH. 25 KMMOSCOW OBL.142718    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IZMAJLOVO'
# '1, LESNAYA, PAVLOVSKAYA SLOBODAMOSKOVSKAYA R143581    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PAVLOVSKAJA SLOBODA'
# 'Voskresensk, str. Kagana, 17MOSCOW REGION140209    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VOSKRESENSK'
# 'G. KRASNOZNAMENSK, UL. POMoskovskaya o143090    50 RUS'	'MOSKOVSKAJA OBL'	->	'KRASNOZNAMENSK'
# 'OZERY, LENINA STR., 2MOSCOW REGION140560    RUSRUS'	'MOSKOVSKAJA OBL'	->	'OZERY'
# '1,MVL,DOMODEDOVO A.P.MOSCOW REGION142000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'BO BEREZKIMOSCOW REGION141534    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LYTKINO'
# 'Podolsk, Gotvalda, 6vMOSCOW REGION142114    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# '28A,KARLA MARKSAMOSCOW REGION140050    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KRASKOVO'
# 'Shatura, prospect Borzova, 1MOSCOW REGION140700    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SHATURA'
# 'ANOSINO D., ISTRINSKIY REGIONMOSKOVSKAYA R143581    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PAVLOVSKAJA SLOBODA'
# 'AIRPORT DOMODEDOVOMOSCOW REG.142015       RUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'Domodedovo, str. Sovetskaya, 17MOSCOW REGION142005    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# '46A LENINSKOGO KOMSOMOLA PRMOSKOVSKAYA O142700    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VIDNOE'
# '2,SKOLNAYA,LESNOY GORODOKMOSKOVSKAYA R143080    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LESNOJ GORODOK'
# 'NOVOSELKYMOSCOW OBL.142941    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOVOSELKI'
# 'KIEVSKOE SH. 37KMMOSKOVSK.OBL.143397    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'MKR-N IKEA,KORP.2MOSKOVSKAYA O141400    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KHIMKI'
# 'Sergiev Posad 3, str. Druzhby 14AMOSCOW REGION141315    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SERGIEV POSAD'
# 'POS SOVKHOZ IM LENINA KASHIRSKOE HW 23 KMMOSCOW REG.142715    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOVKHOZ IM LENINA'
# 'POS SOVKHOZ IM LENINA KASHIRSKOE HW 23 KMMOSCOW REG.142715       RUS'	'MOSKOVSKAJA OBL'	->	'SOVKHOZ IM LENINA'
# '26 KM MKADMOSCOW REG.142712       RUS'	'MOSKOVSKAJA OBL'	->	'GORKI LENINSKIE'
# '21 KM A-D MOSKVA-DONMO142703    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VIDNOE'
# 'KALUZHSKOE HW 21 KMMOSCOW REG.142704    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'Elektrostal, str. Karla Marksa, 30MOSCOW REGION144009    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ELEKTROSTAL'
# 'P. NAKHABINO 1MOSKOVSKIIY R101000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'Olimpiyskiy pr-t, vl.13, bld.1, MytMOSCOW REGION141006    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# '275 GORKI-8MOSKOVSKAYA O143000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# 'str.Uchinskaya, 1, PushkinoMoscow region141207    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PUSHKINO'
# 'KOLONCOVA STR., 1MOSCOW REGION141009    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'T. MYTICSHIMOSCOW REGION141009    RUSRUS"'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'MO, g. Mytischi, SHarapovskij pr-zd, vl.MO143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'Sergiev Posad, str. Tsentralnaya 1MOSCOW REGION141305    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SERGIEV POSAD'
# '2,GLAVNAYAMOSCOW REGION143980    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZHELEZNODOROZHNYJ'
# 'Zelenograd, korp. 234AMOSCOW REGION124498    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZELENOGRAD'
# 'Elektrostal, Noginskoe shosse, 2MOSCOW REGION144000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ELEKTROSTAL'
# 'Noginsk, str. 3-go Internatsionala,MOSCOW REGION142400    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOGINSK'
# 'Dubna, str. Makarenko, 37MOSCOW REGION141983    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DUBNA'
# 'D. SUKHANONO PARKOVAYA STR. 1MOSKOVSKAYA 142702    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VIDNOE'
# '11-2, SOVETSKAYAMOSKOVSKIIY R144000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ELEKTROSTAL'
# 'LYUBERTSY, INITSIATIVNAYA STR., 76MOSCOW REGION140008    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# '(143400), Moskovskaya obl, KrasnogorskiMO143421    46 RUS'	'MOSKOVSKAJA OBL'	->	''
# 'ISTRA, 27-1-26MOSCOW REG143423    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ISTRA'
# 'LENINSKIY DISTRICT, VILL DALNIE PRUDISHCHY, BLDMOSKOVSKAYA 142714    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOLOKOVO'
# 'Sergiev Posad, str. Kooperativnaya3MOSCOW REGION141308    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SERGIEV POSAD'
# '47,DUBININOMOSCOW REGION141508    RUSRUS'	'MOSKOVSKAJA OBL'	->	'REKINTSO'
# 'LENINGRADSKOE SH 32 KMMOSKOVSKAYA O141580    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LUNEVO'
# 'MOSCOVSKAYA OBLAST, GOROD DOLGOPRUDNY, LIKHACHEMOSKOVSKAYA 141707    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOLGOPRUDNYJ'
# '33, TIMONOVOMOSKOVSKIIY R141507    RUSRUS'	'MOSKOVSKAJA OBL'	->	'TIMONOVO'
# 'NOVO-VOLKOVOMOSCOW OBL.143120    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOVOVOLKOVO'
# '85KM MKAD, VL.3, STR.1MOSCOW REGION141000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'VOLODARSKOE SH D REDKINOMOSKOVSKAYA O140123    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VERKHNEE MJACHKOVO'
# 'ROZDESTVENO VL.,60MOSKOVSKAYA O143513    RUSRUS'	'MOSKOVSKAJA OBL'	->	'GIDROUZLA IM KUJBYSHEVA'
# 'G. PUSHKINO, UL. VOKZALNAYA, D. 8MOSCOWSKAYA O105077    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'T. BOLSHEVOMOSCOW REGION141090    RUSRUS"'	'MOSKOVSKAJA OBL'	->	'JUBILEJNYJ'
# 'SHEREMETYEVO TERMINAL FMOSCOWSKAYA O124340    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'str. Oktyabrskoy revolyutsii, 379,MOSCOW REGION140408    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOLOMNA'
# 'MO,Kolomna,ul Oktyabrskoi revolyutsii,dMO140408    46 RUS'	'MOSKOVSKAJA OBL'	->	'KOLOMNA'
# 'mkr. Aviatorov, str. Tretyaka, 8, BMOSCOW REGION143909    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# '17A MIRA PRMOSOBL141006    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'M/DISTR IKEA 2MOSCOW REG.141400    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KHIMKI'
# '30KM MINSKOGO SHMOSKOVSK.OBL.143000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# 'POS.BYKOVO, UL.PRAVOLINEYMoskovskaya o114150    50 RUS'	'MOSKOVSKAJA OBL'	->	''
# 'SOLNECHNOGORSKIY R RJAVKI RP 2MOSKOVSKAYA 141552    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RZHAVKI'
# 'PUSHKINSKY DISTR LESNOY VILL PUSHKINA STR 6 AMOSCOW REG.141231    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LESNOJ'
# '4,1,KOMSOMOLSKAYAMOSCOW REGION141292    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KRASNOARMEJSK'
# '4,KARERMOSCOW REGION142440    RUSRUS'	'MOSKOVSKAJA OBL'	->	'OBUKHOVO'
# 'Troitsk, str. SolnechnayaMOSCOW REGION142191    RUSRUS'	'MOSKOVSKAJA OBL'	->	'TROITSK'
# '23 KM. MKADMOSCOW REGION142700    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VIDNOE'
# 'LENINSKIY DISTR DROZHZHINO VILL NOVOE HW 11MOSKOVSKAYA 142718    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IZMAJLOVO'
# '21-KM VARSHAVSKOGO SHMOSKOVSK.OBL.142793    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'NOVOE SHOSSE,11MOSKOVSKAYA 142718    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IZMAJLOVO'
# 'DONINO VILL TSENTRALNAYA STR 1MOSCOW REG.140124       RUS'	'MOSKOVSKAJA OBL'	->	'DONINO'
# 'NESTEROVOMOSCOW OBL.143150    RUSRUS'	'MOSKOVSKAJA OBL'	->	'STARAJA RUZA'
# 'D. NAZAREVO AZSMO143323    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SVKH ARKHANGELSKIJ'
# 'SOLNECHNOGORSK, MKR.REKINTSO-2, KRAMOSCOW REGION141506    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOLNECHNOGORSK'
# '47KM YAROSLAVSKOGO SHMOSKOVSK.OBL.141273    RUSRUS'	'MOSKOVSKAJA OBL'	->	'TALITSY'
# 'Balashiha, shosse Entuziastov, 9MOSCOW REGION143903    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'Lobnya, str. Mayakovskogo, 10MOSCOW REGION141730    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LOBNJA'
# 'Sergiev Posad , prospekt Krasnoy, AMOSCOW REGION141310    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SERGIEV POSAD'
# 'KRASNOGORSK MEZHDUNARODNAYA STR 18MOSKOVSKAYA O143402       RUS'	'MOSKOVSKAJA OBL'	->	'KRASNOGORSK'
# 'Reutov, str. Pobedy 28MOSCOW REGION143960    RUSRUS'	'MOSKOVSKAJA OBL'	->	'REUTOV'
# 'ARBAT STREET, 29MOSCOW REGION119002    77 RUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# '2-50B,SHKOLNAYAMOSKOW REGION141505    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOLNECHNOGORSK'
# '88A, KARLA MARKSAMOSCOW REGION141601    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KLIN'
# 'VOLOKOLAMSKOE SHOSSE VL 25AMOSKOVSK.OBL.141607    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KLIN'
# 'KIEVSKOE SH 19KMMOSKOVSK.OBL.142701    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VIDNOE'
# '11-B,KOMSOMOLSKIYMOSCOW REGION140000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# 'REUTOV  NOSOVIKHINSKOE HW 61MOSCOW REG.143969    RUSRUS'	'MOSKOVSKAJA OBL'	->	'REUTOV'
# 'Klin, str. Chaykovskogo, 62MOSCOW REGION141613    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KLIN'
# '25B,USHAKOVAMOSCOW REGION141865    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NEKRASOVSKIJ'
# '8A,L.TOLSTOGOMOSCOW REGION141865    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NEKRASOVSKIJ'
# 'd.Drozhzhino,Yuzhnaya,21-2Moskovskaya o142720    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOVODROZHZHINO'
# 'P.CHISMENA, UL. PERVOMAYSMoskovskaya o143650    50 RUS'	'MOSKOVSKAJA OBL'	->	'CHISMENA'
# '12, MEZHDUNARODNAYAMOSCOW REGION143402    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KRASNOGORSK'
# 'T.DOMODEDOVOMOSCOW REGION142040    RUSRUS"'	'MOSKOVSKAJA OBL'	->	'SHUBINO'
# 'NEMCINOVKA VIL. MOSKOVSKAYA STR. 12MOSKOVSKAYA O143026       RUS'	'MOSKOVSKAJA OBL'	->	'NOVOIVANOVSKOE'
# 'GORKI-2 D.7MOSKOVSKAYA O143033    RUSRUS'	'MOSKOVSKAJA OBL'	->	'GORKI'
# 'DOMODEDOVO, BLD.1MOSKOVSKAYA 142015    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'str. Kubinskoe shosse, 6, Naro-FomiMOSCOW REGION143301    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NARO FOMINSK'
# 'DOMODEDOVSKIY R-N, TER-YAMoskovskaya o142015    50 RUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'LENINAMOSCOW REGION141260    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PRAVDINSKIJ'
# '11,SHKOLNAYAMOSCOW REGION142452    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZELENYJ'
# '1,TORGOVAYAMOSCOW REGION143085    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZARECHYE'
# '49, KIROVAMOSCOW REGION142117    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# '40 POBEDY PRMOSOBL142803    RUSRUS'	'MOSKOVSKAJA OBL'	->	'STUPINO'
# 'D. BLIZHNIYE PRUDISHCHI,Moskovskaya o115598    50 RUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# '17,SOVETSKAYAMOSKOVSKAYA R142840    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MIKHNEVO'
# '8A,REKINTSOMOSCOW REGION141508    RUSRUS'	'MOSKOVSKAJA OBL'	->	'REKINTSO'
# '2, PLOSCHAD IUNOSTIMOSKOVSKIIY R124305    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'VOLKOVSKOGO STR.MOSCOW REGION140000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# '22,KOROLEVAMOSCOW REGION141077    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOROLEV'
# '1B, CHAPAEVAMOSCOW REGION141067    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BOLSHEVO'
# 'STUPINO, PRISTANTSIONNAYA, 6MOSCOWSKAYA O142800    RUSRUS'	'MOSKOVSKAJA OBL'	->	'STUPINO'
# 'Korolev, str. Lenina, 25aMOSCOW REGION141070    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOROLEV'
# 'DER. TROSHKOVOMOSCOW OBL.140145    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RECHITSY'
# 'ODINTSOVSKIY DIST., NOVOIVANOVSKOE VILL., ZAPADMOSKOVSKAYA 143026    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOVOIVANOVSKOE'
# 'KOTELNIKI 1 POKROVSKIY PR-D IKEAMOSKOVSKAYA 140053    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SILIKAT'
# 'POS. OPKH YERMOLINO, UL.Moskovskaya o141863    50 RUS'	'MOSKOVSKAJA OBL'	->	'ERMOLINO'
# 'POVEDNIKIMOSCOW REG.141044    RUSRUS'	'MOSKOVSKAJA OBL'	->	'POVEDNIKI'
# 'MO, g. Domodedovo, mkr. Aviacionnyj, pr-t Akademika TupolevaMO129085    46 RUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'str. Dzerzhinskogo, 21/2, IvanteevkMOSCOW REGION141282    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IVANTEEVKA'
# 'MYTISCHINSKY DISTR  PIROGOVO VILL  SOVKHOZNAYA MOSCOW REG.141033    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PIROGOVSKIJ'
# 'Lytkarino, Sportivnaya str., bld.23MOSCOW REGION140083    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LYTKARINO'
# 'Naro-Fominsk, str. Lenina, 8MOSCOW REGION143300    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NARO FOMINSK'
# 'SHKOLNAYA ST.,1MOSKOVSKAYA O143080       RUS'	'MOSKOVSKAJA OBL'	->	'LESNOJ GORODOK'
# 'Orehovo-Zuevo, str. Severnaya 1MOSCOW REGION142603    RUSRUS'	'MOSKOVSKAJA OBL'	->	'OREKHOVO ZUEVO'
# 'G. DOMODEDOVO, AEROPORT DMoskovskaya o141425    50 RUS'	'MOSKOVSKAJA OBL'	->	'SHEREMETYEVO'
# 'KRASNOGORSKIY DISTR PUTILKOVO VILL  16 AMOSCOW REG.143441       RUS'	'MOSKOVSKAJA OBL'	->	'PUTILKOVO'
# 'Dmitrov, str. Professionalnaya, 5VMOSCOW REGION141800    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DMITROV'
# '2, AKADEMIKA SAKHAROVAMOSCOW REGION142281    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PROTVINO'
# '41,LENINAMOSCOW REGION143408    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KRASNOGORSK'
# 'DOROHOVOMOSOBL143160    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOROKHOVO'
# 'G. ODINTSOVO, MOZHAYSKOYE SH., D.141MOSCOWSKAYA O143005    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# '10,SAVVINSKOE SHOSSEMOSCOW REGION143980    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZHELEZNODOROZHNYJ'
# 'LENINA STRMOSCOW REGION140060    RUSRUS'	'MOSKOVSKAJA OBL'	->	'OKTJABRSKIJ'
# '178, KRASNAYAMOSKOW REGION141500    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'SOFRINO,VOKZALNAYA UL.,7AMOSKOVSKAYA O141270    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOFRINO'
# '4, MOSKOVSKAYAMOSKOVSKAYA R140120    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ILYINSKIJ'
# 'Chehov, str. Poligrafistov, 1bMOSCOW REGION142300    RUSRUS'	'MOSKOVSKAJA OBL'	->	'CHEKHOV'
# 'S/P BULATNIKOVSKOYE, UL.Moskovskaya o142702    50 RUS'	'MOSKOVSKAJA OBL'	->	'VIDNOE'
# 'Vidnoe, Zhukovskiy pr-d, 3aMOSCOW REGION142701    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VIDNOE'
# 'SOLNECHNOGORSKIY R-N D.OBMoskovskaya o141554    50 RUS'	'MOSKOVSKAJA OBL'	->	'KRIVTSOVO'
# '1, FABRICHNAYAMOSCOW REGION141033    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PIROGOVSKIJ'
# '10, ZAVODSKAYAMOSKOVSKIIY R141031    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BORODINO'
# 'PYATNITSKOE SHOSSE, 7 KMMOSCOW OBLAST143442    RUSRUS'	'MOSKOVSKAJA OBL'	->	'OTRADNOE'
# 'SEVERNAYA STRMOSCOW OBLAST141071    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOROLEV'
# 'D IVANOVKAMOSKOVSKAYA O140126    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOFYINO'
# 'g. Balashiha, mkr. Aviatorov. ul. Tret'jaka, d.8MO143900    46 RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# 'DMITROVSKIY RAYON, P.NEKRMoskovskaya o141865    50 RUS'	'MOSKOVSKAJA OBL'	->	'NEKRASOVSKIJ'
# 'JELEZNODOROGNAYA STR.MOSCOW REGION141014    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'DER MARUSINO, 3VMOSCOW REG140009    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# '127,OKTYABRSKIIYMOSCOW REGION140005    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# 'T. RAMENSKOEMOSCOW REGION140100    RUSRUS"'	'MOSKOVSKAJA OBL'	->	'RAMENSKOE'
# '1A, SLOBODKAMOSKOVSKIIY R143163    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BOGORODSKOE'
# '10, 1-YA BOL'NICHNAYAMOSCOW REGION141371    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KHOTKOVO'
# 'LYUBERECKIY DISTR KRASKOVO VILL LORHA STR 7 POMMOSCOW REG.140050    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KRASKOVO'
# 'PRAVDINSKIIY,LENINA UL.,21AMOSKOVSKAYA O141260    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PRAVDINSKIJ'
# '2, MKR. DZERZHINETSMOSCOW REGION141202    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PUSHKINO'
# '24 KM.MKADMOSCOW REGION142715    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOVKHOZ IM LENINA'
# 'A-D PODOLSK-DOMODEDOVOMOSKOVSK.OBL.142143    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BYKOVO'
# '3-1, ALTUFEVSKOE SH. 1 KMMOSKOW REGION141000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'UL YUZHNAYA D23K1MOSKOVSKAYA O142720    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOVODROZHZHINO'
# '1, 1-YI POKROVSKIY PROEZMOSKOW REGION140055    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BELAJA DACHA'
# '21A,DZERZHINSKOGOMOSCOW REGION141232    RUSRUS'	'MOSKOVSKAJA OBL'	->	'TISHKOVO'
# '43-12, POLEVAYAMOSCOW REGION141068    RUSRUS'	'MOSKOVSKAJA OBL'	->	'TEKSTILSHCHIK'
# '6 REVOLYUTSII SQMOSOBL236022    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KALININGRAD'
# '110 VL., D.MARFINOMOSKOVSKAYA R143025    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NEMCHINOVKA'
# '3 SOLNECHNAYA STMOSOBL142784    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'D BREHOVOMOSKOVSKAYA O141544    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BREKHOVO'
# 'KRASNOGORSKIY R-N, POS. NMoskovskaya o143432    50 RUS'	'MOSKOVSKAJA OBL'	->	'NAKHABINO'
# '5, 50 LET OKTYABRYAMOSCOW  REGIO140250    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BELOOZERSKIJ'
# '-1, TPZ ALTUFEVOMOSCOW REGION141031    RUSRUS"'	'MOSKOVSKAJA OBL'	->	'BORODINO'
# 'PUTILKOVO VILL., NOVOTUSHINSKAYA STR. 5MOSKOVSKAYA O143441       RUS'	'MOSKOVSKAJA OBL'	->	'PUTILKOVO'
# '7, TSENTRAL'NAYAMOSCOW REGION140221    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IM TSJURUPY'
# 'g. Zheleznodorozhnyj, ul. Granichnaja, d.22, k.2MO143989    46 RUS'	'MOSKOVSKAJA OBL'	->	'ZHELEZNODOROZHNYJ'
# 'g/pos. Voskresensk, g. Voskresensk, ul. Zelinskogo, d. 7aMO140207    46 RUS'	'MOSKOVSKAJA OBL'	->	'VOSKRESENSK'
# '1 PUTILKOVSKOE SHOSSEMOSKOVSKAYA O140000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# 'TROSHKOVOMOSCOW OBL.140145    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RECHITSY'
# 'SOVKHOZ IMENI LENINA SETTL., 1MOSKOVSKAYA 142715    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOVKHOZ IM LENINA'
# '43,BNOVAYAMOSKOVSKIY RE142104    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# 'V R-N S. IGNATOVOMOSKOVSK.OBL.141851    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PODOSINKI'
# ',MOSKOVSKAYA O141870    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BELYJ RAST'
# '5B, NOVORYAZANSKOE SH.MOSCOW REGION140053    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SILIKAT'
# '23, PROFESSIONALNAYAMOSKOVSKAYA O141800    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DMITROV'
# 'RAMENSKOE,LEVASH.UL./SEVER.SH.MOSKOVSKAYA O140100    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RAMENSKOE'
# 'ANDREEVKAMOSCOW OBL.141551    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ANDREEVKA'
# 'D.LOZHKI,S.O.PESHKOVSKIYMoskovskaya o141595    50 RUS'	'MOSKOVSKAJA OBL'	->	'LOZHKI'
# 'D. KABLUKOVOMOSKOVSKAYA O141133    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KABLUKOVO'
# 'MOLODEZHNAYA STRMOSCOW OBLAST140125    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IM TELMANA'
# 'Dubna, pr-t Bogolyubova, 14MOSCOW REGION141985    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DUBNA'
# 'ISTRINSKIY DISTR ANOSINO VILL PODMOSKOVNAYA STRMOSCOW REG.143581    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PAVLOVSKAJA SLOBODA'
# '45A,SHOSSEYNAYAMOSCOW REGION140032    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MALAKHOVKA'
# 'CHERNAYA GRIAZ VILL., SOLNECHNOGORSKIY REG.MOSKOVSKAYA O141580       RUS'	'MOSKOVSKAJA OBL'	->	'LUNEVO'
# '3, AEROPORT SHEREMETEVOMOSKOW REGION101000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# '5,1,PISAREVSKIIYMOSCOW REGION141207    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PUSHKINO'
# '3B,AVE.KOSMONAVTOVMOSCOW REGION141071    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOROLEV'
# '29,LENINAMOSCOW REGION140203    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VOSKRESENSK'
# 'D.VYALKI,UL.NOVOSTROYKA,DMoskovskaya o140142    50 RUS'	'MOSKOVSKAJA OBL'	->	'ZJUZINO'
# '3 KORPUS AEROOTELYAMOSCOW REG.115551    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# '16 KM BOROVSKOGO SHOSSEMOSKOVSK OBL143390    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'CHEKHOVSKIY RAYON, P. TROMoskovskaya o142300    50 RUS'	'MOSKOVSKAJA OBL'	->	'CHEKHOV'
# '1 ZELENYE ALLEI STRMOSKOVSKAYA142703    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VIDNOE'
# '2A, MAKOVSKOGOMOSCOW REGION143000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ODINTSOVO'
# 'LAPSHINKA VILL 8 BLD 1MOSKOVSKAYA 142784    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'PYATNITSKOYE SH.MOSKOVSKAYA R125627    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'EREMINOMOSKOVSKAYA O141051    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KRASNAJA GORKA'
# 'DOMODEDOVO AIROPORTMOSCOW OBLAST142015    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'LESNOIY,PUSHKINA UL.,8BMOSKOVSKAYA O141231    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LESNOJ'
# 'DOLGOPRUDNIY, LIHACHEVSKIY PR.64MOSCOWSKAYA O141707    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOLGOPRUDNYJ'
# 'D.TOPORKOVO BAZA STROITELMoskovskaya o141327    50 RUS'	'MOSKOVSKAJA OBL'	->	'MUKHANOVO'
# 'Fryazino, Sovetskaya str., 13MOSCOW REGION141195    RUSRUS'	'MOSKOVSKAJA OBL'	->	'FRJAZINO'
# 'SOLNECHNOGORSKIY R-ON, S.Moskovskaya o141580    50 RUS'	'MOSKOVSKAJA OBL'	->	'LUNEVO'
# '3B, OKSKIIY PR.MOSCOW REGION140400    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOLOMNA'
# '141A, TSENTRALNAYAMOSKOW REGION142207    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SERPUKHOV'
# '2-1,D.LESHINOMOSCOW REGION142300    RUSRUS'	'MOSKOVSKAJA OBL'	->	'CHEKHOV'
# 'Odintsovskiy rayon, p. Gorki-10,, bMOSCOW REGION143032    RUSRUS'	'MOSKOVSKAJA OBL'	->	'GORKI'
# 'KOTELNIKI, 1-J POKROVSKIJ  D.5MOSKOVSKAYA O140053    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOTELNIKI'
# 'G. KLIN, UL.GAGARINA, D. 5/6MOSCOWSKAYA O141601    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KLIN'
# 'MYTISHCHI, OLIMPIYSKIY PROSPEKT, 13AMOSCOWSKAYA O141006    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MYTISHCHI'
# 'VINOGRADOVO,KOM.5MOSCOW REG.140230    RUSRUS'	'MOSKOVSKAJA OBL'	->	'VINOGRADOVO'
# 'KASHIRSKOE SH 23 KMMOSKOVSK.OBL.142793    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# '49KM NOVOKASHIRSKOGO SHMOSKOVSK.OBL.142000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# '7 PERVOMAYSKAYA STMOSOBL140081    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LYTKARINO'
# '55,MOSKOVSKOEMOSCOW REGION142211    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SERPUKHOV'
# 'G.KASHIRA UL. POBEDY, D.7Moskovskaya o142903    50 RUS'	'MOSKOVSKAJA OBL'	->	'KASHIRA'
# '5,TURGENEVAMOSCOW REGION141200    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PUSHKINO'
# '5,TURGENEVAMOSCOW REGION141207    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PUSHKINO'
# 'G. DUBNA, PR-T BOGOLYUBOVMoskovskaya o141986    50 RUS'	'MOSKOVSKAJA OBL'	->	'DUBNA'
# 'DROZHZHINO VILL., NOVOE HW. 7MOSKOVSKAYA O142720       RUS'	'MOSKOVSKAJA OBL'	->	'NOVODROZHZHINO'
# 'P. SOFRINO, UL. LENINA, DMoskovskaya o141270    50 RUS'	'MOSKOVSKAJA OBL'	->	'SOFRINO'
# 'KHIMKI, AIRPORT SHEREMETEVOMOSKOVSKAYA 141400    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KHIMKI'
# 'LYUBERTSY, UL. MITROFANOVMoskovskaya o140009    50 RUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# 'G. LYUBERTSY, PR-T POBEDY, D.12MOSCOWSKAYA O140013    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# '6, YUZHNAYAMOSCOW REGION140006    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# '9, RABOCHAYAMOSCOW REGION141503    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOLNECHNOGORSK'
# 'STR.16, PARKOVAYAMOSCOW REGION142350    RUSRUS'	'MOSKOVSKAJA OBL'	->	'STOLBOVAJA'
# 'MYTISHCHINSKIY RAYON, ALTMoskovskaya o141031    50 RUS'	'MOSKOVSKAJA OBL'	->	'BORODINO'
# 'SOVHOZ IM. LENINA, DETSKY PARK SKAZOKMOSKOVSKAYA 142715    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOVKHOZ IM LENINA'
# 'BOL. SERPUKHOVSKAYA, 229MOSCOW REG123456    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'SOLNECHNOGORSKIY DISTR LUNEVO VILLMOSCOW REG.141580       RUS'	'MOSKOVSKAJA OBL'	->	'LUNEVO'
# 'DEREVNYA BORISOVO, BORISOMoskovskaya o142200    50 RUS'	'MOSKOVSKAJA OBL'	->	'SERPUKHOV'
# 'D.BORISOVO,SH.BORISOVSKOYMoskovskaya o142200    50 RUS'	'MOSKOVSKAJA OBL'	->	'SERPUKHOV'
# 'D. BORISOVO, 111MO142200    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SERPUKHOV'
# '52 KM KASHIRSKOGO SHMOSKOVSK.OBL.142000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'LESNOY GORODOKMOSCOW REG.143080    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LESNOJ GORODOK'
# 'MO, g. Ivanteevka, ul. Zarechnaya, d. 2MO143907    46 RUS'	'MOSKOVSKAJA OBL'	->	'IVANTEEVKA'
# '21 P OKTYABRSKOY FABRIKIMOSKOVSKAYA O143541    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PAVLOVSKOE'
# '15,INTERNATSIONALNAYAMOSKOVSKAYA R140140    RUSRUS'	'MOSKOVSKAJA OBL'	->	'UDELNAJA'
# 'D. MALAYA DUBNAMOSKOVSKAYA O142631    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MALAJA DUBNA'
# '14,PRIVOKZALNAYA SQ.MOSCOW REGION141540    RUSRUS'	'MOSKOVSKAJA OBL'	->	'POVAROVO'
# '20, ZAVODSKAYAMOSCOW REGION143079    RUSRUS'	'MOSKOVSKAJA OBL'	->	'STARYJ GORODOK'
# '39B,LENINAMOSCOW REGION140060    RUSRUS'	'MOSKOVSKAJA OBL'	->	'OKTJABRSKIJ'
# 'G.REUTOV,UL.YUZHNAYA,10AMOSCOWSKAYA O143965    RUSRUS'	'MOSKOVSKAJA OBL'	->	'REUTOV'
# '7B,SAVVINSKOEMOSCOW REGION143980    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZHELEZNODOROZHNYJ'
# '30A,CHASOVNYAMOSCOW REGION140000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# 'KALUZHSKOE SH. 21 KMMOSKOVSK.OBL.142704    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'SPORTIVNAYA,4-1MOSCOW REG.142370    RUSRUS'	'MOSKOVSKAJA OBL'	->	'TROITSKOE'
# 'G. KRASNOZNAMENSK, UL. MOMoskovskaya o143090    50 RUS'	'MOSKOVSKAJA OBL'	->	'KRASNOZNAMENSK'
# '1,POCHTOVAYAMOSCOW REGION142030    RUSRUS'	'MOSKOVSKAJA OBL'	->	'JAM'
# 'PLATFORMA CHKALOVSKAYAMOSCOW REGION141232    RUSRUS'	'MOSKOVSKAJA OBL'	->	'TISHKOVO'
# '5A, MOSKOVSKOE SHOSSEMOSKOW REGION141850    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DEDENEVO'
# '1,BORISOVSKOE HW.MOSCOW REGION142200    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SERPUKHOV'
# 'AIRPORT DOMODEDOVO BLD 1MOSKOVSKAYA O142015       RUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# 'MYTISHCHINSKIY RAYON, D.Moskovskaya o141051    50 RUS'	'MOSKOVSKAJA OBL'	->	'KRASNAJA GORKA'
# '1 LIKHACHEVSKOE SHMOSOBL141707    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOLGOPRUDNYJ'
# '2 PROEKTIRUEMIY PRMOSOBL143180    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZVENIGOROD'
# '18-2,KOMSOMOLSKAYAMOSCOW REGION140054    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOVROVYJ KOMBINAT'
# '11, VOROVSKOGO,VOROVSKOGO RP.MOSKOVSKAYA R142460    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IM VOROVSKOGO'
# '5,SOVETSKAYAMOSCOW REGION143980    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZHELEZNODOROZHNYJ'
# 'ODINTSOVSKIY R-N, S.NEMCHMoskovskaya o143026    50 RUS'	'MOSKOVSKAJA OBL'	->	'NOVOIVANOVSKOE'
# '33,YUBILEIYNYIY AVE.MOSCOW REGION140054    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOVROVYJ KOMBINAT'
# 'BOLSHIE DVORYMOSKOVSKAYA O142541    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BOLSHIE DVORY'
# '40-LET POBEDY STR 33MOSKOVSKAYA O143912       RUS'	'MOSKOVSKAJA OBL'	->	'BALASHIKHA'
# '1 POKROVSKIY PR-D 1MOSKOVSKAYA O140053    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SILIKAT'
# 'ST. RAMENSKOEMOSCOW REGION140100    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RAMENSKOE'
# 'AIRPORT DOMODEDOVO BLD 1MOSKOVSKAYA 142015    RUSRUS'	'MOSKOVSKAJA OBL'	->	'DOMODEDOVO'
# '8, ZHELEZNODOROZHNAYAMOSKOVSKIIY R141400    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KHIMKI'
# 'DURYKINOMOSKOVSKAYA O141532    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RADUMLJA'
# '40 LET OKTYABRYA, 5MOSCOW REG142200    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SERPUKHOV'
# 'T.PUSHKINOMOSCOW REGION141200    RUSRUS"'	'MOSKOVSKAJA OBL'	->	'PUSHKINO'
# 'NEMCHINOVKA SELO,3 ZAPRUDNAYA STR 14-16MOSKOVSKAYA 143026    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NOVOIVANOVSKOE'
# '27,KOSMONAVTOVMOSCOW REGION141071    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOROLEV'
# '3, ST. GUREVA, RAMENSKOE MOSCOWSKAYA O140108    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RAMENSKOE'
# 'UL MITINSKAYA 25MOSKOVSK.OBL.125430    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# '6A,NOVOSLOBODSKAYAMOSCOW REGION143980    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZHELEZNODOROZHNYJ'
# '11, ILINSKOEMOSKOVSKAYA O143421    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ILYINSKOE USOVO'
# '3, FABRICHNAYAMOSKOW REGION141033    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PIROGOVSKIJ'
# '1,KRASNAYAMOSCOW REGION140000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'LJUBERTSY'
# 'R.P. RZHAVKI, MKR. 2, POM. G27MOSKOVSKAYA 141552    RUSRUS'	'MOSKOVSKAJA OBL'	->	'RZHAVKI'
# 'MIKROGOROD V LESUMOSKOVSKAYA R101000    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOSKVA'
# 'NOVORIZHSKOE HW., 5 KM, VORONKIMOSKOVSKAYA O143420       RUS'	'MOSKOVSKAJA OBL'	->	'ARKHANGELSKOE'
# '25 km avtodor.Baltiya,vlMO143421    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ILYINSKOE USOVO'
# 'SVETLYYE GORY,8MOSCOW REG.143442    RUSRUS'	'MOSKOVSKAJA OBL'	->	'OTRADNOE'
# 'SADOVAYA, 19MOSCOW REG143441    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PUTILKOVO'
# 'LESNAYA ST.,16MOSKOVSKAYA O143442       RUS'	'MOSKOVSKAJA OBL'	->	'OTRADNOE'
# 'LENINSKIY DISTR IM.LENINA VILL 17-3MOSCOW REG.142715    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOVKHOZ IM LENINA'
# 'OLIMPIETS, SVISTUKHA IVANKINOMOSKOW REGION141408    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PLANERNAJA'
# '4, 1-ST POKROVSKIYMOSCOW REGION140053    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SILIKAT'
# 'RAZDORY,55MOSKOVSKAYA O143082    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BARVIKHA'
# 'KRASNOGORSKIY DSTR 26MOSKOVSKAYA O143421       RUS'	'MOSKOVSKAJA OBL'	->	'ILYINSKOE USOVO'
# 'SERKOVO D.MOSKOVSKAYA R141181    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ZAGORJANSKIJ'
# '22-A-2, MKR DMOSKOVSKIIY R142290    RUSRUS'	'MOSKOVSKAJA OBL'	->	'PUSHCHINO'
# 'Moskovskaja oblast', g. Klin, ul. Chajkovskogo, d. 62 AMO141613    46 RUS'	'MOSKOVSKAJA OBL'	->	'KLIN'
# 'G. ZHELEZNODOROZHNYY, UL.Moskovskaya o143985    50 RUS'	'MOSKOVSKAJA OBL'	->	'SAVVINO'
# '1-YA LESOPARKOVAYA, 4AMO143430    RUSRUS'	'MOSKOVSKAJA OBL'	->	'NAKHABINO'
# '14, D. GOLYGINOMOSCOW REGION114136    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'DMITROVSKIY DISTR GORKI-25 VILLMOSCOW REG.141897    RUSRUS'	'MOSKOVSKAJA OBL'	->	'GORKI'
# '29-12,1,KOSMONAVTOV AVE.MOSCOW REGION141070    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOROLEV'
# '1-2, TOLMACHEVAMOSCOW REGION141282    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IVANTEEVKA'
# 'SOLNECHNOGORSKIJ R-N D.YUMOSCOW REGION141544       RUS'	'MOSKOVSKAJA OBL'	->	'BREKHOVO'
# 'ODINTSOVSKIY RAYON, NOVOIMoskovskaya o143025    50 RUS'	'MOSKOVSKAJA OBL'	->	'NEMCHINOVKA'
# 'MOSCOVSKAYA OBLAST, GOROD DOLGOPRUDNY, SPORTIVNMOSKOVSKAYA 127284    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# '1A,ZAVODSKAYAMOSCOW REGION141140    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SVERDLOVSKIJ'
# '1A,ZAVODSKAYA,SVERDLOVSKIY R.P.MOSKOVSKAYA R141140    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SVERDLOVSKIJ'
# 'YUZHNYE GORKI, 1-206MOSCOW REG142034    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MESHCHERINO'
# '18A,ANDREEVKAMOSCOW REGION141551    RUSRUS'	'MOSKOVSKAJA OBL'	->	'ANDREEVKA'
# 'D.UlitinoMoscowskaya o143057    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KARINSKOE'
# 'D. ANDREEVKA, ZHILINSKAYAMO141551000    RUS'	'MOSKOVSKAJA OBL'	->	'ANDREEVKA'
# '(143432), Moskovskaya obl, KrasnogorskiMO143432    46 RUS'	'MOSKOVSKAJA OBL'	->	'NAKHABINO'
# '2B, 1 STR.,ZHELEZNODOROZHNAYAMOSKOVSKAYA R141270    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOFRINO'
# 'MO, g. Podol'sk, Revoljucionnyj prospekt, d. 2/14MO142116    46 RUS'	'MOSKOVSKAJA OBL'	->	'PODOLSK'
# '3,NOVOUGLICHSKOE HW.MOSCOW REGION141300    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SERGIEV POSAD'
# 'D BOBROVO UL KRYMSKAYA 13MOSKOVSK OBL142718    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IZMAJLOVO'
# 'ODINTCOVSKIY REG GOLITCYNO CITY KOMMUNISTICHESKMOSKOVSKAYA 143041    RUSRUS'	'MOSKOVSKAJA OBL'	->	'GOLITSYNO'
# 'LENINSKIY DISTR DALNIYE PRUDISHCHI VILL, BLD. 5MOSKOVSKAYA 142714    RUSRUS'	'MOSKOVSKAJA OBL'	->	'MOLOKOVO'
# 'ZHELEZNODOROZHNYY UL.SOVEMoskovskaya o143980    50 RUS'	'MOSKOVSKAJA OBL'	->	'ZHELEZNODOROZHNYJ'
# 'MYTISHCHINSKIY DISTR ALTUFIEVSKOE HW 3 BLD 1MOSCOW REG.141031    RUSRUS'	'MOSKOVSKAJA OBL'	->	'BORODINO'
# '11,NAGORNAYAMOSCOW REGION142718    RUSRUS'	'MOSKOVSKAJA OBL'	->	'IZMAJLOVO'
# '362,OKTYABRSKOIY REVOLYUTSIIMOSCOW REGION140400    RUSRUS'	'MOSKOVSKAJA OBL'	->	'KOLOMNA'
# '1, SOVKHOZ IM.LENINAMOSCOW REGION142715    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOVKHOZ IM LENINA'
# 'D. ZHEDOCHI (MBT)MOSKOVSK.OBL.143345    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SELJATINO'
# 'DER. BORISOVO, 111MOSCOW REG142251    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'LENINSKIY DISTR SOVKHOZ IM LENINA VILL BLD 1MOSCOW REG.142715    RUSRUS'	'MOSKOVSKAJA OBL'	->	'SOVKHOZ IM LENINA'
# 'DER. RUMYANCEVO STR 2MOSKOVSK.OBL.142784    RUSRUS'	'MOSKOVSKAJA OBL'	->	''
# 'KRASNOGORSK-OTRADNOYE,17MOSCOW REG.143442    RUSRUS'	'MOSKOVSKAJA OBL'	->	'OTRADNOE'
# 'GRIBKI VILL BLD 48MOSCOW REG.141044    RUSRUS'	'MOSKOVSKAJA OBL'	->	'POVEDNIKI'
# '1, KOSMONAVTOVMOSCOW REGION145075    RUSRUS'	'MOSKOVSKAJA OBL'	->	''

# %%
spellchecker = Tie()
spellchecker_reverse = Tie(reverse=True)

cities_not_found_list.discard('ST PETERBURG')
cities_not_found_list.discard('LENINGRADSKAJA OBL')

mask_spb_obl = np.logical_or(
    df_pochta["REGION"] == 'ST PETERBURG',
    df_pochta["REGION"] == 'LENINGRADSKAJA OBL'
)

for item in df_pochta.loc[mask_spb_obl, "CITY"].unique():
    spellchecker.add(item)
    spellchecker_reverse.add(item)
    
for item in df_pochta.loc[mask_spb_obl, "CITY_1"].unique():
    spellchecker.add(item)
    spellchecker_reverse.add(item)

mask_spb_obl = df["city_"] == 'LENINGRADSKAJA OBL'
mask_curr = np.logical_and(mask_spb_obl, mask_russian)

modify_cities_address_by_mask(mask_curr)
# Out:
# 'I STR\LENINGRADSKAY\353740    RUSRUS'	'LENINGRADSKAJA OBL'	->	'LENINGRADSKAJA'
# 'IZII STR BLD A\LENINGRADSKAY\353740    RUSRUS'	'LENINGRADSKAJA OBL'	->	'LENINGRADSKAJA'
# 'VOSARATOVKA-CENTR\LENINGRADSKAY\188680    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KOLTUSHI'
# 'STR\LENINGRADSKAY\353740    RUSRUS'	'LENINGRADSKAJA OBL'	->	'LENINGRADSKAJA'
# 'BLD A\LENINGRADSKAY\353740    RUSRUS'	'LENINGRADSKAJA OBL'	->	'LENINGRADSKAJA'
# 'STR BLD ZH\LENINGRADSKAY\353740    RUSRUS'	'LENINGRADSKAJA OBL'	->	'LENINGRADSKAJA'
# 'NINGRADSKAY OBL. VOLHONSKOE SHOSSE 4\LENINGR. OBL.\0573         RUS'	'LENINGRADSKAJA OBL'	->	''
# 'A STR\LENINGRADSKAY\353740    RUSRUS'	'LENINGRADSKAJA OBL'	->	'LENINGRADSKAJA'
# 'STR BLD A-5\LENINGRADSKAY\353740    RUSRUS'	'LENINGRADSKAJA OBL'	->	'LENINGRADSKAJA'
# 'VIZII, 115A\LENINGRADSKAY\350000    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KRASNODAR'
# '127, CHERNETSKOELENINGRAD REG187439    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KOLCHANOVO'
# 'BUGRYLENINGRADSKAY188660    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# 'UL MAJNILO D100LENINGRADSK O190000    RUSRUS'	'LENINGRADSKAJA OBL'	->	'ST PETERBURG'
# 'SERTOLOVO, INDUSTRIALNAYA STR 12LENINGRADSKAY190000       RUS'	'LENINGRADSKAJA OBL'	->	'SERTOLOVO'
# 'VYBORGSKY R N G. VYBORG UL. ZHELEZNODOROZHNAYLENINGRADSKAY188800    RUSRUS'	'LENINGRADSKAJA OBL'	->	'VYBORG'
# 'MURMANSKOE SH 12 KMLENINGRADSKAY188680    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KOLTUSHI'
# '12-J KM MURMANSKOGO HWLENINGRADSKAY188680       RUS'	'LENINGRADSKAJA OBL'	->	'KOLTUSHI'
# 'd.Novoe Devyatkino,d.17L.O.188661    RUSRUS'	'LENINGRADSKAJA OBL'	->	'NOVOE DEVJATKINO'
# 'MURINO VILL PRIVOKZALNAYA SQ 5-ALENINGRADSKAY188661       RUS'	'LENINGRADSKAJA OBL'	->	'NOVOE DEVJATKINO'
# 'A-D ROSSIYA, 601 KM+800 MLENINGRADSKAY187070    RUSRUS'	'LENINGRADSKAJA OBL'	->	'TRUBNIKOV BOR'
# 'MURMANSKOE HW 12 KMLENINGRADSKAY188680       RUS'	'LENINGRADSKAJA OBL'	->	'KOLTUSHI'
# 'MASSIV SKOTNOELENINGRADSKAY188653    RUSRUS'	'LENINGRADSKAJA OBL'	->	'AGALATOVO'
# 'VSEVOLOZHSKY DISTR MASSIV KORABSELKILENINGRADSKA188660    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# 'VSEVOLOZHSKY DISTR MASSIV KORABSELKILENINGRADSKA125040    RUSRUS'	'LENINGRADSKAJA OBL'	->	'MOSKVA'
# 'Leningrad obl, Poselok Telmana 2 bLeningrad obl187032    RUSRUS'	'LENINGRADSKAJA OBL'	->	'TELMANA'
# 'NOVOE DEVYATKINO VILL 101LENINGRADSKA188661    RUSRUS'	'LENINGRADSKAJA OBL'	->	'NOVOE DEVJATKINO'
# 'VSEVOLOZHSKY DISTR KADLENINGRADSKAY188660       RUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# 'D PODZVANYE 1ALENINGRAD.OBL194362    RUSRUS'	'LENINGRADSKAJA OBL'	->	'PARGOLOVO'
# 'MURINO VILL PRIVOKZALNAYA SQ 1-A KORP 1LENINGRADSKA188661    RUSRUS'	'LENINGRADSKAJA OBL'	->	'NOVOE DEVJATKINO'
# 'BABINOLENINGRAD.OBL187070    RUSRUS'	'LENINGRADSKAJA OBL'	->	'TRUBNIKOV BOR'
# 'VSEVOLOZHSKIY DISTR MURMANSKOE HWLENINGRADSKA197022    RUSRUS'	'LENINGRADSKAJA OBL'	->	'ST PETERBURG'
# '12,MURMANSKOE SH.LENINGRAD REG188680    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KOLTUSHI'
# 'VSEVOLZHSKIY REG MEGA PARNASLENINGRADSKA188660    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# 'd.Gostilitsy,ul.Tsentralnaya,d.1L.O.188520    RUSRUS'	'LENINGRADSKAJA OBL'	->	'GOSTILITSY'
# 'd.Gostilitsy,ul. Tsentralnaya,d.2L.O.188520    RUSRUS'	'LENINGRADSKAJA OBL'	->	'GOSTILITSY'
# 'd.Gostilitsy,ul.Tsentralnaya,d.2L.O.188520    RUSRUS'	'LENINGRADSKAJA OBL'	->	'GOSTILITSY'
# 'p. Bugry,ul.Shkolnaya,d.11,k.1L.O.188660    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# 'S.P. SKREBLOVSKOELENINGRAD.OBL188275    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BOLSHIE SHATNOVICHI'
# 'G. VSEVOLOZHSK, VSEVOLOZHSKY PR., OP VSEVOLOZLENINGRADSKAY188640    RUSRUS'	'LENINGRADSKAJA OBL'	->	'VSEVOLOZHSK'
# '115A IM. 302 DIVIZII STRLENINGRADSKAY350000    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KRASNODAR'
# '14, CHEBYISHEVSKAYALENINGRAD REG198504    RUSRUS'	'LENINGRADSKAJA OBL'	->	'STARYJ PETERGOF'
# 'VYBORGSKY R N G. VYBORG UL. ZHELEZNODOROZHNAYLENINGRADSKAY197022    RUSRUS'	'LENINGRADSKAJA OBL'	->	'ST PETERBURG'
# 'LOMONOSOVSKIY REG SISTO-PALKINO VILLLENINGRADSKA188540    RUSRUS'	'LENINGRADSKAJA OBL'	->	'SOSNOVYJ BOR'
# 'TELMANA VILL. 9LENINGRADSKA187032    RUSRUS'	'LENINGRADSKAJA OBL'	->	'TELMANA'
# 'TELMANA VILL LIT 2VLENINGRADSKA187032    RUSRUS'	'LENINGRADSKAJA OBL'	->	'TELMANA'
# 'POS.BUGRY.LENINGRADSKAYA OBL.LENINGRADSKII188660    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# 'VSEVOLZHSKY DISTR MURMANSKOE HW 12 KMLENINGRADSKA188680    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KOLTUSHI'
# 'd.Yukki,sh.Leningradskoe,22L.O.188652    RUSRUS'	'LENINGRADSKAJA OBL'	->	'JUKKI'
# 'M4, P269LENINGRADSKAY352771    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BOLSHOJ BEJSUG'
# 'BUGRY, NIZHNYA STR. 9LENINGRADSKA190000    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# '13, KHESINALENINGRAD REG188679    RUSRUS'	'LENINGRADSKAJA OBL'	->	'IM MOROZOVA'
# 'VSEVOLZHSKIY DISTR MURMANSKOE HW 12KMLENINGRADSKA188680    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KOLTUSHI'
# 'VSEVOLOZHSKY DISTR MURMANSKOE HW 12 KMLENINGRADSKA188680    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KOLTUSHI'
# 'MURINO, MENDELEEVA BLVD 14LENINGRADSKA188661    RUSRUS'	'LENINGRADSKAJA OBL'	->	'MURINO'
# 'D. TIKOPISLENINGRADSK.O188455    RUSRUS'	'LENINGRADSKAJA OBL'	->	'LESOBIRZHA'
# 'd.Gostilicy,Centralnaya ul.,d.2L.O.188520    RUSRUS'	'LENINGRADSKAJA OBL'	->	'GOSTILITSY'
# 'os.Steklyanniy,d.40-AL.O.188654    RUSRUS"'	'LENINGRADSKAJA OBL'	->	'STEKLJANNYJ'
# 'VSEVOLZHSKIY DISTR MURMANSKOE HW 12 KMLENINGRADSKAY190000       RUS'	'LENINGRADSKAJA OBL'	->	'ST PETERBURG'
# 'p.Murono,Privokzalnaya pl.,1-A,k1Leningradskay188662    RUSRUS'	'LENINGRADSKAJA OBL'	->	'MURINO'
# 'D. PROBALENINGRADSKAY188669    RUSRUS'	'LENINGRADSKAJA OBL'	->	'MURINO'
# 'WARTKO VILL ZARECHNAYA STR 1 ALENINGRADSKAY188732       RUS'	'LENINGRADSKAJA OBL'	->	'PETROVSKOE'
# 'MURMANSKOE HW 12 MLENINGRADSKA188660    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# 'VSEVOLOZHSKIY REG., 12 KM. MURMANSKOGO HW.LENINGRADSKA188657    RUSRUS'	'LENINGRADSKAJA OBL'	->	'MATOKSA'
# 'TORFYANOVKA VILLLENINGRADSKA188800    RUSRUS'	'LENINGRADSKAJA OBL'	->	'VYBORG'
# 'g.Sertolovo,ul.Sosnovaya,d.4,L.AL.O.188650    RUSRUS'	'LENINGRADSKAJA OBL'	->	'SERTOLOVO'
# 'DUBROVKA VILL., LENINGRADSKAYA STR. 8LENINGRADSKAY188684       RUS'	'LENINGRADSKAJA OBL'	->	'DUBROVKA'
# 'IVANOVO VILL PRIDOROZHNAYA STR 8LENINGRADSKAY188730       RUS'	'LENINGRADSKAJA OBL'	->	'SOSNOVO'
# '12-M-1, MURMANSKOELENINGRADSKAY188680    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KOLTUSHI'
# 'G. VOLKHOV, UL. PRIVOKZALNAYA, DOM 1LENINGRADSKAY187400    RUSRUS'	'LENINGRADSKAJA OBL'	->	''
# '30A, DOROGA ZHIZNILENINGRAD REG188670    RUSRUS'	'LENINGRADSKAJA OBL'	->	'ROMANOVKA'
# 'KOMMUNAR, LENINGRADSKAYA STR, 5LENINGRADSKAY188320       RUS'	'LENINGRADSKAJA OBL'	->	'KOMMUNAR'
# 'VSEVOLZHSK  ALEXANDROVSKAYA STR 75 ALENINGRADSKA188643    RUSRUS'	'LENINGRADSKAJA OBL'	->	'VSEVOLOZHSK'
# '12KM,MURMANSKOE SHLENINGRADSKAY188689    RUSRUS'	'LENINGRADSKAJA OBL'	->	'JANINO'
# '20, ST. KURBATOVA, ENKOLOVO LENINGRADSKAY188660    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# 'VENSKAYA,4LENINGRADSKAY187000    RUSRUS'	'LENINGRADSKAJA OBL'	->	'TOSNO'
# 'ZHELEZNODOROZHNAJA 5LENINGRAD OB196084    78 RUS'	'LENINGRADSKAJA OBL'	->	'ST PETERBURG'
# 'ILICHEVA VILL BAZA OTDYKHA ILICHEVOLENINGRADSKA188838    RUSRUS'	'LENINGRADSKAJA OBL'	->	'ILYICHEVO'
# 'RAZMETELEVO VILL 12LENINGRADSKA188686    RUSRUS'	'LENINGRADSKAJA OBL'	->	'RAZMETELEVO'
# 'VSEVOLOZHSKY DISTR KADLENINGRADSKA188660    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# 'BABINOLENINGRADSK.O187000    RUSRUS'	'LENINGRADSKAJA OBL'	->	'TOSNO'
# '(188660), Leningradskaya obl, VsevolozhLeningr obl188660    41 RUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# '3, IZHORSKAYALENINGRAD REG188459    RUSRUS'	'LENINGRADSKAJA OBL'	->	'IVANOVSKOE'
# 'PMURMANSKOE HW 12 TC ""MEGA""LENINGRADSKAY188689       RUS"'	'LENINGRADSKAJA OBL'	->	'JANINO'
# '12KM, MURMANSKOE SHLENINGRADSKAY188689    RUSRUS'	'LENINGRADSKAJA OBL'	->	'JANINO'
# 'ZAKLINELENINGRADSKII188270    RUSRUS'	'LENINGRADSKAJA OBL'	->	'ZAKLINYE ZAKLINSKOE SELSKOE POSELENIE'
# 'KOLTUSHSKOE SH 5LENINGRADSK.O188689    RUSRUS'	'LENINGRADSKAJA OBL'	->	'JANINO'
# 'G.P. KUZMOLOVSKY SVETLAYA STR 1LENINGRADSKAY188663       RUS'	'LENINGRADSKAJA OBL'	->	'KUZMOLOVSKIJ'
# 'G.P. KUZMOLOVSKY SVETLAYA STR 1LENINGRADSKA188663    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KUZMOLOVSKIJ'
# 'GATCHINSKY R N, P.G.T. VYRITSA UL. ZHERTV REVLENINGRADSKAY188380    RUSRUS'	'LENINGRADSKAJA OBL'	->	'VYRITSA'
# 'VSEVOLOZHSKIY DISTR MURMANSKOE HW 12LENINGRADSKA188671    RUSRUS'	'LENINGRADSKAJA OBL'	->	'RAKHJA'
# 'KVARTAL 5, UL. 3 UCH. 1 STR. 1LENINGRAD.OBL188660    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BUGRY'
# 'IVANGOROD 32LENINGRADSK.O187000    RUSRUS'	'LENINGRADSKAJA OBL'	->	'TOSNO'
# 'ROSCHINO, PERVOMAYSKAYA STR, 2LENINGRADSKA188820    RUSRUS'	'LENINGRADSKAJA OBL'	->	'ROSHCHINO'
# 'SKOTNOELENINGRAD.OBL188653    RUSRUS'	'LENINGRADSKAJA OBL'	->	'AGALATOVO'
# '53 KM MOSKOVSKOGO SH.LENINGRADSKAY187000    RUSRUS'	'LENINGRADSKAJA OBL'	->	'TOSNO'
# '2 KM, MURMANSKOYE SHOSSELENINGRADSKAY188640    RUSRUS"'	'LENINGRADSKAJA OBL'	->	'VSEVOLOZHSK'
# 'BORISOVO VLLENINGRADSKAY188380       RUS'	'LENINGRADSKAJA OBL'	->	'VYRITSA'
# 'VSEVOLOZHSKIY DISTR MURMANSKOE HW 12 KMLENINGRADSKA188640    RUSRUS'	'LENINGRADSKAJA OBL'	->	'VSEVOLOZHSK'
# 'LOMONOSOVSKY RAYON, NARVSKOE SH., D.21LENINGRADSKAY188515    RUSRUS'	'LENINGRADSKAJA OBL'	->	'KIPEN'
# 'KUDROVO VILL LENINGRADSKAYA STR 5/2LENINGRADSKA195271    RUSRUS'	'LENINGRADSKAJA OBL'	->	'ST PETERBURG'
# 'KUDROVO VILL., EVROPEYSKIY AV. 11LENINGRADSKA188689    RUSRUS'	'LENINGRADSKAJA OBL'	->	'JANINO'
# 'DUBROVKA VILL., NEVSKAYA STR. 5BLENINGRADSKA188684    RUSRUS'	'LENINGRADSKAJA OBL'	->	'DUBROVKA'
# 'GORELOVO VILL KRASNOSELSKOE HW 54ALENINGRADSKA198323    RUSRUS'	'LENINGRADSKAJA OBL'	->	'GORELOVO'
# 'g.p. Borisa Griva, lit. ALen.oblast188672    RUSRUS'	'LENINGRADSKAJA OBL'	->	'BORISOVA GRIVA'
# 'YUKKI VILL LENINGRADSKOE HW 2LENINGRADSKA188652    RUSRUS'	'LENINGRADSKAJA OBL'	->	'JUKKI'
# 'UKKI VILL LENINGRADSKOE HW 22LENINGRADSKA188652    RUSRUS'	'LENINGRADSKAJA OBL'	->	'JUKKI'
# '53 KM KIEVSKOGO HW 1LENINGRADSKA188309    RUSRUS'	'LENINGRADSKAJA OBL'	->	'GATCHINA'
# 'P.SERTOLOVOLENINGRADSK.O187000    RUSRUS'	'LENINGRADSKAJA OBL'	->	'TOSNO'
# 'VYBORG ZHELEZNODOROZHNAYA STR 10LENINGRADSKAY188900       RUS'	'LENINGRADSKAJA OBL'	->	''
# 'MURINO, PRIVOKZALNAYA SQ 3/3LENINGRADSKA188661    RUSRUS'	'LENINGRADSKAJA OBL'	->	'MURINO'

# %%
map_term_to_city = {
    term : group["city_"].value_counts().idxmax()
    for term, group in df[mask_russian].groupby("terminal_id")
}

df.loc[mask_russian, "city_"] = df.loc[mask_russian, "terminal_id"].map(
    lambda x: map_term_to_city[x])

# %%
df.iloc[0:5]
# Out:
#      amount atm_address  atm_address_lat  atm_address_lon          city  \
# 0  2.884034         NaN              NaN              NaN  ST PETERBURG
# 1  2.775633         NaN              NaN              NaN  ST PETERBURG
# 2  3.708368         NaN              NaN              NaN  ST PETERBURG
# 3  2.787498         NaN              NaN              NaN  ST PETERBURG
# 4  2.892510         NaN              NaN              NaN  ST PETERBURG
#
#   country  currency                       customer_id  home_add_lat  \
# 0     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 1     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 2     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 3     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 4     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
#
#    home_add_lon is_train   mcc  \
# 0        30.232     True  5261
# 1        30.232     True  5261
# 2        30.232     True  5992
# 3        30.232     True  5261
# 4        30.232     True  5261
#
#                                          pos_address  pos_address_lat  \
# 0                                                NaN        59.844074
# 1                                                NaN        59.844074
# 2  PR.MARSHALA ZHUKOVA,31St Petersburg190000    7...        59.858200
# 3                                                NaN        59.844074
# 4                                                NaN        59.844074
#
#    pos_address_lon                       terminal_id transaction_date  \
# 0        30.179153  11606fde0c814ce78e0d726e39a0a5ee       2017-07-15
# 1        30.179153  e9647a5e1eacfb06713b6af755ccc595       2017-10-27
# 2        30.229023  df06c1fcd3718a514535ae822785f716       2017-10-03
# 3        30.179153  6c5e5793ebc984fb72875feffff62854       2017-09-09
# 4        30.179153  0576445d74e374c92c0902e612fca356       2017-07-06
#
#    work_add_lat  work_add_lon         city_
# 0        59.847        30.177  ST PETERBURG
# 1        59.847        30.177  ST PETERBURG
# 2        59.847        30.177  ST PETERBURG
# 3        59.847        30.177  ST PETERBURG
# 4        59.847        30.177  ST PETERBURG

# %%
df.loc[mask_russian, "city"].unique().shape[0], df.loc[mask_russian, "city_"].unique().shape[0]
# Out:
# (4961, 3289)

# %%
r = [(c, g.shape[0]) for c, g in df[mask_russian].groupby("city_")]
r = sorted(r, key=itemgetter(1), reverse=True)

len(filter(lambda x: x[1] > 50, r))
# Out:
# 791

# %%
df["city"] = df["city_"]
df.drop(labels="city_", inplace=True, axis=1)
df.head()
# Out:
#      amount atm_address  atm_address_lat  atm_address_lon          city  \
# 0  2.884034         NaN              NaN              NaN  ST PETERBURG
# 1  2.775633         NaN              NaN              NaN  ST PETERBURG
# 2  3.708368         NaN              NaN              NaN  ST PETERBURG
# 3  2.787498         NaN              NaN              NaN  ST PETERBURG
# 4  2.892510         NaN              NaN              NaN  ST PETERBURG
#
#   country  currency                       customer_id  home_add_lat  \
# 0     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 1     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 2     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 3     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 4     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
#
#    home_add_lon is_train   mcc  \
# 0        30.232     True  5261
# 1        30.232     True  5261
# 2        30.232     True  5992
# 3        30.232     True  5261
# 4        30.232     True  5261
#
#                                          pos_address  pos_address_lat  \
# 0                                                NaN        59.844074
# 1                                                NaN        59.844074
# 2  PR.MARSHALA ZHUKOVA,31St Petersburg190000    7...        59.858200
# 3                                                NaN        59.844074
# 4                                                NaN        59.844074
#
#    pos_address_lon                       terminal_id transaction_date  \
# 0        30.179153  11606fde0c814ce78e0d726e39a0a5ee       2017-07-15
# 1        30.179153  e9647a5e1eacfb06713b6af755ccc595       2017-10-27
# 2        30.229023  df06c1fcd3718a514535ae822785f716       2017-10-03
# 3        30.179153  6c5e5793ebc984fb72875feffff62854       2017-09-09
# 4        30.179153  0576445d74e374c92c0902e612fca356       2017-07-06
#
#    work_add_lat  work_add_lon
# 0        59.847        30.177
# 1        59.847        30.177
# 2        59.847        30.177
# 3        59.847        30.177
# 4        59.847        30.177

# %%
df_1 = df[df["is_train"] == True]
df_1.drop(labels="is_train", inplace=True, axis=1)
df_1.head()
# Out:
# /home/vladimir/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#      amount atm_address  atm_address_lat  atm_address_lon          city  \
# 0  2.884034         NaN              NaN              NaN  ST PETERBURG
# 1  2.775633         NaN              NaN              NaN  ST PETERBURG
# 2  3.708368         NaN              NaN              NaN  ST PETERBURG
# 3  2.787498         NaN              NaN              NaN  ST PETERBURG
# 4  2.892510         NaN              NaN              NaN  ST PETERBURG
#
#   country  currency                       customer_id  home_add_lat  \
# 0     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 1     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 2     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 3     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
# 4     RUS     643.0  0dc0137d280a2a82d2dc89282450ff1b     59.851002
#
#    home_add_lon   mcc                                        pos_address  \
# 0        30.232  5261                                                NaN
# 1        30.232  5261                                                NaN
# 2        30.232  5992  PR.MARSHALA ZHUKOVA,31St Petersburg190000    7...
# 3        30.232  5261                                                NaN
# 4        30.232  5261                                                NaN
#
#    pos_address_lat  pos_address_lon                       terminal_id  \
# 0        59.844074        30.179153  11606fde0c814ce78e0d726e39a0a5ee
# 1        59.844074        30.179153  e9647a5e1eacfb06713b6af755ccc595
# 2        59.858200        30.229023  df06c1fcd3718a514535ae822785f716
# 3        59.844074        30.179153  6c5e5793ebc984fb72875feffff62854
# 4        59.844074        30.179153  0576445d74e374c92c0902e612fca356
#
#   transaction_date  work_add_lat  work_add_lon
# 0       2017-07-15        59.847        30.177
# 1       2017-10-27        59.847        30.177
# 2       2017-10-03        59.847        30.177
# 3       2017-09-09        59.847        30.177
# 4       2017-07-06        59.847        30.177

# %%
df_2 = df[df["is_train"] == False]
df_2.drop(labels="is_train", inplace=True, axis=1)
df_2.head()
# Out:
# /home/vladimir/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#            amount atm_address  atm_address_lat  atm_address_lon        city  \
# 1224734  2.211818         NaN              NaN              NaN  IVANTEEVKA
# 1224735  1.331379         NaN              NaN              NaN  IVANTEEVKA
# 1224736  2.608004         NaN              NaN              NaN    PUSHKINO
# 1224737  1.916752         NaN              NaN              NaN  IVANTEEVKA
# 1224738  1.981067         NaN              NaN              NaN      MOSKVA
#
#         country  currency                       customer_id  home_add_lat  \
# 1224734     RUS     643.0  00fd410f5c580c8351cafa88d82b60f3           NaN
# 1224735     RUS     643.0  00fd410f5c580c8351cafa88d82b60f3           NaN
# 1224736     RUS     643.0  00fd410f5c580c8351cafa88d82b60f3           NaN
# 1224737     RUS     643.0  00fd410f5c580c8351cafa88d82b60f3           NaN
# 1224738     RUS     643.0  00fd410f5c580c8351cafa88d82b60f3           NaN
#
#          home_add_lon   mcc  \
# 1224734           NaN  5411
# 1224735           NaN  4111
# 1224736           NaN  5411
# 1224737           NaN  5411
# 1224738           NaN  5814
#
#                                                pos_address  pos_address_lat  \
# 1224734       2-1 TOLMACHEVA STRIVANTEEVKA141280    RUSRUS        55.967487
# 1224735            SOVETSKIJ, 32IVANTEEVKA141282    RUSRUS        55.971294
# 1224736      105,KRASOARMEYSKOE SHPUSHKINO141206    RUSRUS        56.016590
# 1224737  G. IVANTEEVKA, UL.TOLMACHEVA, D.6IVANTEEVKA141...        55.964508
# 1224738           5 KOMSOMOLSKAYA SQMOSCOW101000    RUSRUS        55.776802
#
#          pos_address_lon                       terminal_id transaction_date  \
# 1224734        37.913681  ff0476dae4b098a7b16aabe93d4268df       2017-08-24
# 1224735        37.905186  7cfd9a60282459d4692ecc85b856072e       2017-08-12
# 1224736        37.909100  7e5a532f0029861d8a9c4f0479b9450b       2017-06-17
# 1224737        37.937912  2afe7d1bc61b86c449f413bdf2119032       2017-08-12
# 1224738        37.657352  ab4f00601ff1d949afc59ee3f804c79c       2017-04-26
#
#          work_add_lat  work_add_lon
# 1224734           NaN           NaN
# 1224735           NaN           NaN
# 1224736           NaN           NaN
# 1224737           NaN           NaN
# 1224738           NaN           NaN

# %%
df_1.to_csv('data/sets/train_set_mod_cities.csv', sep=',', encoding='utf-8', index=False)
df_2.to_csv('data/sets/test_set_mod_cities.csv', sep=',', encoding='utf-8', index=False)

# %%
for c, g in r:
    print "'{}'\t{}".format(c, g)
# Out:
# 'MOSKVA'	906709
# 'ST PETERBURG'	494609
# 'NOVOSIBIRSK'	49620
# 'EKATERINBURG'	48937
# 'NIZHNIJ NOVGOROD'	47678
# 'CHEREPOVETS'	45311
# 'KRASNOJARSK'	35709
# 'KRASNODAR'	33934
# 'SAMARA'	24361
# 'KAZAN'	22377
# 'KHIMKI'	20394
# 'SOCHI'	18984
# 'PODOLSK'	18618
# 'NOVOROSSIJSK'	17813
# 'UFA'	15068
# 'VORONEZH'	15059
# 'OREL'	14778
# 'SYKTYVKAR'	14695
# 'CHELJABINSK'	14635
# 'ROSTOV NA DONU'	14432
# 'MYTISHCHI'	14385
# 'OMSK'	14227
# 'JAROSLAVL'	13659
# 'PETROZAVODSK'	13550
# 'KALUGA'	10911
# 'VOLGOGRAD'	10820
# 'BALASHIKHA'	10344
# 'ODINTSOVO'	10304
# 'ANAPA'	10218
# 'PERM'	10094
# 'KRASNOGORSK'	9676
# 'TULA'	8823
# 'KIROV'	8795
# 'IRKUTSK'	8769
# 'DOMODEDOVO'	8589
# 'SARATOV'	8471
# 'KALININGRAD'	8324
# 'LJUBERTSY'	8128
# 'TJUMEN'	8113
# 'LIPETSK'	8017
# 'KEMEROVO'	7903
# 'SURGUT'	7688
# 'BRJANSK'	7635
# 'KOTELNIKI'	6739
# 'KOROLEV'	6667
# 'SARANSK'	6605
# 'VSEVOLOZHSK'	5858
# 'KURSK'	5596
# 'PUSHKINO'	5467
# 'SMOLENSK'	5392
# 'TOLJATTI'	5287
# 'BELGOROD'	5067
# 'REUTOV'	4770
# 'ZHELEZNODOROZHNYJ'	4766
# 'TOMSK'	4757
# 'ZHELEZNOGORSK'	4691
# 'LOBNJA'	4377
# 'KOLPINO'	3982
# 'KOLOMNA'	3744
# 'RAMENSKOE'	3728
# 'ZHUKOVSKIJ'	3509
# 'GATCHINA'	3490
# 'IVANOVO'	3379
# 'DOLGOPRUDNYJ'	3328
# 'KLIN'	3299
# 'SERPUKHOV'	3219
# 'PUSHKIN'	3002
# 'SHCHELKOVO'	2994
# 'JALUTOROVSK'	2986
# 'NOGINSK'	2834
# 'ZELENOGRAD'	2823
# 'ISTRA'	2780
# 'SHUSHARY'	2773
# 'SERGIEV POSAD'	2756
# 'ELEKTROSTAL'	2725
# 'SEVASTOPOL'	2637
# 'VIDNOE'	2634
# 'DZERZHINSKIJ'	2549
# 'SOLNECHNOGORSK'	2530
# 'CHEKHOV'	2465
# 'IVANTEEVKA'	2384
# 'KRONSHTADT'	2320
# 'TVER'	2262
# 'NARO FOMINSK'	2193
# 'BERDSK'	2173
# 'STUPINO'	2152
# 'VLADIMIR'	2128
# ''	2115
# 'RJAZAN'	2031
# 'PARGOLOVO'	2019
# 'BARNAUL'	2012
# 'KUDROVO'	1890
# 'KLIMOVSK'	1868
# 'MIASS'	1851
# 'STAVROPOL'	1789
# 'SHCHERBINKA'	1751
# 'NABEREZHNYE CHELNY'	1747
# 'PETERGOF'	1712
# 'MOSKOVSKIJ'	1698
# 'TROITSK'	1515
# 'ZVENIGOROD'	1444
# 'TELMANA'	1428
# 'SESTRORETSK'	1403
# 'MURINO'	1370
# 'VOLOGDA'	1362
# 'CHEBOKSARY'	1351
# 'KOMMUNAR'	1301
# 'LAKINSK'	1296
# 'MAGNITOGORSK'	1291
# 'NAKHABINO'	1287
# 'VOLZHSKIJ'	1279
# 'BYKOVO'	1268
# 'VOSKRESENSK'	1233
# 'SHADRINSK'	1188
# 'MALAKHOVKA'	1182
# 'GELENDZHIK'	1173
# 'DUBNA'	1168
# 'DMITROV'	1150
# 'MILKOVO'	1144
# 'OBNINSK'	1138
# 'KONAKOVO'	1135
# 'IZHEVSK'	1133
# 'JUDINO'	1133
# 'BULATNIKOVO'	1112
# 'VERKHNJAJA PYSHMA'	1106
# 'AKSAJ'	1064
# 'VYBORG'	1060
# 'KOMMUNARKA'	1049
# 'PJATIGORSK'	1031
# 'GRJAZI'	1025
# 'OREKHOVO ZUEVO'	1024
# 'KRASNOE'	1015
# 'KOPEJSK'	980
# 'VELIKIJ NOVGOROD'	974
# 'TAGANROG'	966
# 'SOSENSKOE'	947
# 'EZHOVO'	938
# 'BOR'	928
# 'KSTOVO'	853
# 'APRELEVKA'	845
# 'SERTOLOVO'	819
# 'ROSTOV'	796
# 'SOLNECHNYJ'	765
# 'EGORYEVSK'	761
# 'LOMONOSOV'	753
# 'ELETS'	750
# 'BATAJSK'	742
# 'ENGELS'	740
# 'ALEKSANDROV'	728
# 'LYTKARINO'	725
# 'GOLITSYNO'	717
# 'DEDOVSK'	711
# 'ESSENTUKI'	693
# 'STARYJ OSKOL'	689
# 'VLADIMIRSKAJA'	687
# 'NOVOMOSKOVSK'	679
# 'OKTJABRSKIJ'	678
# 'AGALATOVO'	672
# 'KRASNOZNAMENSK'	672
# 'ANGARSK'	667
# 'TOSNO'	653
# 'KOSTROMA'	646
# 'KUBINKA'	640
# 'RZHAVKI'	637
# 'TAMBOV'	632
# 'RYBINSK'	597
# 'TOMILINO'	593
# 'BALABANOVO'	589
# 'LESNOJ GORODOK'	588
# 'NOVAJA ADYGEJA'	588
# 'PENZA'	586
# 'SVERDLOVSKIJ'	580
# 'KIROVSK'	571
# 'SIMFEROPOL'	558
# 'ELEKTROUGLI'	556
# 'KRASUKHA'	549
# 'NOVINKI'	549
# 'PAVLOVSKIJ'	547
# 'SOVETSK'	539
# 'SOBINKA'	535
# 'BISEROVO'	531
# 'BEREZOVSKIJ'	528
# 'PROTVINO'	523
# 'KINGISEPP'	519
# 'NOVOIVANOVSKOE'	516
# 'SHATURA'	516
# 'VLADIVOSTOK'	512
# 'ISKITIM'	499
# 'OTRADNAJA'	499
# 'NOVOKUJBYSHEVSK'	496
# 'LESNOJ'	495
# 'ILYINSKIJ'	492
# 'LABINSK'	492
# 'BRONNITSY'	486
# 'SOVKHOZ IM LENINA'	479
# 'TIKHORETSK'	473
# 'FRJAZINO'	472
# 'PSKOV'	461
# 'KERCH'	458
# 'PETUSHKI'	457
# 'KASHIRA'	456
# 'NOVOKUZNETSK'	455
# 'JALTA'	450
# 'MURMANSK'	444
# 'OTRADNOE'	441
# 'BUGRY'	437
# 'ORENBURG'	435
# 'ROSHCHINO'	435
# 'NEMCHINOVKA'	431
# 'MAJKOP'	420
# 'TIMASHEVSK'	417
# 'KOLTUSHI'	402
# 'LUGA'	396
# 'ARKHANGELSK'	391
# 'VITJAZEVO'	390
# 'KIRISHI'	380
# 'STARAJA KUPAVNA'	376
# 'SOLONTSY'	375
# 'ZLATOUST'	372
# 'SELJATINO'	366
# 'PSEBAJ'	365
# 'VILLOZI'	364
# 'IM MOROZOVA'	360
# 'UDELNAJA'	360
# 'MAMYR'	359
# 'ASTRAKHAN'	358
# 'VOLOKOLAMSK'	356
# 'NOVOE DEVJATKINO'	354
# 'SOSNOVYJ BOR'	353
# 'RUZA'	351
# 'ZELENOGORSK'	344
# 'VLADIKAVKAZ'	341
# 'OZERY'	340
# 'PERVOMAJSKOE'	339
# 'ERMOLINO'	337
# 'RUMJANTSEVO'	337
# 'SHCHEKINO'	337
# 'PRIOZERSK'	336
# 'TSEMDOLINA'	333
# 'STRELNA'	332
# 'PAVLOVSK'	331
# 'NIZHNEVARTOVSK'	328
# 'RYBNAJA SLOBODA'	328
# 'PERVOURALSK'	327
# 'LUKHOVITSY'	324
# 'VYRITSA'	324
# 'MIKHNEVO'	323
# 'ULJANOVSK'	321
# 'MTSENSK'	320
# 'SVETLOGORSK'	320
# 'NIZHNIJ TAGIL'	318
# 'OB'	318
# 'TUCHKOVO'	315
# 'UGLICH'	315
# 'MOZHAJSK'	314
# 'TULSKAJA OBL'	314
# 'ALEKSEEVKA'	310
# 'NIKOLSKOE'	310
# 'MUROM'	307
# 'ILYINSKOE'	306
# 'KRASKOVO'	304
# 'JUBILEJNYJ'	300
# 'MALOJAROSLAVETS'	300
# 'OSTROVTSY'	300
# 'TVERSKAJA OBL'	296
# 'KALUZHSKAJA OBL'	293
# 'ZARECHYE'	292
# 'KHABAROVSK'	281
# 'BORODINO'	280
# 'NOVOPETROVSKOE'	280
# 'MALAJA SHILNA'	277
# 'SOSNOVO'	274
# 'GAJDUK'	272
# 'KRASNOGORSKIJ'	268
# 'KOLTSOVO'	267
# 'POKROV'	266
# 'LJUBUCHANY'	264
# 'METALLOSTROJ'	264
# 'SEVERSK'	262
# 'MOSTOVSKOJ'	261
# 'NOVYJ BYT'	260
# 'GORKI'	259
# 'ANNINO'	258
# 'LAPSHINSKAJA'	257
# 'GORODETS'	256
# 'DUBOVOE'	255
# 'FEDJUKOVO'	255
# 'PERESLAVL ZALESSKIJ'	253
# 'PUTILKOVO'	253
# 'ZELENOGRADSK'	251
# 'VNUKOVSKOE'	248
# 'KIMRY'	247
# 'TOKSOVO'	246
# 'ARAMIL'	245
# 'SHEREMETYEVO'	245
# 'LEBEDEVKA'	242
# 'PROLETARSKIJ'	240
# 'BELOOZERSKIJ'	237
# 'MAMONOVO'	237
# 'KIRZHACH'	236
# 'KRASNOOBSK'	235
# 'KRASNYJ BOR'	233
# 'PECHERSK'	232
# 'USADY'	232
# 'TEMRJUK'	230
# 'ULJANOVKA'	230
# 'STARODUB'	229
# 'KUZMOLOVSKIJ'	225
# 'PAVLOVSKIJ POSAD'	225
# 'SIVERSKIJ'	224
# 'ZHAVORONKI'	224
# 'MOROZOVA'	221
# 'SHEBEKINO'	218
# 'SOSNOGORSK'	216
# 'TSIBANOBALKA'	216
# 'VASILKOVO'	216
# 'KAMENSK URALSKIJ'	215
# 'KRIVODANOVKA'	215
# 'DUBROVKA'	214
# 'FORNOSOVO'	214
# 'NEZHNOVO'	214
# 'MIKHALKOVO'	213
# 'TALDOM'	213
# 'SUPONEVO'	207
# 'JOSHKAR OLA'	206
# 'EVPATORIJA'	205
# 'JABLONOVSKIJ'	204
# 'REPINO'	204
# 'SNEGIRI'	204
# 'TARUSA'	204
# 'MICHURINSKIJ'	203
# 'VNIISSOK'	203
# 'ELINO'	202
# 'LVOVSKIJ'	201
# 'MORINO'	201
# 'NIZHEGORODSKAJA'	201
# 'LENINA'	200
# 'LOGOVSKOE'	199
# 'CHEBARKUL'	197
# 'MOKSHINO'	197
# 'TOBOLSK'	196
# 'KIRPICHNOE'	195
# 'PAVLOVO'	194
# 'VOLODARSKOGO'	194
# 'KHOTKOVO'	192
# 'GUBKIN'	191
# 'MOLOKOVO'	191
# 'UKHTA'	191
# 'CHELVA'	190
# 'KONDROVO'	189
# 'TAJTSY'	188
# 'LENINSKIJ'	184
# 'RODNIKI'	184
# 'VYSOKAJA GORA'	183
# 'KARABANOVO'	182
# 'LUNEVO'	181
# 'JUROVKA'	179
# 'MOZHGA'	179
# 'TONSHALOVO'	179
# 'ALESHKOVO'	177
# 'BORISOVKA'	177
# 'ELIZAVETINSKOE'	176
# 'IVANGOROD'	176
# 'RADIOTSENTR'	176
# 'LOTOSHINO'	175
# 'NOVOCHERKASSK'	175
# 'JARTSEVO'	174
# 'KISLOVODSK'	174
# 'ANDREEVKA'	172
# 'BARVIKHA'	172
# 'POVAROVO'	172
# 'SOSNOVOBORSK'	172
# 'ARMAVIR'	171
# 'JAKHROMA'	170
# 'STERLITAMAK'	168
# 'KALININETS'	167
# 'KLIMOVO'	167
# 'KOSTINO'	167
# 'SUZDAL'	167
# 'ZELENYJ'	167
# 'POBEDA'	166
# 'BOROVSK'	164
# 'CHERKIZOVO'	164
# 'JANINO'	164
# 'SHAKHOVSKAJA'	164
# 'ZARAJSK'	164
# 'NOVOCHEBOKSARSK'	163
# 'RASKOVO'	163
# 'BELOUSOVO'	160
# 'VJAZMA'	158
# 'NOVOGORSK'	157
# 'KRYMSK'	156
# 'RADUZHNYJ'	156
# 'LENINSKOE'	155
# 'ZNAMENKA'	154
# 'GUS KHRUSTALNYJ'	153
# 'POCHEP'	153
# 'LIKINO DULEVO'	152
# 'MONINO'	152
# 'UZLOVAJA'	152
# 'BOLSHIE VJAZEMY'	151
# 'SELTSO'	151
# 'SHEKSNA'	151
# 'VOLKHOV'	151
# 'CHERNAJA GRJAZ'	148
# 'KRASNODARSKIJ'	147
# 'NOVOSELYE'	147
# 'AFIPSKIJ'	146
# 'KAMENKA'	146
# 'ABAKAN'	145
# 'ANAPSKAJA'	145
# 'EJSK'	145
# 'FEODOSIJA'	145
# 'LOSEVO'	144
# 'NOVAJA'	143
# 'ROMANOVKA'	143
# 'VOSKRESENSKOE'	143
# 'REVDA'	142
# 'SIM'	142
# 'VINOGRADOVO'	142
# 'NEKRASOVSKIJ'	141
# 'KOKHMA'	140
# 'TRUBCHEVSK'	140
# 'KHAPO OE'	139
# 'LOPUKHINKA'	139
# 'NAGORNYJ'	139
# 'DROZHZHINO'	138
# 'ZELENODOLSK'	138
# 'DERBENT'	137
# 'PEREMYSHL'	137
# 'SVETLYJ'	136
# 'ASHITKOVO'	135
# 'LESKOLOVO'	135
# 'NOVOURALSK'	134
# 'SEMILUKI'	134
# 'SHOLOKHOVO'	133
# 'SOSENKI'	133
# 'AZOV'	132
# 'KUNGUR'	132
# 'UST LABINSK'	132
# 'SHLISSELBURG'	130
# 'VNUKOVO'	130
# 'KALABINO'	129
# 'SEVERNYJ'	129
# 'SLANTSY'	129
# 'ULAN UDE'	129
# 'DOROKHOVO'	128
# 'KALUZHSKOE'	128
# 'KOVROV'	128
# 'PUSHCHINO'	128
# 'SOFRINO'	128
# 'JAROSLAVSKAJA'	127
# 'TROSHKOVO'	126
# 'MERKULYEVO'	125
# 'BAKHTA'	124
# 'KONDRATYEVO'	124
# 'SEVERODVINSK'	124
# 'SPASS'	124
# 'KRASNOARMEJSK'	123
# 'VOLOSOVO'	123
# 'ARSK'	122
# 'DAVYDOVO'	122
# 'KARPINSK'	122
# 'KASILOVO'	122
# 'NIZHNESORTYMSKIJ'	122
# 'LERMONTOV'	121
# 'SOFYINO'	121
# 'VJAZNIKI'	121
# 'LOSINO PETROVSKIJ'	120
# 'RJAZANOVSKOE'	120
# 'LENINGRADSKAJA'	119
# 'EMELJANOVO'	118
# 'ISTOK'	118
# 'MAKHACHKALA'	118
# 'DUBKI'	117
# 'NOVOALTAJSK'	117
# 'PRUDNOE'	117
# 'RAKHJA'	117
# 'SEVERKA'	117
# 'ZHDANOVSKIJ'	117
# 'LODEJNOE POLE'	116
# 'OSTROV'	116
# 'ROSSOSH'	116
# 'VERBILKI'	116
# 'PESOCHNYJ'	115
# 'GOLIKOVO'	114
# 'JUZHNO SAKHALINSK'	114
# 'KIMOVSK'	114
# 'KULTAEVO'	114
# 'PETROVSKOE'	114
# 'TREKHGORNYJ'	114
# 'VYSOKOVSK'	114
# 'BARSUKI'	113
# 'DEDENEVO'	113
# 'LJADY'	113
# 'TAKHTAMUKAJ'	113
# 'ZHUKOV'	113
# 'ALEKSIN'	111
# 'BLAGOVESHCHENKA'	111
# 'SREDNEURALSK'	111
# 'BELYJ JAR'	110
# 'KRASNYJ JAR'	110
# 'MEDVEZHYI OZERA'	110
# 'PIROGOVSKIJ'	110
# 'POLJANY'	110
# 'SOVETSKIJ'	110
# 'ZHELEZNOVODSK'	110
# 'DUBROVKI'	109
# 'JANTARNYJ'	109
# 'KINEL'	109
# 'MARFINO'	109
# 'NORILSK'	109
# 'SORTAVALA'	109
# 'SYZRAN'	109
# 'ERSHOVO'	108
# 'KAMYSHLOV'	108
# 'MALECHKINO'	108
# 'OGUDNEVO'	108
# 'SKHODNJA'	108
# 'STANOVOE'	108
# 'TUAPSE'	108
# 'VERBILOVO'	108
# 'JUZHNYJ'	107
# 'ZARECHNYJ'	107
# 'LEVASHOVO'	106
# 'BORSK'	105
# 'PJATNITSA'	104
# 'DZHUBGA'	103
# 'LYSKOVO'	103
# 'TARASOVKA'	103
# 'BULGAKOVO'	102
# 'PRIDOROZHNYJ'	102
# 'PROKOPYEVSK'	101
# 'ZAOKSKIJ'	101
# 'ACHINSK'	100
# 'ATEPTSEVO'	100
# 'IZMAJLOVO'	100
# 'UST KUT'	100
# 'FEDKINO'	99
# 'JASNOGORSK'	99
# 'RECHITSY'	99
# 'SJASSTROJ'	99
# 'USTJUZHNA'	99
# 'RYBNOE'	98
# 'DEGTJARSK'	97
# 'DREZNA'	96
# 'REDKINO'	96
# 'STARAJA'	96
# 'SVERDLOVA'	96
# 'ZONALNYJ'	96
# 'MEDYN'	95
# 'NOVYJ URENGOJ'	95
# 'SEBEZH'	95
# 'ALMETYEVSK'	94
# 'BEREZOVYJ'	93
# 'DJATKOVO'	93
# 'GURYEVSK'	93
# 'ASBEST'	92
# 'BUTOVO'	92
# 'DIMITROVSKIJ'	92
# 'STRINSKIJ'	92
# 'TOLMACHEVO'	92
# 'ALUSHTA'	91
# 'BOROVSKIJ'	91
# 'CHEREPICHNYJ'	91
# 'DIVNOGORSK'	91
# 'GORJACHIJ KLJUCH'	91
# 'LEBEDJAN'	91
# 'NATUKHAEVSKAJA'	91
# 'ZONALNAJA STANTSIJA'	91
# 'CHERNOGOLOVKA'	90
# 'SERGIEVSKIJ'	90
# 'CHESMA'	89
# 'KOLCHUGINO'	89
# 'ROPSHA'	89
# 'TIKHVIN'	89
# 'IM VOROVSKOGO'	88
# 'CHERNJAKHOVSK'	87
# 'PRAVDINSKIJ'	87
# 'DER NOVYE PSARKI'	86
# 'RAZUMNOE'	86
# 'SLOBODSKOJ'	86
# 'KUROVSKOE'	85
# 'VELJAMINOVO'	85
# 'BIJSK'	84
# 'IVANOVSKAJA'	84
# 'GORSHKOVO'	83
# 'NEKRASOVKA'	83
# 'VYSHESTEBLIEVSKAJA'	83
# 'MOSKOVSKAJA OBL'	82
# 'SYSERT'	82
# 'EMANZHELINSK'	81
# 'GOLITSINO'	81
# 'GORELOVO'	81
# 'PIROGOVO'	81
# 'RZHEV'	81
# 'ZHUKOVKA'	81
# 'ZVEREVO'	81
# 'ASHUKINO'	80
# 'DETCHINO'	80
# 'DINSKAJA'	80
# 'JASNAJA POLJANA'	80
# 'KOKOSHKINO'	80
# 'PODSTEPKI'	80
# 'BEREZOVKA'	79
# 'BIRSK'	79
# 'MGA'	79
# 'PIONERSKIJ'	79
# 'MIKHAJLOVKA'	78
# 'POROSHINO'	78
# 'KURLAKOVO'	77
# 'CHEMBURKA'	76
# 'AFANASOVO'	75
# 'DMITRIEVKA'	75
# 'PAVLOVSKAJA'	75
# 'POLAZNA'	75
# 'SVETOGORSK'	75
# 'VERKHNIJ BAKSAN'	75
# 'KALJAZIN'	74
# 'KUSAK'	74
# 'NOVOE'	74
# 'PRILADOZHSKIJ'	74
# 'ROZHDESTVENO'	74
# 'SOVKHOZNYJ'	74
# 'ZAPADNYJ'	74
# 'ZHELEZNYJ'	74
# 'BUGULMA'	73
# 'IVANOVKA'	73
# 'MINJAR'	73
# 'REDUTOVO'	73
# 'VEREJA'	73
# 'ELISTA'	72
# 'IKSHA'	72
# 'KOMAROVO'	72
# 'MIKHAJLOVSKAJA'	72
# 'PODPOROZHYE'	72
# 'ROGACHEVO'	72
# 'VERKHNJAJA MARA'	72
# 'LAZURNYJ'	71
# 'APUKHTINO'	70
# 'CHELOBITYEVO'	70
# 'EFREMOV'	70
# 'IM SVERDLOVA'	70
# 'MUKHINO'	70
# 'OSINOVO'	70
# 'SOKUR'	70
# 'STRUNINO'	70
# 'ZIMOVNIKI'	70
# 'BOLSHAJA IZHORA'	69
# 'LIPITSY'	69
# 'MININO'	69
# 'BELOKURIKHA'	68
# 'GIDROUZLA IM KUJBYSHEVA'	68
# 'GROMOVO'	68
# 'KANASH'	68
# 'ORLOVO'	68
# 'PODZ'	68
# 'ROSTOVKA'	68
# 'TEKSTILSHCHIK'	68
# 'ZJUZINO'	68
# 'AFONINO'	67
# 'BARYBINO'	67
# 'KURLOVO'	67
# 'MAGADAN'	67
# 'NOVOTITAROVSKAJA'	67
# 'PERVOMAJSKIJ'	67
# 'STARYJ GORODOK'	67
# 'SUPSEKH'	67
# 'TUTAEV'	67
# 'VAKHONINO'	67
# 'VARENIKOVSKAJA'	67
# 'VYLGORT'	67
# 'AVDON'	66
# 'GOSTAGAEVSKAJA'	65
# 'JUKHNOV'	65
# 'SHUM'	65
# 'BOLSHIE KOLPANY'	64
# 'CHERTOVITSY'	64
# 'GORNJATSKIJ'	64
# 'GOSTILITSY'	64
# 'BREKHOVO'	63
# 'NALCHIK'	63
# 'PUSHKINSKIJ'	63
# 'VALKI'	63
# 'VLADIMIRSKAJA OBL'	63
# 'BELYE BEREGA'	62
# 'CHANKO'	62
# 'DOLZHANSKAJA'	62
# 'NEKRASOVSKOE'	62
# 'NOVOSINKOVO'	62
# 'SAFONOVO'	62
# 'SHUJA'	62
# 'ZNAMJA OKTJABRJA'	62
# 'DANKOV'	61
# 'ELEKTROGORSK'	61
# 'KHORLOVO'	61
# 'MICHURINSKOE'	61
# 'MORJAKOVSKIJ ZATON'	61
# 'NOVOZAVIDOVSKIJ'	61
# 'PTICHNOE'	61
# 'VOROTYNSK'	61
# 'BOBROVO'	60
# 'CHALTYR'	60
# 'DIVNOMORSKOE'	60
# 'LEBJAZHIJ'	60
# 'LOBANOVO'	60
# 'LUKOJANOV'	60
# 'MARUSHKINO'	60
# 'MINUSINSK'	60
# 'NEVINNOMYSSK'	60
# 'NOJABRSK'	60
# 'PROKUDSKOE'	60
# 'SEREBRJANOE'	60
# 'STOLBISHCHE'	60
# 'CHITA'	59
# 'GRIVKI'	59
# 'KUJUMBA'	59
# 'RAZMETELEVO'	59
# 'KHVOROSTJANKA'	58
# 'KONDRATOVO'	58
# 'LISKI'	58
# 'SHEMELINKI'	58
# 'STROITEL'	58
# 'VALDAJ'	58
# 'AVSJUNINO'	57
# 'KURGAN'	57
# 'MALINO'	57
# 'RASTUNOVO'	57
# 'RUZAEVKA'	57
# 'SHARAPOVO'	57
# 'STOLBOVAJA'	57
# 'TOVARKOVO'	57
# 'ABRAU DJURSO'	56
# 'ANTIPINO'	56
# 'DESENOVSKOE'	56
# 'GOROKHOVETS'	56
# 'KOMSOMOLSKIJ'	56
# 'KORENOVSK'	56
# 'KRASNAJA POLJANA'	56
# 'KRASNOZATONSKIJ'	56
# 'LUKHOVKA'	56
# 'NIZHNEKAMSK'	56
# 'OBUKHOVO'	56
# 'OPOCHKA'	56
# 'PUGACHEV'	56
# 'BOLSHEVIK'	55
# 'FRJAZEVO'	55
# 'KABARDINKA'	55
# 'KURILOVO'	55
# 'MAGNITNYJ'	55
# 'ORDYNSKOE'	55
# 'PRIMORSK'	55
# 'VERESHCHAGINO'	55
# 'DROFINO'	54
# 'OPOLYE'	54
# 'RAMENSKIJ'	54
# 'RAMESHKI'	54
# 'SADOVYJ'	54
# 'VESHKI'	54
# 'ZUBTSOV'	54
# 'BELOJARSKIJ'	53
# 'JUKKI'	53
# 'KONDOPOGA'	53
# 'LAPINO'	53
# 'MENDELEEVO'	53
# 'NEFTEJUGANSK'	53
# 'NOVOGUROVSKIJ'	53
# 'PODOSINKI'	53
# 'POKROVKA'	53
# 'ROSSIJSKIJ'	53
# 'TRUBNIKOV BOR'	53
# 'BOLSHOJ ISTOK'	52
# 'CHULKOVO'	52
# 'FROLY'	52
# 'GORKI LENINSKIE'	52
# 'KOBRALOVO'	52
# 'PONTONNYJ'	52
# 'ROSTOVSKAJA OBL'	52
# 'SMAGINO'	52
# 'STARAJA RUZA'	52
# 'VYKSA'	52
# 'BELYJ'	51
# 'ELITA'	51
# 'GAVRILOVKA'	51
# 'JAM'	51
# 'KHANTY MANSIJSK'	51
# 'KOGALYM'	51
# 'KRATOVO'	51
# 'LIPKI'	51
# 'TUMBOTINO'	51
# 'UGRA'	51
# 'ADYGEJA'	50
# 'BLAGOVESHCHENSK'	50
# 'FEDOROVSKIJ'	50
# 'GAGARIN'	50
# 'KOSULINO'	50
# 'NERJUNGRI'	50
# 'NIKOLAEVKA'	50
# 'RAEVSKAJA'	50
# 'RJABOVO'	50
# 'SMYSHLJAEVKA'	50
# 'ULJANINO'	50
# 'VOLGOGRADSKAJA OBL'	50
# 'VORSINO'	50
# 'FRJANOVO'	49
# 'ILYINSKOE USOVO'	49
# 'KIRILLOVKA'	49
# 'KOLODINO'	49
# 'KRESTTSY'	49
# 'MISHUTINO'	49
# 'NEKLJUDOVO'	49
# 'ZELENOGRADSKIJ'	49
# 'CHITAEVO'	48
# 'KASHINO'	48
# 'KUSHCHEVSKAJA'	48
# 'PERESVET'	48
# 'RASSVET'	48
# 'SEMRINO'	48
# 'SHAKHTY'	48
# 'SLAVJANSK NA KUBANI'	48
# 'SMOLENSKAJA OBL'	48
# 'VOLGODONSK'	48
# 'BALAKOVO'	47
# 'BRJANSKAJA OBL'	47
# 'ELOVO'	47
# 'JUZHNOURALSK'	47
# 'KAGALNITSKAJA'	47
# 'KUZNECHIKHA'	47
# 'NOVAJA USMAN'	46
# 'RYLSK'	46
# 'SPAS KLEPIKI'	46
# 'SUKHANOVO'	46
# 'UCHKEKEN'	46
# 'VASILEVO'	46
# 'VATUTINKI'	46
# 'GORNYJ SHCHIT'	45
# 'GRACHEVKA'	45
# 'KIPEN'	45
# 'KOLOSISTYJ'	45
# 'KOLYVAN'	45
# 'MSTIKHINO'	45
# 'ORZHITSY'	45
# 'OSTASHEVO'	45
# 'PETRODVORETS'	45
# 'SOSNOVKA'	45
# 'TUNOSHNA'	45
# 'DOLGODEREVENSKOE'	44
# 'FEDOROVSKOE'	44
# 'GRIBANOVO'	44
# 'KHADYZHENSK'	44
# 'KRASNOKAMSK'	44
# 'LENINAVAN'	44
# 'LEVOKUMSKOE'	44
# 'MOSRENTGEN'	44
# 'NAGAEVO'	44
# 'NOVOZYBKOV'	44
# 'RODIONOVO NESVETAJSKAJA'	44
# 'SHARYPOVO'	44
# 'SHATURTORF'	44
# 'ARKHANGELSKOE'	43
# 'DOBRINKA'	43
# 'ENEM'	43
# 'GLUKHOVO'	43
# 'GOLUBITSKAJA'	43
# 'LISIJ NOS'	43
# 'MALAJA VISHERA'	43
# 'MALAKHOVO'	43
# 'MARUSINO'	43
# 'NEVJANSK'	43
# 'POKROVSKOE'	43
# 'ROMANTSEVO'	43
# 'RUSKEALA'	43
# 'UVAROVKA'	43
# 'VINNITSY'	43
# 'BIOKOMBINATA'	42
# 'CHERNOVO'	42
# 'NOVOMIKHAJLOVKA'	42
# 'PAVLOVSKOE'	42
# 'PLJUSSA'	42
# 'SADAKOVSKIJ'	42
# 'SOKURY'	42
# 'SUSANINO'	42
# 'VORONOVSKOE'	42
# 'VORSMA'	42
# 'ZAVOLZHYE'	42
# 'BOGANDINSKIJ'	41
# 'JAKOVLEVSKOE'	41
# 'KURSKAJA OBL'	41
# 'LESNAJA POLJANA'	41
# 'MALOE VEREVO'	41
# 'MOSTOVIK'	41
# 'MYSKHAKO'	41
# 'OLENINO'	41
# 'SARATOVSKIJ'	41
# 'DOBRUN'	40
# 'KRASNAJA PAKHRA'	40
# 'NOGINSKAJA'	40
# 'NOVOMINSKAJA'	40
# 'PODTYBOK'	40
# 'PUDOST'	40
# 'REKINTSO'	40
# 'ZARECHENSKIJ'	40
# 'KHRABROVO'	39
# 'KOTELNICH'	39
# 'LOGINOVO'	39
# 'MASLOVA PRISTAN'	39
# 'PRIBREZHNOE'	39
# 'SEREDA'	39
# 'SJASKELEVO'	39
# 'SJUKSJUM'	39
# 'STAROBZHEGOKAJ'	39
# 'VORONEZHSKAJA'	39
# 'DRUZHBA'	38
# 'GORODISHCHE'	38
# 'GRUZINO'	38
# 'IGLINO'	38
# 'KLINTSY'	38
# 'KUDINOVO'	38
# 'LIPETSKAJA OBL'	38
# 'OBOLENSK'	38
# 'SENNOJ'	38
# 'TROITSKOE'	38
# 'TROPAREVO'	38
# 'BARSOVO'	37
# 'BUREVESTNIK'	37
# 'CHAPAEVSK'	37
# 'DAGESTANSKIE OGNI'	37
# 'FILIPPOVSKOE'	37
# 'GORSKIJ'	37
# 'KAMENSKOE'	37
# 'KONSTANTINOVO'	37
# 'NESTEROVO'	37
# 'OSELKI'	37
# 'POROSINO'	37
# 'RADUMLJA'	37
# 'ROSHAL'	37
# 'SINJAVINO'	37
# 'VASKELOVO'	37
# 'VLASIKHA'	37
# 'VYRUBOVO'	37
# 'ZAGORJANSKIJ'	37
# 'ALEKSANDROVKA'	36
# 'BELOZERSK'	36
# 'BEREZNIKI'	36
# 'BOGORODSKOE'	36
# 'BOTOVO'	36
# 'ESSENTUKSKAJA'	36
# 'FOKINO'	36
# 'KARELIJA'	36
# 'KOZELSK'	36
# 'KRASNOSLOBODSK'	36
# 'KURSKAJA'	36
# 'LAISHEVO'	36
# 'MELNIKOVO'	36
# 'OREL IZUMRUD'	36
# 'OZHERELYE'	36
# 'PUSHKINSKIE GORY'	36
# 'RAKHMANOVO'	36
# 'UZHUR'	36
# 'A'	35
# 'AGROGORODOK'	35
# 'BABYNINO'	35
# 'DONSKOJ'	35
# 'IVANKOVO'	35
# 'KOMAROVKA'	35
# 'KONOBEEVO'	35
# 'KORNEVO'	35
# 'KUKUSHTAN'	35
# 'MEDNOGORSK'	35
# 'NOVOTROITSKOE'	35
# 'OLONETS'	35
# 'RESHETIKHA'	35
# 'SEMENOVSKOE'	35
# 'SLOBODA'	35
# 'SONINO'	35
# 'SPAS ZAULOK'	35
# 'VITIM'	35
# 'ZAPLAVNOE'	35
# 'BALAKHTA'	34
# 'BOGORODSK'	34
# 'CHERNOMORSKIJ'	34
# 'CHUPRJAKOVO'	34
# 'DEREVJANNOE'	34
# 'GRJAZOVETS'	34
# 'JAKIMOVSKOE'	34
# 'KOROBITSYNO'	34
# 'KOSTROVO'	34
# 'KRASNAJA GORKA'	34
# 'LJANTOR'	34
# 'MAJSKIJ'	34
# 'MALOE KARLINO'	34
# 'MARUSHKINSKOE'	34
# 'NOVOFEDOROVSKOE'	34
# 'PIONER'	34
# 'PLAVSK'	34
# 'POKROVSKOE E'	34
# 'POLUSHKINO'	34
# 'RODYKI'	34
# 'ROGOVSKOE'	34
# 'SUVOROV'	34
# 'TALITSY'	34
# 'VAGANOVO'	34
# 'ZUBOVO'	34
# 'ABINSK'	33
# 'ALUPKA'	33
# 'BOLSHOE ISAKOVO'	33
# 'GOREVO'	33
# 'GROZNYJ'	33
# 'IM TSJURUPY'	33
# 'KAMEN NA OBI'	33
# 'KANSK'	33
# 'KRASNOZNAMENSKIJ'	33
# 'LOPATINO'	33
# 'OBOLENSKOE'	33
# 'VARAKSINO'	33
# 'BORISOVO'	32
# 'BUDOGOSHCH'	32
# 'GUSEV'	32
# 'IRDOMATKA'	32
# 'KIROVO CHEPETSK'	32
# 'MAKSATIKHA'	32
# 'MYSHKIN'	32
# 'NEMTSEVO'	32
# 'NOVOE GRISHINO'	32
# 'RUSSKO VYSOTSKOE'	32
# 'SAKI'	32
# 'SUDAK'	32
# 'TAMAN'	32
# 'VYSHNIJ VOLOCHEK'	32
# 'ZAPOROZHSKOE'	32
# 'BOGDANOVICH'	31
# 'BUZHAROVO'	31
# 'GOLUBOE'	31
# 'GOLYGINO'	31
# 'ILYICH'	31
# 'INOZEMTSEVO'	31
# 'IVANOV BOR'	31
# 'IZMALKOVO'	31
# 'KOSTEREVO'	31
# 'KUJBYSHEVSKIJ'	31
# 'NADYM'	31
# 'NOVOMYSHASTOVSKAJA'	31
# 'ORSK'	31
# 'OSA'	31
# 'PYSHMA'	31
# 'RUBTSOVSK'	31
# 'SEGEZHA'	31
# 'SHILA'	31
# 'SOVKHOZA KREKSHINO'	31
# 'VARYPAEVO'	31
# 'VERKHNEBAKANSKIJ'	31
# 'VOZDVIZHENSKOE'	31
# 'VYSELKI'	31
# 'ZAVIDOVO'	31
# 'BUZULUK'	30
# 'CHEMSKOE'	30
# 'CHUDOVO'	30
# 'GLAZOVO'	30
# 'KASIMOV'	30
# 'LENINSK KUZNETSKIJ'	30
# 'MAKSIMOVKA'	30
# 'MOLDOVKA'	30
# 'NAZARYEVO'	30
# 'OKULOVKA'	30
# 'OZERNYJ'	30
# 'PLODOVOE'	30
# 'SHATSK'	30
# 'SLOBODKA'	30
# 'ARTEM'	29
# 'BILJARSK'	29
# 'BOGORODITSK'	29
# 'ELATMA'	29
# 'GEORGIEVSK'	29
# 'KOROTOVO'	29
# 'KROPOTKIN'	29
# 'MECHNIKOVA'	29
# 'NOVOSELKI'	29
# 'OKHOTNOE'	29
# 'PAMJATNOE'	29
# 'PAVLINO'	29
# 'PETROPAVLOVSK'	29
# 'PREDGORNYJ'	29
# 'TJUMENJAK'	29
# 'VOSKRESENKA'	29
# 'BALTIJSK'	28
# 'BEGUNITSY'	28
# 'BOLSHOE ALEKSEEVSKOE'	28
# 'JAGANOVO'	28
# 'KHLEVNOE'	28
# 'KRASNYJ KHOLM'	28
# 'KUCHINO'	28
# 'LERMONTOVO'	28
# 'MARTOVKA'	28
# 'MOCHISHCHE'	28
# 'OZERETSKOE'	28
# 'OZERSK'	28
# 'PAVLOVSKAJA SLOBODA'	28
# 'SUDA'	28
# 'TABUNY'	28
# 'TOPKANOVO'	28
# 'TUGOLESSKIJ BOR'	28
# 'VASJURINSKAJA'	28
# 'ABATSKOE'	27
# 'BELEBEJ'	27
# 'BORINSKOE'	27
# 'BORISOGLEBSK'	27
# 'DONINO'	27
# 'FILINSKOE'	27
# 'IM LENINA'	27
# 'KALACH'	27
# 'KHOMUTOVO'	27
# 'KIRPICHNYJ ZAVOD'	27
# 'KRASNOZNAMENKA'	27
# 'KUCHUGURY'	27
# 'LESOSIBIRSK'	27
# 'MATUR'	27
# 'MEDVEZHYEGORSK'	27
# 'MORSHANSK'	27
# 'PLES'	27
# 'PRIMORSKIJ'	27
# 'RAMON'	27
# 'REMMASH'	27
# 'REVJAKINO'	27
# 'TSIMLJANSK'	27
# 'USPENSKOE'	27
# 'VESELOE'	27
# 'ARZAMAS'	26
# 'AZOVO'	26
# 'BRATSK'	26
# 'BUNKOVO'	26
# 'CHASTSY'	26
# 'DIMITROVGRAD'	26
# 'KALACHINSK'	26
# 'KALUZHSKAJA'	26
# 'KULIKOVO'	26
# 'MARKOVA'	26
# 'MINSKOE'	26
# 'MOKINO'	26
# 'MOLODEZHNOE'	26
# 'PRIBREZHNYJ'	26
# 'PRIVETNINSKOE'	26
# 'SHULMA'	26
# 'VOLOVO'	26
# 'VORONOVO'	26
# 'VOROVSKOGO'	26
# 'VURNARY'	26
# 'ZELENETS'	26
# 'ZHOSTOVO'	26
# 'ZNAMENSK'	26
# 'AGRYZ'	25
# 'BELOOMUT'	25
# 'BRJUKHOVETSKAJA'	25
# 'CHERNUSHKA'	25
# 'CHESNOKOVKA'	25
# 'FERZIKOVO'	25
# 'GORNO ALTAJSK'	25
# 'KAMENSK SHAKHTINSKIJ'	25
# 'KOKTEBEL'	25
# 'LVOVSKOE'	25
# 'MICHURINSK'	25
# 'OREDEZH'	25
# 'PECHORY'	25
# 'PORKHOV'	25
# 'PUSTOSHKA'	25
# 'ROSLAVL'	25
# 'VAZHINY'	25
# 'VERKHNEE MJACHKOVO'	25
# 'ZADONSK'	25
# 'ZHILINO'	25
# 'AKBERDINO'	24
# 'BAJKALSK'	24
# 'BELGORODSKAJA OBL'	24
# 'DIVEEVO'	24
# 'DOROZHNYJ'	24
# 'DUBININO'	24
# 'DZERZHINSK'	24
# 'FROLOVO'	24
# 'ISAKOVO'	24
# 'KARINSKOE'	24
# 'KOMINTERN'	24
# 'LENSOVETOVSKIJ'	24
# 'MINERALNYE VODY'	24
# 'NEBUG'	24
# 'NELIDOVO'	24
# 'NOVOLISINO'	24
# 'OLEKMINSK'	24
# 'OMSKAJA OBL'	24
# 'PIKALEVO'	24
# 'PSKOVSKAJA OBL'	24
# 'SEMIBRATOVO'	24
# 'SEVERSKAJA'	24
# 'SYCHEVO'	24
# 'TAVROVO'	24
# 'TJULJACHI'	24
# 'VERKHNIJ USLON'	24
# 'VOSTOK'	24
# 'ZHITNEVO'	24
# 'BALAKHNA'	23
# 'BELSKIJ'	23
# 'BUDENNOVSK'	23
# 'DRUZHNAJA GORKA'	23
# 'GORKA'	23
# 'KORJAZHMA'	23
# 'KRJAZHLY'	23
# 'KUZNETSOVO'	23
# 'LINEVSKOE'	23
# 'MIKHAJLOVSK'	23
# 'MJACHKOVO'	23
# 'NOVONIKOLAEVSK'	23
# 'NOVYJ'	23
# 'PANINO'	23
# 'ROZHDESTVENNO'	23
# 'RYBACHIJ'	23
# 'SALSK'	23
# 'SHABROVSKIJ'	23
# 'SHCHAPOVO'	23
# 'STARAJA SLOBODA'	23
# 'STAROKORSUNSKAJA'	23
# 'SVERDLOVO'	23
# 'TRUDOBELIKOVSKIJ'	23
# 'VALAVA'	23
# 'BOLOKHOVO'	22
# 'BRUSJANSKIJ'	22
# 'DEFANOVKA'	22
# 'DESNA'	22
# 'GIAGINSKAJA'	22
# 'GLAZHEVO'	22
# 'GOLOVCHINO'	22
# 'KAMENKI'	22
# 'KARABASH'	22
# 'KHOLSHCHEVIKI'	22
# 'KINDER'	22
# 'KIRSANOV'	22
# 'KOTELNIKOV'	22
# 'MAMADYSH'	22
# 'MAMONTOVO'	22
# 'MEKHZAVOD'	22
# 'MIRNYJ'	22
# 'PUDOMJAGI'	22
# 'TURGOJAK'	22
# 'USHAKI'	22
# 'VILGA'	22
# 'ABAKANOVO'	21
# 'ANISHINO'	21
# 'BELYJ RAST'	21
# 'BEZHETSK'	21
# 'DENKOVO'	21
# 'DMITRIEVO'	21
# 'GLEBYCHEVO'	21
# 'GLUSHKOVO'	21
# 'GORBUNKI'	21
# 'KOREIZ'	21
# 'KOVYLKINO'	21
# 'KRASNAJA'	21
# 'LAKHDENPOKHJA'	21
# 'MESHCHERINO'	21
# 'NAVASHINO'	21
# 'NIKULINO'	21
# 'OSMINO'	21
# 'PIROCHI'	21
# 'PLESHCHEEVO'	21
# 'RAZDOLYE'	21
# 'SAPERNYJ'	21
# 'SERDOBSK'	21
# 'SIMEIZ'	21
# 'TATARINOVO'	21
# 'TATARSTAN'	21
# 'APSHERONSK'	20
# 'AROVO'	20
# 'ATJASHEVO'	20
# 'BALAKIREVO'	20
# 'BOROVICHI'	20
# 'CHEREMUSHKINO'	20
# 'DJADKOVO'	20
# 'IVNJAKI'	20
# 'KIEVSKIJ'	20
# 'KIRILLOV'	20
# 'KLENOVO'	20
# 'KUMERTAU'	20
# 'LENINO'	20
# 'LJUBAN'	20
# 'NEVEL'	20
# 'NOVOUKRAINSKIJ'	20
# 'SAJANOGORSK'	20
# 'SILIKAT'	20
# 'SKOPIN'	20
# 'VERKHOVYE'	20
# 'VINOGRADNYJ'	20
# 'ZHURAVLEVO'	20
# 'ADZHEROM'	19
# 'ALKINO'	19
# 'BELAVKA'	19
# 'BULATNIKOVSKOE'	19
# 'DALNEE KONSTANTINOVO'	19
# 'DESNOGORSK'	19
# 'EGORYEVSKOE'	19
# 'GONCHAROVO'	19
# 'GOROKHOVO'	19
# 'IVANOV'	19
# 'IVANOVSKOE'	19
# 'JUSHKOVO'	19
# 'KADUJ'	19
# 'KAJALSKIJ'	19
# 'KOCHKUROVO'	19
# 'KORTKEROS'	19
# 'KORZHEVSKIJ'	19
# 'KRUTINKA'	19
# 'LOZHKI'	19
# 'NOVYJ SVET'	19
# 'OBRAZTSOVYJ'	19
# 'OSTASHKOV'	19
# 'POSHEKHONYE'	19
# 'RAZBEGAEVO'	19
# 'SHEPELEVO'	19
# 'STARAJA RUSSA'	19
# 'TALPAKI'	19
# 'TUGULYM'	19
# 'UCHALY'	19
# 'ULT JAGUN'	19
# 'VACHA'	19
# 'VLADIMIROVKA'	19
# 'ZHUKOVO'	19
# 'AGAPOVKA'	18
# 'BEKASOVO'	18
# 'BOLSHAJA KACHKA'	18
# 'CHEREPANOVO'	18
# 'CHERKESSK'	18
# 'DANILOVKA'	18
# 'KALININSKAJA'	18
# 'KARASUK'	18
# 'KOTELSKIJ'	18
# 'KRASNAJA GORA'	18
# 'KRASNOVIDOVO'	18
# 'KUZNETSK'	18
# 'LAVROVSK'	18
# 'MALOARKHANGELSK'	18
# 'MALYSHEVO'	18
# 'MOLODEZHNYJ'	18
# 'MURAVLENKO'	18
# 'NOVOE DOMOZEROVO'	18
# 'NOVOVELICHKOVSKAJA'	18
# 'NOVYJ OSKOL'	18
# 'ORLOVKA'	18
# 'OSTANKINO'	18
# 'OTRADNYJ'	18
# 'PETROVSKAJA'	18
# 'PODDUBYE'	18
# 'SALAVAT'	18
# 'SEVERO ENISEJSKIJ'	18
# 'SOSNY'	18
# 'SSELKI'	18
# 'SUDZHA'	18
# 'SVKH ARKHANGELSKIJ'	18
# 'TORZHOK'	18
# 'ZASECHNOE'	18
# 'ZVIZZHI'	18
# 'AEROPORT'	17
# 'ALEJSK'	17
# 'ARKHIPO OSIPOVKA'	17
# 'BARYSHEVO'	17
# 'CHISHMY'	17
# 'DEREVJANKA'	17
# 'DONSKOE'	17
# 'EPIFAN'	17
# 'GAJ'	17
# 'GORNYJ'	17
# 'IOGACH'	17
# 'JAKIMANSKAJA SLOBODA'	17
# 'JAROSLAVSKOE'	17
# 'KAZACHJA SLOBODA'	17
# 'KOZLOVO'	17
# 'MATJUSHKINO'	17
# 'MISAJLOVO'	17
# 'MOSEEVO'	17
# 'NIZHNEBAKANSKAJA'	17
# 'NOVOVORONEZH'	17
# 'PLOSHCHEVO'	17
# 'PYSHLITSY'	17
# 'SANATORIJA JANGANTAU'	17
# 'SHUKHOBOD'	17
# 'SOKOL'	17
# 'TALASHKINO'	17
# 'VOSTOCHNYJ'	17
# 'ZAPADNAJA DVINA'	17
# 'ZAVOLZHSK'	17
# 'ZHUCHKI'	17
# 'ZONOVO'	17
# 'ALEKSANDROVSK'	16
# 'BAZARNYE MATAKI'	16
# 'BELOGORSK'	16
# 'BELYE STOLBY'	16
# 'BEREZINO'	16
# 'EZDOCHNOE'	16
# 'IDRITSA'	16
# 'KAMENNOGORSK'	16
# 'KAMYSHIN'	16
# 'KRASNYJ SULIN'	16
# 'KULIKOVSKIJ'	16
# 'KUROVSKOJ'	16
# 'LESNOE'	16
# 'LOZA'	16
# 'MAJMA'	16
# 'MALEEVKA'	16
# 'MARJANOVKA'	16
# 'MOKVA JA'	16
# 'NOVOTROITSK'	16
# 'OSINOVAJA RECHKA'	16
# 'OVECHKINO'	16
# 'PASHA'	16
# 'PASHINO'	16
# 'PESKI'	16
# 'PETRA DUBRAVA'	16
# 'PLOTNIKOVO'	16
# 'PROMYSHLENNOVSKIJ'	16
# 'SELISHCHE'	16
# 'SHATKI'	16
# 'SLAVGOROD'	16
# 'SUDOGDA'	16
# 'VELIKOVO'	16
# 'VERKH NEJVINSKIJ'	16
# 'VOJSKOVITSY'	16
# 'VOLOGODSKAJA OBL'	16
# 'VYSOKINICHI'	16
# 'ZNAMENSKIJ'	16
# 'ARTI'	15
# 'ASHA'	15
# 'AVDOTYINO'	15
# 'BOKOVSKAJA'	15
# 'BOLSHOE KOZINO'	15
# 'CHISMENA'	15
# 'GORODOK'	15
# 'GURZUF'	15
# 'ILYINKA'	15
# 'JURLA'	15
# 'KHOKTA'	15
# 'KIKERINO'	15
# 'KOTOVKA'	15
# 'KRASNAJA DOLINA'	15
# 'KURUMOCH'	15
# 'LUKASHI'	15
# 'MANKOVO'	15
# 'MELIORATIVNYJ'	15
# 'MOLODOVSK'	15
# 'NOVOIVANOVSKIJ'	15
# 'NOVOSEMEJKINO'	15
# 'NOVOSIBIRSKOE'	15
# 'ODINTSOVSKAJA'	15
# 'OMCHAK'	15
# 'PERESYP'	15
# 'PLASTUNOVSKAJA'	15
# 'PLATNIROVSKAJA'	15
# 'PODBOROVYE'	15
# 'RAZDORY'	15
# 'ROGOVO'	15
# 'SERGACH'	15
# 'SHELTOZERO'	15
# 'SHIMSK'	15
# 'SHPANKOVO'	15
# 'SMOLENSKAJA'	15
# 'STEKLJANNYJ'	15
# 'TJUBUK'	15
# 'TLJUSTENKHABL'	15
# 'VASILYEVSKOE'	15
# 'VERKHNERUSSKOE'	15
# 'VINZILI'	15
# 'VYTEGRA'	15
# 'ZELENOBORSK'	15
# 'ABDULINO'	14
# 'ALAPAEVSK'	14
# 'ATJURYEVO'	14
# 'BELOZERKI'	14
# 'BOLGAR'	14
# 'BOLSHIE SHATNOVICHI'	14
# 'BOLSHOJ BEJSUG'	14
# 'CHUSOVOJ'	14
# 'DALNIJ'	14
# 'DE KASTRI'	14
# 'DONETSK'	14
# 'DUDKINO'	14
# 'ELYKAEVO'	14
# 'GANINO'	14
# 'GRAKHOVO'	14
# 'INNOPOLIS'	14
# 'KANEVSKAJA'	14
# 'KOLI'	14
# 'KOLJUBAKINO'	14
# 'KON KOLODEZ'	14
# 'KOSTOMUKSHA'	14
# 'KRASNOUFIMSK'	14
# 'KRIVANDINO'	14
# 'KYZYL'	14
# 'LAZO'	14
# 'MELNITSA'	14
# 'NOVODROZHZHINO'	14
# 'OBOJAN'	14
# 'OCHER'	14
# 'OSENEVO'	14
# 'PIZHMA'	14
# 'SAMARSKAJA OBL'	14
# 'SBORNYJ'	14
# 'SEMENOV'	14
# 'SHUMASH'	14
# 'SOKOLNIKOVO'	14
# 'TIMOFEEVKA'	14
# 'UTORGOSH'	14
# 'VOLZHSK'	14
# 'VOSKRESENSKIJ'	14
# 'ZELENOKUMSK'	14
# 'ZENDIKOVO'	14
# 'ZHIGULEVSK'	14
# 'ADAGUM'	13
# 'ANNA'	13
# 'ANOPINO'	13
# 'ANTSIFEROVO'	13
# 'BASKOVSKOE'	13
# 'BOLOTNOE'	13
# 'BORISOGLEBSKIJ'	13
# 'BREJTOVO'	13
# 'CHEGEM'	13
# 'CHERUSTI'	13
# 'DUBRAVNYJ'	13
# 'DULINO'	13
# 'DZHIDA'	13
# 'ELOVKA'	13
# 'FEDOROVKA'	13
# 'FRUKTOVAJA'	13
# 'GORELKI'	13
# 'GORODISHCHI'	13
# 'INDUSTRIALNYJ'	13
# 'INKERMAN'	13
# 'ISTOMINO'	13
# 'KHATUN'	13
# 'KONSTANTINOVKA'	13
# 'KREMENKI'	13
# 'KRESTY'	13
# 'KROMY'	13
# 'KURCHATOV'	13
# 'LYKOVO'	13
# 'MANZHEROK'	13
# 'MATMASY'	13
# 'MEDVEDKOVO'	13
# 'MIKHAJLOVSKOE'	13
# 'MIKHNOVKA'	13
# 'MJATLEVO'	13
# 'MURMASHI'	13
# 'NARYSHKINO'	13
# 'NEBOLCHI'	13
# 'NOVGORODSKAJA OBL'	13
# 'NOVOSMOLINSKIJ'	13
# 'NURLINO'	13
# 'OVSJANKA'	13
# 'PALEKH'	13
# 'PATRUSHI'	13
# 'PORECHYE'	13
# 'PREOBRAZHENKA'	13
# 'RAZVILKA'	13
# 'REZVAN'	13
# 'SAVVINO'	13
# 'SHUBINO'	13
# 'SOLNECHNOE'	13
# 'STARITSA'	13
# 'STAROTITAROVSKAJA'	13
# 'SUZEMKA'	13
# 'SVETLOE'	13
# 'UMET'	13
# 'URZHUM'	13
# 'USOVO TUPIK'	13
# 'VENEV'	13
# 'VIRGA'	13
# 'VOROTYNETS'	13
# 'ZELENOVKA'	13
# 'ALATYR'	12
# 'BELKINO'	12
# 'BELORECHENSK'	12
# 'BOLOGOE'	12
# 'CHAMZINKA'	12
# 'CHEREMKHOVO'	12
# 'CHIK'	12
# 'CHISTOPOL'	12
# 'DOLGIJ MOST'	12
# 'DUBROVSKIJ'	12
# 'DUMINICHI'	12
# 'DVURECHENSK'	12
# 'ELDIGINO'	12
# 'ELEKTROIZOLJATOR'	12
# 'ELIZAVETINO'	12
# 'ETKUL'	12
# 'GIDROTORF'	12
# 'JAROSLAVSKAJA OBL'	12
# 'JASNOGORSKIJ'	12
# 'KAGALNIK'	12
# 'KISELNJA'	12
# 'KULESHOVKA'	12
# 'KYSHTYM'	12
# 'LJASKELJA'	12
# 'LUZHKI'	12
# 'MARKS'	12
# 'MOKHOVO'	12
# 'MUKHANOVO'	12
# 'NIZHNJAJA TURA'	12
# 'NOVOROSSIJSKOE'	12
# 'OKTJABRSKOE'	12
# 'PAVLOVKA'	12
# 'PELEDUJ'	12
# 'PODREZKOVO'	12
# 'PRIJUTOVO'	12
# 'RUDNJA'	12
# 'SALEKHARD'	12
# 'SAROV'	12
# 'SELIVERSTOVO'	12
# 'SHARJA'	12
# 'SHCHELKINO'	12
# 'SJAMZHA'	12
# 'SKOROPUSKOVSKIJ'	12
# 'SLIZNEVO'	12
# 'STAROMINSKAJA'	12
# 'SUVOROVO'	12
# 'SVOBODA'	12
# 'TERNOVOJ'	12
# 'TOROPETS'	12
# 'UNECHA'	12
# 'VALY'	12
# 'VOZZHAEVKA'	12
# 'VYSOTSK'	12
# 'ZAPOLYE'	12
# 'ZARJA'	12
# 'ALABUSHEVO'	11
# 'APATITY'	11
# 'BEREZNJAKI'	11
# 'CHERNIKOV'	11
# 'DNO'	11
# 'DVORIKI'	11
# 'KARAVAEVO'	11
# 'KHVALYNSK'	11
# 'KNJAZHE'	11
# 'KRASKI'	11
# 'KRASNOPAKHORSKOE'	11
# 'KRASNOZAVODSK'	11
# 'KUTUKOVO'	11
# 'LEZHNEVO'	11
# 'MANIKHINO'	11
# 'MARTJUSH'	11
# 'MIKHAJLOV'	11
# 'NOVORZHEV'	11
# 'NOVOSELOVO'	11
# 'NOVOSPASSKOE'	11
# 'NOVOVOLKOVSKIJ'	11
# 'NURMA'	11
# 'ODOEV'	11
# 'PASHKOVSKIJ'	11
# 'PIZHANKA'	11
# 'PLESHKI'	11
# 'PODOLINO'	11
# 'POSAD'	11
# 'PRIMORSKO AKHTARSK'	11
# 'PRJAZHA'	11
# 'PUSHNOJ'	11
# 'RASSHEVATSKAJA'	11
# 'SELKHOZTEKHNIKA'	11
# 'SEREBRJANYE PRUDY'	11
# 'SHEPSI'	11
# 'SINKOVO'	11
# 'SPAS DEMENSK'	11
# 'TJARLEVO'	11
# 'TSIVILSK'	11
# 'UST ILIMSK'	11
# 'UST KINELSKIJ'	11
# 'VENGEROVO'	11
# 'VERKH TULA'	11
# 'VERKHOSHIZHEMYE'	11
# 'VICHUGA'	11
# 'VOLGINSKIJ'	11
# 'VOLOCHAEVKA'	11
# 'ZABRODY'	11
# 'ZOLOTILOVO'	11
# 'ALEKSANDRIJSKIJ'	10
# 'BALASHOV'	10
# 'BARAKI'	10
# 'BARANOVSKOE'	10
# 'BELOVO'	10
# 'BURMAKINO'	10
# 'CHAPLYGIN'	10
# 'CHERNAJA'	10
# 'CHKALOVSK'	10
# 'DUBOVETS'	10
# 'ERZOVKA'	10
# 'FERMA'	10
# 'GAJ KODZOR'	10
# 'GLAZUNOVKA'	10
# 'IGRIM'	10
# 'JAMM'	10
# 'JAROVOE'	10
# 'KAMENNOMOSTSKIJ'	10
# 'KASHIN'	10
# 'KHOTEICHI'	10
# 'KOMARICHI'	10
# 'KOROBCHEEVO'	10
# 'KREKSHINO'	10
# 'KRIVSKOE'	10
# 'KUKMOR'	10
# 'KULEBAKI'	10
# 'KUZNETSY'	10
# 'LAZAREVSKIJ'	10
# 'LENTYEVO'	10
# 'MALOBRUSJANSKOE'	10
# 'MARJANSKAJA'	10
# 'MOSTOVAJA'	10
# 'MOSTOVKA'	10
# 'MUEZERSKIJ'	10
# 'NEFTEKAMSK'	10
# 'NENASHEVO'	10
# 'NOVAJA LADOGA'	10
# 'NOVO'	10
# 'NOVOALEKSANDROVO'	10
# 'NOVOSHAKHTINSK'	10
# 'NOVOVOLKOVO'	10
# 'OKTJABRSKAJA'	10
# 'OPOLZNEVOE'	10
# 'ORUDYEVO'	10
# 'PAZHGA'	10
# 'PESCHANOKOPSKOE'	10
# 'PESTJAKI'	10
# 'PITKJARANTA'	10
# 'PODKUMOK'	10
# 'PRIVOLZHSK'	10
# 'PRIVOLZHYE'	10
# 'PUDOZH'	10
# 'RJAZHSK'	10
# 'ROMODANOVO'	10
# 'SAPRONOVO'	10
# 'SELIKHOVO'	10
# 'SEMIKARAKORSK'	10
# 'SHCHELKUN'	10
# 'SHUMIKHA'	10
# 'STEPANSHCHINO'	10
# 'SUKHODOL'	10
# 'SUKKO'	10
# 'SUROVATIKHA'	10
# 'TERJAEVO'	10
# 'TROSNA'	10
# 'UPORNYJ'	10
# 'VARVARINO'	10
# 'VELIKIJ USTJUG'	10
# 'VELIZH'	10
# 'VERKHNIJ DVOR'	10
# 'VORONEZHSKAJA OBL'	10
# 'ZAPRUDNJA'	10
# 'ZVJAGINO'	10
# 'AKHTYRSKIJ'	9
# 'ANASTASIEVSKAJA'	9
# 'ARISTOVO'	9
# 'BAKHCHISARAJ'	9
# 'BARANTSEVO'	9
# 'BELORETSK'	9
# 'BEREZA'	9
# 'BEZENCHUK'	9
# 'BORISOGLEBSKOE'	9
# 'BOROVKOVO'	9
# 'BUGROVOE'	9
# 'BUGURUSLAN'	9
# 'CHAJKOVSKIJ'	9
# 'CHEKON'	9
# 'CHEMAL'	9
# 'CHIRIKOVO'	9
# 'DJURTJULI'	9
# 'DOROBINO'	9
# 'DUBNEVO'	9
# 'DUBOVKA'	9
# 'DUKHOVSHCHINA'	9
# 'ELTON'	9
# 'ENERGETIK'	9
# 'GLAZOV'	9
# 'GORY'	9
# 'GUMRAK'	9
# 'GURYEVO'	9
# 'IM LVA TOLSTOGO'	9
# 'JURTSOVO'	9
# 'KABANOVO'	9
# 'KLJAZMA'	9
# 'KOBJAKOVO'	9
# 'KOLCHANOVO'	9
# 'KOSAJA GORA'	9
# 'KOSHEKHABL'	9
# 'KOTELNIKOVO'	9
# 'KURGANINSK'	9
# 'KURTAMYSH'	9
# 'KUZNECHNOE'	9
# 'LETNIJ OTDYKH'	9
# 'LIPNA'	9
# 'LISTVJANKA'	9
# 'LUZINO'	9
# 'LYSYE GORY'	9
# 'MAGO'	9
# 'MATKASELKJA'	9
# 'MEDVEDOVSKAJA'	9
# 'MOLODTSOVO'	9
# 'MULINO'	9
# 'NAVOLOKI'	9
# 'NEFTEGORSK'	9
# 'NEVERKINO'	9
# 'NIZHNEUDINSK'	9
# 'OBJACHEVO'	9
# 'OLGINSKAJA'	9
# 'OREVO'	9
# 'POJKOVSKIJ'	9
# 'POLTAVSKIJ'	9
# 'POMARY'	9
# 'RJAZANOVSKIJ'	9
# 'SAFAKULEVO'	9
# 'SALMI'	9
# 'SELIZHAROVO'	9
# 'SEROVO'	9
# 'SHCHELKANOVO'	9
# 'SHUJSKAJA'	9
# 'SHUMERLJA'	9
# 'SOLNECHNODOLSK'	9
# 'SOSNOVSKOE'	9
# 'SPASSK RJAZANSKIJ'	9
# 'SUZANOVO'	9
# 'TJAMSHA'	9
# 'VZMORYE'	9
# 'ZALUKOKOAZHE'	9
# 'ZAMOSTYE'	9
# 'ZEMTSY'	9
# 'ZHILETOVO'	9
# 'AGRONOM'	8
# 'ANOKHINO'	8
# 'ATEMAR'	8
# 'BARABANOVO'	8
# 'BETLITSA'	8
# 'BOLSHAJA BREMBOLA'	8
# 'BOLSHOE POLPINO'	8
# 'CHERNOE'	8
# 'DOLGORUKOVO'	8
# 'ELNIKI'	8
# 'GDOV'	8
# 'IM TELMANA'	8
# 'IZBORSK'	8
# 'JAKUTSK'	8
# 'JUGO KAMSKIJ'	8
# 'KALININSK'	8
# 'KARACHEV'	8
# 'KHOMJAKOVO'	8
# 'KLJUCHI'	8
# 'KRASNYE BAKI'	8
# 'KUMENY'	8
# 'KUSINO'	8
# 'LOKNJA'	8
# 'MAKURINO'	8
# 'MASLOVSKIJ'	8
# 'MATOKSA'	8
# 'MELEUZ'	8
# 'MESHCHERSKOE'	8
# 'MEZENSKOE'	8
# 'MIR'	8
# 'MORDVES'	8
# 'MOSHKOVO'	8
# 'MOSTOVSKIJ'	8
# 'MSHINSKAJA'	8
# 'NADVOITSY'	8
# 'NARJAN MAR'	8
# 'NATALYINO'	8
# 'NEVSKOE'	8
# 'NIKOLO RAMENYE'	8
# 'NOVOKHOPERSK'	8
# 'NOVYJ SNOPOK'	8
# 'ORICHI'	8
# 'PERELESKI'	8
# 'PEREVALOVO'	8
# 'PETROVKA'	8
# 'PETROVO'	8
# 'PODBEREZYE'	8
# 'POLEVSKOJ'	8
# 'PROLETARIJ'	8
# 'PUTJATINO'	8
# 'RASSKAZOVO'	8
# 'RETJUN'	8
# 'RJAZANOVO'	8
# 'RJAZANTSEVO'	8
# 'RUBEZHNOE'	8
# 'RUSJATINO'	8
# 'RYLEEVO'	8
# 'RZHAKSA'	8
# 'SANATORIJA IM CHEKHOVA'	8
# 'SAPOZHOK'	8
# 'SHEREGESH'	8
# 'SHILDA'	8
# 'SHISHKIN LES'	8
# 'SOKOLNIKI'	8
# 'STAROVELICHKOVSKAJA'	8
# 'STEPANOVSKOE'	8
# 'SUVOROV CHERKESSKIJ'	8
# 'SUVOROVSKAJA'	8
# 'TABORY'	8
# 'TERBUNY'	8
# 'TEREK'	8
# 'TERSKOL'	8
# 'TIMINO'	8
# 'TOPKI'	8
# 'TURAN'	8
# 'VERKH CHEBULA'	8
# 'VESELOVKA'	8
# 'VOLCHENKI'	8
# 'VOSTRJAKOVO'	8
# 'VYEZDNOE'	8
# 'VYSOKINSKIJ'	8
# 'ZORKALTSEVO'	8
# 'ZYKOVO'	8
# 'ABRAMTSEVO'	7
# 'AEROPORT KRASNOJARSK'	7
# 'AGOJ'	7
# 'ALEKSANDRO NEVSKIJ'	7
# 'AVAZBAKEEVA'	7
# 'BAGAEVSKAJA'	7
# 'BEKAN'	7
# 'BELOMESTNOE'	7
# 'BERSENEVKA'	7
# 'BESEDINO'	7
# 'BIOFABRIKA'	7
# 'BODAJBO'	7
# 'BOLSHOE'	7
# 'BORSHCHEVKA'	7
# 'BUJNAKSK'	7
# 'BULANOVO'	7
# 'CHALNA'	7
# 'CHERN'	7
# 'CHERNOVSKOE'	7
# 'DAVLEKANOVO'	7
# 'DOBRJANKA'	7
# 'DZHIGINKA'	7
# 'ELTSY'	7
# 'ENISEJSK'	7
# 'ERTIL'	7
# 'ESAULOVO'	7
# 'FURMANOV'	7
# 'INZHAVINO'	7
# 'IZOBILNYJ'	7
# 'JALGELEVO'	7
# 'KALTASY'	7
# 'KAMYSHEVAKHA'	7
# 'KANDALAKSHA'	7
# 'KARPOVO'	7
# 'KARTALY'	7
# 'KASPIJSK'	7
# 'KINESHMA'	7
# 'KOLOKSHA'	7
# 'KOLOMNO'	7
# 'KONCHEZERO'	7
# 'KOROLIKHA'	7
# 'KOTOVO'	7
# 'KOTOVSK'	7
# 'KOZHINO'	7
# 'KOZLOVSKIJ'	7
# 'KRASNAJA GLINKA'	7
# 'KRUTOVO'	7
# 'KURGANOVO'	7
# 'LEBJAZHYE'	7
# 'LIKHOSLAVL'	7
# 'LUCHINSKOE'	7
# 'LYSVA'	7
# 'MILJUTINSKAJA'	7
# 'MOSALSK'	7
# 'NAGORNOE'	7
# 'NIKOLO PAVLOVSKOE'	7
# 'NOVAJA LJADA'	7
# 'NOVOBEREZOVSKIJ'	7
# 'NOVOLUGOVOE'	7
# 'NOVOMICHURINSK'	7
# 'NOVOOMSKIJ'	7
# 'NYTVA'	7
# 'OSOKINO'	7
# 'PEREVOZ'	7
# 'PESOCHNOE'	7
# 'PESTOVO'	7
# 'PISKOVICHI'	7
# 'POKHVISTNEVO'	7
# 'PRIGORODNYJ'	7
# 'PROKHLADNYJ'	7
# 'SANKI'	7
# 'SAPERNOE'	7
# 'SARAPUL'	7
# 'SELEKTSIONNOE'	7
# 'SELKOVO'	7
# 'SHARANGA'	7
# 'SHILOVO'	7
# 'SHUKLINO'	7
# 'SKOLKOVO'	7
# 'SOBOLEVO'	7
# 'SOSKOVO'	7
# 'SPASSK'	7
# 'SROSTKI'	7
# 'SUKHINICHI'	7
# 'SUROVIKINO'	7
# 'TERENINO'	7
# 'TERVOLOVO'	7
# 'TIMONOVO'	7
# 'TORTYM'	7
# 'TRUBINO'	7
# 'TVOROZHKOVO'	7
# 'UKHOLOVO'	7
# 'UREN'	7
# 'URJUPINSK'	7
# 'URSHELSKIJ'	7
# 'USINSK'	7
# 'USOLYE SIBIRSKOE'	7
# 'UST KACHKA'	7
# 'UST MANA'	7
# 'VAKHRUSHI'	7
# 'VELSK'	7
# 'VERETEVO'	7
# 'VESELOVO'	7
# 'VOLODARSKOE'	7
# 'ZAOLESHENKA'	7
# 'ZAOZERYE'	7
# 'ZAVJALOVO'	7
# 'ZEMETCHINO'	7
# 'ZERNOGRAD'	7
# 'ZHILEVO'	7
# 'ZUEVKA'	7
# 'AKTASH'	6
# 'ALEKHOVSHCHINA'	6
# 'ALEKSEEVSKOE'	6
# 'BAKLASHI'	6
# 'BALTIKA'	6
# 'BELOMORSK'	6
# 'BOKSITOGORSK'	6
# 'BOLSHEBRUSJANSKOE'	6
# 'BOLSHIE DVORY'	6
# 'BYKOV OTROG'	6
# 'CHEREMISSKOE'	6
# 'DEDOVICHI'	6
# 'DOBROE'	6
# 'ELIZAVETINSKAJA'	6
# 'ERMILOVO'	6
# 'GLEBKOVO'	6
# 'GOLUMET'	6
# 'GORETOVO'	6
# 'GUBINO'	6
# 'IZHEVSKOE'	6
# 'JAMNOE'	6
# 'JARANSK'	6
# 'JARKOVO'	6
# 'JUZHNAJA OZEREEVKA'	6
# 'KALIKINO'	6
# 'KANTAUROVO'	6
# 'KASHARY'	6
# 'KAZINKA'	6
# 'KHLJUPINO'	6
# 'KIROVGRAD'	6
# 'KONDOL'	6
# 'KOROCHA'	6
# 'KRASNAJA ZARJA'	6
# 'KRIVTSOVO'	6
# 'KRYLOVSKAJA'	6
# 'KUGESI'	6
# 'LADOZHSKAJA'	6
# 'LADOZHSKOE OZERO'	6
# 'LINDA'	6
# 'LIVADIJA'	6
# 'LMS'	6
# 'LUGI'	6
# 'MAKARIJ'	6
# 'MAMONY'	6
# 'MEDNOE'	6
# 'MOROZOVSK'	6
# 'MORSOVO'	6
# 'NAGORYE'	6
# 'NARTKALA'	6
# 'NAVLJA'	6
# 'NECHAEVKA'	6
# 'NOVLJANSKOE'	6
# 'NOVOGORNYJ'	6
# 'NOVOKUBANSK'	6
# 'OLGINO'	6
# 'ORLOV'	6
# 'PAKINO'	6
# 'PERKHUSHKOVO'	6
# 'PERVOMAJSK'	6
# 'PESTRETSY'	6
# 'PETROVA'	6
# 'POSADNIKOVO'	6
# 'POZDNJAKOVO'	6
# 'PRUDKI'	6
# 'PUCHEZH'	6
# 'PUTEVKA'	6
# 'REZH'	6
# 'RJAZANSKAJA'	6
# 'RJAZANSKAJA OBL'	6
# 'RTISHCHEVO'	6
# 'RUSSKIJ JURMASH'	6
# 'SALTYKOVKA'	6
# 'SJATRAKASY'	6
# 'SOLTSY'	6
# 'SOVKHOZ IM LETIJA OKTJABRJA'	6
# 'STARAJA SITNJA'	6
# 'STAROSIVERSKAJA'	6
# 'STEPANKOVO'	6
# 'STRUGI KRASNYE'	6
# 'SVOBODNYJ'	6
# 'TAPTYKOVO'	6
# 'TARASKOVO'	6
# 'TBILISSKAJA'	6
# 'TISHKOVO'	6
# 'TOGOD'	6
# 'TOMAROVKA'	6
# 'TORBEEVO'	6
# 'TSENTRALNYJ'	6
# 'TSVETOCHNYJ'	6
# 'UZUNOVO'	6
# 'VETLUGA'	6
# 'VLADIMIRSKIJ'	6
# 'VOROBYEVKA'	6
# 'VORONOV LOG'	6
# 'ZHEMCHUZHNYJ'	6
# 'AJSHA'	5
# 'AKSUBAEVO'	5
# 'ANDREJKOVO'	5
# 'APASTOVO'	5
# 'ARGAJASH'	5
# 'ARKHANGEL'	5
# 'ASLANA'	5
# 'BEKOVO'	5
# 'BELAJA BEREZKA'	5
# 'BOBROVSKOE'	5
# 'BOGATYR'	5
# 'BOLSHOE GRYZLOVO'	5
# 'BOLSHOE SAVINO'	5
# 'BORZYNI'	5
# 'BUTURLINO'	5
# 'CHEREPET'	5
# 'CHERNJANKA'	5
# 'CHERNOGORSK'	5
# 'CHIRICHKASY'	5
# 'DAKHOVSKAJA'	5
# 'DENEZHNIKOVO'	5
# 'EGORLYKSKAJA'	5
# 'ELKHOVKA'	5
# 'FEDOSEEVKA'	5
# 'FERAPONTOVO'	5
# 'GASPRA'	5
# 'GNEZDOVO'	5
# 'GRISHINO'	5
# 'ILANSKIJ'	5
# 'ILYINOGORSK'	5
# 'ISSAD'	5
# 'JUROVO'	5
# 'KALININO'	5
# 'KAMENSK'	5
# 'KARACHAEVSK'	5
# 'KARINO'	5
# 'KASLI'	5
# 'KEPSHA'	5
# 'KETOVO'	5
# 'KHILOVO'	5
# 'KHOKHLOVO'	5
# 'KHVASTOVICHI'	5
# 'KIREEVSK'	5
# 'KIZILJURT'	5
# 'KOLA'	5
# 'KOMSOMOLSKOE'	5
# 'KORATUN'	5
# 'KORMILOVKA'	5
# 'KOURAK'	5
# 'KRASNYJ'	5
# 'KRIVOPOLJANYE'	5
# 'KURKOVITSY'	5
# 'KUSHNARENKOVO'	5
# 'LENSK'	5
# 'LETKA'	5
# 'LGOV'	5
# 'LJAMBIR'	5
# 'LJUDINOVO'	5
# 'LUKJANOVO'	5
# 'LYTKINO'	5
# 'MAGNITKA'	5
# 'MAJAK'	5
# 'MAKSIMOVO'	5
# 'MALAJA DUBNA'	5
# 'MALMYZH'	5
# 'MARIINSK'	5
# 'MITINO'	5
# 'MITROFANOVO'	5
# 'MOLCHANOVO'	5
# 'MURASHI'	5
# 'NAZAROVO'	5
# 'NOVOMIKHAJLOVSKIJ'	5
# 'NOVOMOSKOVSKOE'	5
# 'OKUNEVSKOE'	5
# 'OLENEGORSK'	5
# 'ONEGA'	5
# 'OZERKI'	5
# 'PIVOVARIKHA'	5
# 'PLAST'	5
# 'PLAVNENSKIJ'	5
# 'POGORELKA'	5
# 'POROSHINA'	5
# 'PROMYSHLENNAJA'	5
# 'RYBREKA'	5
# 'SAKHJURTA'	5
# 'SEKIOTOVO'	5
# 'SEREDKA'	5
# 'SERGIEVO'	5
# 'SEVERNOE'	5
# 'SHALAEVO'	5
# 'SHCHAPOVSKOE'	5
# 'SHELEKHOV'	5
# 'SHIRA'	5
# 'SHUGAROVO'	5
# 'SHUGOZERO'	5
# 'SIBAJ'	5
# 'SOLTANOVO'	5
# 'SOZONOVO'	5
# 'STARAJA LADOGA'	5
# 'STRELTSY'	5
# 'SUKHOJ LOG'	5
# 'SURAZH'	5
# 'TARASOVO'	5
# 'TIMIRJAZEVSKIJ'	5
# 'TUZHA'	5
# 'TYNDA'	5
# 'UJAR'	5
# 'URAZOVKA'	5
# 'USOVSKIJ'	5
# 'UST IZHORA'	5
# 'UST KOKSA'	5
# 'VJATSKIE POLJANY'	5
# 'VOTKINSK'	5
# 'VYGONICHI'	5
# 'ZABOLOTYE'	5
# 'ZAKLINYE ZAKLINSKOE SELSKOE POSELENIE'	5
# 'ZALEGOSHCH'	5
# 'ZHILINDA'	5
# 'ADYGEJSK'	4
# 'AKHTY'	4
# 'ALTUN'	4
# 'ANTONOVKA'	4
# 'ARKHYZ'	4
# 'ARSHAN'	4
# 'BELAJA DACHA'	4
# 'BELAJA GLINA'	4
# 'BELGORODSKOE'	4
# 'BELIDZHI'	4
# 'BELOGORKA'	4
# 'BELOOSTROV'	4
# 'BERDJUZHYE'	4
# 'BEREZNIK'	4
# 'BLIZHNEE'	4
# 'BOGOSLOVKA'	4
# 'BORISOVA GRIVA'	4
# 'BORSKOE'	4
# 'BRATOVSHCHINA'	4
# 'BUINSK'	4
# 'BUZDJAK'	4
# 'CHAADAEVO'	4
# 'CHANY'	4
# 'CHEMODANOVKA'	4
# 'CHERNOMORSKOE'	4
# 'CHKALOVSKIJ'	4
# 'DEMJANSK'	4
# 'ELABUGA'	4
# 'ERMAKOVO'	4
# 'ERYSHI'	4
# 'FABRIKI IM MAJA'	4
# 'FEDURINO'	4
# 'GABISHEVO'	4
# 'GATI'	4
# 'GAVRILOV JAM'	4
# 'GLINISHCHEVO'	4
# 'GORBATOVKA'	4
# 'GORODSKOJ'	4
# 'GUSINOOZERSK'	4
# 'GVARDEJSK'	4
# 'IGNATKOVO'	4
# 'ILYINSKIJ POGOST'	4
# 'ISETSKOE'	4
# 'ISHIMBAJ'	4
# 'ISHNJA'	4
# 'ISTYE'	4
# 'JAGODNOE'	4
# 'JARINSKOE'	4
# 'KALITSINO'	4
# 'KHOROL'	4
# 'KHUZHIR'	4
# 'KICHMENGSKIJ GORODOK'	4
# 'KIEVSKOE'	4
# 'KLIMOVSKOE'	4
# 'KOCHENEVO'	4
# 'KOCHKOMA'	4
# 'KOLJUPANOVO'	4
# 'KOPORYE'	4
# 'KORABLINO'	4
# 'KORSHIK'	4
# 'KOSIKHA'	4
# 'KOSTROMSKOE'	4
# 'KOVROVO'	4
# 'KOVROVYJ KOMBINAT'	4
# 'KOZHEVNIKOVO'	4
# 'KOZMODEMJANSK'	4
# 'KOZULKA'	4
# 'KRASNOZERSKOE'	4
# 'KREMENKUL'	4
# 'KRJUKOVO'	4
# 'KUKUEVKA'	4
# 'KULOTINO'	4
# 'KULTUK'	4
# 'LESOBIRZHA'	4
# 'LESOZAVODSK'	4
# 'LIKINO'	4
# 'LJUBYTINO'	4
# 'LOSINYJ'	4
# 'LUKINO'	4
# 'MAGINSK'	4
# 'MECHETINSKAJA'	4
# 'MEDIKO INSTRUMENTALNOGO ZAVODA'	4
# 'MEDVEDEVO'	4
# 'MESHCHOVSK'	4
# 'MEZHDURECHENSK'	4
# 'MOKROE'	4
# 'MONCHEGORSK'	4
# 'MONETNYJ'	4
# 'MOROZOVO'	4
# 'MYS'	4
# 'NAROVCHAT'	4
# 'NARYNKA'	4
# 'NEVER'	4
# 'NIKITSKOE'	4
# 'NIKOLOGORY'	4
# 'NIKOLSKOE E'	4
# 'NIZHNIJ LOMOV'	4
# 'NOVAJA SLOBODA'	4
# 'NOVOSIL'	4
# 'OLKHA'	4
# 'PACHELMA'	4
# 'PENIKI'	4
# 'PESHKOVO'	4
# 'PETROVSKIJ'	4
# 'PICHAEVO'	4
# 'PLESETSK'	4
# 'POBEDINO'	4
# 'POCHINKI'	4
# 'PODGORNOE'	4
# 'POLOVINKA'	4
# 'POLYSAEVO'	4
# 'POVEDNIKI'	4
# 'PRIGORODNOE'	4
# 'PRISTENNOE'	4
# 'PROGRESS'	4
# 'PROKOP'	4
# 'PRZHEVALSKOE'	4
# 'RAKITNOE'	4
# 'RUSSKIJ'	4
# 'SANATORIJ PODMOSKOVJA'	4
# 'SEMIGORSK'	4
# 'SHABUROVO'	4
# 'SHAKHUNJA'	4
# 'SHCHIGRY'	4
# 'SNEZHINSK'	4
# 'SOKOLSKOE'	4
# 'SOLOVETSKIJ'	4
# 'SOTNIKOVO'	4
# 'SREDNJAJA AKHTUBA'	4
# 'STAROALEKSANDROVKA'	4
# 'STARYJ PETERGOF'	4
# 'STAVROVO'	4
# 'STRELETSKAJA'	4
# 'SUBBOTINO'	4
# 'TALALIKHINO'	4
# 'TALMENKA'	4
# 'TAVRICHESKOE'	4
# 'TEJKOVO'	4
# 'TELEGINO'	4
# 'TEMKINO'	4
# 'TETRINO'	4
# 'TRUSOVO'	4
# 'TSAGAN AMAN'	4
# 'TUJMAZY'	4
# 'UMANSKIJ'	4
# 'VALUJKI'	4
# 'VERKHNJAJA SUN'	4
# 'VESYEGONSK'	4
# 'VET'	4
# 'VISHNJAKOVSKIE DACHI'	4
# 'VISTINO'	4
# 'VOEJKOVO'	4
# 'VOLKHOVSKIJ'	4
# 'VORONEZHSKIJ'	4
# 'VOZHEGA'	4
# 'VURMANKASY'	4
# 'VYSOKOE'	4
# 'VYSOKOGORSKIJ'	4
# 'VYSOKOVO'	4
# 'ZABORYE'	4
# 'ZASTOLBYE'	4
# 'ZAVOROVO'	4
# 'ZEJA'	4
# 'ZENINO'	4
# 'ZHERDEVKA'	4
# 'ZNAMENSKOE'	4
# 'ZVEZDNYJ'	4
# 'ABZAKOVO'	3
# 'AEROFLOTSKIJ'	3
# 'AIM'	3
# 'AKHTUBINSK'	3
# 'AMURSK'	3
# 'ANDREAPOL'	3
# 'ANNENKA'	3
# 'ANZHERO SUDZHENSK'	3
# 'ARDATOV'	3
# 'ARMANIKHA'	3
# 'BADRJASHEVO'	3
# 'BALTYM'	3
# 'BARABINSK'	3
# 'BARYSH'	3
# 'BEKHTEEVKA'	3
# 'BELAVINO'	3
# 'BELINSKIJ'	3
# 'BELJANAJA GORA'	3
# 'BELORUSSKIJ'	3
# 'BELOZERNYJ'	3
# 'BEREGOVOE'	3
# 'BIRJULJA'	3
# 'BOGASHEVO'	3
# 'BOGOTOL'	3
# 'BOJARKINO'	3
# 'BOLSHEVO'	3
# 'BORODINSKIJ'	3
# 'BRIN NAVOLOK'	3
# 'BUDOVO'	3
# 'BUTUNTAJ'	3
# 'CHERNORECHENSK'	3
# 'CHERNYJ JAR'	3
# 'CHERVISHEVO'	3
# 'CHKALOVO'	3
# 'CHULYM'	3
# 'DAVYDOVSKOE'	3
# 'DEDILOVSKIE VYSELKI'	3
# 'DEMSHINKA'	3
# 'DIASERJA'	3
# 'DMITROVA GORA'	3
# 'DZHANKOJ'	3
# 'ELANTSY'	3
# 'ELEKMONAR'	3
# 'ELNJA'	3
# 'EMMAUS'	3
# 'ERINO'	3
# 'ERMOLAEVO'	3
# 'ESSOJLA'	3
# 'GAGINO'	3
# 'GLEBOVSKOE'	3
# 'GORNOZAVODSK'	3
# 'GOVOROVO'	3
# 'GUBAKHA'	3
# 'ICHALKI'	3
# 'INSHINSKIJ'	3
# 'IRTYSHSKIJ'	3
# 'IVAKINO'	3
# 'IVANOVSKIJ'	3
# 'IZBERBASH'	3
# 'JANTAL'	3
# 'JAZOVO'	3
# 'JURYEV POLSKIJ'	3
# 'KABAKOVO'	3
# 'KADYJ'	3
# 'KALUZHSKAJA OPYTNAJA SELSKOKHOZJAJSTVENNAJA STANTSIJA'	3
# 'KAMESHKOVO'	3
# 'KANTEMIROVKA'	3
# 'KASPLJA'	3
# 'KHANSKAJA'	3
# 'KHELJULJA'	3
# 'KHYRKASY'	3
# 'KINELSKIJ'	3
# 'KIZLJAR'	3
# 'KIZNER'	3
# 'KLEMENTYEVO'	3
# 'KOLONTAEVKA'	3
# 'KRAPIVNA'	3
# 'KRASNOGOR'	3
# 'KRASNOTURYINSK'	3
# 'KRASNYE TKACHI'	3
# 'KSHENSKIJ'	3
# 'KUDMA'	3
# 'KUDRJASHOVSKIJ'	3
# 'KUNJA'	3
# 'KURORTNOE'	3
# 'KUSA'	3
# 'LADUSHKIN'	3
# 'LARINO'	3
# 'LENINOGORSK'	3
# 'LESNAJA'	3
# 'LESNYE POLJANY'	3
# 'LETOSHNIKI'	3
# 'LEVOBEREZHNYJ'	3
# 'LIPTSY'	3
# 'LOBOK'	3
# 'LOKOMOTIVNYJ'	3
# 'LUGOVOE'	3
# 'LUNINO'	3
# 'MAGANSK'	3
# 'MAJANGA'	3
# 'MAKUSHINO'	3
# 'MALOE POLPINO'	3
# 'MALYJ MAJAK'	3
# 'MARI TUREK'	3
# 'MEREVO'	3
# 'MOSKOVO'	3
# 'MOZHAJSKIJ'	3
# 'MURMINO'	3
# 'NARIMANOV'	3
# 'NAZYVAEVSK'	3
# 'NEKHAEVSKAJA'	3
# 'NIKOLSK'	3
# 'NJAGAN'	3
# 'NOVO IVANOVSKOE'	3
# 'NOVOSINEGLAZOVSKIJ'	3
# 'NOVOSOKOLNIKI'	3
# 'NUDOL'	3
# 'OJKHA'	3
# 'OKTJABRSK'	3
# 'OLGINKA'	3
# 'OLKHOVATKA'	3
# 'OLKHOVKA'	3
# 'OPALIKHA'	3
# 'ORDZHONIKIDZE'	3
# 'OSINKI'	3
# 'OSKINO'	3
# 'PALLASOVKA'	3
# 'PARTENIT'	3
# 'PAVLISHCHEV BOR'	3
# 'PERSIANOVSKIJ'	3
# 'PETROVSK'	3
# 'PILNA'	3
# 'PLANERNAJA'	3
# 'PLEKHANOVO'	3
# 'POKROVO PRIGORODNOE'	3
# 'PRONSK'	3
# 'PUGACHEVSKIJ'	3
# 'PUJKKOLA'	3
# 'RADOVITSKIJ'	3
# 'RAMENO'	3
# 'RESHETNIKOVO'	3
# 'RODIONOVKA'	3
# 'SAJANSK'	3
# 'SAKHAROVO'	3
# 'SAMARSKOE'	3
# 'SAMBEK'	3
# 'SAMOJLOVKA'	3
# 'SANATORIJ VOSKHOD'	3
# 'SERNUR'	3
# 'SHEMETOVO'	3
# 'SHUSH'	3
# 'SHUVAEVO'	3
# 'SLAVJANKA'	3
# 'SLJUDJANKA'	3
# 'SOLONSKOE'	3
# 'SOLONTSOVSKIJ'	3
# 'SOSENSKIJ'	3
# 'SOVJAKI'	3
# 'STAROE'	3
# 'STAROE CHURILINO'	3
# 'STAROSELYE'	3
# 'SVATKOVO'	3
# 'SVETLYJ JAR'	3
# 'SYCHEVKA'	3
# 'TALOVAJA'	3
# 'TASHIROVO'	3
# 'TELIGI'	3
# 'TEPLOE'	3
# 'TIKHMENEVO'	3
# 'TOGUCHIN'	3
# 'TOTMA'	3
# 'TROITSA'	3
# 'UDOMLJA'	3
# 'URALETS'	3
# 'URMARY'	3
# 'USOVO'	3
# 'UST KULOM'	3
# 'USTYE'	3
# 'USTYINSKIJ'	3
# 'VERKHNEJARKEEVO'	3
# 'VERKHNESADOVOE'	3
# 'VERKHNJAJA KHILA'	3
# 'VESELEVO'	3
# 'VINY'	3
# 'VIZINGA'	3
# 'VKHODNOJ'	3
# 'VORONYE'	3
# 'VVEDENSKOE'	3
# 'VYZHELES'	3
# 'ZARINSK'	3
# 'ZAVODOUKOVSK'	3
# 'ZHIGULI'	3
# 'ZHIRNOVSK'	3
# 'ZHIZDRA'	3
# 'ABAN'	2
# 'AJKINO'	2
# 'ALFIMOVO'	2
# 'ALNASHI'	2
# 'ARGUN'	2
# 'ARTSYBASHEVO'	2
# 'ASKINO'	2
# 'ATAZHUKINO'	2
# 'BABARYKINO'	2
# 'BAGRATIONOVSK'	2
# 'BAJKALOVO'	2
# 'BAKALY'	2
# 'BARTAT'	2
# 'BATETSKIJ'	2
# 'BELAJA KOLP'	2
# 'BELJANINOVO'	2
# 'BEZHANITSY'	2
# 'BILIMBAJ'	2
# 'BOGATOE'	2
# 'BOLDINO'	2
# 'BOLSHAJA ORLOVKA'	2
# 'BOLSHOE RUNOVO'	2
# 'BRYN'	2
# 'BUDOCHKI'	2
# 'BURKOVSKIJ'	2
# 'BURLATSKOE'	2
# 'BUTURLINOVKA'	2
# 'BYSTROVKA'	2
# 'CHAGODA'	2
# 'CHELJUSKINSKIJ'	2
# 'CHEMODUROVO'	2
# 'CHERNOVSKIJ'	2
# 'CHERNYSHIKHA'	2
# 'CHERNYSHKOVSKIJ'	2
# 'CHIKOLA'	2
# 'DACHNOE'	2
# 'DALNEGORSK'	2
# 'DEMIKHOVO'	2
# 'DIVENSKIJ'	2
# 'DIVJA'	2
# 'DMITROVSKOE'	2
# 'DOVOLNOE'	2
# 'DRAKINO'	2
# 'DUBJAZY'	2
# 'ELAN'	2
# 'ELOVOE'	2
# 'ERIK'	2
# 'ERMAKOVSKOE'	2
# 'ERMEKEEVO'	2
# 'ESIPOVO'	2
# 'EVGENYEVKA'	2
# 'FATEZH'	2
# 'FEDJAKINO'	2
# 'FOMINSKIJ'	2
# 'FOMINSKOE'	2
# 'FRUNZE'	2
# 'GALICH'	2
# 'GEORGIEVKA'	2
# 'GIRVAS'	2
# 'GIZEL'	2
# 'GORKOVKA'	2
# 'GORODOVIKOVSK'	2
# 'GRITSOVSKIJ'	2
# 'GULKEVICHI'	2
# 'GUZERIPL'	2
# 'IGRA'	2
# 'IKRJANOE'	2
# 'ILSKIJ'	2
# 'IM CHAJKOVSKOGO'	2
# 'ISHIM'	2
# 'IZMODENOVO'	2
# 'J'	2
# 'JANISHPOLE'	2
# 'JARINO'	2
# 'JAROSLAVSKIJ'	2
# 'JUKHTA'	2
# 'JURGAMYSH'	2
# 'KAMENNAJA BALKA'	2
# 'KAMYSHEVKA'	2
# 'KAMYSHLA'	2
# 'KARAIDEL'	2
# 'KARLA LIBKNEKHTA'	2
# 'KASKARA'	2
# 'KAZACHINSKOE'	2
# 'KEDROVKA'	2
# 'KEM'	2
# 'KHASAVJURT'	2
# 'KHLEBNIKOVO'	2
# 'KHOLMSKAJA'	2
# 'KHOR'	2
# 'KHOTYNETS'	2
# 'KISLENKA'	2
# 'KITOVO'	2
# 'KJAPPESELGA'	2
# 'KLJUCHISHCHI'	2
# 'KOCHKI'	2
# 'KOLATSELGA'	2
# 'KOMSOMOLSK'	2
# 'KOMSOMOLSK NA AMURE'	2
# 'KONSTANTINOVSK'	2
# 'KONYSHEVKA'	2
# 'KOPEVO'	2
# 'KORENEVO'	2
# 'KORKINO'	2
# 'KOROTSKO'	2
# 'KOTLJAKOVO'	2
# 'KOVALEVSKOE'	2
# 'KRASNOGORODSK'	2
# 'KRASNOJARSKIJ'	2
# 'KRASNOOZERNOE'	2
# 'KRASNOSHCHEKOVO'	2
# 'KRASNYJ PAKHAR'	2
# 'KRJUCHKOVO'	2
# 'KUKTOVO'	2
# 'KURCHANSKAJA'	2
# 'KURGANSKAJA OBL'	2
# 'KURKINO'	2
# 'KURSKOE'	2
# 'KUSHVA'	2
# 'KUZMICHI'	2
# 'LAJA'	2
# 'LAVROVO'	2
# 'LEV TOLSTOJ'	2
# 'LINEVO'	2
# 'LITVINOVO'	2
# 'LJUBINSKIJ'	2
# 'LOMOVKA'	2
# 'LUBNJA'	2
# 'LUGOVAJA'	2
# 'MAGAS'	2
# 'MALAJA PURGA'	2
# 'MALTSEVO'	2
# 'MARYINA ROSHCHA'	2
# 'MATYRSKIJ'	2
# 'MEDVENKA'	2
# 'MEZHVODNOE'	2
# 'MILOVKA'	2
# 'MINEEVO'	2
# 'MITENEVO'	2
# 'MOLDAVANSKOE'	2
# 'MOZDOK'	2
# 'MUCHKAPSKIJ'	2
# 'NADEZHDA'	2
# 'NAKHODKA'	2
# 'NAZIJA'	2
# 'NESTEROV'	2
# 'NIFANTOVO'	2
# 'NIKONOVSKOE'	2
# 'NIVENSKOE'	2
# 'NOLINSK'	2
# 'NOSOVO'	2
# 'NOVAJA BURA'	2
# 'NOVAJA OTRADOVKA'	2
# 'NOVOANNINSKIJ'	2
# 'NOVOARKHANGELKA'	2
# 'NOVOPAVLOVSK'	2
# 'NOVOPJATNITSKOE'	2
# 'NOVOPOKROVSKOE'	2
# 'NOVOSELITSKOE'	2
# 'NOVOULJANOVSK'	2
# 'NOVYJ BUJAN'	2
# 'NOVYJ IZBORSK'	2
# 'OBLIVSKAJA'	2
# 'OBUKHOVSKOE'	2
# 'OLAREVO'	2
# 'OLJAVIDOVO'	2
# 'OLSHA'	2
# 'ORDA'	2
# 'ORLOVSKAJA OBL'	2
# 'OSTROGOZHSK'	2
# 'PARTIZANSKAJA'	2
# 'PAVLOVICHI'	2
# 'PEREJASLAVKA'	2
# 'PEREVALNOE'	2
# 'PEREVOLOKI'	2
# 'PETRO SLAVJANKA'	2
# 'PIONERNYJ'	2
# 'PJATOVSKIJ'	2
# 'PLASTINKA'	2
# 'PLOSKAJA'	2
# 'POGAR'	2
# 'POGORELOVKA'	2
# 'POLETAEVO'	2
# 'POMOZDINO'	2
# 'PONYRI'	2
# 'POVORINO'	2
# 'PRAVDINSK'	2
# 'PRIGORSKOE'	2
# 'PRJAMITSYNO'	2
# 'PROKHOROVKA'	2
# 'PUSHKINSKOE'	2
# 'PYT JAKH'	2
# 'RAMZAJ'	2
# 'RAZVETYE'	2
# 'RODINA'	2
# 'RODNIKOVSKAJA'	2
# 'SADKI'	2
# 'SANINO'	2
# 'SARATOVSKAJA OBL'	2
# 'SASOVO'	2
# 'SASYKINO'	2
# 'SATKA'	2
# 'SAUK DERE'	2
# 'SAVELYEVO'	2
# 'SAZONOVO'	2
# 'SECHENOVO'	2
# 'SERKOVO'	2
# 'SERMENEVO'	2
# 'SEROV'	2
# 'SESHCHA'	2
# 'SEVEROURALSK'	2
# 'SEVSK'	2
# 'SHADRINO'	2
# 'SHAGAEVO'	2
# 'SHEMORDAN'	2
# 'SHERSHNI'	2
# 'SHMAKOVO'	2
# 'SHOKSHA'	2
# 'SHUMJACHI'	2
# 'SIDOROVO'	2
# 'SIVKOVO'	2
# 'SKOVORODINO'	2
# 'SLEDNEVO'	2
# 'SLOBODSKOE'	2
# 'SOLNTSEVO'	2
# 'SPITSINO'	2
# 'SREDNIJ'	2
# 'STAROCHERKASSKAJA'	2
# 'STAROMARYEVKA'	2
# 'STRAKHOVO'	2
# 'STRELETSKIJ'	2
# 'STRELITSA'	2
# 'SUOJARVI'	2
# 'SVERCHKOVO'	2
# 'SVETLOGRAD'	2
# 'TAGAJ'	2
# 'TAGILSKOE'	2
# 'TARASIKHA'	2
# 'TATARSK'	2
# 'TJUMENSKAJA OBL'	2
# 'TJUMENTSEVO'	2
# 'TOLBAZY'	2
# 'TOVARKOVSKIJ'	2
# 'TRUBICHINO'	2
# 'TSELINNOE'	2
# 'UDOBNAJA'	2
# 'UGLJANETS'	2
# 'UGLOVKA'	2
# 'ULJANOVSKAJA'	2
# 'UST LUGA'	2
# 'UST ORDYNSKIJ'	2
# 'VASILYEVSKIJ'	2
# 'VITIMSKIJ'	2
# 'VJATSKOE'	2
# 'VJAZEMSKIJ'	2
# 'VOJSKOROVO'	2
# 'VOKHMA'	2
# 'VOLKOVO'	2
# 'VOLNA'	2
# 'VOZHSKIJ'	2
# 'VYSOKAJA'	2
# 'ZAINSK'	2
# 'ZARECHNOE'	2
# 'ZARUDNJA'	2
# 'ZAVETY ILYICHA'	2
# 'ZELENAJA POLJANA'	2
# 'ZELENCHUKSKAJA'	2
# 'ZENKINO'	2
# 'ZHESHART'	2
# 'ZIMITITSY'	2
# 'ZUBAREVO'	2
# 'ZUBOVO POLJANA'	2
# 'ZUJA'	2
# 'AFANASOVKA'	1
# 'AJA'	1
# 'AKHTANIZOVSKAJA'	1
# 'AKJAR'	1
# 'AKSAKOVO'	1
# 'ALAGIR'	1
# 'ALATORKA'	1
# 'ALESHNJA'	1
# 'ALTAJSKOE'	1
# 'APARINSKIJ'	1
# 'ARSENYEV'	1
# 'ARTEMOVSKIJ'	1
# 'ASEKEEVO'	1
# 'ATIG'	1
# 'AVANGARD'	1
# 'AZNAKAEVO'	1
# 'AZOVSKAJA'	1
# 'BAKHTEMIR'	1
# 'BARABASH'	1
# 'BARJATINO'	1
# 'BASHMAKOVO'	1
# 'BATURINO'	1
# 'BATYREVO'	1
# 'BAVLY'	1
# 'BELAJA KALITVA'	1
# 'BELEV'	1
# 'BELSK'	1
# 'BEREZHKI'	1
# 'BESLAN'	1
# 'BETTA'	1
# 'BIKLJAN'	1
# 'BIRJUCH'	1
# 'BISERT'	1
# 'BLAGOEVO'	1
# 'BOBINO'	1
# 'BOBROVKA'	1
# 'BOGOLJUBOVO'	1
# 'BOGUCHAR'	1
# 'BOJKOPONURA'	1
# 'BOLSHERECHYE'	1
# 'BOLSHIE KLJUCHI'	1
# 'BOLSHOE IGNATOVO'	1
# 'BOLSHOJ LOG'	1
# 'BOLYCHEVO'	1
# 'BOROVKI'	1
# 'BRATOVKA'	1
# 'BUGAEVKA'	1
# 'BYZOVO'	1
# 'CHAJKA'	1
# 'CHASTOOZERYE'	1
# 'CHEKMAGUSH'	1
# 'CHEMIKHINO'	1
# 'CHERDAKLY'	1
# 'CHERDYNTSEVO'	1
# 'CHEREMUSHKI'	1
# 'CHERKESOVSKIJ'	1
# 'CHERNYSHEVSKOE'	1
# 'CHUPA'	1
# 'CHUROVSKOE'	1
# 'DALMATOVO'	1
# 'DEDINOVO'	1
# 'DEMIDOV'	1
# 'DERGACHI'	1
# 'DETSKOSELSKIJ'	1
# 'DIVNOE'	1
# 'DMITROVO'	1
# 'DODZ'	1
# 'DOMBAJ'	1
# 'DOMOZHIROVO'	1
# 'DON'	1
# 'DONGUZ'	1
# 'DOROGINO'	1
# 'DOROGOBUZH'	1
# 'DORONICHI'	1
# 'DROSKOVO'	1
# 'DRUZHININO'	1
# 'DRUZHNYJ'	1
# 'DUBOVAJA ROSHCHA'	1
# 'DUDINKA'	1
# 'DUPLENSKAJA'	1
# 'DZERZHINSKOGO'	1
# 'EDROVO'	1
# 'EFIMOVSKIJ'	1
# 'EGERUKHAJ'	1
# 'EKATERINOSLAVKA'	1
# 'ELETSKOE'	1
# 'ELSHANKA'	1
# 'EMMAUSS'	1
# 'EMVA'	1
# 'EREMINO'	1
# 'ERMISH'	1
# 'ESAULSKIJ'	1
# 'EVSINO'	1
# 'FIRSOVO'	1
# 'GAVRILOVSKAJA'	1
# 'GAVRILOVSKIJ'	1
# 'GAVRY'	1
# 'GAZIMURSKIJ ZAVOD'	1
# 'GLUBOKIJ'	1
# 'GOLOVINO'	1
# 'GONCHARNOE'	1
# 'GORBATOV'	1
# 'GORJACHEVODSKIJ'	1
# 'GORNJAK'	1
# 'GORSHECHNOE'	1
# 'GRAJVORON'	1
# 'GREMJACHEE'	1
# 'GRIBANOVSKIJ'	1
# 'GRIBOVKA'	1
# 'GRIGOROVO'	1
# 'GRJADY'	1
# 'GUKOVO'	1
# 'GZHELSKIJ KIRPICHNYJ ZAVOD'	1
# 'IGARKA'	1
# 'ILOVLJA'	1
# 'ILYICHEVO'	1
# 'IPATOVO'	1
# 'IRBIT'	1
# 'ISAKLY'	1
# 'IVNJA'	1
# 'JADRIN'	1
# 'JAGUNOVSKIJ'	1
# 'JAKOVSKOE'	1
# 'JAM TESOVO'	1
# 'JANAUL'	1
# 'JARENSK'	1
# 'JUGANETS'	1
# 'JUMAGUZINO'	1
# 'JURGA'	1
# 'JURJUZAN'	1
# 'JURYEVETS'	1
# 'JUTSA'	1
# 'KABANSK'	1
# 'KABLUKOVO'	1
# 'KACHKANAR'	1
# 'KACHUG'	1
# 'KADOSHKINO'	1
# 'KAJSATSKOE'	1
# 'KALACH NA DONU'	1
# 'KALININA'	1
# 'KALINOVO'	1
# 'KAMYSHLOVSKIJ'	1
# 'KANDINKA'	1
# 'KANDRY'	1
# 'KANEVKA'	1
# 'KARABUDAKHKENT'	1
# 'KARDYMOVO'	1
# 'KARGASOK'	1
# 'KASHKHATAU'	1
# 'KATAJSK'	1
# 'KEMEROVSKAJA OBL'	1
# 'KESOVA GORA'	1
# 'KHIJDENSELGA'	1
# 'KHLEBINO'	1
# 'KHOLJAZINO'	1
# 'KIMILTEJ'	1
# 'KIRGIZ MIJAKI'	1
# 'KIRITSY'	1
# 'KIZEL'	1
# 'KLESHCHEVO'	1
# 'KLETNJA'	1
# 'KLISHINO'	1
# 'KOKOREVO'	1
# 'KOLODEZNYJ'	1
# 'KOLOSOVKA'	1
# 'KOLPASHEVO'	1
# 'KOLPNA'	1
# 'KOMSOMOLETS'	1
# 'KOPNINO'	1
# 'KOPTSEVY KHUTORA'	1
# 'KOREKOZEVO'	1
# 'KORENEVSHCHINO'	1
# 'KOROTKOVO'	1
# 'KORYSTOVO'	1
# 'KOSHELEVO'	1
# 'KOSHKI'	1
# 'KOTLAS'	1
# 'KOVALEVO'	1
# 'KOVRINO'	1
# 'KOZHMUDOR'	1
# 'KRASAVINO'	1
# 'KRASINSKOE'	1
# 'KRASNAJA POJMA'	1
# 'KRASNODARSKIJ KRAJ'	1
# 'KRASNOE NA VOLGE'	1
# 'KRASNOGORSKAJA'	1
# 'KRASNOJARKA'	1
# 'KRASNOJARSKAJA'	1
# 'KRASNOKAMENSK'	1
# 'KRASNORECHENSKIJ'	1
# 'KRASNYE BARRIKADY'	1
# 'KRASNYE CHETAI'	1
# 'KRASNYJ KUT'	1
# 'KRUTOJAR'	1
# 'KUJBYSHEV'	1
# 'KUJTUN'	1
# 'KUTUZOVSKIJ'	1
# 'KUTYRLY'	1
# 'KUVANDYK'	1
# 'KUVSHINOVO'	1
# 'KUZNETSOV'	1
# 'KUZOVATOVO'	1
# 'LAGOLOVO'	1
# 'LANGEPAS'	1
# 'LAZAREVO'	1
# 'LENINSK'	1
# 'LJANGASOVO'	1
# 'LJUBIMETS'	1
# 'LJUBOKHNA'	1
# 'LOKOSOVO'	1
# 'LOUKHI'	1
# 'MALOJAZ'	1
# 'MALORECHENSKOE'	1
# 'MALYE DERBETY'	1
# 'MANTUROVO'	1
# 'MANUSHKINO'	1
# 'MARYINO'	1
# 'MASSANDRA'	1
# 'MEDVEDSKOE'	1
# 'MEGION'	1
# 'MELENKI'	1
# 'MESHKOVOE'	1
# 'METALLPLOSHCHADKA'	1
# 'MGLIN'	1
# 'MIASSKOE'	1
# 'MICHURINA'	1
# 'MIKUN'	1
# 'MJAKSA'	1
# 'MOKROUS'	1
# 'MOKSHAN'	1
# 'MOLVINO'	1
# 'MONASTYRSHCHINA'	1
# 'MONASTYRSKOE'	1
# 'MOSKALENKI'	1
# 'MSTERA'	1
# 'MUROMTSEVO'	1
# 'NAJDORF'	1
# 'NEZAMAEVSKAJA'	1
# 'NEZHINKA'	1
# 'NIKOLA'	1
# 'NIKOLAEV'	1
# 'NIKOLAEVSK'	1
# 'NIKOLSKIJ'	1
# 'NIZHNIJ INGASH'	1
# 'NJUVCHIM'	1
# 'NOVAJA UDA'	1
# 'NOVOALEKSANDROVSK'	1
# 'NOVOCINKOVO'	1
# 'NOVODZHERELIEVSKAJA'	1
# 'NOVOORSK'	1
# 'NOVOPERUNOVO'	1
# 'NOVOSELTSEVO'	1
# 'NOVOSELTSY'	1
# 'NOVOSHCHAPOVO'	1
# 'NOVOSHCHERBINOVSKAJA'	1
# 'NOVOTALITSY'	1
# 'NOVOTARMANSKIJ'	1
# 'NOVOTYRYSHKINO'	1
# 'NOVYE DARKOVICHI'	1
# 'NOVYE GORKI'	1
# 'NURLAT'	1
# 'OBOLDINO'	1
# 'OKOROKOVO'	1
# 'OKSKIJ'	1
# 'OLGINSKIJ'	1
# 'ONGUDAJ'	1
# 'ORLOVSKIJ'	1
# 'ORSHANKA'	1
# 'OSTRETSOVO'	1
# 'OTRADNENSKOE'	1
# 'PALNIKI'	1
# 'PANDIKOVO'	1
# 'PARATUNKA'	1
# 'PARFENOVO'	1
# 'PARFENTYEVO'	1
# 'PENO'	1
# 'PEREDELKINO'	1
# 'PESCHANKA'	1
# 'PETELINO'	1
# 'PITELINO'	1
# 'PITERKA'	1
# 'PJATIRECHYE'	1
# 'PLATONOVKA'	1
# 'PODJACHEVO'	1
# 'POGRUZNAJA'	1
# 'POJARKOVO'	1
# 'POLITOTDELSKOE'	1
# 'POLJANA'	1
# 'POLOM'	1
# 'PONOMAREVKA'	1
# 'POVARNJA'	1
# 'PRIDOROZHNAJA'	1
# 'PRIMORKA'	1
# 'PRIOBSKIJ'	1
# 'PRIVOLZHSKIJ'	1
# 'PROBUZHDENIE'	1
# 'PROKHOROVO'	1
# 'PUSHNOE'	1
# 'PYTALOVO'	1
# 'RAUTALAKHTI'	1
# 'RAZDOLNAJA'	1
# 'REFTINSKIJ'	1
# 'REMONTNOE'	1
# 'ROMANOVSKAJA'	1
# 'ROVDINO'	1
# 'ROVENKI'	1
# 'RUCHEJ'	1
# 'SANATORIJ OZERO BELOE'	1
# 'SANDATA'	1
# 'SANDOVO'	1
# 'SARAI'	1
# 'SAVINKA'	1
# 'SAVINO'	1
# 'SELEKTSIONNOJ STANTSII'	1
# 'SELNIKOVO'	1
# 'SEMENKOVO'	1
# 'SEMENOVKA'	1
# 'SENGILEJ'	1
# 'SEVEROBAJKALSK'	1
# 'SHADEJKA'	1
# 'SHAKHOVSKOE'	1
# 'SHALI'	1
# 'SHAR'	1
# 'SHELOKSHA'	1
# 'SHIGONY'	1
# 'SHIKHAZANY'	1
# 'SHOPINO'	1
# 'SHUGUROVO'	1
# 'SHUMEJKA'	1
# 'SHVARTSEVSKIJ'	1
# 'SMOLENSKIJ'	1
# 'SMOLENSKOE'	1
# 'SNEZHNYJ'	1
# 'SOLIGALICH'	1
# 'SOLIKAMSK'	1
# 'SOLNECHNAJA DOLINA'	1
# 'SOLOVYEVKA'	1
# 'SOROCHINSK'	1
# 'SPIRIDONOVKA'	1
# 'STAKHANOVSKIJ'	1
# 'STANOVOJ KOLODEZ'	1
# 'STAROJURYEVO'	1
# 'STEPNOE'	1
# 'STOROZHEVSK'	1
# 'STUKLOVO'	1
# 'STUPINSKAJA'	1
# 'SUKHAREVO'	1
# 'SUKHOVO'	1
# 'SUNA'	1
# 'SURSKOE'	1
# 'SVERDLOVSKOE'	1
# 'SYLVA'	1
# 'SYRSKOE'	1
# 'TAJMURZINO'	1
# 'TAKSIMO'	1
# 'TANKOVOE'	1
# 'TASHBULATOVO'	1
# 'TAVATUJ'	1
# 'TEDINO'	1
# 'TEMIZHBEKSKIJ'	1
# 'TEPLAJA GORA'	1
# 'TEPLOVKA'	1
# 'TEREKLI MEKTEB'	1
# 'TIMIRJAZEVA'	1
# 'TORGASHINO'	1
# 'TRESKOVO'	1
# 'TSEKEEVO'	1
# 'TSVELODUBOVO'	1
# 'TSVETKOVSKIJ'	1
# 'TSVETOCHNOE'	1
# 'TUMA'	1
# 'TUROCHAK'	1
# 'UGLEGORSK'	1
# 'UJUTNOE'	1
# 'URAJ'	1
# 'URGA'	1
# 'URIK'	1
# 'USOGORSK'	1
# 'USSURIJSK'	1
# 'UST DONETSKIJ'	1
# 'UST KURDJUM'	1
# 'UST UREN'	1
# 'USTJUG'	1
# 'UTEVKA'	1
# 'UVA'	1
# 'UVELSKIJ'	1
# 'VAD'	1
# 'VASILEVKA'	1
# 'VASILYEVO'	1
# 'VERKHNEPASHINO'	1
# 'VERKHNEURALSK'	1
# 'VERKHNEZEJSK'	1
# 'VERKHNIE TATYSHLY'	1
# 'VERKHNJAJA KHAVA'	1
# 'VERKHOTURYE'	1
# 'VERKHOVINO'	1
# 'VESELAJA ZHIZN'	1
# 'VESELO VOZNESENOVKA'	1
# 'VETLUZHSKIJ'	1
# 'VOLGORECHENSK'	1
# 'VOLJA'	1
# 'VOLNO NADEZHDINSKOE'	1
# 'VOLODARSK'	1
# 'VOLODARSKIJ'	1
# 'VOLZHSKIJ UTES'	1
# 'VOROVSKIJ'	1
# 'VUKTYL'	1
# 'VYPOLZOVO'	1
# 'ZABAJKALSK'	1
# 'ZADONSKIJ'	1
# 'ZAKHAROVO'	1
# 'ZAOZERNYJ'	1
# 'ZAPOLJARNYJ'	1
# 'ZAPOROZHSKAJA'	1
# 'ZAURALSKIJ'	1
# 'ZELENGA'	1
# 'ZHARKOVSKIJ'	1
# 'ZHELEZNODOROZHNOJ STANTSII VYSOKAJA GORA'	1
# 'ZHIZN'	1
# 'ZIMA'	1
# 'ZUDILOVO'	1
# 'ZVEROSOVKHOZ'	1
# 'ZYRJANSKOE'	1
