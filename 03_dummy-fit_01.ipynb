# %%
from operator import itemgetter

import numpy as np
import pandas as pd

import xgboost as xgb
import sklearn

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib

# %%
dtype = {
    'amount': np.float32,
    'city': np.int32,
    'country': np.int32,
    'currency': np.int32,
    'customer_id': object,
    'home_add_lat': np.float32,
    'home_add_lon': np.float32,
    'mcc': np.int32,
    'terminal_id': object,
    'work_add_lat': np.float32,
    'work_add_lon': np.float32,
    'access24h': np.int8,
    'is_office': np.int8,
    'lat': np.float32,
    'lon': np.float32,
    'n_points': np.int32,
    'is_atm': np.int8,
    'is_raiff': np.int8,
    'is_partner': np.int8,
    'pct_same': np.float32,
    'neg_home': np.int8,
    'neg_work': np.int8,
    'pos_home': np.int8,
    'pos_work': np.int8,
    'mcc_group': np.int32,
    'has_car': np.int8,
    'has_children': np.int8,
    'has_pet': np.int8,
    'amount_mean': np.float32,
    'amount_sub': np.float32,
    'amount_div': np.float32,
    'day': np.int8,
    'day_of_week': np.int8,
    'days_after_holiday': np.int8,
    'days_before_holiday': np.int8,
    'is_dayoff': np.int8,
    'is_holiday': np.int8,
    'is_short': np.int8,
    'is_weekend': np.int8,
    'month': np.int8,
    'timestamp': np.int64,
    'week_of_year': np.int8,
    'pct_term_counts': np.float32,
    'pct_mcc_g_counts': np.float32,
    'is_abroad': np.int8,
    'amount_true': np.float32
}

df = pd.read_csv("data/sets/train_set_final.csv", sep=',', encoding='utf-8', dtype=dtype)
df.head()
# Out:
#      amount  city  country  currency                       customer_id  \
# 0  2.884034     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 1  2.775633     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 2  3.708368     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 3  3.708368     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
# 4  2.787498     1        0       643  0dc0137d280a2a82d2dc89282450ff1b
#
#    home_add_lat  home_add_lon   mcc                       terminal_id  \
# 0     59.851002        30.232  5261  11606fde0c814ce78e0d726e39a0a5ee
# 1     59.851002        30.232  5261  e9647a5e1eacfb06713b6af755ccc595
# 2     59.851002        30.232  5992  df06c1fcd3718a514535ae822785f716
# 3     59.851002        30.232  5992  df06c1fcd3718a514535ae822785f716
# 4     59.851002        30.232  5261  6c5e5793ebc984fb72875feffff62854
#
#    work_add_lat    ...      is_short  is_weekend  month   timestamp  \
# 0        59.847    ...             0           1      7  1500066000
# 1        59.847    ...             0           0     10  1509051600
# 2        59.847    ...             0           0     10  1506978000
# 3        59.847    ...             0           0     10  1506978000
# 4        59.847    ...             0           1      9  1504904400
#
#    week_of_year  pct_term_counts  pct_mcc_g_counts  is_abroad   amount_true  \
# 0            28         0.013889          0.138889          0   1914.140991
# 1            43         0.013889          0.138889          0   1491.327759
# 2            40         0.013889          0.013889          0  12773.453125
# 3            40         0.013889          0.013889          0  12773.453125
# 4            36         0.013889          0.138889          0   1532.631592
#
#    is_native
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 47 columns]

# %%
def is_inside_area(lat_pred, lon_pred, lat_true, lon_true, radius=0.02):
    return np.power(lat_pred - lat_true, 2) + np.power(lon_pred - lon_true, 2) <= radius ** 2

# %%
mask = df.loc[:, ["home_add_lat", "home_add_lon"]].notnull().all(axis=1)
df["is_home"] = is_inside_area(
    df.loc[mask, "lat"], df.loc[mask, "lon"],
    df.loc[mask, "home_add_lat"], df.loc[mask, "home_add_lon"]
)

mask = df.loc[:, ["work_add_lat", "work_add_lon"]].notnull().all(axis=1)
df["is_work"] = is_inside_area(
    df.loc[mask, "lat"], df.loc[mask, "lon"],
    df.loc[mask, "work_add_lat"], df.loc[mask, "work_add_lon"]
)

# %%
features = df.columns.tolist()
for f in ['home_add_lon', 'home_add_lat',
          'work_add_lon', 'work_add_lat',
          'is_work', 'is_home',
          'customer_id', 'terminal_id']:
    features.remove(f)
features
# Out:
# [u'amount',
#  u'city',
#  u'country',
#  u'currency',
#  u'mcc',
#  u'access24h',
#  u'is_office',
#  u'lat',
#  u'lon',
#  u'n_points',
#  u'is_atm',
#  u'is_raiff',
#  u'is_partner',
#  u'pct_same',
#  u'neg_home',
#  u'neg_work',
#  u'pos_home',
#  u'pos_work',
#  u'mcc_group',
#  u'has_car',
#  u'has_children',
#  u'has_pet',
#  u'amount_mean',
#  u'amount_sub',
#  u'amount_div',
#  u'day',
#  u'day_of_week',
#  u'days_after_holiday',
#  u'days_before_holiday',
#  u'is_dayoff',
#  u'is_holiday',
#  u'is_short',
#  u'is_weekend',
#  u'month',
#  u'timestamp',
#  u'week_of_year',
#  u'pct_term_counts',
#  u'pct_mcc_g_counts',
#  u'is_abroad',
#  u'amount_true',
#  u'is_native']

# %%
model_0 = {
    'is_home': xgb.XGBClassifier(n_estimators=200, n_jobs=3, max_depth=7),
    'is_work': xgb.XGBClassifier(n_estimators=200, n_jobs=3, max_depth=7)
}

# %%
def choose_best(group, pred):
    pred_i = group[pred].idxmax()
    return group.loc[pred_i, ['lat', 'lon']]


def modify_prediction(df, y_pred, col):
    cols = ['customer_id', 'lat', 'lon']
    pred = 'pred:{}'.format(col)
    
    df = df.loc[:, cols]
    df[pred] = y_pred
    
    return df.groupby('customer_id').apply(lambda x: choose_best(x, pred)).reset_index()


def score(df, y_pred, col):
    lon, lat = {
        'is_home': ('home_add_lon', 'home_add_lat'),
        'is_work': ('work_add_lon', 'work_add_lat')
    }[col]
    cols = ['customer_id', lat, lon]
    
    df_true = df.loc[:, cols].groupby('customer_id', as_index=False).median()
    df_pred = modify_prediction(df, y_pred, col)
    
    df_result = pd.merge(df_true, df_pred, how='left', on='customer_id')
    result = is_inside_area(df_result[lat], df_result[lon], df_result['lat'], df_result['lon'])
    return sum(result) / float(len(result))

# %%
model = dict()

np.random.seed(8888)

for col in ['is_home', 'is_work']:
    mask = df.loc[:, col].notnull()
    
    customers = df.loc[mask, 'customer_id'].unique()
    np.random.shuffle(customers)
    
    border = int(len(customers) * 0.9)
    cust_train, cust_valid = set(customers[:border]), set(customers[border:])
    
    mask_train = np.logical_and(mask, df["customer_id"].map(lambda x: x in cust_train))
    mask_valid = np.logical_and(mask, df["customer_id"].map(lambda x: x in cust_valid))
    
    print "Training:", col
    print "nb_train = {}; nb_valid = {}; nb_total = {}".format(
        sum(mask_train), sum(mask_valid), sum(mask_train) + sum(mask_valid))
    
    clf = sklearn.base.clone(model_0[col])
    clf.fit(
        df.loc[mask_train, features], df.loc[mask_train, col],
        eval_metric='logloss',
        eval_set=[
            (df.loc[mask_train, features], df.loc[mask_train, col]),
            (df.loc[mask_valid, features], df.loc[mask_valid, col])
        ],
        early_stopping_rounds=10,
        verbose=1
    )
    model[col] = clf

    print "Fitted..."

    y_pred = clf.predict_proba(df.loc[mask_train, features])
    print "Train score: {}".format(score(df.loc[mask_train], y_pred[:,1], col))

    y_pred = clf.predict_proba(df.loc[mask_valid, features])
    print "Valid score: {}".format(score(df.loc[mask_valid], y_pred[:,1], col))
    
    break
# Out:
# Training: is_home
# nb_train = 1943287; nb_valid = 209724; nb_total = 2153011
# [0]	validation_0-logloss:0.655647	validation_1-logloss:0.658514
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.624969	validation_1-logloss:0.630598
# [2]	validation_0-logloss:0.599442	validation_1-logloss:0.607496
# [3]	validation_0-logloss:0.578076	validation_1-logloss:0.588096
# [4]	validation_0-logloss:0.559989	validation_1-logloss:0.571949
# [5]	validation_0-logloss:0.544498	validation_1-logloss:0.558207
# [6]	validation_0-logloss:0.531377	validation_1-logloss:0.546768
# [7]	validation_0-logloss:0.520027	validation_1-logloss:0.536661
# [8]	validation_0-logloss:0.510374	validation_1-logloss:0.528331
# [9]	validation_0-logloss:0.502031	validation_1-logloss:0.521332
# [10]	validation_0-logloss:0.494543	validation_1-logloss:0.515341
# [11]	validation_0-logloss:0.488096	validation_1-logloss:0.510012
# [12]	validation_0-logloss:0.482404	validation_1-logloss:0.505514
# [13]	validation_0-logloss:0.477437	validation_1-logloss:0.501656
# [14]	validation_0-logloss:0.473072	validation_1-logloss:0.498322
# [15]	validation_0-logloss:0.468643	validation_1-logloss:0.495169
# [16]	validation_0-logloss:0.465155	validation_1-logloss:0.492566
# [17]	validation_0-logloss:0.461958	validation_1-logloss:0.490363
# [18]	validation_0-logloss:0.458742	validation_1-logloss:0.488296
# [19]	validation_0-logloss:0.456401	validation_1-logloss:0.486615
# [20]	validation_0-logloss:0.453586	validation_1-logloss:0.485278
# [21]	validation_0-logloss:0.451679	validation_1-logloss:0.483829
# [22]	validation_0-logloss:0.449662	validation_1-logloss:0.482461
# [23]	validation_0-logloss:0.447699	validation_1-logloss:0.481531
# [24]	validation_0-logloss:0.445462	validation_1-logloss:0.480213
# [25]	validation_0-logloss:0.443947	validation_1-logloss:0.479593
# [26]	validation_0-logloss:0.441985	validation_1-logloss:0.478385
# [27]	validation_0-logloss:0.44001	validation_1-logloss:0.477616
# [28]	validation_0-logloss:0.438524	validation_1-logloss:0.477141
# [29]	validation_0-logloss:0.435844	validation_1-logloss:0.476591
# [30]	validation_0-logloss:0.434294	validation_1-logloss:0.476008
# [31]	validation_0-logloss:0.432566	validation_1-logloss:0.474971
# [32]	validation_0-logloss:0.431244	validation_1-logloss:0.474615
# [33]	validation_0-logloss:0.429918	validation_1-logloss:0.474003
# [34]	validation_0-logloss:0.428342	validation_1-logloss:0.473565
# [35]	validation_0-logloss:0.427313	validation_1-logloss:0.473243
# [36]	validation_0-logloss:0.426406	validation_1-logloss:0.472669
# [37]	validation_0-logloss:0.425122	validation_1-logloss:0.472161
# [38]	validation_0-logloss:0.42429	validation_1-logloss:0.471981
# [39]	validation_0-logloss:0.421974	validation_1-logloss:0.47216
# [40]	validation_0-logloss:0.421014	validation_1-logloss:0.472035
# [41]	validation_0-logloss:0.420281	validation_1-logloss:0.471587
# [42]	validation_0-logloss:0.418901	validation_1-logloss:0.471468
# [43]	validation_0-logloss:0.417919	validation_1-logloss:0.471496
# [44]	validation_0-logloss:0.416606	validation_1-logloss:0.471464
# [45]	validation_0-logloss:0.415927	validation_1-logloss:0.471087
# [46]	validation_0-logloss:0.414503	validation_1-logloss:0.470971
# [47]	validation_0-logloss:0.413594	validation_1-logloss:0.471398
# [48]	validation_0-logloss:0.413087	validation_1-logloss:0.471116
# [49]	validation_0-logloss:0.411615	validation_1-logloss:0.471381
# [50]	validation_0-logloss:0.410656	validation_1-logloss:0.471449
# [51]	validation_0-logloss:0.409883	validation_1-logloss:0.471119
# [52]	validation_0-logloss:0.408687	validation_1-logloss:0.470378
# [53]	validation_0-logloss:0.407996	validation_1-logloss:0.470269
# [54]	validation_0-logloss:0.406639	validation_1-logloss:0.469998
# [55]	validation_0-logloss:0.405674	validation_1-logloss:0.469626
# [56]	validation_0-logloss:0.404242	validation_1-logloss:0.469979
# [57]	validation_0-logloss:0.403741	validation_1-logloss:0.469721
# [58]	validation_0-logloss:0.402882	validation_1-logloss:0.469411
# [59]	validation_0-logloss:0.402337	validation_1-logloss:0.469708
# [60]	validation_0-logloss:0.401432	validation_1-logloss:0.469605
# [61]	validation_0-logloss:0.399436	validation_1-logloss:0.468763
# [62]	validation_0-logloss:0.398234	validation_1-logloss:0.468776
# [63]	validation_0-logloss:0.397532	validation_1-logloss:0.46813
# [64]	validation_0-logloss:0.397252	validation_1-logloss:0.468248
# [65]	validation_0-logloss:0.396664	validation_1-logloss:0.468079
# [66]	validation_0-logloss:0.396129	validation_1-logloss:0.467959
# [67]	validation_0-logloss:0.395769	validation_1-logloss:0.46749
# [68]	validation_0-logloss:0.395105	validation_1-logloss:0.467335
# [69]	validation_0-logloss:0.394365	validation_1-logloss:0.467389
# [70]	validation_0-logloss:0.39388	validation_1-logloss:0.467169
# [71]	validation_0-logloss:0.392205	validation_1-logloss:0.467064
# [72]	validation_0-logloss:0.391974	validation_1-logloss:0.466968
# [73]	validation_0-logloss:0.390425	validation_1-logloss:0.467257
# [74]	validation_0-logloss:0.38937	validation_1-logloss:0.467321
# [75]	validation_0-logloss:0.388496	validation_1-logloss:0.467453
# [76]	validation_0-logloss:0.387636	validation_1-logloss:0.467338
# [77]	validation_0-logloss:0.387336	validation_1-logloss:0.467241
# [78]	validation_0-logloss:0.386932	validation_1-logloss:0.467284
# [79]	validation_0-logloss:0.38619	validation_1-logloss:0.467371
# [80]	validation_0-logloss:0.385073	validation_1-logloss:0.467289
# [81]	validation_0-logloss:0.384578	validation_1-logloss:0.467242
# [82]	validation_0-logloss:0.384176	validation_1-logloss:0.467118
# Stopping. Best iteration:
# [72]	validation_0-logloss:0.391974	validation_1-logloss:0.466968
#
# Fitted...
# Train score: 0.440555555556
# Valid score: 0.374
# Training: is_work
# nb_train = 1060045; nb_valid = 126157; nb_total = 1186202
# [0]	validation_0-logloss:0.641298	validation_1-logloss:0.64209
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.599228	validation_1-logloss:0.600963
# [2]	validation_0-logloss:0.564141	validation_1-logloss:0.566501
# [3]	validation_0-logloss:0.534597	validation_1-logloss:0.537809
# [4]	validation_0-logloss:0.509117	validation_1-logloss:0.513275
# [5]	validation_0-logloss:0.487269	validation_1-logloss:0.492403
# [6]	validation_0-logloss:0.468813	validation_1-logloss:0.474251
# [7]	validation_0-logloss:0.452258	validation_1-logloss:0.458798
# [8]	validation_0-logloss:0.438158	validation_1-logloss:0.446658
# [9]	validation_0-logloss:0.425469	validation_1-logloss:0.435245
# [10]	validation_0-logloss:0.414987	validation_1-logloss:0.425024
# [11]	validation_0-logloss:0.404951	validation_1-logloss:0.415957
# [12]	validation_0-logloss:0.396241	validation_1-logloss:0.407964
# [13]	validation_0-logloss:0.388917	validation_1-logloss:0.401094
# [14]	validation_0-logloss:0.382714	validation_1-logloss:0.395099
# [15]	validation_0-logloss:0.376249	validation_1-logloss:0.390074
# [16]	validation_0-logloss:0.370671	validation_1-logloss:0.385192
# [17]	validation_0-logloss:0.365647	validation_1-logloss:0.380542
# [18]	validation_0-logloss:0.361141	validation_1-logloss:0.377063
# [19]	validation_0-logloss:0.35747	validation_1-logloss:0.373859
# [20]	validation_0-logloss:0.35359	validation_1-logloss:0.370806
# [21]	validation_0-logloss:0.349315	validation_1-logloss:0.366707
# [22]	validation_0-logloss:0.346334	validation_1-logloss:0.364018
# [23]	validation_0-logloss:0.343215	validation_1-logloss:0.360723
# [24]	validation_0-logloss:0.340386	validation_1-logloss:0.359156
# [25]	validation_0-logloss:0.338071	validation_1-logloss:0.358281
# [26]	validation_0-logloss:0.336241	validation_1-logloss:0.356522
# [27]	validation_0-logloss:0.33367	validation_1-logloss:0.354369
# [28]	validation_0-logloss:0.331948	validation_1-logloss:0.353336
# [29]	validation_0-logloss:0.330143	validation_1-logloss:0.352413
# [30]	validation_0-logloss:0.327746	validation_1-logloss:0.350154
# [31]	validation_0-logloss:0.325789	validation_1-logloss:0.349164
# [32]	validation_0-logloss:0.323972	validation_1-logloss:0.347969
# [33]	validation_0-logloss:0.322113	validation_1-logloss:0.347099
# [34]	validation_0-logloss:0.320107	validation_1-logloss:0.346225
# [35]	validation_0-logloss:0.318634	validation_1-logloss:0.345701
# [36]	validation_0-logloss:0.317421	validation_1-logloss:0.344982
# [37]	validation_0-logloss:0.316375	validation_1-logloss:0.344367
# [38]	validation_0-logloss:0.315086	validation_1-logloss:0.344084
# [39]	validation_0-logloss:0.312425	validation_1-logloss:0.342788
# [40]	validation_0-logloss:0.310637	validation_1-logloss:0.342241
# [41]	validation_0-logloss:0.30979	validation_1-logloss:0.341231
# [42]	validation_0-logloss:0.308807	validation_1-logloss:0.341022
# [43]	validation_0-logloss:0.308089	validation_1-logloss:0.34088
# [44]	validation_0-logloss:0.30659	validation_1-logloss:0.339979
# [45]	validation_0-logloss:0.305696	validation_1-logloss:0.339812
# [46]	validation_0-logloss:0.304772	validation_1-logloss:0.33909
# [47]	validation_0-logloss:0.304395	validation_1-logloss:0.339198
# [48]	validation_0-logloss:0.300597	validation_1-logloss:0.336178
# [49]	validation_0-logloss:0.299009	validation_1-logloss:0.336439
# [50]	validation_0-logloss:0.298323	validation_1-logloss:0.336417
# [51]	validation_0-logloss:0.297952	validation_1-logloss:0.336529
# [52]	validation_0-logloss:0.296711	validation_1-logloss:0.335841
# [53]	validation_0-logloss:0.296023	validation_1-logloss:0.336316
# [54]	validation_0-logloss:0.294686	validation_1-logloss:0.336528
# [55]	validation_0-logloss:0.293878	validation_1-logloss:0.336165
# [56]	validation_0-logloss:0.29339	validation_1-logloss:0.335962
# [57]	validation_0-logloss:0.291264	validation_1-logloss:0.334531
# [58]	validation_0-logloss:0.290107	validation_1-logloss:0.334474
# [59]	validation_0-logloss:0.289581	validation_1-logloss:0.334668
# [60]	validation_0-logloss:0.288885	validation_1-logloss:0.334701
# [61]	validation_0-logloss:0.288065	validation_1-logloss:0.335056
# [62]	validation_0-logloss:0.287415	validation_1-logloss:0.334877
# [63]	validation_0-logloss:0.285274	validation_1-logloss:0.334633
# [64]	validation_0-logloss:0.284632	validation_1-logloss:0.333697
# [65]	validation_0-logloss:0.283385	validation_1-logloss:0.33364
# [66]	validation_0-logloss:0.282434	validation_1-logloss:0.333561
# [67]	validation_0-logloss:0.280038	validation_1-logloss:0.332434
# [68]	validation_0-logloss:0.279053	validation_1-logloss:0.332406
# [69]	validation_0-logloss:0.278714	validation_1-logloss:0.332306
# [70]	validation_0-logloss:0.278187	validation_1-logloss:0.332373
# [71]	validation_0-logloss:0.277083	validation_1-logloss:0.332711
# [72]	validation_0-logloss:0.275268	validation_1-logloss:0.33352
# [73]	validation_0-logloss:0.272895	validation_1-logloss:0.333537
# [74]	validation_0-logloss:0.271262	validation_1-logloss:0.332646
# [75]	validation_0-logloss:0.270916	validation_1-logloss:0.332761
# [76]	validation_0-logloss:0.269015	validation_1-logloss:0.332162
# [77]	validation_0-logloss:0.268486	validation_1-logloss:0.332118
# [78]	validation_0-logloss:0.26797	validation_1-logloss:0.332071
# [79]	validation_0-logloss:0.266903	validation_1-logloss:0.331514
# [80]	validation_0-logloss:0.265432	validation_1-logloss:0.331332
# [81]	validation_0-logloss:0.264746	validation_1-logloss:0.331676
# [82]	validation_0-logloss:0.264022	validation_1-logloss:0.331252
# [83]	validation_0-logloss:0.263561	validation_1-logloss:0.331204
# [84]	validation_0-logloss:0.262687	validation_1-logloss:0.33105
# [85]	validation_0-logloss:0.262368	validation_1-logloss:0.331039
# [86]	validation_0-logloss:0.261647	validation_1-logloss:0.330646
# [87]	validation_0-logloss:0.261032	validation_1-logloss:0.330459
# [88]	validation_0-logloss:0.260747	validation_1-logloss:0.330682
# [89]	validation_0-logloss:0.260003	validation_1-logloss:0.330463
# [90]	validation_0-logloss:0.258603	validation_1-logloss:0.33101
# [91]	validation_0-logloss:0.258221	validation_1-logloss:0.331167
# [92]	validation_0-logloss:0.257749	validation_1-logloss:0.331432
# [93]	validation_0-logloss:0.257509	validation_1-logloss:0.331648
# [94]	validation_0-logloss:0.257042	validation_1-logloss:0.331349
# [95]	validation_0-logloss:0.256776	validation_1-logloss:0.331596
# [96]	validation_0-logloss:0.2556	validation_1-logloss:0.331791
# [97]	validation_0-logloss:0.254817	validation_1-logloss:0.332358
# Stopping. Best iteration:
# [87]	validation_0-logloss:0.261032	validation_1-logloss:0.330459
#
# Fitted...
# Train score: 0.362990090478
# Valid score: 0.323643410853

# %%
for f, i in sorted(zip(features, model['is_home'].feature_importances_), key=itemgetter(1), reverse=True):
    print "{}\t{}".format(f, i)
# Out:
# lat	0.157819390297
# amount_mean	0.152092516422
# lon	0.150220260024
# n_points	0.0915198251605
# pct_mcc_g_counts	0.0812775343657
# city	0.0807268694043
# pct_term_counts	0.0796255543828
# pct_same	0.0470264330506
# amount	0.0183920711279
# mcc	0.0183920711279
# is_native	0.0174008812755
# has_car	0.0134361237288
# has_children	0.010462555103
# has_pet	0.010462555103
# timestamp	0.00914096925408
# day_of_week	0.00792951509356
# mcc_group	0.00704845832661
# pos_home	0.00671806186438
# amount_sub	0.00561673985794
# days_after_holiday	0.00528634339571
# day	0.00429515400901
# days_before_holiday	0.00396475754678
# amount_div	0.00319383270107
# is_office	0.0024229073897
# is_atm	0.0024229073897
# neg_home	0.00231277523562
# pos_work	0.00231277523562
# is_raiff	0.00220264308155
# access24h	0.00198237877339
# is_partner	0.00176211458165
# currency	0.000770925136749
# month	0.000770925136749
# is_dayoff	0.000660792924464
# neg_work	0.000330396462232
# country	0.0
# is_holiday	0.0
# is_short	0.0
# is_weekend	0.0
# week_of_year	0.0
# is_abroad	0.0
# amount_true	0.0

# %%
for f, i in sorted(zip(features, model['is_work'].feature_importances_), key=itemgetter(1), reverse=True):
    print "{}\t{}".format(f, i)
# Out:
# lon	0.156432896852
# lat	0.155687987804
# amount_mean	0.146642550826
# n_points	0.0968394204974
# pct_term_counts	0.0940725728869
# pct_mcc_g_counts	0.0933276563883
# city	0.0477812066674
# pct_same	0.0405448563397
# mcc	0.0203256364912
# amount	0.0190486330539
# has_car	0.0139406193048
# is_native	0.0123443650082
# day_of_week	0.0111737791449
# has_children	0.0108545282856
# has_pet	0.00936469063163
# amount_sub	0.00904543977231
# timestamp	0.00744918594137
# days_before_holiday	0.00638501672074
# access24h	0.00595934875309
# is_raiff	0.00585293164477
# mcc_group	0.00585293164477
# days_after_holiday	0.0057465150021
# day	0.00489517953247
# amount_div	0.00436309445649
# pos_work	0.00361817609519
# pos_home	0.00329892523587
# is_office	0.00212833890691
# is_atm	0.00202192179859
# neg_work	0.00148983718827
# month	0.00106416945346
# is_dayoff	0.000957752461545
# is_partner	0.000638501660433
# neg_home	0.000425667763921
# currency	0.000319250830216
# is_abroad	0.00010641694098
# country	0.0
# is_holiday	0.0
# is_short	0.0
# is_weekend	0.0
# week_of_year	0.0
# amount_true	0.0

# %%
joblib.dump(model['is_home'], 'data/models/clf_home_01.model')
# Out:
# ['data/models/clf_home_01.model']

# %%
joblib.dump(model['is_work'], 'data/models/clf_work_01.model')
# Out:
# ['data/models/clf_work_01.model']
